# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df= pd.read_csv('C://Users//User//Desktop//MSc Westminster//Dissertation//DataSets//Heart_Disease_Indicators.csv')

# %%
from sklearn.model_selection import train_test_split

target_size = 50000

num_class_0 = int(target_size * df['HeartDiseaseorAttack'].value_counts(normalize=True)[0])
num_class_1 = target_size - num_class_0

df_class_0 = df[df['HeartDiseaseorAttack'] == 0]
df_class_1 = df[df['HeartDiseaseorAttack'] == 1]

df_class_0_sampled = df_class_0.sample(n=num_class_0, random_state=15)
df_class_1_sampled = df_class_1.sample(n=num_class_1, random_state=15)

df_sampled = pd.concat([df_class_0_sampled, df_class_1_sampled])

df_sampled = df_sampled.sample(frac=1, random_state=15).reset_index(drop=True)
df= df_sampled
print(df['HeartDiseaseorAttack'].value_counts(normalize=True))
# Out:
# 0    0.90582
# 1    0.09418
# Name: HeartDiseaseorAttack, dtype: float64

# %%
df.drop_duplicates(inplace= True)
df.shape
# Out:
# (48050, 22)

# %%
df= df[df['Diabetes'] != 1].copy()
df.loc[df['Diabetes'] == 2, 'Diabetes'] = 1
print(df['Diabetes'].value_counts())
# Out:
# 0    40175
# 1     6968
# Name: Diabetes, dtype: int64

# %%
categorical_columns= ['HighBP', 'HighChol', 'CholCheck', 'Smoker', 'Stroke', 'Diabetes', 'PhysActivity',
                      'Fruits', 'Veggies', 'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost', 'DiffWalk',
                      'Sex', 'Age', 'Education', 'Income'
                     ]
df[categorical_columns]= df[categorical_columns].astype(str)
df= pd.get_dummies(df, columns= categorical_columns, drop_first= True)

# %%
X= df.drop(['HeartDiseaseorAttack'], axis= 1)
y= df['HeartDiseaseorAttack']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

continuous_columns = ['BMI', 'GenHlth', 'MentHlth', 'PhysHlth']

from sklearn.preprocessing import StandardScaler
ss= StandardScaler()
X_train= ss.fit_transform(X_train)
X_test= ss.transform(X_test)

# %% [markdown]
# --- Isolation Forest ---

# %%
from sklearn.ensemble import IsolationForest
from sklearn.metrics import confusion_matrix, classification_report, precision_score, accuracy_score, roc_auc_score

iso_forest= IsolationForest(contamination= 0.01, random_state= 15)
iso_forest.fit(X_train[y_train== 0])
y_pred_iso_forest= iso_forest.predict(X_test)
y_pred_iso_forest= [1 if x== -1 else 0 for x in y_pred_iso_forest]
y_pred_prob_iso_forest= iso_forest.decision_function(X_test)

cm= confusion_matrix(y_test, y_pred_iso_forest)
print(classification_report(y_test, y_pred_iso_forest, zero_division= 0))
print('Precision:', precision_score(y_test, y_pred_iso_forest, zero_division= 0))
print('Accuracy:', accuracy_score(y_test, y_pred_iso_forest))
print('AUC:', roc_auc_score(y_test, y_pred_prob_iso_forest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.39      0.06      0.10       912
#
#     accuracy                           0.90      9429
#    macro avg       0.65      0.53      0.53      9429
# weighted avg       0.86      0.90      0.87      9429
#
# Precision: 0.39285714285714285
# Accuracy: 0.9000954502068088
# AUC: 0.27241460062331474

# %% [markdown]
# --- Combining One-Class Isolation Forest with Traditional Classifiers ---

# %%
iso_forest= IsolationForest(contamination= 0.01, random_state= 15)
iso_forest.fit(X_train[y_train== 0])

X_train_iso_forest_scores= iso_forest.decision_function(X_train).reshape(-1, 1)
X_test_iso_forest_scores= iso_forest.decision_function(X_test).reshape(-1, 1)
X_train_combined= np.hstack((X_train, X_train_iso_forest_scores))
X_test_combined= np.hstack((X_test, X_test_iso_forest_scores))

# %% [markdown]
# --- LogisticRegression ---

# %%
from sklearn.linear_model import LogisticRegression
lr_combined= LogisticRegression(max_iter= 1000, random_state= 15)
lr_combined.fit(X_train_combined, y_train)
y_pred_lr_combined = lr_combined.predict(X_test_combined)
y_pred_prob_lr_combined= lr_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_lr_combined, labels= lr_combined.classes_)
print(classification_report(y_test, y_pred_lr_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_lr_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_lr_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_lr_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.57      0.14      0.22       912
#
#     accuracy                           0.91      9429
#    macro avg       0.74      0.56      0.58      9429
# weighted avg       0.88      0.91      0.88      9429
#
# Precision: 0.5688073394495413
# Accuracy: 0.9064587973273942
# AUC: 0.8545074453775627

# %% [markdown]
# --- DecisionTreeClassifier ---

# %%
from sklearn.tree import DecisionTreeClassifier
dt_combined = DecisionTreeClassifier(random_state=15)
dt_combined.fit(X_train_combined, y_train)
y_pred_dt_combined = dt_combined.predict(X_test_combined)
y_pred_prob_dt_combined= dt_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_dt_combined, labels= dt_combined.classes_)
print(classification_report(y_test, y_pred_dt_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_dt_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_dt_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_dt_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91      8517
#            1       0.22      0.24      0.23       912
#
#     accuracy                           0.85      9429
#    macro avg       0.57      0.57      0.57      9429
# weighted avg       0.85      0.85      0.85      9429
#
# Precision: 0.22142121524201855
# Accuracy: 0.8459009438964895
# AUC: 0.5730483692058608

# %% [markdown]
# --- Tuned - DecisionTreeClassifier ---

# %%
from sklearn.model_selection import GridSearchCV
param_grid= {
             'max_depth': [None, 10, 20, 30, 40, 50],
             'min_samples_split': [2, 10, 20],
             'min_samples_leaf': [1, 5, 10],
             'max_features': [None, 'sqrt', 'log2'],
             'criterion': ['gini', 'entropy']
            }

gs_dt_combined= GridSearchCV(estimator= dt_combined, param_grid= param_grid, cv= 5, scoring= 'precision')
gs_dt_combined.fit(X_train_combined, y_train)

print("Best Parameters:", gs_dt_combined.best_params_)
print("Best Precision Score:", gs_dt_combined.best_score_)
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# Best Precision Score: 0.4777994971861396

# %%
tuned_dt_combined= gs_dt_combined.best_estimator_
y_pred_tuned_dt_combined= tuned_dt_combined.predict(X_test_combined)
y_pred_prob_tuned_dt_combined= tuned_dt_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_dt_combined, labels= tuned_dt_combined.classes_)
print(classification_report(y_test, y_pred_tuned_dt_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_dt_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_dt_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_dt_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.40      0.08      0.13       912
#
#     accuracy                           0.90      9429
#    macro avg       0.66      0.53      0.54      9429
# weighted avg       0.86      0.90      0.87      9429
#
# Precision: 0.40331491712707185
# Accuracy: 0.8995651712800933
# AUC: 0.7818997582749876

# %% [markdown]
# --- KNeighborsClassifier ---

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_combined= KNeighborsClassifier()
knn_combined.fit(X_train_combined, y_train)
y_pred_knn_combined= knn_combined.predict(X_test_combined)
y_pred_prob_knn_combined= knn_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_knn_combined, labels= knn_combined.classes_)
print(classification_report(y_test, y_pred_knn_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_knn_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_knn_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_knn_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      8517
#            1       0.37      0.11      0.17       912
#
#     accuracy                           0.90      9429
#    macro avg       0.64      0.55      0.56      9429
# weighted avg       0.86      0.90      0.87      9429
#
# Precision: 0.36619718309859156
# Accuracy: 0.8952168840810266
# AUC: 0.7062157933874254

# %% [markdown]
# --- Tuned - KNeighborsClassifier ---

# %%
param_grid= {
             'n_neighbors': np.arange(1,40),
             'weights': ['uniform', 'distance'],
             'metric': ['euclidean', 'manhattan', 'minkowski']
            }

gs_knn_combined= GridSearchCV(estimator= knn_combined, param_grid= param_grid, cv=5, scoring= 'precision')
gs_knn_combined.fit(X_train_combined, y_train)
print("Best Parameters:", gs_knn_combined.best_params_)
print("Best Precision Score:", gs_knn_combined.best_score_)
# Out:
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 28, 'weights': 'uniform'}
# Best Precision Score: 0.6761708619374523

# %%
tuned_knn_combined= gs_knn_combined.best_estimator_
y_pred_tuned_knn_combined= tuned_knn_combined.predict(X_test_combined)
y_pred_prob_tuned_knn_combined= tuned_knn_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_knn_combined, labels= tuned_knn_combined.classes_)
print(classification_report(y_test, y_pred_tuned_knn_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_knn_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_knn_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_knn_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      8517
#            1       0.52      0.01      0.03       912
#
#     accuracy                           0.90      9429
#    macro avg       0.71      0.51      0.49      9429
# weighted avg       0.87      0.90      0.86      9429
#
# Precision: 0.52
# Accuracy: 0.9033831795524446
# AUC: 0.808556583942538

# %% [markdown]
# --- GaussianNB ---

# %%
from sklearn.naive_bayes import GaussianNB
nb_combined= GaussianNB()
nb_combined.fit(X_train_combined, y_train)
y_pred_nb_combined= nb_combined.predict(X_test_combined)
y_pred_prob_nb_combined= nb_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_nb_combined, labels= nb_combined.classes_)
print(classification_report(y_test, y_pred_nb_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_nb_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_nb_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_nb_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.70      0.81      8517
#            1       0.22      0.77      0.34       912
#
#     accuracy                           0.71      9429
#    macro avg       0.59      0.73      0.57      9429
# weighted avg       0.89      0.71      0.77      9429
#
# Precision: 0.21567417463745758
# Accuracy: 0.7078163113797857
# AUC: 0.8080232723407674

# %% [markdown]
# --- SVM ---

# %%
from sklearn.svm import SVC
svc_combined= SVC(kernel= 'rbf',probability= True, gamma= 1, random_state=15)
svc_combined.fit(X_train_combined, y_train)
y_pred_svc_combined= svc_combined.predict(X_test_combined)
y_pred_prob_svc_combined= svc_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_svc_combined, labels= svc_combined.classes_)
print(classification_report(y_test, y_pred_svc_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_svc_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_svc_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_svc_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      8517
#            1       0.20      0.00      0.01       912
#
#     accuracy                           0.90      9429
#    macro avg       0.55      0.50      0.48      9429
# weighted avg       0.84      0.90      0.86      9429
#
# Precision: 0.2
# Accuracy: 0.9020044543429844
# AUC: 0.6972400014213062

# %% [markdown]
# --- Random Forest ---

# %%
from sklearn.ensemble import RandomForestClassifier
rf_combined= RandomForestClassifier(random_state=15)
rf_combined.fit(X_train_combined, y_train)
y_pred_rf_combined= rf_combined.predict(X_test_combined)
y_pred_prob_rf_combined= rf_combined.predict_proba(X_test_combined)[:,1]

# %%
cm= confusion_matrix(y_test, y_pred_rf_combined, labels= rf_combined.classes_)
print(classification_report(y_test, y_pred_rf_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_rf_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_rf_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_rf_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.39      0.06      0.11       912
#
#     accuracy                           0.90      9429
#    macro avg       0.65      0.53      0.53      9429
# weighted avg       0.86      0.90      0.87      9429
#
# Precision: 0.38926174496644295
# Accuracy: 0.8997772828507795
# AUC: 0.8248994142777397

# %%
param_grid= {
             'n_estimators': [100, 200, 300],
             'max_depth': [None, 10, 20, 30],
             'min_samples_split': [2, 5, 10],
             'min_samples_leaf': [1, 2, 4],
            }

gs_tuned_rf_combined= GridSearchCV(estimator= rf_combined, param_grid= param_grid, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_tuned_rf_combined.fit(X_train_combined, y_train)
print("Best Parameters:", gs_tuned_rf_combined.best_params_)
print("Best Precision Score:", gs_tuned_rf_combined.best_score_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
# Best Precision Score: 0.6931029357116314

# %%
tuned_rf_combined= gs_tuned_rf_combined.best_estimator_
y_pred_tuned_rf_combined= tuned_rf_combined.predict(X_test_combined)
y_pred_prob_tuned_rf_combined= tuned_rf_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_rf_combined, labels= tuned_rf_combined.classes_)
print(classification_report(y_test, y_pred_tuned_rf_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_rf_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_rf_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_rf_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      8517
#            1       0.66      0.04      0.07       912
#
#     accuracy                           0.90      9429
#    macro avg       0.78      0.52      0.51      9429
# weighted avg       0.88      0.90      0.86      9429
#
# Precision: 0.66
# Accuracy: 0.9049740163325909
# AUC: 0.8479631938393595

# %% [markdown]
# --- AdaBoost ---

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_combined= AdaBoostClassifier(random_state=15)
ada_combined.fit(X_train_combined, y_train)
y_pred_ada_combined= ada_combined.predict(X_test_combined)
y_pred_prob_ada_combined= ada_combined.predict_proba(X_test_combined)[:,1]

# %%
cm= confusion_matrix(y_test, y_pred_ada_combined, labels= ada_combined.classes_)
print(classification_report(y_test, y_pred_ada_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_ada_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_ada_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_ada_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      8517
#            1       0.53      0.15      0.24       912
#
#     accuracy                           0.90      9429
#    macro avg       0.72      0.57      0.59      9429
# weighted avg       0.88      0.90      0.88      9429
#
# Precision: 0.5285171102661597
# Accuracy: 0.9048679605472478
# AUC: 0.8533943464979226

# %%
param_grid= {'n_estimators': [50, 100, 200]}

gs_ada_combined= GridSearchCV(estimator= ada_combined, param_grid= param_grid, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_ada_combined.fit(X_train_combined, y_train)
print("Best Parameters:", gs_ada_combined.best_params_)
print("Best Precision Score:", gs_ada_combined.best_score_)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best Parameters: {'n_estimators': 100}
# Best Precision Score: 0.5356166327094426

# %%
tuned_ada_combined= gs_ada_combined.best_estimator_
y_pred_tuned_ada_combined= tuned_ada_combined.predict(X_test_combined)
y_pred_prob_tuned_ada_combined= tuned_ada_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_ada_combined, labels= tuned_ada_combined.classes_)
print(classification_report(y_test, y_pred_tuned_ada_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_ada_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_ada_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_ada_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      8517
#            1       0.51      0.15      0.23       912
#
#     accuracy                           0.90      9429
#    macro avg       0.71      0.57      0.59      9429
# weighted avg       0.88      0.90      0.88      9429
#
# Precision: 0.5115384615384615
# Accuracy: 0.90391345847916
# AUC: 0.8529823737458003

# %% [markdown]
# --- GradientBoosting ---

# %%
from sklearn.ensemble import GradientBoostingClassifier
grb_combined= GradientBoostingClassifier(random_state=15)
grb_combined.fit(X_train_combined, y_train)
y_pred_grb_combined= grb_combined.predict(X_test_combined)
y_pred_prob_grb_combined= grb_combined.predict_proba(X_test_combined)[:,1]


cm= confusion_matrix(y_test, y_pred_grb_combined, labels= grb_combined.classes_)
print(classification_report(y_test, y_pred_grb_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_grb_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_grb_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_grb_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.55      0.12      0.19       912
#
#     accuracy                           0.91      9429
#    macro avg       0.73      0.55      0.57      9429
# weighted avg       0.88      0.91      0.88      9429
#
# Precision: 0.5520833333333334
# Accuracy: 0.9053982394739633
# AUC: 0.8530007837781609

# %%
param_grid= {'learning_rate': [0.01, 0.1, 0.2]}

gs_grb_combined= GridSearchCV(estimator= grb_combined, param_grid= param_grid, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_grb_combined.fit(X_train_combined, y_train)

print("Best Parameters:", gs_grb_combined.best_params_)
print("Best Precision Score:", gs_grb_combined.best_score_)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best Parameters: {'learning_rate': 0.1}
# Best Precision Score: 0.5655353296936242

# %%
tuned_grb_combined= gs_grb_combined.best_estimator_
y_pred_tuned_grb_combined= tuned_grb_combined.predict(X_test_combined)
y_pred_prob_tuned_grb_combined= tuned_grb_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_grb_combined, labels= tuned_grb_combined.classes_)
print(classification_report(y_test, y_pred_tuned_grb_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_grb_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_grb_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_grb_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.55      0.12      0.19       912
#
#     accuracy                           0.91      9429
#    macro avg       0.73      0.55      0.57      9429
# weighted avg       0.88      0.91      0.88      9429
#
# Precision: 0.5520833333333334
# Accuracy: 0.9053982394739633
# AUC: 0.8530007837781609

# %% [markdown]
# --- XGB ---

# %%
from xgboost import XGBClassifier
xgb_combined= XGBClassifier(random_state=15)
xgb_combined.fit(X_train_combined, y_train)
y_pred_xgb_combined= xgb_combined.predict(X_test_combined)
y_pred_prob_xgb_combined= xgb_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_xgb_combined, labels= xgb_combined.classes_)
print(classification_report(y_test, y_pred_xgb_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_xgb_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_xgb_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_xgb_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.95      8517
#            1       0.49      0.14      0.22       912
#
#     accuracy                           0.90      9429
#    macro avg       0.70      0.56      0.58      9429
# weighted avg       0.87      0.90      0.88      9429
#
# Precision: 0.4883720930232558
# Accuracy: 0.902640789055043
# AUC: 0.8366507439197972

# %%
params_XGBoost= {'learning_rate': [0.01, 0.1, 1.0]}

gs_xgb_combined= GridSearchCV(estimator= xgb_combined, param_grid= params_XGBoost, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_xgb_combined.fit(X_train_combined, y_train)

print("Best Parameters:", gs_xgb_combined.best_params_)
print("Best Precision Score:", gs_xgb_combined.best_score_)

tuned_xgb_combined= gs_xgb_combined.best_estimator_
y_pred_tuned_xgb_combined= tuned_xgb_combined.predict(X_test_combined)
y_pred_prob_tuned_xgb_combined= tuned_xgb_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_xgb_combined, labels= tuned_xgb_combined.classes_)
print(classification_report(y_test, y_pred_tuned_xgb_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_xgb_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_xgb_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_xgb_combined))
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best Parameters: {'learning_rate': 0.1}
# Best Precision Score: 0.5229290880590447
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.51      0.09      0.16       912
#
#     accuracy                           0.90      9429
#    macro avg       0.71      0.54      0.55      9429
# weighted avg       0.87      0.90      0.87      9429
#
# Precision: 0.5120481927710844
# Accuracy: 0.9037013469084738
# AUC: 0.8506267264233143

# %% [markdown]
# --- LGBM ---

# %%
from lightgbm import LGBMClassifier
lgm_combined= LGBMClassifier(random_state=15)
lgm_combined.fit(X_train_combined, y_train)
y_pred_lgm_combined= lgm_combined.predict(X_test_combined)
y_pred_prob_lgm_combined= lgm_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_lgm_combined, labels= lgm_combined.classes_)
print(classification_report(y_test, y_pred_lgm_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_lgm_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_lgm_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_lgm_combined))
# Out:
# [LightGBM] [Info] Number of positive: 3649, number of negative: 34065
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009898 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 506
# [LightGBM] [Info] Number of data points in the train set: 37714, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.096755 -> initscore=-2.233817
# [LightGBM] [Info] Start training from score -2.233817
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.54      0.09      0.16       912
#
#     accuracy                           0.90      9429
#    macro avg       0.72      0.54      0.55      9429
# weighted avg       0.87      0.90      0.87      9429
#
# Precision: 0.5384615384615384
# Accuracy: 0.9045497931912185
# AUC: 0.8505501896104591

# %%
params_LGB= {'learning_rate': [0.001, 0.01, 0.1, 1.0],
             'num_leaves': [31, 127],
             'reg_alpha': [0.1, 0.5],
             'min_data_in_leaf': [30, 50, 100, 300, 400]}

gs_lgm_combined= GridSearchCV(estimator= lgm_combined, param_grid= params_LGB, cv=5, scoring='precision', n_jobs=-1, verbose=2)
gs_lgm_combined.fit(X_train_combined, y_train)

print("Best Parameters:", gs_lgm_combined.best_params_)
print("Best Precision Score:", gs_lgm_combined.best_score_)

tuned_lgm_combined= gs_lgm_combined.best_estimator_
y_pred_tuned_lgm_combined= tuned_lgm_combined.predict(X_test_combined)
y_pred_prob_tuned_lgm_combined= tuned_lgm_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_lgm_combined, labels= tuned_lgm_combined.classes_)
print(classification_report(y_test, y_pred_tuned_lgm_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_lgm_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_lgm_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_lgm_combined))
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Info] Number of positive: 3649, number of negative: 34065
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008225 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 506
# [LightGBM] [Info] Number of data points in the train set: 37714, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.096755 -> initscore=-2.233817
# [LightGBM] [Info] Start training from score -2.233817
# Best Parameters: {'learning_rate': 0.1, 'min_data_in_leaf': 30, 'num_leaves': 31, 'reg_alpha': 0.1}
# Best Precision Score: 0.5572835412744545
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.55      0.10      0.16       912
#
#     accuracy                           0.91      9429
#    macro avg       0.73      0.54      0.56      9429
# weighted avg       0.88      0.91      0.87      9429
#
# Precision: 0.554140127388535
# Accuracy: 0.9050800721179341
# AUC: 0.8511624197425582

# %% [markdown]
# --- CatBoost ---

# %%
from catboost import CatBoostClassifier
cat_combined= CatBoostClassifier(random_state=15)
cat_combined.fit(X_train_combined, y_train)
y_pred_cat_combined= cat_combined.predict(X_test_combined)
y_pred_prob_cat_combined= cat_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_cat_combined, labels= cat_combined.classes_)
print(classification_report(y_test, y_pred_cat_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_cat_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_cat_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_cat_combined))
# Out:
# Learning rate set to 0.04854
# 0:	learn: 0.6401293	total: 167ms	remaining: 2m 47s
# 1:	learn: 0.5952381	total: 186ms	remaining: 1m 32s
# 2:	learn: 0.5564288	total: 204ms	remaining: 1m 7s
# 3:	learn: 0.5246917	total: 223ms	remaining: 55.4s
# 4:	learn: 0.4934666	total: 240ms	remaining: 47.8s
# 5:	learn: 0.4689867	total: 259ms	remaining: 42.9s
# 6:	learn: 0.4423395	total: 278ms	remaining: 39.5s
# 7:	learn: 0.4220842	total: 296ms	remaining: 36.8s
# 8:	learn: 0.4013030	total: 315ms	remaining: 34.7s
# 9:	learn: 0.3871715	total: 334ms	remaining: 33.1s
# 10:	learn: 0.3725733	total: 353ms	remaining: 31.8s
# 11:	learn: 0.3596578	total: 372ms	remaining: 30.6s
# 12:	learn: 0.3480112	total: 391ms	remaining: 29.7s
# 13:	learn: 0.3384408	total: 409ms	remaining: 28.8s
# 14:	learn: 0.3296327	total: 427ms	remaining: 28s
# 15:	learn: 0.3219040	total: 447ms	remaining: 27.5s
# 16:	learn: 0.3153698	total: 467ms	remaining: 27s
# 17:	learn: 0.3091380	total: 484ms	remaining: 26.4s
# 18:	learn: 0.3036219	total: 503ms	remaining: 26s
# 19:	learn: 0.2987161	total: 521ms	remaining: 25.5s
# 20:	learn: 0.2941167	total: 540ms	remaining: 25.2s
# 21:	learn: 0.2901637	total: 557ms	remaining: 24.8s
# 22:	learn: 0.2865977	total: 576ms	remaining: 24.5s
# 23:	learn: 0.2827930	total: 601ms	remaining: 24.4s
# 24:	learn: 0.2800771	total: 624ms	remaining: 24.4s
# 25:	learn: 0.2777347	total: 645ms	remaining: 24.1s
# 26:	learn: 0.2751405	total: 667ms	remaining: 24s
# 27:	learn: 0.2728890	total: 685ms	remaining: 23.8s
# 28:	learn: 0.2708738	total: 705ms	remaining: 23.6s
# 29:	learn: 0.2692510	total: 723ms	remaining: 23.4s
# 30:	learn: 0.2678575	total: 741ms	remaining: 23.2s
# 31:	learn: 0.2665931	total: 759ms	remaining: 23s
# 32:	learn: 0.2650037	total: 778ms	remaining: 22.8s
# 33:	learn: 0.2635021	total: 796ms	remaining: 22.6s
# 34:	learn: 0.2622035	total: 814ms	remaining: 22.4s
# 35:	learn: 0.2614508	total: 831ms	remaining: 22.3s
# 36:	learn: 0.2602009	total: 854ms	remaining: 22.2s
# 37:	learn: 0.2593163	total: 883ms	remaining: 22.4s
# 38:	learn: 0.2587515	total: 899ms	remaining: 22.1s
# 39:	learn: 0.2578458	total: 917ms	remaining: 22s
# 40:	learn: 0.2569643	total: 937ms	remaining: 21.9s
# 41:	learn: 0.2561089	total: 958ms	remaining: 21.9s
# 42:	learn: 0.2554442	total: 976ms	remaining: 21.7s
# 43:	learn: 0.2548557	total: 993ms	remaining: 21.6s
# 44:	learn: 0.2541476	total: 1.01s	remaining: 21.5s
# 45:	learn: 0.2536128	total: 1.03s	remaining: 21.4s
# 46:	learn: 0.2530243	total: 1.05s	remaining: 21.2s
# 47:	learn: 0.2525669	total: 1.06s	remaining: 21.1s
# 48:	learn: 0.2520590	total: 1.08s	remaining: 21s
# 49:	learn: 0.2516829	total: 1.1s	remaining: 21s
# 50:	learn: 0.2513477	total: 1.12s	remaining: 20.9s
# 51:	learn: 0.2510961	total: 1.14s	remaining: 20.8s
# 52:	learn: 0.2507027	total: 1.16s	remaining: 20.8s
# 53:	learn: 0.2504281	total: 1.18s	remaining: 20.7s
# 54:	learn: 0.2501356	total: 1.21s	remaining: 20.7s
# 55:	learn: 0.2497376	total: 1.23s	remaining: 20.7s
# 56:	learn: 0.2493629	total: 1.25s	remaining: 20.7s
# 57:	learn: 0.2491130	total: 1.27s	remaining: 20.7s
# 58:	learn: 0.2488745	total: 1.3s	remaining: 20.7s
# 59:	learn: 0.2486816	total: 1.32s	remaining: 20.7s
# 60:	learn: 0.2484384	total: 1.34s	remaining: 20.6s
# 61:	learn: 0.2481707	total: 1.36s	remaining: 20.7s
# 62:	learn: 0.2478883	total: 1.39s	remaining: 20.6s
# 63:	learn: 0.2477129	total: 1.41s	remaining: 20.6s
# 64:	learn: 0.2474281	total: 1.43s	remaining: 20.5s
# 65:	learn: 0.2471901	total: 1.45s	remaining: 20.5s
# 66:	learn: 0.2469244	total: 1.47s	remaining: 20.5s
# 67:	learn: 0.2467416	total: 1.49s	remaining: 20.4s
# 68:	learn: 0.2464944	total: 1.51s	remaining: 20.4s
# 69:	learn: 0.2462667	total: 1.53s	remaining: 20.3s
# 70:	learn: 0.2460842	total: 1.55s	remaining: 20.3s
# 71:	learn: 0.2459079	total: 1.57s	remaining: 20.3s
# 72:	learn: 0.2457215	total: 1.59s	remaining: 20.2s
# 73:	learn: 0.2455220	total: 1.61s	remaining: 20.2s
# 74:	learn: 0.2453389	total: 1.63s	remaining: 20.1s
# 75:	learn: 0.2451500	total: 1.65s	remaining: 20.1s
# 76:	learn: 0.2449503	total: 1.67s	remaining: 20.1s
# 77:	learn: 0.2448037	total: 1.69s	remaining: 20s
# 78:	learn: 0.2446844	total: 1.72s	remaining: 20s
# 79:	learn: 0.2445263	total: 1.74s	remaining: 20s
# 80:	learn: 0.2443526	total: 1.76s	remaining: 19.9s
# 81:	learn: 0.2442010	total: 1.78s	remaining: 19.9s
# 82:	learn: 0.2440321	total: 1.8s	remaining: 19.9s
# 83:	learn: 0.2439125	total: 1.82s	remaining: 19.8s
# 84:	learn: 0.2438084	total: 1.84s	remaining: 19.8s
# 85:	learn: 0.2437064	total: 1.86s	remaining: 19.7s
# 86:	learn: 0.2435903	total: 1.88s	remaining: 19.7s
# 87:	learn: 0.2434691	total: 1.9s	remaining: 19.7s
# 88:	learn: 0.2433390	total: 1.92s	remaining: 19.7s
# 89:	learn: 0.2432451	total: 1.95s	remaining: 19.7s
# 90:	learn: 0.2431220	total: 1.97s	remaining: 19.7s
# 91:	learn: 0.2429930	total: 1.99s	remaining: 19.7s
# 92:	learn: 0.2428747	total: 2.02s	remaining: 19.7s
# 93:	learn: 0.2427922	total: 2.04s	remaining: 19.7s
# 94:	learn: 0.2426957	total: 2.07s	remaining: 19.7s
# 95:	learn: 0.2425710	total: 2.09s	remaining: 19.7s
# 96:	learn: 0.2424190	total: 2.12s	remaining: 19.7s
# 97:	learn: 0.2423047	total: 2.14s	remaining: 19.7s
# 98:	learn: 0.2421900	total: 2.16s	remaining: 19.6s
# 99:	learn: 0.2420959	total: 2.18s	remaining: 19.6s
# 100:	learn: 0.2419782	total: 2.2s	remaining: 19.6s
# 101:	learn: 0.2418623	total: 2.22s	remaining: 19.6s
# 102:	learn: 0.2417606	total: 2.25s	remaining: 19.6s
# 103:	learn: 0.2416439	total: 2.27s	remaining: 19.6s
# 104:	learn: 0.2415499	total: 2.29s	remaining: 19.5s
# 105:	learn: 0.2414376	total: 2.31s	remaining: 19.5s
# 106:	learn: 0.2413400	total: 2.34s	remaining: 19.5s
# 107:	learn: 0.2412355	total: 2.36s	remaining: 19.5s
# 108:	learn: 0.2411469	total: 2.39s	remaining: 19.5s
# 109:	learn: 0.2410310	total: 2.41s	remaining: 19.5s
# 110:	learn: 0.2409373	total: 2.43s	remaining: 19.5s
# 111:	learn: 0.2408288	total: 2.46s	remaining: 19.5s
# 112:	learn: 0.2407661	total: 2.48s	remaining: 19.5s
# 113:	learn: 0.2406659	total: 2.5s	remaining: 19.4s
# 114:	learn: 0.2405809	total: 2.52s	remaining: 19.4s
# 115:	learn: 0.2405013	total: 2.54s	remaining: 19.4s
# 116:	learn: 0.2404294	total: 2.57s	remaining: 19.4s
# 117:	learn: 0.2403137	total: 2.59s	remaining: 19.4s
# 118:	learn: 0.2402031	total: 2.61s	remaining: 19.3s
# 119:	learn: 0.2401071	total: 2.63s	remaining: 19.3s
# 120:	learn: 0.2400292	total: 2.65s	remaining: 19.3s
# 121:	learn: 0.2399536	total: 2.67s	remaining: 19.2s
# 122:	learn: 0.2398739	total: 2.69s	remaining: 19.2s
# 123:	learn: 0.2397675	total: 2.71s	remaining: 19.2s
# 124:	learn: 0.2396882	total: 2.74s	remaining: 19.2s
# 125:	learn: 0.2395883	total: 2.76s	remaining: 19.1s
# 126:	learn: 0.2394840	total: 2.78s	remaining: 19.1s
# 127:	learn: 0.2393443	total: 2.8s	remaining: 19.1s
# 128:	learn: 0.2392793	total: 2.82s	remaining: 19s
# 129:	learn: 0.2392054	total: 2.84s	remaining: 19s
# 130:	learn: 0.2390984	total: 2.86s	remaining: 19s
# 131:	learn: 0.2390008	total: 2.88s	remaining: 19s
# 132:	learn: 0.2389109	total: 2.9s	remaining: 18.9s
# 133:	learn: 0.2388078	total: 2.92s	remaining: 18.9s
# 134:	learn: 0.2387120	total: 2.95s	remaining: 18.9s
# 135:	learn: 0.2386229	total: 2.97s	remaining: 18.8s
# 136:	learn: 0.2385072	total: 2.99s	remaining: 18.8s
# 137:	learn: 0.2384361	total: 3.01s	remaining: 18.8s
# 138:	learn: 0.2383686	total: 3.03s	remaining: 18.8s
# 139:	learn: 0.2382877	total: 3.05s	remaining: 18.7s
# 140:	learn: 0.2382239	total: 3.07s	remaining: 18.7s
# 141:	learn: 0.2381490	total: 3.09s	remaining: 18.7s
# 142:	learn: 0.2380399	total: 3.11s	remaining: 18.7s
# 143:	learn: 0.2379135	total: 3.13s	remaining: 18.6s
# 144:	learn: 0.2378537	total: 3.15s	remaining: 18.6s
# 145:	learn: 0.2377660	total: 3.18s	remaining: 18.6s
# 146:	learn: 0.2376537	total: 3.2s	remaining: 18.5s
# 147:	learn: 0.2375795	total: 3.22s	remaining: 18.5s
# 148:	learn: 0.2375186	total: 3.24s	remaining: 18.5s
# 149:	learn: 0.2374544	total: 3.26s	remaining: 18.5s
# 150:	learn: 0.2373715	total: 3.28s	remaining: 18.4s
# 151:	learn: 0.2373063	total: 3.3s	remaining: 18.4s
# 152:	learn: 0.2372389	total: 3.32s	remaining: 18.4s
# 153:	learn: 0.2371736	total: 3.34s	remaining: 18.3s
# 154:	learn: 0.2370940	total: 3.36s	remaining: 18.3s
# 155:	learn: 0.2370113	total: 3.38s	remaining: 18.3s
# 156:	learn: 0.2369194	total: 3.4s	remaining: 18.3s
# 157:	learn: 0.2368397	total: 3.42s	remaining: 18.2s
# 158:	learn: 0.2367383	total: 3.44s	remaining: 18.2s
# 159:	learn: 0.2366318	total: 3.47s	remaining: 18.2s
# 160:	learn: 0.2365798	total: 3.49s	remaining: 18.2s
# 161:	learn: 0.2364771	total: 3.51s	remaining: 18.1s
# 162:	learn: 0.2363685	total: 3.54s	remaining: 18.2s
# 163:	learn: 0.2362753	total: 3.56s	remaining: 18.1s
# 164:	learn: 0.2362237	total: 3.58s	remaining: 18.1s
# 165:	learn: 0.2361349	total: 3.6s	remaining: 18.1s
# 166:	learn: 0.2360856	total: 3.62s	remaining: 18s
# 167:	learn: 0.2359874	total: 3.64s	remaining: 18s
# 168:	learn: 0.2359114	total: 3.66s	remaining: 18s
# 169:	learn: 0.2357931	total: 3.68s	remaining: 18s
# 170:	learn: 0.2357153	total: 3.7s	remaining: 18s
# 171:	learn: 0.2356642	total: 3.73s	remaining: 17.9s
# 172:	learn: 0.2355748	total: 3.75s	remaining: 17.9s
# 173:	learn: 0.2354901	total: 3.77s	remaining: 17.9s
# 174:	learn: 0.2354345	total: 3.79s	remaining: 17.9s
# 175:	learn: 0.2353540	total: 3.82s	remaining: 17.9s
# 176:	learn: 0.2352829	total: 3.84s	remaining: 17.8s
# 177:	learn: 0.2352299	total: 3.86s	remaining: 17.8s
# 178:	learn: 0.2351632	total: 3.88s	remaining: 17.8s
# 179:	learn: 0.2350979	total: 3.9s	remaining: 17.8s
# 180:	learn: 0.2350195	total: 3.92s	remaining: 17.7s
# 181:	learn: 0.2349394	total: 3.94s	remaining: 17.7s
# 182:	learn: 0.2348461	total: 3.97s	remaining: 17.7s
# 183:	learn: 0.2347673	total: 4s	remaining: 17.7s
# 184:	learn: 0.2346797	total: 4.02s	remaining: 17.7s
# 185:	learn: 0.2345843	total: 4.04s	remaining: 17.7s
# 186:	learn: 0.2345143	total: 4.07s	remaining: 17.7s
# 187:	learn: 0.2344267	total: 4.08s	remaining: 17.6s
# 188:	learn: 0.2343364	total: 4.11s	remaining: 17.6s
# 189:	learn: 0.2342260	total: 4.13s	remaining: 17.6s
# 190:	learn: 0.2341739	total: 4.14s	remaining: 17.6s
# 191:	learn: 0.2341125	total: 4.17s	remaining: 17.5s
# 192:	learn: 0.2340344	total: 4.19s	remaining: 17.5s
# 193:	learn: 0.2339472	total: 4.21s	remaining: 17.5s
# 194:	learn: 0.2338726	total: 4.23s	remaining: 17.5s
# 195:	learn: 0.2337846	total: 4.25s	remaining: 17.4s
# 196:	learn: 0.2337272	total: 4.27s	remaining: 17.4s
# 197:	learn: 0.2336577	total: 4.29s	remaining: 17.4s
# 198:	learn: 0.2335735	total: 4.31s	remaining: 17.4s
# 199:	learn: 0.2334919	total: 4.33s	remaining: 17.3s
# 200:	learn: 0.2334161	total: 4.35s	remaining: 17.3s
# 201:	learn: 0.2333325	total: 4.38s	remaining: 17.3s
# 202:	learn: 0.2332383	total: 4.39s	remaining: 17.3s
# 203:	learn: 0.2331420	total: 4.41s	remaining: 17.2s
# 204:	learn: 0.2330843	total: 4.43s	remaining: 17.2s
# 205:	learn: 0.2330134	total: 4.46s	remaining: 17.2s
# 206:	learn: 0.2329272	total: 4.48s	remaining: 17.2s
# 207:	learn: 0.2328644	total: 4.5s	remaining: 17.1s
# 208:	learn: 0.2327866	total: 4.52s	remaining: 17.1s
# 209:	learn: 0.2327094	total: 4.54s	remaining: 17.1s
# 210:	learn: 0.2326571	total: 4.57s	remaining: 17.1s
# 211:	learn: 0.2325897	total: 4.59s	remaining: 17.1s
# 212:	learn: 0.2325265	total: 4.62s	remaining: 17.1s
# 213:	learn: 0.2324657	total: 4.64s	remaining: 17s
# 214:	learn: 0.2323798	total: 4.66s	remaining: 17s
# 215:	learn: 0.2322995	total: 4.68s	remaining: 17s
# 216:	learn: 0.2322415	total: 4.7s	remaining: 17s
# 217:	learn: 0.2321684	total: 4.72s	remaining: 16.9s
# 218:	learn: 0.2320903	total: 4.74s	remaining: 16.9s
# 219:	learn: 0.2320068	total: 4.76s	remaining: 16.9s
# 220:	learn: 0.2319269	total: 4.78s	remaining: 16.9s
# 221:	learn: 0.2318475	total: 4.8s	remaining: 16.8s
# 222:	learn: 0.2317511	total: 4.82s	remaining: 16.8s
# 223:	learn: 0.2316714	total: 4.84s	remaining: 16.8s
# 224:	learn: 0.2315898	total: 4.87s	remaining: 16.8s
# 225:	learn: 0.2315488	total: 4.88s	remaining: 16.7s
# 226:	learn: 0.2314621	total: 4.91s	remaining: 16.7s
# 227:	learn: 0.2313900	total: 4.92s	remaining: 16.7s
# 228:	learn: 0.2313134	total: 4.95s	remaining: 16.7s
# 229:	learn: 0.2312500	total: 4.96s	remaining: 16.6s
# 230:	learn: 0.2311578	total: 4.99s	remaining: 16.6s
# 231:	learn: 0.2310767	total: 5.01s	remaining: 16.6s
# 232:	learn: 0.2310327	total: 5.04s	remaining: 16.6s
# 233:	learn: 0.2309218	total: 5.07s	remaining: 16.6s
# 234:	learn: 0.2308368	total: 5.09s	remaining: 16.6s
# 235:	learn: 0.2307639	total: 5.11s	remaining: 16.6s
# 236:	learn: 0.2306859	total: 5.14s	remaining: 16.6s
# 237:	learn: 0.2306420	total: 5.16s	remaining: 16.5s
# 238:	learn: 0.2305439	total: 5.18s	remaining: 16.5s
# 239:	learn: 0.2304834	total: 5.21s	remaining: 16.5s
# 240:	learn: 0.2304206	total: 5.23s	remaining: 16.5s
# 241:	learn: 0.2303442	total: 5.25s	remaining: 16.4s
# 242:	learn: 0.2303097	total: 5.27s	remaining: 16.4s
# 243:	learn: 0.2302312	total: 5.29s	remaining: 16.4s
# 244:	learn: 0.2301487	total: 5.31s	remaining: 16.4s
# 245:	learn: 0.2300773	total: 5.33s	remaining: 16.3s
# 246:	learn: 0.2299982	total: 5.36s	remaining: 16.3s
# 247:	learn: 0.2299058	total: 5.38s	remaining: 16.3s
# 248:	learn: 0.2298550	total: 5.4s	remaining: 16.3s
# 249:	learn: 0.2297979	total: 5.42s	remaining: 16.3s
# 250:	learn: 0.2297385	total: 5.44s	remaining: 16.2s
# 251:	learn: 0.2296625	total: 5.47s	remaining: 16.2s
# 252:	learn: 0.2296014	total: 5.49s	remaining: 16.2s
# 253:	learn: 0.2295126	total: 5.51s	remaining: 16.2s
# 254:	learn: 0.2294336	total: 5.54s	remaining: 16.2s
# 255:	learn: 0.2293554	total: 5.56s	remaining: 16.2s
# 256:	learn: 0.2292739	total: 5.58s	remaining: 16.1s
# 257:	learn: 0.2291844	total: 5.6s	remaining: 16.1s
# 258:	learn: 0.2291193	total: 5.62s	remaining: 16.1s
# 259:	learn: 0.2290291	total: 5.65s	remaining: 16.1s
# 260:	learn: 0.2289810	total: 5.67s	remaining: 16s
# 261:	learn: 0.2289182	total: 5.69s	remaining: 16s
# 262:	learn: 0.2288268	total: 5.71s	remaining: 16s
# 263:	learn: 0.2287798	total: 5.73s	remaining: 16s
# 264:	learn: 0.2287206	total: 5.75s	remaining: 16s
# 265:	learn: 0.2286616	total: 5.78s	remaining: 15.9s
# 266:	learn: 0.2285849	total: 5.79s	remaining: 15.9s
# 267:	learn: 0.2285228	total: 5.82s	remaining: 15.9s
# 268:	learn: 0.2284754	total: 5.84s	remaining: 15.9s
# 269:	learn: 0.2284068	total: 5.86s	remaining: 15.8s
# 270:	learn: 0.2283485	total: 5.88s	remaining: 15.8s
# 271:	learn: 0.2282940	total: 5.9s	remaining: 15.8s
# 272:	learn: 0.2282146	total: 5.92s	remaining: 15.8s
# 273:	learn: 0.2281413	total: 5.94s	remaining: 15.7s
# 274:	learn: 0.2280328	total: 5.96s	remaining: 15.7s
# 275:	learn: 0.2279653	total: 5.98s	remaining: 15.7s
# 276:	learn: 0.2279043	total: 6s	remaining: 15.7s
# 277:	learn: 0.2278460	total: 6.03s	remaining: 15.6s
# 278:	learn: 0.2277903	total: 6.05s	remaining: 15.6s
# 279:	learn: 0.2277180	total: 6.07s	remaining: 15.6s
# 280:	learn: 0.2276564	total: 6.09s	remaining: 15.6s
# 281:	learn: 0.2276022	total: 6.11s	remaining: 15.6s
# 282:	learn: 0.2275054	total: 6.13s	remaining: 15.5s
# 283:	learn: 0.2274447	total: 6.15s	remaining: 15.5s
# 284:	learn: 0.2273669	total: 6.17s	remaining: 15.5s
# 285:	learn: 0.2273052	total: 6.19s	remaining: 15.5s
# 286:	learn: 0.2272153	total: 6.21s	remaining: 15.4s
# 287:	learn: 0.2271689	total: 6.24s	remaining: 15.4s
# 288:	learn: 0.2271057	total: 6.25s	remaining: 15.4s
# 289:	learn: 0.2270400	total: 6.27s	remaining: 15.4s
# 290:	learn: 0.2269846	total: 6.3s	remaining: 15.3s
# 291:	learn: 0.2269291	total: 6.32s	remaining: 15.3s
# 292:	learn: 0.2268515	total: 6.34s	remaining: 15.3s
# 293:	learn: 0.2267823	total: 6.36s	remaining: 15.3s
# 294:	learn: 0.2267190	total: 6.38s	remaining: 15.3s
# 295:	learn: 0.2266663	total: 6.4s	remaining: 15.2s
# 296:	learn: 0.2265828	total: 6.42s	remaining: 15.2s
# 297:	learn: 0.2264935	total: 6.45s	remaining: 15.2s
# 298:	learn: 0.2264380	total: 6.47s	remaining: 15.2s
# 299:	learn: 0.2263689	total: 6.49s	remaining: 15.1s
# 300:	learn: 0.2262931	total: 6.51s	remaining: 15.1s
# 301:	learn: 0.2262190	total: 6.54s	remaining: 15.1s
# 302:	learn: 0.2261487	total: 6.56s	remaining: 15.1s
# 303:	learn: 0.2260963	total: 6.58s	remaining: 15.1s
# 304:	learn: 0.2260563	total: 6.6s	remaining: 15s
# 305:	learn: 0.2259806	total: 6.62s	remaining: 15s
# 306:	learn: 0.2258862	total: 6.64s	remaining: 15s
# 307:	learn: 0.2258173	total: 6.66s	remaining: 15s
# 308:	learn: 0.2257362	total: 6.69s	remaining: 15s
# 309:	learn: 0.2256738	total: 6.71s	remaining: 14.9s
# 310:	learn: 0.2256301	total: 6.73s	remaining: 14.9s
# 311:	learn: 0.2255591	total: 6.75s	remaining: 14.9s
# 312:	learn: 0.2254717	total: 6.77s	remaining: 14.9s
# 313:	learn: 0.2254079	total: 6.79s	remaining: 14.8s
# 314:	learn: 0.2253608	total: 6.82s	remaining: 14.8s
# 315:	learn: 0.2253051	total: 6.84s	remaining: 14.8s
# 316:	learn: 0.2252516	total: 6.86s	remaining: 14.8s
# 317:	learn: 0.2251863	total: 6.88s	remaining: 14.8s
# 318:	learn: 0.2251495	total: 6.9s	remaining: 14.7s
# 319:	learn: 0.2250995	total: 6.92s	remaining: 14.7s
# 320:	learn: 0.2250321	total: 6.94s	remaining: 14.7s
# 321:	learn: 0.2249662	total: 6.96s	remaining: 14.7s
# 322:	learn: 0.2248910	total: 6.99s	remaining: 14.6s
# 323:	learn: 0.2248157	total: 7.01s	remaining: 14.6s
# 324:	learn: 0.2247799	total: 7.03s	remaining: 14.6s
# 325:	learn: 0.2247193	total: 7.05s	remaining: 14.6s
# 326:	learn: 0.2246512	total: 7.07s	remaining: 14.5s
# 327:	learn: 0.2246080	total: 7.09s	remaining: 14.5s
# 328:	learn: 0.2245684	total: 7.11s	remaining: 14.5s
# 329:	learn: 0.2245311	total: 7.13s	remaining: 14.5s
# 330:	learn: 0.2244753	total: 7.16s	remaining: 14.5s
# 331:	learn: 0.2244237	total: 7.18s	remaining: 14.4s
# 332:	learn: 0.2243577	total: 7.2s	remaining: 14.4s
# 333:	learn: 0.2243008	total: 7.22s	remaining: 14.4s
# 334:	learn: 0.2242364	total: 7.24s	remaining: 14.4s
# 335:	learn: 0.2241738	total: 7.26s	remaining: 14.3s
# 336:	learn: 0.2241138	total: 7.28s	remaining: 14.3s
# 337:	learn: 0.2240712	total: 7.3s	remaining: 14.3s
# 338:	learn: 0.2240299	total: 7.32s	remaining: 14.3s
# 339:	learn: 0.2239530	total: 7.34s	remaining: 14.3s
# 340:	learn: 0.2238640	total: 7.37s	remaining: 14.2s
# 341:	learn: 0.2237935	total: 7.39s	remaining: 14.2s
# 342:	learn: 0.2237364	total: 7.41s	remaining: 14.2s
# 343:	learn: 0.2236907	total: 7.43s	remaining: 14.2s
# 344:	learn: 0.2236197	total: 7.45s	remaining: 14.1s
# 345:	learn: 0.2235768	total: 7.47s	remaining: 14.1s
# 346:	learn: 0.2235191	total: 7.5s	remaining: 14.1s
# 347:	learn: 0.2235107	total: 7.52s	remaining: 14.1s
# 348:	learn: 0.2234497	total: 7.54s	remaining: 14.1s
# 349:	learn: 0.2233972	total: 7.57s	remaining: 14.1s
# 350:	learn: 0.2233315	total: 7.59s	remaining: 14s
# 351:	learn: 0.2232589	total: 7.61s	remaining: 14s
# 352:	learn: 0.2232059	total: 7.63s	remaining: 14s
# 353:	learn: 0.2231432	total: 7.65s	remaining: 14s
# 354:	learn: 0.2231395	total: 7.67s	remaining: 13.9s
# 355:	learn: 0.2231021	total: 7.69s	remaining: 13.9s
# 356:	learn: 0.2230730	total: 7.71s	remaining: 13.9s
# 357:	learn: 0.2229881	total: 7.74s	remaining: 13.9s
# 358:	learn: 0.2229434	total: 7.76s	remaining: 13.8s
# 359:	learn: 0.2228985	total: 7.78s	remaining: 13.8s
# 360:	learn: 0.2228510	total: 7.8s	remaining: 13.8s
# 361:	learn: 0.2227864	total: 7.82s	remaining: 13.8s
# 362:	learn: 0.2227502	total: 7.84s	remaining: 13.8s
# 363:	learn: 0.2226814	total: 7.86s	remaining: 13.7s
# 364:	learn: 0.2226188	total: 7.88s	remaining: 13.7s
# 365:	learn: 0.2225025	total: 7.91s	remaining: 13.7s
# 366:	learn: 0.2224364	total: 7.93s	remaining: 13.7s
# 367:	learn: 0.2224357	total: 7.95s	remaining: 13.7s
# 368:	learn: 0.2223854	total: 7.97s	remaining: 13.6s
# 369:	learn: 0.2223466	total: 7.99s	remaining: 13.6s
# 370:	learn: 0.2223024	total: 8.02s	remaining: 13.6s
# 371:	learn: 0.2222291	total: 8.04s	remaining: 13.6s
# 372:	learn: 0.2221429	total: 8.06s	remaining: 13.6s
# 373:	learn: 0.2220788	total: 8.09s	remaining: 13.5s
# 374:	learn: 0.2220382	total: 8.11s	remaining: 13.5s
# 375:	learn: 0.2219750	total: 8.13s	remaining: 13.5s
# 376:	learn: 0.2219282	total: 8.15s	remaining: 13.5s
# 377:	learn: 0.2218879	total: 8.18s	remaining: 13.5s
# 378:	learn: 0.2218052	total: 8.2s	remaining: 13.4s
# 379:	learn: 0.2217515	total: 8.22s	remaining: 13.4s
# 380:	learn: 0.2217174	total: 8.24s	remaining: 13.4s
# 381:	learn: 0.2216312	total: 8.27s	remaining: 13.4s
# 382:	learn: 0.2215979	total: 8.29s	remaining: 13.3s
# 383:	learn: 0.2215291	total: 8.31s	remaining: 13.3s
# 384:	learn: 0.2214651	total: 8.33s	remaining: 13.3s
# 385:	learn: 0.2214323	total: 8.35s	remaining: 13.3s
# 386:	learn: 0.2213684	total: 8.37s	remaining: 13.3s
# 387:	learn: 0.2213087	total: 8.39s	remaining: 13.2s
# 388:	learn: 0.2212595	total: 8.41s	remaining: 13.2s
# 389:	learn: 0.2212096	total: 8.43s	remaining: 13.2s
# 390:	learn: 0.2211543	total: 8.46s	remaining: 13.2s
# 391:	learn: 0.2211151	total: 8.48s	remaining: 13.1s
# 392:	learn: 0.2210573	total: 8.5s	remaining: 13.1s
# 393:	learn: 0.2210177	total: 8.52s	remaining: 13.1s
# 394:	learn: 0.2210171	total: 8.53s	remaining: 13.1s
# 395:	learn: 0.2209854	total: 8.55s	remaining: 13s
# 396:	learn: 0.2208941	total: 8.58s	remaining: 13s
# 397:	learn: 0.2208628	total: 8.6s	remaining: 13s
# 398:	learn: 0.2207880	total: 8.62s	remaining: 13s
# 399:	learn: 0.2207124	total: 8.64s	remaining: 13s
# 400:	learn: 0.2206687	total: 8.66s	remaining: 12.9s
# 401:	learn: 0.2206261	total: 8.68s	remaining: 12.9s
# 402:	learn: 0.2205729	total: 8.7s	remaining: 12.9s
# 403:	learn: 0.2205056	total: 8.72s	remaining: 12.9s
# 404:	learn: 0.2204696	total: 8.75s	remaining: 12.8s
# 405:	learn: 0.2203880	total: 8.77s	remaining: 12.8s
# 406:	learn: 0.2203733	total: 8.79s	remaining: 12.8s
# 407:	learn: 0.2203398	total: 8.81s	remaining: 12.8s
# 408:	learn: 0.2202767	total: 8.83s	remaining: 12.8s
# 409:	learn: 0.2202321	total: 8.85s	remaining: 12.7s
# 410:	learn: 0.2201668	total: 8.87s	remaining: 12.7s
# 411:	learn: 0.2200948	total: 8.89s	remaining: 12.7s
# 412:	learn: 0.2200136	total: 8.91s	remaining: 12.7s
# 413:	learn: 0.2199452	total: 8.93s	remaining: 12.6s
# 414:	learn: 0.2199039	total: 8.95s	remaining: 12.6s
# 415:	learn: 0.2198558	total: 8.97s	remaining: 12.6s
# 416:	learn: 0.2198031	total: 8.99s	remaining: 12.6s
# 417:	learn: 0.2197697	total: 9.02s	remaining: 12.6s
# 418:	learn: 0.2196890	total: 9.04s	remaining: 12.5s
# 419:	learn: 0.2196328	total: 9.06s	remaining: 12.5s
# 420:	learn: 0.2195955	total: 9.08s	remaining: 12.5s
# 421:	learn: 0.2195517	total: 9.1s	remaining: 12.5s
# 422:	learn: 0.2195192	total: 9.12s	remaining: 12.4s
# 423:	learn: 0.2194705	total: 9.14s	remaining: 12.4s
# 424:	learn: 0.2194295	total: 9.16s	remaining: 12.4s
# 425:	learn: 0.2193725	total: 9.19s	remaining: 12.4s
# 426:	learn: 0.2193010	total: 9.21s	remaining: 12.4s
# 427:	learn: 0.2192652	total: 9.23s	remaining: 12.3s
# 428:	learn: 0.2192038	total: 9.25s	remaining: 12.3s
# 429:	learn: 0.2191280	total: 9.27s	remaining: 12.3s
# 430:	learn: 0.2190669	total: 9.29s	remaining: 12.3s
# 431:	learn: 0.2190283	total: 9.31s	remaining: 12.2s
# 432:	learn: 0.2189618	total: 9.33s	remaining: 12.2s
# 433:	learn: 0.2188885	total: 9.35s	remaining: 12.2s
# 434:	learn: 0.2188199	total: 9.37s	remaining: 12.2s
# 435:	learn: 0.2187575	total: 9.39s	remaining: 12.2s
# 436:	learn: 0.2187079	total: 9.41s	remaining: 12.1s
# 437:	learn: 0.2186334	total: 9.43s	remaining: 12.1s
# 438:	learn: 0.2185720	total: 9.46s	remaining: 12.1s
# 439:	learn: 0.2184980	total: 9.48s	remaining: 12.1s
# 440:	learn: 0.2184312	total: 9.5s	remaining: 12s
# 441:	learn: 0.2183803	total: 9.53s	remaining: 12s
# 442:	learn: 0.2183338	total: 9.55s	remaining: 12s
# 443:	learn: 0.2182731	total: 9.57s	remaining: 12s
# 444:	learn: 0.2182541	total: 9.59s	remaining: 12s
# 445:	learn: 0.2181835	total: 9.61s	remaining: 11.9s
# 446:	learn: 0.2181385	total: 9.64s	remaining: 11.9s
# 447:	learn: 0.2180736	total: 9.66s	remaining: 11.9s
# 448:	learn: 0.2180295	total: 9.69s	remaining: 11.9s
# 449:	learn: 0.2179830	total: 9.71s	remaining: 11.9s
# 450:	learn: 0.2179390	total: 9.73s	remaining: 11.8s
# 451:	learn: 0.2178853	total: 9.76s	remaining: 11.8s
# 452:	learn: 0.2178321	total: 9.78s	remaining: 11.8s
# 453:	learn: 0.2177990	total: 9.8s	remaining: 11.8s
# 454:	learn: 0.2177401	total: 9.82s	remaining: 11.8s
# 455:	learn: 0.2176655	total: 9.85s	remaining: 11.7s
# 456:	learn: 0.2176286	total: 9.87s	remaining: 11.7s
# 457:	learn: 0.2175728	total: 9.89s	remaining: 11.7s
# 458:	learn: 0.2175187	total: 9.91s	remaining: 11.7s
# 459:	learn: 0.2174520	total: 9.94s	remaining: 11.7s
# 460:	learn: 0.2173850	total: 9.96s	remaining: 11.6s
# 461:	learn: 0.2173398	total: 9.98s	remaining: 11.6s
# 462:	learn: 0.2172755	total: 10s	remaining: 11.6s
# 463:	learn: 0.2172210	total: 10s	remaining: 11.6s
# 464:	learn: 0.2171879	total: 10.1s	remaining: 11.6s
# 465:	learn: 0.2171474	total: 10.1s	remaining: 11.5s
# 466:	learn: 0.2170817	total: 10.1s	remaining: 11.5s
# 467:	learn: 0.2170375	total: 10.1s	remaining: 11.5s
# 468:	learn: 0.2169808	total: 10.1s	remaining: 11.5s
# 469:	learn: 0.2169205	total: 10.2s	remaining: 11.5s
# 470:	learn: 0.2168524	total: 10.2s	remaining: 11.4s
# 471:	learn: 0.2168043	total: 10.2s	remaining: 11.4s
# 472:	learn: 0.2167551	total: 10.2s	remaining: 11.4s
# 473:	learn: 0.2167178	total: 10.3s	remaining: 11.4s
# 474:	learn: 0.2166475	total: 10.3s	remaining: 11.4s
# 475:	learn: 0.2166145	total: 10.3s	remaining: 11.3s
# 476:	learn: 0.2165438	total: 10.3s	remaining: 11.3s
# 477:	learn: 0.2164849	total: 10.3s	remaining: 11.3s
# 478:	learn: 0.2164361	total: 10.4s	remaining: 11.3s
# 479:	learn: 0.2164047	total: 10.4s	remaining: 11.2s
# 480:	learn: 0.2163662	total: 10.4s	remaining: 11.2s
# 481:	learn: 0.2163001	total: 10.4s	remaining: 11.2s
# 482:	learn: 0.2162569	total: 10.4s	remaining: 11.2s
# 483:	learn: 0.2162125	total: 10.5s	remaining: 11.2s
# 484:	learn: 0.2161586	total: 10.5s	remaining: 11.1s
# 485:	learn: 0.2160773	total: 10.5s	remaining: 11.1s
# 486:	learn: 0.2160033	total: 10.5s	remaining: 11.1s
# 487:	learn: 0.2159452	total: 10.6s	remaining: 11.1s
# 488:	learn: 0.2159015	total: 10.6s	remaining: 11.1s
# 489:	learn: 0.2158985	total: 10.6s	remaining: 11s
# 490:	learn: 0.2158575	total: 10.6s	remaining: 11s
# 491:	learn: 0.2157988	total: 10.7s	remaining: 11s
# 492:	learn: 0.2157731	total: 10.7s	remaining: 11s
# 493:	learn: 0.2157374	total: 10.7s	remaining: 11s
# 494:	learn: 0.2157369	total: 10.7s	remaining: 10.9s
# 495:	learn: 0.2156816	total: 10.8s	remaining: 10.9s
# 496:	learn: 0.2156720	total: 10.8s	remaining: 10.9s
# 497:	learn: 0.2156151	total: 10.8s	remaining: 10.9s
# 498:	learn: 0.2155808	total: 10.8s	remaining: 10.9s
# 499:	learn: 0.2155378	total: 10.8s	remaining: 10.8s
# 500:	learn: 0.2154957	total: 10.9s	remaining: 10.8s
# 501:	learn: 0.2154079	total: 10.9s	remaining: 10.8s
# 502:	learn: 0.2153615	total: 10.9s	remaining: 10.8s
# 503:	learn: 0.2153010	total: 10.9s	remaining: 10.8s
# 504:	learn: 0.2152082	total: 10.9s	remaining: 10.7s
# 505:	learn: 0.2151485	total: 11s	remaining: 10.7s
# 506:	learn: 0.2151116	total: 11s	remaining: 10.7s
# 507:	learn: 0.2150812	total: 11s	remaining: 10.7s
# 508:	learn: 0.2150144	total: 11.1s	remaining: 10.7s
# 509:	learn: 0.2149431	total: 11.1s	remaining: 10.7s
# 510:	learn: 0.2148728	total: 11.1s	remaining: 10.6s
# 511:	learn: 0.2148250	total: 11.1s	remaining: 10.6s
# 512:	learn: 0.2147642	total: 11.2s	remaining: 10.6s
# 513:	learn: 0.2146984	total: 11.2s	remaining: 10.6s
# 514:	learn: 0.2146909	total: 11.2s	remaining: 10.6s
# 515:	learn: 0.2146365	total: 11.2s	remaining: 10.5s
# 516:	learn: 0.2145752	total: 11.3s	remaining: 10.5s
# 517:	learn: 0.2145312	total: 11.3s	remaining: 10.5s
# 518:	learn: 0.2144928	total: 11.3s	remaining: 10.5s
# 519:	learn: 0.2144799	total: 11.3s	remaining: 10.5s
# 520:	learn: 0.2144795	total: 11.4s	remaining: 10.4s
# 521:	learn: 0.2144284	total: 11.4s	remaining: 10.4s
# 522:	learn: 0.2143733	total: 11.4s	remaining: 10.4s
# 523:	learn: 0.2143628	total: 11.4s	remaining: 10.4s
# 524:	learn: 0.2143102	total: 11.4s	remaining: 10.4s
# 525:	learn: 0.2142471	total: 11.5s	remaining: 10.3s
# 526:	learn: 0.2142074	total: 11.5s	remaining: 10.3s
# 527:	learn: 0.2141367	total: 11.5s	remaining: 10.3s
# 528:	learn: 0.2140808	total: 11.5s	remaining: 10.3s
# 529:	learn: 0.2140278	total: 11.6s	remaining: 10.2s
# 530:	learn: 0.2139584	total: 11.6s	remaining: 10.2s
# 531:	learn: 0.2138854	total: 11.6s	remaining: 10.2s
# 532:	learn: 0.2138294	total: 11.6s	remaining: 10.2s
# 533:	learn: 0.2138257	total: 11.6s	remaining: 10.2s
# 534:	learn: 0.2138205	total: 11.7s	remaining: 10.1s
# 535:	learn: 0.2137657	total: 11.7s	remaining: 10.1s
# 536:	learn: 0.2137295	total: 11.7s	remaining: 10.1s
# 537:	learn: 0.2136581	total: 11.7s	remaining: 10.1s
# 538:	learn: 0.2136105	total: 11.7s	remaining: 10s
# 539:	learn: 0.2135411	total: 11.8s	remaining: 10s
# 540:	learn: 0.2134993	total: 11.8s	remaining: 10s
# 541:	learn: 0.2134628	total: 11.8s	remaining: 9.98s
# 542:	learn: 0.2134231	total: 11.8s	remaining: 9.96s
# 543:	learn: 0.2133532	total: 11.9s	remaining: 9.94s
# 544:	learn: 0.2133036	total: 11.9s	remaining: 9.92s
# 545:	learn: 0.2132537	total: 11.9s	remaining: 9.9s
# 546:	learn: 0.2132170	total: 11.9s	remaining: 9.88s
# 547:	learn: 0.2131748	total: 11.9s	remaining: 9.85s
# 548:	learn: 0.2131247	total: 12s	remaining: 9.83s
# 549:	learn: 0.2130838	total: 12s	remaining: 9.81s
# 550:	learn: 0.2130375	total: 12s	remaining: 9.79s
# 551:	learn: 0.2129954	total: 12s	remaining: 9.77s
# 552:	learn: 0.2129571	total: 12.1s	remaining: 9.75s
# 553:	learn: 0.2128861	total: 12.1s	remaining: 9.72s
# 554:	learn: 0.2128152	total: 12.1s	remaining: 9.71s
# 555:	learn: 0.2127888	total: 12.1s	remaining: 9.68s
# 556:	learn: 0.2127334	total: 12.2s	remaining: 9.66s
# 557:	learn: 0.2126938	total: 12.2s	remaining: 9.64s
# 558:	learn: 0.2126575	total: 12.2s	remaining: 9.62s
# 559:	learn: 0.2126013	total: 12.2s	remaining: 9.6s
# 560:	learn: 0.2125346	total: 12.2s	remaining: 9.57s
# 561:	learn: 0.2125105	total: 12.3s	remaining: 9.55s
# 562:	learn: 0.2124462	total: 12.3s	remaining: 9.53s
# 563:	learn: 0.2123893	total: 12.3s	remaining: 9.51s
# 564:	learn: 0.2123354	total: 12.3s	remaining: 9.49s
# 565:	learn: 0.2122840	total: 12.3s	remaining: 9.47s
# 566:	learn: 0.2122461	total: 12.4s	remaining: 9.44s
# 567:	learn: 0.2122038	total: 12.4s	remaining: 9.42s
# 568:	learn: 0.2121563	total: 12.4s	remaining: 9.4s
# 569:	learn: 0.2121156	total: 12.4s	remaining: 9.38s
# 570:	learn: 0.2120606	total: 12.5s	remaining: 9.36s
# 571:	learn: 0.2120096	total: 12.5s	remaining: 9.34s
# 572:	learn: 0.2119584	total: 12.5s	remaining: 9.32s
# 573:	learn: 0.2119051	total: 12.5s	remaining: 9.3s
# 574:	learn: 0.2118426	total: 12.6s	remaining: 9.28s
# 575:	learn: 0.2118053	total: 12.6s	remaining: 9.26s
# 576:	learn: 0.2117196	total: 12.6s	remaining: 9.24s
# 577:	learn: 0.2116714	total: 12.6s	remaining: 9.21s
# 578:	learn: 0.2116621	total: 12.6s	remaining: 9.19s
# 579:	learn: 0.2115973	total: 12.7s	remaining: 9.17s
# 580:	learn: 0.2115370	total: 12.7s	remaining: 9.15s
# 581:	learn: 0.2114883	total: 12.7s	remaining: 9.13s
# 582:	learn: 0.2114540	total: 12.7s	remaining: 9.11s
# 583:	learn: 0.2114002	total: 12.8s	remaining: 9.08s
# 584:	learn: 0.2113422	total: 12.8s	remaining: 9.06s
# 585:	learn: 0.2112703	total: 12.8s	remaining: 9.04s
# 586:	learn: 0.2112150	total: 12.8s	remaining: 9.02s
# 587:	learn: 0.2111734	total: 12.8s	remaining: 9s
# 588:	learn: 0.2111155	total: 12.9s	remaining: 8.97s
# 589:	learn: 0.2110595	total: 12.9s	remaining: 8.95s
# 590:	learn: 0.2109949	total: 12.9s	remaining: 8.94s
# 591:	learn: 0.2109297	total: 12.9s	remaining: 8.91s
# 592:	learn: 0.2108853	total: 13s	remaining: 8.89s
# 593:	learn: 0.2108814	total: 13s	remaining: 8.88s
# 594:	learn: 0.2108778	total: 13s	remaining: 8.85s
# 595:	learn: 0.2108333	total: 13s	remaining: 8.83s
# 596:	learn: 0.2108194	total: 13.1s	remaining: 8.81s
# 597:	learn: 0.2107792	total: 13.1s	remaining: 8.79s
# 598:	learn: 0.2107371	total: 13.1s	remaining: 8.77s
# 599:	learn: 0.2106865	total: 13.1s	remaining: 8.74s
# 600:	learn: 0.2106511	total: 13.1s	remaining: 8.72s
# 601:	learn: 0.2106088	total: 13.2s	remaining: 8.7s
# 602:	learn: 0.2105246	total: 13.2s	remaining: 8.68s
# 603:	learn: 0.2104782	total: 13.2s	remaining: 8.66s
# 604:	learn: 0.2104181	total: 13.2s	remaining: 8.64s
# 605:	learn: 0.2103834	total: 13.3s	remaining: 8.62s
# 606:	learn: 0.2103157	total: 13.3s	remaining: 8.6s
# 607:	learn: 0.2102814	total: 13.3s	remaining: 8.57s
# 608:	learn: 0.2102409	total: 13.3s	remaining: 8.55s
# 609:	learn: 0.2102025	total: 13.3s	remaining: 8.53s
# 610:	learn: 0.2101438	total: 13.4s	remaining: 8.51s
# 611:	learn: 0.2100817	total: 13.4s	remaining: 8.49s
# 612:	learn: 0.2100426	total: 13.4s	remaining: 8.47s
# 613:	learn: 0.2100018	total: 13.4s	remaining: 8.45s
# 614:	learn: 0.2099500	total: 13.5s	remaining: 8.43s
# 615:	learn: 0.2098906	total: 13.5s	remaining: 8.4s
# 616:	learn: 0.2098415	total: 13.5s	remaining: 8.38s
# 617:	learn: 0.2097849	total: 13.5s	remaining: 8.36s
# 618:	learn: 0.2097255	total: 13.5s	remaining: 8.34s
# 619:	learn: 0.2096900	total: 13.6s	remaining: 8.32s
# 620:	learn: 0.2096386	total: 13.6s	remaining: 8.3s
# 621:	learn: 0.2096384	total: 13.6s	remaining: 8.27s
# 622:	learn: 0.2095606	total: 13.6s	remaining: 8.25s
# 623:	learn: 0.2095156	total: 13.7s	remaining: 8.23s
# 624:	learn: 0.2094572	total: 13.7s	remaining: 8.21s
# 625:	learn: 0.2094017	total: 13.7s	remaining: 8.19s
# 626:	learn: 0.2093605	total: 13.7s	remaining: 8.16s
# 627:	learn: 0.2093026	total: 13.7s	remaining: 8.14s
# 628:	learn: 0.2092440	total: 13.8s	remaining: 8.12s
# 629:	learn: 0.2091775	total: 13.8s	remaining: 8.1s
# 630:	learn: 0.2091239	total: 13.8s	remaining: 8.08s
# 631:	learn: 0.2090465	total: 13.8s	remaining: 8.06s
# 632:	learn: 0.2089956	total: 13.9s	remaining: 8.04s
# 633:	learn: 0.2089497	total: 13.9s	remaining: 8.02s
# 634:	learn: 0.2089032	total: 13.9s	remaining: 8s
# 635:	learn: 0.2088330	total: 13.9s	remaining: 7.97s
# 636:	learn: 0.2087815	total: 14s	remaining: 7.95s
# 637:	learn: 0.2087183	total: 14s	remaining: 7.93s
# 638:	learn: 0.2086587	total: 14s	remaining: 7.92s
# 639:	learn: 0.2086250	total: 14s	remaining: 7.89s
# 640:	learn: 0.2085605	total: 14.1s	remaining: 7.87s
# 641:	learn: 0.2085043	total: 14.1s	remaining: 7.85s
# 642:	learn: 0.2084532	total: 14.1s	remaining: 7.83s
# 643:	learn: 0.2084269	total: 14.1s	remaining: 7.82s
# 644:	learn: 0.2083734	total: 14.2s	remaining: 7.8s
# 645:	learn: 0.2083135	total: 14.2s	remaining: 7.78s
# 646:	learn: 0.2082501	total: 14.2s	remaining: 7.76s
# 647:	learn: 0.2082141	total: 14.2s	remaining: 7.74s
# 648:	learn: 0.2081508	total: 14.3s	remaining: 7.72s
# 649:	learn: 0.2081082	total: 14.3s	remaining: 7.7s
# 650:	learn: 0.2080555	total: 14.3s	remaining: 7.68s
# 651:	learn: 0.2080180	total: 14.3s	remaining: 7.66s
# 652:	learn: 0.2079860	total: 14.4s	remaining: 7.63s
# 653:	learn: 0.2079462	total: 14.4s	remaining: 7.61s
# 654:	learn: 0.2079063	total: 14.4s	remaining: 7.59s
# 655:	learn: 0.2078659	total: 14.4s	remaining: 7.57s
# 656:	learn: 0.2078309	total: 14.5s	remaining: 7.55s
# 657:	learn: 0.2077890	total: 14.5s	remaining: 7.53s
# 658:	learn: 0.2077275	total: 14.5s	remaining: 7.51s
# 659:	learn: 0.2076895	total: 14.5s	remaining: 7.48s
# 660:	learn: 0.2076554	total: 14.5s	remaining: 7.46s
# 661:	learn: 0.2076353	total: 14.6s	remaining: 7.44s
# 662:	learn: 0.2075939	total: 14.6s	remaining: 7.42s
# 663:	learn: 0.2075315	total: 14.6s	remaining: 7.39s
# 664:	learn: 0.2074803	total: 14.6s	remaining: 7.37s
# 665:	learn: 0.2074373	total: 14.7s	remaining: 7.35s
# 666:	learn: 0.2073855	total: 14.7s	remaining: 7.33s
# 667:	learn: 0.2073419	total: 14.7s	remaining: 7.31s
# 668:	learn: 0.2072940	total: 14.7s	remaining: 7.29s
# 669:	learn: 0.2072410	total: 14.8s	remaining: 7.27s
# 670:	learn: 0.2072143	total: 14.8s	remaining: 7.25s
# 671:	learn: 0.2071614	total: 14.8s	remaining: 7.22s
# 672:	learn: 0.2071136	total: 14.8s	remaining: 7.2s
# 673:	learn: 0.2070710	total: 14.8s	remaining: 7.18s
# 674:	learn: 0.2070378	total: 14.9s	remaining: 7.16s
# 675:	learn: 0.2069785	total: 14.9s	remaining: 7.14s
# 676:	learn: 0.2069369	total: 14.9s	remaining: 7.12s
# 677:	learn: 0.2069029	total: 14.9s	remaining: 7.09s
# 678:	learn: 0.2068406	total: 15s	remaining: 7.07s
# 679:	learn: 0.2068197	total: 15s	remaining: 7.05s
# 680:	learn: 0.2067751	total: 15s	remaining: 7.03s
# 681:	learn: 0.2067396	total: 15s	remaining: 7s
# 682:	learn: 0.2066730	total: 15s	remaining: 6.98s
# 683:	learn: 0.2066361	total: 15.1s	remaining: 6.96s
# 684:	learn: 0.2066254	total: 15.1s	remaining: 6.94s
# 685:	learn: 0.2065884	total: 15.1s	remaining: 6.92s
# 686:	learn: 0.2065745	total: 15.1s	remaining: 6.89s
# 687:	learn: 0.2065435	total: 15.2s	remaining: 6.87s
# 688:	learn: 0.2064829	total: 15.2s	remaining: 6.85s
# 689:	learn: 0.2064227	total: 15.2s	remaining: 6.83s
# 690:	learn: 0.2064097	total: 15.2s	remaining: 6.8s
# 691:	learn: 0.2063602	total: 15.2s	remaining: 6.78s
# 692:	learn: 0.2063015	total: 15.3s	remaining: 6.76s
# 693:	learn: 0.2062573	total: 15.3s	remaining: 6.74s
# 694:	learn: 0.2062004	total: 15.3s	remaining: 6.72s
# 695:	learn: 0.2061538	total: 15.3s	remaining: 6.7s
# 696:	learn: 0.2061310	total: 15.4s	remaining: 6.67s
# 697:	learn: 0.2060885	total: 15.4s	remaining: 6.65s
# 698:	learn: 0.2060180	total: 15.4s	remaining: 6.63s
# 699:	learn: 0.2059651	total: 15.4s	remaining: 6.61s
# 700:	learn: 0.2059169	total: 15.4s	remaining: 6.58s
# 701:	learn: 0.2058735	total: 15.5s	remaining: 6.56s
# 702:	learn: 0.2058315	total: 15.5s	remaining: 6.54s
# 703:	learn: 0.2057951	total: 15.5s	remaining: 6.52s
# 704:	learn: 0.2057578	total: 15.5s	remaining: 6.5s
# 705:	learn: 0.2057257	total: 15.6s	remaining: 6.48s
# 706:	learn: 0.2056624	total: 15.6s	remaining: 6.46s
# 707:	learn: 0.2056168	total: 15.6s	remaining: 6.43s
# 708:	learn: 0.2055724	total: 15.6s	remaining: 6.41s
# 709:	learn: 0.2055240	total: 15.6s	remaining: 6.39s
# 710:	learn: 0.2054594	total: 15.7s	remaining: 6.37s
# 711:	learn: 0.2054007	total: 15.7s	remaining: 6.35s
# 712:	learn: 0.2053306	total: 15.7s	remaining: 6.32s
# 713:	learn: 0.2052783	total: 15.7s	remaining: 6.3s
# 714:	learn: 0.2052412	total: 15.8s	remaining: 6.28s
# 715:	learn: 0.2052008	total: 15.8s	remaining: 6.26s
# 716:	learn: 0.2051200	total: 15.8s	remaining: 6.24s
# 717:	learn: 0.2050803	total: 15.8s	remaining: 6.21s
# 718:	learn: 0.2050136	total: 15.8s	remaining: 6.19s
# 719:	learn: 0.2049730	total: 15.9s	remaining: 6.17s
# 720:	learn: 0.2049304	total: 15.9s	remaining: 6.15s
# 721:	learn: 0.2048769	total: 15.9s	remaining: 6.13s
# 722:	learn: 0.2048328	total: 15.9s	remaining: 6.11s
# 723:	learn: 0.2047862	total: 16s	remaining: 6.08s
# 724:	learn: 0.2047484	total: 16s	remaining: 6.06s
# 725:	learn: 0.2046869	total: 16s	remaining: 6.04s
# 726:	learn: 0.2046480	total: 16s	remaining: 6.02s
# 727:	learn: 0.2045833	total: 16s	remaining: 5.99s
# 728:	learn: 0.2045359	total: 16.1s	remaining: 5.97s
# 729:	learn: 0.2044875	total: 16.1s	remaining: 5.95s
# 730:	learn: 0.2044303	total: 16.1s	remaining: 5.93s
# 731:	learn: 0.2043710	total: 16.1s	remaining: 5.91s
# 732:	learn: 0.2043269	total: 16.2s	remaining: 5.89s
# 733:	learn: 0.2042800	total: 16.2s	remaining: 5.86s
# 734:	learn: 0.2042302	total: 16.2s	remaining: 5.84s
# 735:	learn: 0.2041829	total: 16.2s	remaining: 5.82s
# 736:	learn: 0.2041370	total: 16.3s	remaining: 5.8s
# 737:	learn: 0.2040917	total: 16.3s	remaining: 5.78s
# 738:	learn: 0.2040331	total: 16.3s	remaining: 5.76s
# 739:	learn: 0.2039570	total: 16.3s	remaining: 5.74s
# 740:	learn: 0.2039151	total: 16.4s	remaining: 5.72s
# 741:	learn: 0.2038802	total: 16.4s	remaining: 5.7s
# 742:	learn: 0.2038186	total: 16.4s	remaining: 5.68s
# 743:	learn: 0.2037766	total: 16.4s	remaining: 5.65s
# 744:	learn: 0.2037246	total: 16.5s	remaining: 5.63s
# 745:	learn: 0.2036788	total: 16.5s	remaining: 5.61s
# 746:	learn: 0.2036450	total: 16.5s	remaining: 5.59s
# 747:	learn: 0.2035898	total: 16.5s	remaining: 5.57s
# 748:	learn: 0.2035510	total: 16.5s	remaining: 5.54s
# 749:	learn: 0.2034975	total: 16.6s	remaining: 5.52s
# 750:	learn: 0.2034579	total: 16.6s	remaining: 5.5s
# 751:	learn: 0.2034106	total: 16.6s	remaining: 5.48s
# 752:	learn: 0.2033778	total: 16.6s	remaining: 5.46s
# 753:	learn: 0.2033428	total: 16.7s	remaining: 5.43s
# 754:	learn: 0.2033239	total: 16.7s	remaining: 5.41s
# 755:	learn: 0.2032397	total: 16.7s	remaining: 5.39s
# 756:	learn: 0.2031885	total: 16.7s	remaining: 5.37s
# 757:	learn: 0.2031509	total: 16.7s	remaining: 5.34s
# 758:	learn: 0.2031204	total: 16.8s	remaining: 5.32s
# 759:	learn: 0.2030974	total: 16.8s	remaining: 5.3s
# 760:	learn: 0.2030431	total: 16.8s	remaining: 5.28s
# 761:	learn: 0.2030121	total: 16.8s	remaining: 5.26s
# 762:	learn: 0.2029412	total: 16.9s	remaining: 5.24s
# 763:	learn: 0.2029058	total: 16.9s	remaining: 5.21s
# 764:	learn: 0.2028488	total: 16.9s	remaining: 5.19s
# 765:	learn: 0.2028246	total: 16.9s	remaining: 5.17s
# 766:	learn: 0.2027838	total: 16.9s	remaining: 5.15s
# 767:	learn: 0.2027412	total: 17s	remaining: 5.13s
# 768:	learn: 0.2027268	total: 17s	remaining: 5.11s
# 769:	learn: 0.2026921	total: 17s	remaining: 5.08s
# 770:	learn: 0.2026798	total: 17s	remaining: 5.06s
# 771:	learn: 0.2026057	total: 17.1s	remaining: 5.04s
# 772:	learn: 0.2025483	total: 17.1s	remaining: 5.02s
# 773:	learn: 0.2024936	total: 17.1s	remaining: 5s
# 774:	learn: 0.2024293	total: 17.1s	remaining: 4.97s
# 775:	learn: 0.2023750	total: 17.2s	remaining: 4.95s
# 776:	learn: 0.2023363	total: 17.2s	remaining: 4.93s
# 777:	learn: 0.2022752	total: 17.2s	remaining: 4.91s
# 778:	learn: 0.2022319	total: 17.2s	remaining: 4.89s
# 779:	learn: 0.2021951	total: 17.2s	remaining: 4.86s
# 780:	learn: 0.2021515	total: 17.3s	remaining: 4.84s
# 781:	learn: 0.2020928	total: 17.3s	remaining: 4.82s
# 782:	learn: 0.2020623	total: 17.3s	remaining: 4.8s
# 783:	learn: 0.2019926	total: 17.3s	remaining: 4.78s
# 784:	learn: 0.2019547	total: 17.4s	remaining: 4.75s
# 785:	learn: 0.2019024	total: 17.4s	remaining: 4.73s
# 786:	learn: 0.2018591	total: 17.4s	remaining: 4.71s
# 787:	learn: 0.2018559	total: 17.4s	remaining: 4.69s
# 788:	learn: 0.2018256	total: 17.4s	remaining: 4.66s
# 789:	learn: 0.2017894	total: 17.5s	remaining: 4.64s
# 790:	learn: 0.2017541	total: 17.5s	remaining: 4.62s
# 791:	learn: 0.2017126	total: 17.5s	remaining: 4.6s
# 792:	learn: 0.2016744	total: 17.5s	remaining: 4.58s
# 793:	learn: 0.2015967	total: 17.6s	remaining: 4.55s
# 794:	learn: 0.2015525	total: 17.6s	remaining: 4.53s
# 795:	learn: 0.2015130	total: 17.6s	remaining: 4.51s
# 796:	learn: 0.2014774	total: 17.6s	remaining: 4.49s
# 797:	learn: 0.2014514	total: 17.6s	remaining: 4.46s
# 798:	learn: 0.2013971	total: 17.7s	remaining: 4.44s
# 799:	learn: 0.2013443	total: 17.7s	remaining: 4.42s
# 800:	learn: 0.2013099	total: 17.7s	remaining: 4.4s
# 801:	learn: 0.2012609	total: 17.7s	remaining: 4.38s
# 802:	learn: 0.2012277	total: 17.7s	remaining: 4.35s
# 803:	learn: 0.2011824	total: 17.8s	remaining: 4.33s
# 804:	learn: 0.2011446	total: 17.8s	remaining: 4.31s
# 805:	learn: 0.2010867	total: 17.8s	remaining: 4.29s
# 806:	learn: 0.2010334	total: 17.8s	remaining: 4.26s
# 807:	learn: 0.2009845	total: 17.9s	remaining: 4.24s
# 808:	learn: 0.2009353	total: 17.9s	remaining: 4.22s
# 809:	learn: 0.2008781	total: 17.9s	remaining: 4.2s
# 810:	learn: 0.2008364	total: 17.9s	remaining: 4.18s
# 811:	learn: 0.2008032	total: 17.9s	remaining: 4.15s
# 812:	learn: 0.2007609	total: 18s	remaining: 4.13s
# 813:	learn: 0.2007217	total: 18s	remaining: 4.11s
# 814:	learn: 0.2006869	total: 18s	remaining: 4.09s
# 815:	learn: 0.2006449	total: 18s	remaining: 4.06s
# 816:	learn: 0.2005817	total: 18s	remaining: 4.04s
# 817:	learn: 0.2005432	total: 18.1s	remaining: 4.02s
# 818:	learn: 0.2005071	total: 18.1s	remaining: 4s
# 819:	learn: 0.2004739	total: 18.1s	remaining: 3.98s
# 820:	learn: 0.2004306	total: 18.1s	remaining: 3.95s
# 821:	learn: 0.2003737	total: 18.2s	remaining: 3.93s
# 822:	learn: 0.2003508	total: 18.2s	remaining: 3.91s
# 823:	learn: 0.2003121	total: 18.2s	remaining: 3.89s
# 824:	learn: 0.2002796	total: 18.2s	remaining: 3.86s
# 825:	learn: 0.2002308	total: 18.2s	remaining: 3.84s
# 826:	learn: 0.2001793	total: 18.3s	remaining: 3.82s
# 827:	learn: 0.2001440	total: 18.3s	remaining: 3.8s
# 828:	learn: 0.2001018	total: 18.3s	remaining: 3.77s
# 829:	learn: 0.2000687	total: 18.3s	remaining: 3.75s
# 830:	learn: 0.2000555	total: 18.3s	remaining: 3.73s
# 831:	learn: 0.2000288	total: 18.4s	remaining: 3.71s
# 832:	learn: 0.1999887	total: 18.4s	remaining: 3.69s
# 833:	learn: 0.1999285	total: 18.4s	remaining: 3.67s
# 834:	learn: 0.1998830	total: 18.4s	remaining: 3.64s
# 835:	learn: 0.1998288	total: 18.5s	remaining: 3.62s
# 836:	learn: 0.1997833	total: 18.5s	remaining: 3.6s
# 837:	learn: 0.1997401	total: 18.5s	remaining: 3.58s
# 838:	learn: 0.1996868	total: 18.5s	remaining: 3.56s
# 839:	learn: 0.1996141	total: 18.6s	remaining: 3.54s
# 840:	learn: 0.1995751	total: 18.6s	remaining: 3.52s
# 841:	learn: 0.1995478	total: 18.6s	remaining: 3.49s
# 842:	learn: 0.1995010	total: 18.6s	remaining: 3.47s
# 843:	learn: 0.1994454	total: 18.7s	remaining: 3.45s
# 844:	learn: 0.1993937	total: 18.7s	remaining: 3.43s
# 845:	learn: 0.1993266	total: 18.7s	remaining: 3.41s
# 846:	learn: 0.1992644	total: 18.7s	remaining: 3.38s
# 847:	learn: 0.1992271	total: 18.8s	remaining: 3.36s
# 848:	learn: 0.1991784	total: 18.8s	remaining: 3.34s
# 849:	learn: 0.1991182	total: 18.8s	remaining: 3.32s
# 850:	learn: 0.1990821	total: 18.8s	remaining: 3.3s
# 851:	learn: 0.1990273	total: 18.9s	remaining: 3.27s
# 852:	learn: 0.1989666	total: 18.9s	remaining: 3.25s
# 853:	learn: 0.1988969	total: 18.9s	remaining: 3.23s
# 854:	learn: 0.1988482	total: 18.9s	remaining: 3.21s
# 855:	learn: 0.1987953	total: 18.9s	remaining: 3.19s
# 856:	learn: 0.1987501	total: 19s	remaining: 3.16s
# 857:	learn: 0.1986845	total: 19s	remaining: 3.14s
# 858:	learn: 0.1986492	total: 19s	remaining: 3.12s
# 859:	learn: 0.1986117	total: 19s	remaining: 3.1s
# 860:	learn: 0.1985738	total: 19.1s	remaining: 3.08s
# 861:	learn: 0.1985441	total: 19.1s	remaining: 3.05s
# 862:	learn: 0.1985369	total: 19.1s	remaining: 3.03s
# 863:	learn: 0.1985265	total: 19.1s	remaining: 3.01s
# 864:	learn: 0.1984890	total: 19.2s	remaining: 2.99s
# 865:	learn: 0.1984508	total: 19.2s	remaining: 2.97s
# 866:	learn: 0.1984015	total: 19.2s	remaining: 2.94s
# 867:	learn: 0.1983436	total: 19.2s	remaining: 2.92s
# 868:	learn: 0.1983120	total: 19.2s	remaining: 2.9s
# 869:	learn: 0.1982466	total: 19.3s	remaining: 2.88s
# 870:	learn: 0.1981975	total: 19.3s	remaining: 2.86s
# 871:	learn: 0.1981371	total: 19.3s	remaining: 2.83s
# 872:	learn: 0.1980818	total: 19.3s	remaining: 2.81s
# 873:	learn: 0.1980380	total: 19.3s	remaining: 2.79s
# 874:	learn: 0.1979997	total: 19.4s	remaining: 2.77s
# 875:	learn: 0.1979350	total: 19.4s	remaining: 2.75s
# 876:	learn: 0.1978988	total: 19.4s	remaining: 2.72s
# 877:	learn: 0.1978518	total: 19.4s	remaining: 2.7s
# 878:	learn: 0.1978091	total: 19.5s	remaining: 2.68s
# 879:	learn: 0.1977465	total: 19.5s	remaining: 2.66s
# 880:	learn: 0.1977280	total: 19.5s	remaining: 2.63s
# 881:	learn: 0.1976829	total: 19.5s	remaining: 2.61s
# 882:	learn: 0.1976220	total: 19.6s	remaining: 2.59s
# 883:	learn: 0.1976155	total: 19.6s	remaining: 2.57s
# 884:	learn: 0.1975343	total: 19.6s	remaining: 2.55s
# 885:	learn: 0.1974715	total: 19.7s	remaining: 2.53s
# 886:	learn: 0.1974326	total: 19.7s	remaining: 2.51s
# 887:	learn: 0.1973994	total: 19.7s	remaining: 2.49s
# 888:	learn: 0.1973666	total: 19.7s	remaining: 2.46s
# 889:	learn: 0.1972719	total: 19.8s	remaining: 2.44s
# 890:	learn: 0.1972275	total: 19.8s	remaining: 2.42s
# 891:	learn: 0.1971818	total: 19.8s	remaining: 2.4s
# 892:	learn: 0.1971363	total: 19.8s	remaining: 2.38s
# 893:	learn: 0.1970952	total: 19.8s	remaining: 2.35s
# 894:	learn: 0.1970557	total: 19.9s	remaining: 2.33s
# 895:	learn: 0.1970160	total: 19.9s	remaining: 2.31s
# 896:	learn: 0.1969908	total: 19.9s	remaining: 2.29s
# 897:	learn: 0.1969322	total: 19.9s	remaining: 2.26s
# 898:	learn: 0.1968968	total: 20s	remaining: 2.24s
# 899:	learn: 0.1968643	total: 20s	remaining: 2.22s
# 900:	learn: 0.1967964	total: 20s	remaining: 2.2s
# 901:	learn: 0.1967404	total: 20s	remaining: 2.18s
# 902:	learn: 0.1966987	total: 20.1s	remaining: 2.15s
# 903:	learn: 0.1966717	total: 20.1s	remaining: 2.13s
# 904:	learn: 0.1966313	total: 20.1s	remaining: 2.11s
# 905:	learn: 0.1966156	total: 20.1s	remaining: 2.09s
# 906:	learn: 0.1966115	total: 20.1s	remaining: 2.06s
# 907:	learn: 0.1965761	total: 20.2s	remaining: 2.04s
# 908:	learn: 0.1965353	total: 20.2s	remaining: 2.02s
# 909:	learn: 0.1964821	total: 20.2s	remaining: 2s
# 910:	learn: 0.1964629	total: 20.2s	remaining: 1.98s
# 911:	learn: 0.1964431	total: 20.2s	remaining: 1.95s
# 912:	learn: 0.1964048	total: 20.3s	remaining: 1.93s
# 913:	learn: 0.1963453	total: 20.3s	remaining: 1.91s
# 914:	learn: 0.1963094	total: 20.3s	remaining: 1.89s
# 915:	learn: 0.1962698	total: 20.3s	remaining: 1.86s
# 916:	learn: 0.1962502	total: 20.3s	remaining: 1.84s
# 917:	learn: 0.1962006	total: 20.4s	remaining: 1.82s
# 918:	learn: 0.1961748	total: 20.4s	remaining: 1.8s
# 919:	learn: 0.1961263	total: 20.4s	remaining: 1.78s
# 920:	learn: 0.1960704	total: 20.5s	remaining: 1.75s
# 921:	learn: 0.1960323	total: 20.5s	remaining: 1.73s
# 922:	learn: 0.1960098	total: 20.5s	remaining: 1.71s
# 923:	learn: 0.1959760	total: 20.6s	remaining: 1.69s
# 924:	learn: 0.1959462	total: 20.6s	remaining: 1.67s
# 925:	learn: 0.1959058	total: 20.6s	remaining: 1.65s
# 926:	learn: 0.1958541	total: 20.7s	remaining: 1.63s
# 927:	learn: 0.1958058	total: 20.7s	remaining: 1.6s
# 928:	learn: 0.1957661	total: 20.7s	remaining: 1.58s
# 929:	learn: 0.1957112	total: 20.8s	remaining: 1.56s
# 930:	learn: 0.1956904	total: 20.8s	remaining: 1.54s
# 931:	learn: 0.1956367	total: 20.8s	remaining: 1.52s
# 932:	learn: 0.1955881	total: 20.9s	remaining: 1.5s
# 933:	learn: 0.1955610	total: 20.9s	remaining: 1.48s
# 934:	learn: 0.1955305	total: 20.9s	remaining: 1.46s
# 935:	learn: 0.1954559	total: 21s	remaining: 1.44s
# 936:	learn: 0.1954128	total: 21s	remaining: 1.41s
# 937:	learn: 0.1953703	total: 21.1s	remaining: 1.39s
# 938:	learn: 0.1953322	total: 21.1s	remaining: 1.37s
# 939:	learn: 0.1952750	total: 21.1s	remaining: 1.35s
# 940:	learn: 0.1952451	total: 21.2s	remaining: 1.33s
# 941:	learn: 0.1952147	total: 21.2s	remaining: 1.3s
# 942:	learn: 0.1951845	total: 21.2s	remaining: 1.28s
# 943:	learn: 0.1951437	total: 21.3s	remaining: 1.26s
# 944:	learn: 0.1951216	total: 21.3s	remaining: 1.24s
# 945:	learn: 0.1950764	total: 21.3s	remaining: 1.22s
# 946:	learn: 0.1950430	total: 21.4s	remaining: 1.2s
# 947:	learn: 0.1950025	total: 21.4s	remaining: 1.17s
# 948:	learn: 0.1949618	total: 21.4s	remaining: 1.15s
# 949:	learn: 0.1949221	total: 21.5s	remaining: 1.13s
# 950:	learn: 0.1948729	total: 21.5s	remaining: 1.11s
# 951:	learn: 0.1948424	total: 21.5s	remaining: 1.09s
# 952:	learn: 0.1948257	total: 21.6s	remaining: 1.06s
# 953:	learn: 0.1947915	total: 21.6s	remaining: 1.04s
# 954:	learn: 0.1947644	total: 21.6s	remaining: 1.02s
# 955:	learn: 0.1947262	total: 21.7s	remaining: 997ms
# 956:	learn: 0.1946812	total: 21.7s	remaining: 975ms
# 957:	learn: 0.1946536	total: 21.7s	remaining: 953ms
# 958:	learn: 0.1946134	total: 21.8s	remaining: 931ms
# 959:	learn: 0.1945463	total: 21.8s	remaining: 908ms
# 960:	learn: 0.1945084	total: 21.8s	remaining: 886ms
# 961:	learn: 0.1944511	total: 21.9s	remaining: 864ms
# 962:	learn: 0.1943884	total: 21.9s	remaining: 841ms
# 963:	learn: 0.1943213	total: 21.9s	remaining: 819ms
# 964:	learn: 0.1942478	total: 22s	remaining: 797ms
# 965:	learn: 0.1942106	total: 22s	remaining: 774ms
# 966:	learn: 0.1941862	total: 22s	remaining: 752ms
# 967:	learn: 0.1941557	total: 22.1s	remaining: 730ms
# 968:	learn: 0.1941218	total: 22.1s	remaining: 708ms
# 969:	learn: 0.1940729	total: 22.2s	remaining: 685ms
# 970:	learn: 0.1940267	total: 22.2s	remaining: 663ms
# 971:	learn: 0.1939736	total: 22.2s	remaining: 640ms
# 972:	learn: 0.1939291	total: 22.3s	remaining: 618ms
# 973:	learn: 0.1938933	total: 22.3s	remaining: 595ms
# 974:	learn: 0.1938443	total: 22.3s	remaining: 572ms
# 975:	learn: 0.1937966	total: 22.4s	remaining: 550ms
# 976:	learn: 0.1937595	total: 22.4s	remaining: 527ms
# 977:	learn: 0.1937236	total: 22.4s	remaining: 504ms
# 978:	learn: 0.1936701	total: 22.5s	remaining: 482ms
# 979:	learn: 0.1936196	total: 22.5s	remaining: 459ms
# 980:	learn: 0.1935961	total: 22.5s	remaining: 436ms
# 981:	learn: 0.1935690	total: 22.5s	remaining: 413ms
# 982:	learn: 0.1935289	total: 22.6s	remaining: 390ms
# 983:	learn: 0.1934697	total: 22.6s	remaining: 368ms
# 984:	learn: 0.1934215	total: 22.6s	remaining: 345ms
# 985:	learn: 0.1933846	total: 22.7s	remaining: 322ms
# 986:	learn: 0.1933560	total: 22.7s	remaining: 299ms
# 987:	learn: 0.1933153	total: 22.7s	remaining: 276ms
# 988:	learn: 0.1932779	total: 22.8s	remaining: 253ms
# 989:	learn: 0.1932299	total: 22.8s	remaining: 230ms
# 990:	learn: 0.1931989	total: 22.8s	remaining: 207ms
# 991:	learn: 0.1931507	total: 22.9s	remaining: 184ms
# 992:	learn: 0.1931114	total: 22.9s	remaining: 161ms
# 993:	learn: 0.1930820	total: 22.9s	remaining: 138ms
# 994:	learn: 0.1930453	total: 22.9s	remaining: 115ms
# 995:	learn: 0.1930330	total: 23s	remaining: 92.3ms
# 996:	learn: 0.1929793	total: 23s	remaining: 69.2ms
# 997:	learn: 0.1929283	total: 23s	remaining: 46.2ms
# 998:	learn: 0.1928992	total: 23.1s	remaining: 23.1ms
# 999:	learn: 0.1928649	total: 23.1s	remaining: 0us
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.54      0.11      0.19       912
#
#     accuracy                           0.90      9429
#    macro avg       0.73      0.55      0.57      9429
# weighted avg       0.88      0.90      0.88      9429
#
# Precision: 0.5416666666666666
# Accuracy: 0.9049740163325909
# AUC: 0.8491754880332215

# %%
params_CatBoost= {
                  'depth': [3,5,10],
                  'learning_rate' : [0.01,0.1,1],
                  'iterations' : [5,10,50,100]
                 }

gs_cat_combined= GridSearchCV(estimator= cat_combined, param_grid= params_CatBoost, cv=5, scoring='precision', n_jobs=-1, verbose=2)
gs_cat_combined.fit(X_train_combined, y_train)

print("Best Parameters:", gs_cat_combined.best_params_)
print("Best Precision Score:", gs_cat_combined.best_score_)

tuned_cat_combined= gs_cat_combined.best_estimator_
y_pred_tuned_cat_combined= tuned_cat_combined.predict(X_test_combined)
y_pred_prob_tuned_cat_combined= tuned_cat_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_cat_combined, labels= tuned_cat_combined.classes_)
print(classification_report(y_test, y_pred_tuned_cat_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_cat_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_cat_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_cat_combined))
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# 0:	learn: 0.6810789	total: 80.4ms	remaining: 723ms
# 1:	learn: 0.6693369	total: 164ms	remaining: 657ms
# 2:	learn: 0.6584132	total: 249ms	remaining: 580ms
# 3:	learn: 0.6472170	total: 286ms	remaining: 429ms
# 4:	learn: 0.6379745	total: 363ms	remaining: 363ms
# 5:	learn: 0.6289233	total: 443ms	remaining: 295ms
# 6:	learn: 0.6184043	total: 523ms	remaining: 224ms
# 7:	learn: 0.6086066	total: 575ms	remaining: 144ms
# 8:	learn: 0.5996223	total: 607ms	remaining: 67.4ms
# 9:	learn: 0.5911849	total: 644ms	remaining: 0us
# Best Parameters: {'depth': 10, 'iterations': 10, 'learning_rate': 0.01}
# Best Precision Score: 0.7761904761904762
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      8517
#            1       0.75      0.01      0.02       912
#
#     accuracy                           0.90      9429
#    macro avg       0.83      0.50      0.48      9429
# weighted avg       0.89      0.90      0.86      9429
#
# Precision: 0.75
# Accuracy: 0.90391345847916
# AUC: 0.82432702963526

# %% [markdown]
# --- Visualisation ---

# %%
precision_scores= {
                    'Logistic Regression Precision:': precision_score(y_test, y_pred_lr_combined, zero_division= 0),
                    'Decision Tree Precision:': precision_score(y_test, y_pred_dt_combined, zero_division= 0),
                    'Tuned Decision Tree Precision:': precision_score(y_test, y_pred_tuned_dt_combined, zero_division= 0),
                    'KNeighborsClassifier Precision:': precision_score(y_test, y_pred_knn_combined, zero_division= 0),
                    'Tuned KNeighborsClassifier Precision:': precision_score(y_test, y_pred_tuned_knn_combined, zero_division= 0),
                    'GaussianNB Precision:': precision_score(y_test, y_pred_nb_combined, zero_division= 0),
                    'SVM Precision:': precision_score(y_test, y_pred_svc_combined, zero_division= 0),
                    'Random Forest Precision:': precision_score(y_test, y_pred_rf_combined, zero_division= 0),
                    'Tuned Random Forest Precision:': precision_score(y_test, y_pred_tuned_rf_combined, zero_division= 0),
                    'AdaBoost Precision:': precision_score(y_test, y_pred_ada_combined, zero_division= 0),
                    'Tuned AdaBoost Precision:': precision_score(y_test, y_pred_tuned_ada_combined, zero_division= 0),
                    'GradientBoosting Precision:': precision_score(y_test, y_pred_grb_combined, zero_division= 0),
                    'Tuned GradientBoosting Precision:': precision_score(y_test, y_pred_tuned_grb_combined, zero_division= 0),
                    'XGB Precision:': precision_score(y_test, y_pred_xgb_combined, zero_division= 0),
                    'Tuned XGB Precision:': precision_score(y_test, y_pred_tuned_xgb_combined, zero_division= 0),
                    'LGBM Precision:': precision_score(y_test, y_pred_lgm_combined, zero_division= 0),
                    'Tuned LGBM Precision:': precision_score(y_test, y_pred_tuned_lgm_combined, zero_division= 0),
                    'CatBoost Precision:': precision_score(y_test, y_pred_cat_combined, zero_division= 0),
                    'Tuned CatBoost Precision:': precision_score(y_test, y_pred_tuned_cat_combined, zero_division= 0)
                  }

combined_precision= pd.DataFrame(list(precision_scores.items()), columns= ['Model', 'Precision Score'])
combined_precision= combined_precision.sort_values(by= 'Precision Score', ascending=False)
print(combined_precision)
# Out:
#                                     Model  Precision Score
# 18              Tuned CatBoost Precision:         0.750000
# 8          Tuned Random Forest Precision:         0.660000
# 0          Logistic Regression Precision:         0.568807
# 16                  Tuned LGBM Precision:         0.554140
# 11            GradientBoosting Precision:         0.552083
# 12      Tuned GradientBoosting Precision:         0.552083
# 17                    CatBoost Precision:         0.541667
# 15                        LGBM Precision:         0.538462
# 9                     AdaBoost Precision:         0.528517
# 4   Tuned KNeighborsClassifier Precision:         0.520000
# 14                   Tuned XGB Precision:         0.512048
# 10              Tuned AdaBoost Precision:         0.511538
# 13                         XGB Precision:         0.488372
# 2          Tuned Decision Tree Precision:         0.403315
# 7                Random Forest Precision:         0.389262
# 3         KNeighborsClassifier Precision:         0.366197
# 1                Decision Tree Precision:         0.221421
# 5                   GaussianNB Precision:         0.215674
# 6                          SVM Precision:         0.200000

# %%
accuracy_scores= {
                    'Logistic Regression Accuracy:': accuracy_score(y_test, y_pred_lr_combined),
                    'Decision Tree Accuracy:': accuracy_score(y_test, y_pred_dt_combined),
                    'Tuned Decision Tree Accuracy:': accuracy_score(y_test, y_pred_tuned_dt_combined),
                    'KNeighborsClassifier Accuracy:': accuracy_score(y_test, y_pred_knn_combined),
                    'Tuned KNeighborsClassifier Accuracy:': accuracy_score(y_test, y_pred_tuned_knn_combined),
                    'GaussianNB Accuracy:': accuracy_score(y_test, y_pred_nb_combined),
                    'SVM Accuracy:': accuracy_score(y_test, y_pred_svc_combined),
                    'Random Forest Accuracy:': accuracy_score(y_test, y_pred_rf_combined),
                    'Tuned Random Forest Accuracy:': accuracy_score(y_test, y_pred_tuned_rf_combined),
                    'AdaBoost Accuracy:': accuracy_score(y_test, y_pred_ada_combined),
                    'Tuned AdaBoost Accuracy:': accuracy_score(y_test, y_pred_tuned_ada_combined),
                    'GradientBoosting Accuracy:': accuracy_score(y_test, y_pred_grb_combined),
                    'Tuned GradientBoosting Accuracy:': accuracy_score(y_test, y_pred_tuned_grb_combined),
                    'XGB Accuracy:': accuracy_score(y_test, y_pred_xgb_combined),
                    'Tuned XGB Accuracy:': accuracy_score(y_test, y_pred_tuned_xgb_combined),
                    'LGBM Accuracy:': accuracy_score(y_test, y_pred_lgm_combined),
                    'Tuned LGBM Accuracy:': accuracy_score(y_test, y_pred_tuned_lgm_combined),
                    'CatBoost Accuracy:': accuracy_score(y_test, y_pred_cat_combined),
                    'Tuned CatBoost Accuracy:': accuracy_score(y_test, y_pred_tuned_cat_combined)
                  }

combined_accuracy= pd.DataFrame(list(accuracy_scores.items()), columns= ['Model', 'Accuracy Score'])
combined_accuracy= combined_accuracy.sort_values(by= 'Accuracy Score', ascending=False)
print(combined_accuracy)
# Out:
#                                    Model  Accuracy Score
# 0          Logistic Regression Accuracy:        0.906459
# 12      Tuned GradientBoosting Accuracy:        0.905398
# 11            GradientBoosting Accuracy:        0.905398
# 16                  Tuned LGBM Accuracy:        0.905080
# 8          Tuned Random Forest Accuracy:        0.904974
# 17                    CatBoost Accuracy:        0.904974
# 9                     AdaBoost Accuracy:        0.904868
# 15                        LGBM Accuracy:        0.904550
# 10              Tuned AdaBoost Accuracy:        0.903913
# 18              Tuned CatBoost Accuracy:        0.903913
# 14                   Tuned XGB Accuracy:        0.903701
# 4   Tuned KNeighborsClassifier Accuracy:        0.903383
# 13                         XGB Accuracy:        0.902641
# 6                          SVM Accuracy:        0.902004
# 7                Random Forest Accuracy:        0.899777
# 2          Tuned Decision Tree Accuracy:        0.899565
# 3         KNeighborsClassifier Accuracy:        0.895217
# 1                Decision Tree Accuracy:        0.845901
# 5                   GaussianNB Accuracy:        0.707816

# %%
auc_scores= {
                    'Logistic Regression AUC:': roc_auc_score(y_test, y_pred_prob_lr_combined),
                    'Decision Tree AUC:': roc_auc_score(y_test, y_pred_prob_dt_combined),
                    'Tuned Decision Tree AUC:': roc_auc_score(y_test, y_pred_prob_tuned_dt_combined),
                    'KNeighborsClassifier AUC:': roc_auc_score(y_test, y_pred_prob_knn_combined),
                    'Tuned KNeighborsClassifier AUC:': roc_auc_score(y_test, y_pred_prob_tuned_knn_combined),
                    'GaussianNB AUC:': roc_auc_score(y_test, y_pred_prob_nb_combined),
                    'SVM AUC:': roc_auc_score(y_test, y_pred_prob_svc_combined),
                    'Random Forest AUC:': roc_auc_score(y_test, y_pred_prob_rf_combined),
                    'Tuned Random Forest AUC:': roc_auc_score(y_test, y_pred_prob_tuned_rf_combined),
                    'AdaBoost AUC:': roc_auc_score(y_test, y_pred_prob_ada_combined),
                    'Tuned AdaBoost AUC:': roc_auc_score(y_test, y_pred_prob_tuned_ada_combined),
                    'GradientBoosting AUC:': roc_auc_score(y_test, y_pred_prob_grb_combined),
                    'Tuned GradientBoosting AUC:': roc_auc_score(y_test, y_pred_prob_tuned_grb_combined),
                    'XGB AUC:': roc_auc_score(y_test, y_pred_prob_xgb_combined),
                    'Tuned XGB AUC:': roc_auc_score(y_test, y_pred_prob_tuned_xgb_combined),
                    'LGBM AUC:': roc_auc_score(y_test, y_pred_prob_lgm_combined),
                    'Tuned LGBM AUC:': roc_auc_score(y_test, y_pred_prob_tuned_lgm_combined),
                    'CatBoost AUC:': roc_auc_score(y_test, y_pred_prob_cat_combined),
                    'Tuned CatBoost AUC:': roc_auc_score(y_test, y_pred_prob_tuned_cat_combined)
                  }

combined_auc= pd.DataFrame(list(auc_scores.items()), columns= ['Model', 'AUC Score'])
combined_auc= combined_auc.sort_values(by= 'AUC Score', ascending=False)
print(combined_auc)
# Out:
#                               Model  AUC Score
# 0          Logistic Regression AUC:   0.854507
# 9                     AdaBoost AUC:   0.853394
# 12      Tuned GradientBoosting AUC:   0.853001
# 11            GradientBoosting AUC:   0.853001
# 10              Tuned AdaBoost AUC:   0.852982
# 16                  Tuned LGBM AUC:   0.851162
# 14                   Tuned XGB AUC:   0.850627
# 15                        LGBM AUC:   0.850550
# 17                    CatBoost AUC:   0.849175
# 8          Tuned Random Forest AUC:   0.847963
# 13                         XGB AUC:   0.836651
# 7                Random Forest AUC:   0.824899
# 18              Tuned CatBoost AUC:   0.824327
# 4   Tuned KNeighborsClassifier AUC:   0.808557
# 5                   GaussianNB AUC:   0.808023
# 2          Tuned Decision Tree AUC:   0.781900
# 3         KNeighborsClassifier AUC:   0.706216
# 6                          SVM AUC:   0.697240
# 1                Decision Tree AUC:   0.573048
