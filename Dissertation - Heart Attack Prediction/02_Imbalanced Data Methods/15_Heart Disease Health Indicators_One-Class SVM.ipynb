# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df= pd.read_csv('C://Users//User//Desktop//MSc Westminster//Dissertation//DataSets//Heart_Disease_Indicators.csv')

# %%
from sklearn.model_selection import train_test_split

target_size = 50000

num_class_0 = int(target_size * df['HeartDiseaseorAttack'].value_counts(normalize=True)[0])
num_class_1 = target_size - num_class_0

df_class_0 = df[df['HeartDiseaseorAttack'] == 0]
df_class_1 = df[df['HeartDiseaseorAttack'] == 1]

df_class_0_sampled = df_class_0.sample(n=num_class_0, random_state=15)
df_class_1_sampled = df_class_1.sample(n=num_class_1, random_state=15)

df_sampled = pd.concat([df_class_0_sampled, df_class_1_sampled])

df_sampled = df_sampled.sample(frac=1, random_state=15).reset_index(drop=True)
df= df_sampled
print(df['HeartDiseaseorAttack'].value_counts(normalize=True))
# Out:
# 0    0.90582
# 1    0.09418
# Name: HeartDiseaseorAttack, dtype: float64

# %%
df.drop_duplicates(inplace= True)
df.shape
# Out:
# (48050, 22)

# %%
df= df[df['Diabetes'] != 1].copy()
df.loc[df['Diabetes'] == 2, 'Diabetes'] = 1
print(df['Diabetes'].value_counts())
# Out:
# 0    40175
# 1     6968
# Name: Diabetes, dtype: int64

# %%
categorical_columns= ['HighBP', 'HighChol', 'CholCheck', 'Smoker', 'Stroke', 'Diabetes', 'PhysActivity',
                      'Fruits', 'Veggies', 'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost', 'DiffWalk',
                      'Sex', 'Age', 'Education', 'Income'
                     ]
df[categorical_columns]= df[categorical_columns].astype(str)
df= pd.get_dummies(df, columns= categorical_columns, drop_first= True)

# %%
X= df.drop(['HeartDiseaseorAttack'], axis= 1)
y= df['HeartDiseaseorAttack']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

continuous_columns = ['BMI', 'GenHlth', 'MentHlth', 'PhysHlth']

from sklearn.preprocessing import StandardScaler
ss= StandardScaler()
X_train= ss.fit_transform(X_train)
X_test= ss.transform(X_test)

# %% [markdown]
# --- One-Class SVM ---

# %%
from sklearn.svm import OneClassSVM
from sklearn.metrics import confusion_matrix, classification_report, precision_score, accuracy_score, roc_auc_score

ocsvc= OneClassSVM(gamma= 'auto', nu= 0.01)
ocsvc.fit(X_train[y_train== 0])
y_pred_ocsvc= ocsvc.predict(X_test)
y_pred_ocsvc= [1 if x== -1 else 0 for x in y_pred_ocsvc]
y_pred_prob_ocsvc= ocsvc.decision_function(X_test)

cm= confusion_matrix(y_test, y_pred_ocsvc)
print(classification_report(y_test, y_pred_ocsvc, zero_division= 0))
print('Precision:', precision_score(y_test, y_pred_ocsvc, zero_division= 0))
print('Accuracy:', accuracy_score(y_test, y_pred_ocsvc))
print('AUC:', roc_auc_score(y_test, y_pred_prob_ocsvc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      8517
#            1       0.22      0.05      0.08       912
#
#     accuracy                           0.89      9429
#    macro avg       0.56      0.51      0.51      9429
# weighted avg       0.84      0.89      0.86      9429
#
# Precision: 0.21782178217821782
# Accuracy: 0.8911867642379891
# AUC: 0.3958033365673195

# %% [markdown]
# --- Combining One-Class SVM with Traditional Classifiers ---

# %%
ocsvc= OneClassSVM(gamma='auto', nu=0.01)
ocsvc.fit(X_train[y_train== 0])

X_train_ocsvc_scores= ocsvc.decision_function(X_train).reshape(-1, 1)
X_test_ocsvc_scores= ocsvc.decision_function(X_test).reshape(-1, 1)
X_train_combined= np.hstack((X_train, X_train_ocsvc_scores))
X_test_combined= np.hstack((X_test, X_test_ocsvc_scores))

# %% [markdown]
# --- LogisticRegression ---

# %%
from sklearn.linear_model import LogisticRegression
lr_combined= LogisticRegression(max_iter= 1000, random_state= 15)
lr_combined.fit(X_train_combined, y_train)
y_pred_lr_combined = lr_combined.predict(X_test_combined)
y_pred_prob_lr_combined= lr_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_lr_combined, labels= lr_combined.classes_)
print(classification_report(y_test, y_pred_lr_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_lr_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_lr_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_lr_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.56      0.13      0.21       912
#
#     accuracy                           0.91      9429
#    macro avg       0.74      0.56      0.58      9429
# weighted avg       0.88      0.91      0.88      9429
#
# Precision: 0.5601851851851852
# Accuracy: 0.9060345741860218
# AUC: 0.8541337088464969

# %% [markdown]
# --- DecisionTreeClassifier ---

# %%
from sklearn.tree import DecisionTreeClassifier
dt_combined = DecisionTreeClassifier(random_state=15)
dt_combined.fit(X_train_combined, y_train)
y_pred_dt_combined = dt_combined.predict(X_test_combined)
y_pred_prob_dt_combined= dt_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_dt_combined, labels= dt_combined.classes_)
print(classification_report(y_test, y_pred_dt_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_dt_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_dt_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_dt_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91      8517
#            1       0.24      0.27      0.25       912
#
#     accuracy                           0.85      9429
#    macro avg       0.58      0.59      0.58      9429
# weighted avg       0.85      0.85      0.85      9429
#
# Precision: 0.23902439024390243
# Accuracy: 0.8465372786085481
# AUC: 0.5881687347698823

# %% [markdown]
# --- Tuned - DecisionTreeClassifier ---

# %%
from sklearn.model_selection import GridSearchCV
param_grid= {
             'max_depth': [None, 10, 20, 30, 40, 50],
             'min_samples_split': [2, 10, 20],
             'min_samples_leaf': [1, 5, 10],
             'max_features': [None, 'sqrt', 'log2'],
             'criterion': ['gini', 'entropy']
            }

gs_dt_combined= GridSearchCV(estimator= dt_combined, param_grid= param_grid, cv= 5, scoring= 'precision')
gs_dt_combined.fit(X_train_combined, y_train)

print("Best Parameters:", gs_dt_combined.best_params_)
print("Best Precision Score:", gs_dt_combined.best_score_)
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# Best Precision Score: 0.5083388503993207

# %%
tuned_dt_combined= gs_dt_combined.best_estimator_
y_pred_tuned_dt_combined= tuned_dt_combined.predict(X_test_combined)
y_pred_prob_tuned_dt_combined= tuned_dt_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_dt_combined, labels= tuned_dt_combined.classes_)
print(classification_report(y_test, y_pred_tuned_dt_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_dt_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_dt_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_dt_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.43      0.07      0.12       912
#
#     accuracy                           0.90      9429
#    macro avg       0.67      0.53      0.53      9429
# weighted avg       0.86      0.90      0.87      9429
#
# Precision: 0.4305555555555556
# Accuracy: 0.9011560080602397
# AUC: 0.8020015824903342

# %% [markdown]
# --- KNeighborsClassifier ---

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_combined= KNeighborsClassifier()
knn_combined.fit(X_train_combined, y_train)
y_pred_knn_combined= knn_combined.predict(X_test_combined)
y_pred_prob_knn_combined= knn_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_knn_combined, labels= knn_combined.classes_)
print(classification_report(y_test, y_pred_knn_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_knn_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_knn_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_knn_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      8517
#            1       0.36      0.11      0.17       912
#
#     accuracy                           0.90      9429
#    macro avg       0.64      0.55      0.56      9429
# weighted avg       0.86      0.90      0.87      9429
#
# Precision: 0.36428571428571427
# Accuracy: 0.8952168840810266
# AUC: 0.7026886629218343

# %% [markdown]
# --- Tuned - KNeighborsClassifier ---

# %%
param_grid= {
             'n_neighbors': np.arange(1,40),
             'weights': ['uniform', 'distance'],
             'metric': ['euclidean', 'manhattan', 'minkowski']
            }

gs_knn_combined= GridSearchCV(estimator= knn_combined, param_grid= param_grid, cv=5, scoring= 'precision')
gs_knn_combined.fit(X_train_combined, y_train)
print("Best Parameters:", gs_knn_combined.best_params_)
print("Best Precision Score:", gs_knn_combined.best_score_)
# Out:
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 38, 'weights': 'uniform'}
# Best Precision Score: 0.7323485838779956

# %%
tuned_knn_combined= gs_knn_combined.best_estimator_
y_pred_tuned_knn_combined= tuned_knn_combined.predict(X_test_combined)
y_pred_prob_tuned_knn_combined= tuned_knn_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_knn_combined, labels= tuned_knn_combined.classes_)
print(classification_report(y_test, y_pred_tuned_knn_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_knn_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_knn_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_knn_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      8517
#            1       0.56      0.02      0.03       912
#
#     accuracy                           0.90      9429
#    macro avg       0.73      0.51      0.49      9429
# weighted avg       0.87      0.90      0.86      9429
#
# Precision: 0.56
# Accuracy: 0.9035952911231308
# AUC: 0.8137179588192036

# %% [markdown]
# --- GaussianNB ---

# %%
from sklearn.naive_bayes import GaussianNB
nb_combined= GaussianNB()
nb_combined.fit(X_train_combined, y_train)
y_pred_nb_combined= nb_combined.predict(X_test_combined)
y_pred_prob_nb_combined= nb_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_nb_combined, labels= nb_combined.classes_)
print(classification_report(y_test, y_pred_nb_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_nb_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_nb_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_nb_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.69      0.81      8517
#            1       0.21      0.77      0.33       912
#
#     accuracy                           0.70      9429
#    macro avg       0.59      0.73      0.57      9429
# weighted avg       0.89      0.70      0.76      9429
#
# Precision: 0.2121120819523953
# Accuracy: 0.7006045179764556
# AUC: 0.8055804670329105

# %% [markdown]
# --- SVM ---

# %%
from sklearn.svm import SVC
svc_combined= SVC(kernel= 'rbf',probability= True, gamma= 1, random_state=15)
svc_combined.fit(X_train_combined, y_train)
y_pred_svc_combined= svc_combined.predict(X_test_combined)
y_pred_prob_svc_combined= svc_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_svc_combined, labels= svc_combined.classes_)
print(classification_report(y_test, y_pred_svc_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_svc_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_svc_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_svc_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      8517
#            1       0.17      0.00      0.01       912
#
#     accuracy                           0.90      9429
#    macro avg       0.54      0.50      0.48      9429
# weighted avg       0.83      0.90      0.86      9429
#
# Precision: 0.16666666666666666
# Accuracy: 0.9020044543429844
# AUC: 0.696488279890168

# %% [markdown]
# --- Random Forest ---

# %%
from sklearn.ensemble import RandomForestClassifier
rf_combined= RandomForestClassifier(random_state=15)
rf_combined.fit(X_train_combined, y_train)
y_pred_rf_combined= rf_combined.predict(X_test_combined)
y_pred_prob_rf_combined= rf_combined.predict_proba(X_test_combined)[:,1]

# %%
cm= confusion_matrix(y_test, y_pred_rf_combined, labels= rf_combined.classes_)
print(classification_report(y_test, y_pred_rf_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_rf_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_rf_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_rf_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.43      0.07      0.12       912
#
#     accuracy                           0.90      9429
#    macro avg       0.67      0.53      0.53      9429
# weighted avg       0.86      0.90      0.87      9429
#
# Precision: 0.4266666666666667
# Accuracy: 0.9009438964895535
# AUC: 0.8223596022609065

# %%
param_grid= {
             'n_estimators': [100, 200, 300],
             'max_depth': [None, 10, 20, 30],
             'min_samples_split': [2, 5, 10],
             'min_samples_leaf': [1, 2, 4],
            }

gs_tuned_rf_combined= GridSearchCV(estimator= rf_combined, param_grid= param_grid, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_tuned_rf_combined.fit(X_train_combined, y_train)
print("Best Parameters:", gs_tuned_rf_combined.best_params_)
print("Best Precision Score:", gs_tuned_rf_combined.best_score_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Best Precision Score: 0.7052517905379709

# %%
tuned_rf_combined= gs_tuned_rf_combined.best_estimator_
y_pred_tuned_rf_combined= tuned_rf_combined.predict(X_test_combined)
y_pred_prob_tuned_rf_combined= tuned_rf_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_rf_combined, labels= tuned_rf_combined.classes_)
print(classification_report(y_test, y_pred_tuned_rf_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_rf_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_rf_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_rf_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      8517
#            1       0.58      0.04      0.07       912
#
#     accuracy                           0.90      9429
#    macro avg       0.74      0.52      0.51      9429
# weighted avg       0.87      0.90      0.86      9429
#
# Precision: 0.5789473684210527
# Accuracy: 0.9042316258351893
# AUC: 0.8482993378567941

# %% [markdown]
# --- AdaBoost ---

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_combined= AdaBoostClassifier(random_state=15)
ada_combined.fit(X_train_combined, y_train)
y_pred_ada_combined= ada_combined.predict(X_test_combined)
y_pred_prob_ada_combined= ada_combined.predict_proba(X_test_combined)[:,1]

# %%
cm= confusion_matrix(y_test, y_pred_ada_combined, labels= ada_combined.classes_)
print(classification_report(y_test, y_pred_ada_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_ada_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_ada_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_ada_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      8517
#            1       0.53      0.16      0.25       912
#
#     accuracy                           0.91      9429
#    macro avg       0.73      0.57      0.60      9429
# weighted avg       0.88      0.91      0.88      9429
#
# Precision: 0.5347985347985348
# Accuracy: 0.9052921836886202
# AUC: 0.8532928338369701

# %%
param_grid= {'n_estimators': [50, 100, 200]}

gs_ada_combined= GridSearchCV(estimator= ada_combined, param_grid= param_grid, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_ada_combined.fit(X_train_combined, y_train)
print("Best Parameters:", gs_ada_combined.best_params_)
print("Best Precision Score:", gs_ada_combined.best_score_)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best Parameters: {'n_estimators': 200}
# Best Precision Score: 0.5613090844520825

# %%
tuned_ada_combined= gs_ada_combined.best_estimator_
y_pred_tuned_ada_combined= tuned_ada_combined.predict(X_test_combined)
y_pred_prob_tuned_ada_combined= tuned_ada_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_ada_combined, labels= tuned_ada_combined.classes_)
print(classification_report(y_test, y_pred_tuned_ada_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_ada_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_ada_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_ada_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      8517
#            1       0.52      0.16      0.25       912
#
#     accuracy                           0.90      9429
#    macro avg       0.72      0.57      0.60      9429
# weighted avg       0.88      0.90      0.88      9429
#
# Precision: 0.5211267605633803
# Accuracy: 0.9045497931912185
# AUC: 0.8519154930592889

# %% [markdown]
# --- GradientBoosting ---

# %%
from sklearn.ensemble import GradientBoostingClassifier
grb_combined= GradientBoostingClassifier(random_state=15)
grb_combined.fit(X_train_combined, y_train)
y_pred_grb_combined= grb_combined.predict(X_test_combined)
y_pred_prob_grb_combined= grb_combined.predict_proba(X_test_combined)[:,1]


cm= confusion_matrix(y_test, y_pred_grb_combined, labels= grb_combined.classes_)
print(classification_report(y_test, y_pred_grb_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_grb_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_grb_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_grb_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.53      0.12      0.20       912
#
#     accuracy                           0.90      9429
#    macro avg       0.72      0.56      0.57      9429
# weighted avg       0.88      0.90      0.88      9429
#
# Precision: 0.5336538461538461
# Accuracy: 0.9047619047619048
# AUC: 0.8532785435321307

# %%
param_grid= {'learning_rate': [0.01, 0.1, 0.2]}

gs_grb_combined= GridSearchCV(estimator= grb_combined, param_grid= param_grid, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_grb_combined.fit(X_train_combined, y_train)

print("Best Parameters:", gs_grb_combined.best_params_)
print("Best Precision Score:", gs_grb_combined.best_score_)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best Parameters: {'learning_rate': 0.01}
# Best Precision Score: 0.5933333333333334

# %%
tuned_grb_combined= gs_grb_combined.best_estimator_
y_pred_tuned_grb_combined= tuned_grb_combined.predict(X_test_combined)
y_pred_prob_tuned_grb_combined= tuned_grb_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_grb_combined, labels= tuned_grb_combined.classes_)
print(classification_report(y_test, y_pred_tuned_grb_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_grb_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_grb_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_grb_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      8517
#            1       1.00      0.00      0.00       912
#
#     accuracy                           0.90      9429
#    macro avg       0.95      0.50      0.48      9429
# weighted avg       0.91      0.90      0.86      9429
#
# Precision: 1.0
# Accuracy: 0.9033831795524446
# AUC: 0.8297489772776427

# %% [markdown]
# --- XGB ---

# %%
from xgboost import XGBClassifier
xgb_combined= XGBClassifier(random_state=15)
xgb_combined.fit(X_train_combined, y_train)
y_pred_xgb_combined= xgb_combined.predict(X_test_combined)
y_pred_prob_xgb_combined= xgb_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_xgb_combined, labels= xgb_combined.classes_)
print(classification_report(y_test, y_pred_xgb_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_xgb_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_xgb_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_xgb_combined))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      8517
#            1       0.47      0.16      0.24       912
#
#     accuracy                           0.90      9429
#    macro avg       0.69      0.57      0.59      9429
# weighted avg       0.87      0.90      0.88      9429
#
# Precision: 0.4670846394984326
# Accuracy: 0.9010499522748966
# AUC: 0.8381440807754976

# %%
params_XGBoost= {'learning_rate': [0.01, 0.1, 1.0]}

gs_xgb_combined= GridSearchCV(estimator= xgb_combined, param_grid= params_XGBoost, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_xgb_combined.fit(X_train_combined, y_train)

print("Best Parameters:", gs_xgb_combined.best_params_)
print("Best Precision Score:", gs_xgb_combined.best_score_)

tuned_xgb_combined= gs_xgb_combined.best_estimator_
y_pred_tuned_xgb_combined= tuned_xgb_combined.predict(X_test_combined)
y_pred_prob_tuned_xgb_combined= tuned_xgb_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_xgb_combined, labels= tuned_xgb_combined.classes_)
print(classification_report(y_test, y_pred_tuned_xgb_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_xgb_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_xgb_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_xgb_combined))
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best Parameters: {'learning_rate': 0.01}
# Best Precision Score: 0.7297619047619048
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      8517
#            1       0.50      0.01      0.02       912
#
#     accuracy                           0.90      9429
#    macro avg       0.70      0.50      0.48      9429
# weighted avg       0.86      0.90      0.86      9429
#
# Precision: 0.5
# Accuracy: 0.9032771237671015
# AUC: 0.8395279873689154

# %% [markdown]
# --- LGBM ---

# %%
from lightgbm import LGBMClassifier
lgm_combined= LGBMClassifier(random_state=15)
lgm_combined.fit(X_train_combined, y_train)
y_pred_lgm_combined= lgm_combined.predict(X_test_combined)
y_pred_prob_lgm_combined= lgm_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_lgm_combined, labels= lgm_combined.classes_)
print(classification_report(y_test, y_pred_lgm_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_lgm_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_lgm_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_lgm_combined))
# Out:
# [LightGBM] [Info] Number of positive: 3649, number of negative: 34065
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016206 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 506
# [LightGBM] [Info] Number of data points in the train set: 37714, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.096755 -> initscore=-2.233817
# [LightGBM] [Info] Start training from score -2.233817
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.50      0.11      0.18       912
#
#     accuracy                           0.90      9429
#    macro avg       0.70      0.55      0.57      9429
# weighted avg       0.87      0.90      0.87      9429
#
# Precision: 0.4951923076923077
# Accuracy: 0.9030650121964153
# AUC: 0.8498403734327012

# %%
params_LGB= {'learning_rate': [0.001, 0.01, 0.1, 1.0],
             'num_leaves': [31, 127],
             'reg_alpha': [0.1, 0.5],
             'min_data_in_leaf': [30, 50, 100, 300, 400]}

gs_lgm_combined= GridSearchCV(estimator= lgm_combined, param_grid= params_LGB, cv=5, scoring='precision', n_jobs=-1, verbose=2)
gs_lgm_combined.fit(X_train_combined, y_train)

print("Best Parameters:", gs_lgm_combined.best_params_)
print("Best Precision Score:", gs_lgm_combined.best_score_)

tuned_lgm_combined= gs_lgm_combined.best_estimator_
y_pred_tuned_lgm_combined= tuned_lgm_combined.predict(X_test_combined)
y_pred_prob_tuned_lgm_combined= tuned_lgm_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_lgm_combined, labels= tuned_lgm_combined.classes_)
print(classification_report(y_test, y_pred_tuned_lgm_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_lgm_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_lgm_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_lgm_combined))
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Info] Number of positive: 3649, number of negative: 34065
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015555 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 506
# [LightGBM] [Info] Number of data points in the train set: 37714, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.096755 -> initscore=-2.233817
# [LightGBM] [Info] Start training from score -2.233817
# Best Parameters: {'learning_rate': 0.1, 'min_data_in_leaf': 400, 'num_leaves': 31, 'reg_alpha': 0.5}
# Best Precision Score: 0.5735016018062243
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.53      0.13      0.21       912
#
#     accuracy                           0.90      9429
#    macro avg       0.72      0.56      0.58      9429
# weighted avg       0.88      0.90      0.88      9429
#
# Precision: 0.5263157894736842
# Accuracy: 0.9045497931912185
# AUC: 0.8491102161003071

# %% [markdown]
# --- CatBoost ---

# %%
from catboost import CatBoostClassifier
cat_combined= CatBoostClassifier(random_state=15)
cat_combined.fit(X_train_combined, y_train)
y_pred_cat_combined= cat_combined.predict(X_test_combined)
y_pred_prob_cat_combined= cat_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_cat_combined, labels= cat_combined.classes_)
print(classification_report(y_test, y_pred_cat_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_cat_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_cat_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_cat_combined))
# Out:
# Learning rate set to 0.04854
# 0:	learn: 0.6398277	total: 167ms	remaining: 2m 46s
# 1:	learn: 0.5936016	total: 184ms	remaining: 1m 31s
# 2:	learn: 0.5544625	total: 208ms	remaining: 1m 9s
# 3:	learn: 0.5202186	total: 223ms	remaining: 55.6s
# 4:	learn: 0.4898430	total: 239ms	remaining: 47.5s
# 5:	learn: 0.4665616	total: 255ms	remaining: 42.3s
# 6:	learn: 0.4415526	total: 272ms	remaining: 38.5s
# 7:	learn: 0.4214460	total: 286ms	remaining: 35.4s
# 8:	learn: 0.4006967	total: 301ms	remaining: 33.1s
# 9:	learn: 0.3865920	total: 315ms	remaining: 31.2s
# 10:	learn: 0.3736702	total: 329ms	remaining: 29.6s
# 11:	learn: 0.3594068	total: 342ms	remaining: 28.2s
# 12:	learn: 0.3487720	total: 357ms	remaining: 27.1s
# 13:	learn: 0.3390812	total: 383ms	remaining: 27s
# 14:	learn: 0.3312052	total: 399ms	remaining: 26.2s
# 15:	learn: 0.3230133	total: 417ms	remaining: 25.6s
# 16:	learn: 0.3159163	total: 433ms	remaining: 25s
# 17:	learn: 0.3103558	total: 448ms	remaining: 24.4s
# 18:	learn: 0.3054374	total: 462ms	remaining: 23.9s
# 19:	learn: 0.3010168	total: 478ms	remaining: 23.4s
# 20:	learn: 0.2963992	total: 495ms	remaining: 23.1s
# 21:	learn: 0.2925266	total: 512ms	remaining: 22.8s
# 22:	learn: 0.2897596	total: 528ms	remaining: 22.4s
# 23:	learn: 0.2860163	total: 541ms	remaining: 22s
# 24:	learn: 0.2825346	total: 555ms	remaining: 21.7s
# 25:	learn: 0.2795895	total: 570ms	remaining: 21.4s
# 26:	learn: 0.2770453	total: 585ms	remaining: 21.1s
# 27:	learn: 0.2745468	total: 599ms	remaining: 20.8s
# 28:	learn: 0.2722278	total: 621ms	remaining: 20.8s
# 29:	learn: 0.2702264	total: 642ms	remaining: 20.8s
# 30:	learn: 0.2685587	total: 659ms	remaining: 20.6s
# 31:	learn: 0.2671370	total: 677ms	remaining: 20.5s
# 32:	learn: 0.2654372	total: 694ms	remaining: 20.3s
# 33:	learn: 0.2640564	total: 710ms	remaining: 20.2s
# 34:	learn: 0.2625870	total: 727ms	remaining: 20s
# 35:	learn: 0.2615258	total: 742ms	remaining: 19.9s
# 36:	learn: 0.2606134	total: 757ms	remaining: 19.7s
# 37:	learn: 0.2597845	total: 777ms	remaining: 19.7s
# 38:	learn: 0.2588801	total: 793ms	remaining: 19.5s
# 39:	learn: 0.2579324	total: 811ms	remaining: 19.5s
# 40:	learn: 0.2570936	total: 833ms	remaining: 19.5s
# 41:	learn: 0.2563552	total: 849ms	remaining: 19.4s
# 42:	learn: 0.2555956	total: 863ms	remaining: 19.2s
# 43:	learn: 0.2549203	total: 879ms	remaining: 19.1s
# 44:	learn: 0.2543825	total: 895ms	remaining: 19s
# 45:	learn: 0.2539070	total: 911ms	remaining: 18.9s
# 46:	learn: 0.2534327	total: 928ms	remaining: 18.8s
# 47:	learn: 0.2529053	total: 945ms	remaining: 18.7s
# 48:	learn: 0.2522914	total: 960ms	remaining: 18.6s
# 49:	learn: 0.2517633	total: 973ms	remaining: 18.5s
# 50:	learn: 0.2512513	total: 990ms	remaining: 18.4s
# 51:	learn: 0.2509061	total: 1.01s	remaining: 18.3s
# 52:	learn: 0.2505139	total: 1.02s	remaining: 18.3s
# 53:	learn: 0.2503046	total: 1.04s	remaining: 18.3s
# 54:	learn: 0.2499116	total: 1.06s	remaining: 18.2s
# 55:	learn: 0.2494151	total: 1.07s	remaining: 18.1s
# 56:	learn: 0.2490223	total: 1.09s	remaining: 18s
# 57:	learn: 0.2485810	total: 1.1s	remaining: 17.9s
# 58:	learn: 0.2482703	total: 1.12s	remaining: 17.8s
# 59:	learn: 0.2480261	total: 1.13s	remaining: 17.8s
# 60:	learn: 0.2477694	total: 1.15s	remaining: 17.7s
# 61:	learn: 0.2475888	total: 1.17s	remaining: 17.6s
# 62:	learn: 0.2472741	total: 1.18s	remaining: 17.6s
# 63:	learn: 0.2469947	total: 1.2s	remaining: 17.5s
# 64:	learn: 0.2467621	total: 1.21s	remaining: 17.4s
# 65:	learn: 0.2465660	total: 1.22s	remaining: 17.3s
# 66:	learn: 0.2463080	total: 1.24s	remaining: 17.3s
# 67:	learn: 0.2460311	total: 1.26s	remaining: 17.3s
# 68:	learn: 0.2458563	total: 1.28s	remaining: 17.3s
# 69:	learn: 0.2456157	total: 1.3s	remaining: 17.2s
# 70:	learn: 0.2453929	total: 1.31s	remaining: 17.2s
# 71:	learn: 0.2452012	total: 1.33s	remaining: 17.1s
# 72:	learn: 0.2450144	total: 1.34s	remaining: 17s
# 73:	learn: 0.2448063	total: 1.36s	remaining: 17s
# 74:	learn: 0.2446787	total: 1.38s	remaining: 17s
# 75:	learn: 0.2445201	total: 1.39s	remaining: 17s
# 76:	learn: 0.2443799	total: 1.41s	remaining: 16.9s
# 77:	learn: 0.2442336	total: 1.43s	remaining: 16.8s
# 78:	learn: 0.2440744	total: 1.44s	remaining: 16.8s
# 79:	learn: 0.2439021	total: 1.46s	remaining: 16.8s
# 80:	learn: 0.2437874	total: 1.47s	remaining: 16.7s
# 81:	learn: 0.2436498	total: 1.49s	remaining: 16.7s
# 82:	learn: 0.2435258	total: 1.5s	remaining: 16.6s
# 83:	learn: 0.2433384	total: 1.52s	remaining: 16.6s
# 84:	learn: 0.2431778	total: 1.53s	remaining: 16.5s
# 85:	learn: 0.2429962	total: 1.55s	remaining: 16.4s
# 86:	learn: 0.2428614	total: 1.56s	remaining: 16.4s
# 87:	learn: 0.2427415	total: 1.58s	remaining: 16.3s
# 88:	learn: 0.2425630	total: 1.59s	remaining: 16.3s
# 89:	learn: 0.2424023	total: 1.61s	remaining: 16.3s
# 90:	learn: 0.2422788	total: 1.63s	remaining: 16.2s
# 91:	learn: 0.2421743	total: 1.64s	remaining: 16.2s
# 92:	learn: 0.2420840	total: 1.66s	remaining: 16.2s
# 93:	learn: 0.2419607	total: 1.67s	remaining: 16.1s
# 94:	learn: 0.2418168	total: 1.69s	remaining: 16.1s
# 95:	learn: 0.2416334	total: 1.7s	remaining: 16s
# 96:	learn: 0.2414663	total: 1.72s	remaining: 16s
# 97:	learn: 0.2412990	total: 1.73s	remaining: 16s
# 98:	learn: 0.2411971	total: 1.75s	remaining: 15.9s
# 99:	learn: 0.2410736	total: 1.77s	remaining: 15.9s
# 100:	learn: 0.2409788	total: 1.78s	remaining: 15.9s
# 101:	learn: 0.2408843	total: 1.8s	remaining: 15.8s
# 102:	learn: 0.2407951	total: 1.81s	remaining: 15.8s
# 103:	learn: 0.2407251	total: 1.83s	remaining: 15.8s
# 104:	learn: 0.2405760	total: 1.85s	remaining: 15.7s
# 105:	learn: 0.2404755	total: 1.87s	remaining: 15.7s
# 106:	learn: 0.2403550	total: 1.88s	remaining: 15.7s
# 107:	learn: 0.2402426	total: 1.9s	remaining: 15.7s
# 108:	learn: 0.2401630	total: 1.91s	remaining: 15.6s
# 109:	learn: 0.2400369	total: 1.93s	remaining: 15.6s
# 110:	learn: 0.2399636	total: 1.94s	remaining: 15.5s
# 111:	learn: 0.2398387	total: 1.96s	remaining: 15.5s
# 112:	learn: 0.2397296	total: 1.97s	remaining: 15.5s
# 113:	learn: 0.2396562	total: 1.99s	remaining: 15.4s
# 114:	learn: 0.2395385	total: 2s	remaining: 15.4s
# 115:	learn: 0.2394375	total: 2.02s	remaining: 15.4s
# 116:	learn: 0.2393551	total: 2.03s	remaining: 15.3s
# 117:	learn: 0.2392763	total: 2.05s	remaining: 15.3s
# 118:	learn: 0.2392099	total: 2.06s	remaining: 15.3s
# 119:	learn: 0.2390833	total: 2.08s	remaining: 15.2s
# 120:	learn: 0.2389758	total: 2.09s	remaining: 15.2s
# 121:	learn: 0.2389232	total: 2.1s	remaining: 15.1s
# 122:	learn: 0.2388794	total: 2.12s	remaining: 15.1s
# 123:	learn: 0.2387929	total: 2.13s	remaining: 15s
# 124:	learn: 0.2387031	total: 2.15s	remaining: 15s
# 125:	learn: 0.2386174	total: 2.17s	remaining: 15s
# 126:	learn: 0.2385260	total: 2.18s	remaining: 15s
# 127:	learn: 0.2384385	total: 2.19s	remaining: 14.9s
# 128:	learn: 0.2383501	total: 2.21s	remaining: 14.9s
# 129:	learn: 0.2382639	total: 2.22s	remaining: 14.9s
# 130:	learn: 0.2381893	total: 2.23s	remaining: 14.8s
# 131:	learn: 0.2381065	total: 2.25s	remaining: 14.8s
# 132:	learn: 0.2380221	total: 2.26s	remaining: 14.7s
# 133:	learn: 0.2379302	total: 2.28s	remaining: 14.7s
# 134:	learn: 0.2379240	total: 2.29s	remaining: 14.7s
# 135:	learn: 0.2378409	total: 2.3s	remaining: 14.6s
# 136:	learn: 0.2377501	total: 2.31s	remaining: 14.6s
# 137:	learn: 0.2376499	total: 2.33s	remaining: 14.6s
# 138:	learn: 0.2375774	total: 2.34s	remaining: 14.5s
# 139:	learn: 0.2374980	total: 2.36s	remaining: 14.5s
# 140:	learn: 0.2373790	total: 2.38s	remaining: 14.5s
# 141:	learn: 0.2373153	total: 2.39s	remaining: 14.4s
# 142:	learn: 0.2372484	total: 2.41s	remaining: 14.4s
# 143:	learn: 0.2371790	total: 2.43s	remaining: 14.4s
# 144:	learn: 0.2371017	total: 2.44s	remaining: 14.4s
# 145:	learn: 0.2370423	total: 2.46s	remaining: 14.4s
# 146:	learn: 0.2369647	total: 2.47s	remaining: 14.3s
# 147:	learn: 0.2369062	total: 2.49s	remaining: 14.3s
# 148:	learn: 0.2368093	total: 2.5s	remaining: 14.3s
# 149:	learn: 0.2367171	total: 2.52s	remaining: 14.3s
# 150:	learn: 0.2366188	total: 2.53s	remaining: 14.2s
# 151:	learn: 0.2365239	total: 2.55s	remaining: 14.2s
# 152:	learn: 0.2364178	total: 2.56s	remaining: 14.2s
# 153:	learn: 0.2363204	total: 2.58s	remaining: 14.2s
# 154:	learn: 0.2362489	total: 2.6s	remaining: 14.2s
# 155:	learn: 0.2361604	total: 2.61s	remaining: 14.1s
# 156:	learn: 0.2361067	total: 2.63s	remaining: 14.1s
# 157:	learn: 0.2360093	total: 2.64s	remaining: 14.1s
# 158:	learn: 0.2359316	total: 2.66s	remaining: 14.1s
# 159:	learn: 0.2358371	total: 2.68s	remaining: 14.1s
# 160:	learn: 0.2357915	total: 2.7s	remaining: 14.1s
# 161:	learn: 0.2357121	total: 2.71s	remaining: 14s
# 162:	learn: 0.2356388	total: 2.73s	remaining: 14s
# 163:	learn: 0.2355582	total: 2.74s	remaining: 14s
# 164:	learn: 0.2354986	total: 2.76s	remaining: 14s
# 165:	learn: 0.2354266	total: 2.77s	remaining: 13.9s
# 166:	learn: 0.2353306	total: 2.78s	remaining: 13.9s
# 167:	learn: 0.2352600	total: 2.79s	remaining: 13.8s
# 168:	learn: 0.2351891	total: 2.81s	remaining: 13.8s
# 169:	learn: 0.2350749	total: 2.82s	remaining: 13.8s
# 170:	learn: 0.2349980	total: 2.83s	remaining: 13.7s
# 171:	learn: 0.2349156	total: 2.85s	remaining: 13.7s
# 172:	learn: 0.2348258	total: 2.86s	remaining: 13.7s
# 173:	learn: 0.2347349	total: 2.88s	remaining: 13.7s
# 174:	learn: 0.2346600	total: 2.89s	remaining: 13.6s
# 175:	learn: 0.2345737	total: 2.9s	remaining: 13.6s
# 176:	learn: 0.2344550	total: 2.92s	remaining: 13.6s
# 177:	learn: 0.2343652	total: 2.93s	remaining: 13.5s
# 178:	learn: 0.2342725	total: 2.94s	remaining: 13.5s
# 179:	learn: 0.2341938	total: 2.96s	remaining: 13.5s
# 180:	learn: 0.2341092	total: 2.97s	remaining: 13.4s
# 181:	learn: 0.2340053	total: 2.98s	remaining: 13.4s
# 182:	learn: 0.2339335	total: 3s	remaining: 13.4s
# 183:	learn: 0.2338541	total: 3.01s	remaining: 13.4s
# 184:	learn: 0.2338125	total: 3.03s	remaining: 13.3s
# 185:	learn: 0.2337255	total: 3.04s	remaining: 13.3s
# 186:	learn: 0.2336337	total: 3.06s	remaining: 13.3s
# 187:	learn: 0.2335441	total: 3.08s	remaining: 13.3s
# 188:	learn: 0.2334551	total: 3.09s	remaining: 13.3s
# 189:	learn: 0.2333578	total: 3.11s	remaining: 13.3s
# 190:	learn: 0.2332940	total: 3.12s	remaining: 13.2s
# 191:	learn: 0.2332285	total: 3.14s	remaining: 13.2s
# 192:	learn: 0.2331548	total: 3.15s	remaining: 13.2s
# 193:	learn: 0.2330310	total: 3.16s	remaining: 13.1s
# 194:	learn: 0.2329567	total: 3.17s	remaining: 13.1s
# 195:	learn: 0.2328881	total: 3.19s	remaining: 13.1s
# 196:	learn: 0.2328275	total: 3.2s	remaining: 13s
# 197:	learn: 0.2327565	total: 3.21s	remaining: 13s
# 198:	learn: 0.2326879	total: 3.22s	remaining: 13s
# 199:	learn: 0.2326230	total: 3.23s	remaining: 12.9s
# 200:	learn: 0.2325031	total: 3.25s	remaining: 12.9s
# 201:	learn: 0.2324318	total: 3.26s	remaining: 12.9s
# 202:	learn: 0.2323426	total: 3.28s	remaining: 12.9s
# 203:	learn: 0.2322569	total: 3.29s	remaining: 12.8s
# 204:	learn: 0.2321867	total: 3.3s	remaining: 12.8s
# 205:	learn: 0.2321015	total: 3.31s	remaining: 12.8s
# 206:	learn: 0.2320325	total: 3.33s	remaining: 12.7s
# 207:	learn: 0.2319649	total: 3.34s	remaining: 12.7s
# 208:	learn: 0.2318805	total: 3.35s	remaining: 12.7s
# 209:	learn: 0.2318137	total: 3.36s	remaining: 12.7s
# 210:	learn: 0.2317504	total: 3.38s	remaining: 12.6s
# 211:	learn: 0.2316645	total: 3.39s	remaining: 12.6s
# 212:	learn: 0.2316107	total: 3.41s	remaining: 12.6s
# 213:	learn: 0.2315557	total: 3.42s	remaining: 12.6s
# 214:	learn: 0.2314828	total: 3.44s	remaining: 12.6s
# 215:	learn: 0.2314050	total: 3.46s	remaining: 12.6s
# 216:	learn: 0.2313271	total: 3.48s	remaining: 12.6s
# 217:	learn: 0.2312362	total: 3.5s	remaining: 12.6s
# 218:	learn: 0.2311720	total: 3.52s	remaining: 12.5s
# 219:	learn: 0.2310855	total: 3.53s	remaining: 12.5s
# 220:	learn: 0.2309892	total: 3.54s	remaining: 12.5s
# 221:	learn: 0.2309090	total: 3.56s	remaining: 12.5s
# 222:	learn: 0.2308242	total: 3.57s	remaining: 12.4s
# 223:	learn: 0.2307402	total: 3.58s	remaining: 12.4s
# 224:	learn: 0.2306911	total: 3.6s	remaining: 12.4s
# 225:	learn: 0.2305895	total: 3.61s	remaining: 12.4s
# 226:	learn: 0.2305109	total: 3.62s	remaining: 12.3s
# 227:	learn: 0.2304457	total: 3.64s	remaining: 12.3s
# 228:	learn: 0.2303949	total: 3.65s	remaining: 12.3s
# 229:	learn: 0.2302866	total: 3.66s	remaining: 12.3s
# 230:	learn: 0.2301970	total: 3.68s	remaining: 12.3s
# 231:	learn: 0.2301218	total: 3.7s	remaining: 12.2s
# 232:	learn: 0.2300299	total: 3.71s	remaining: 12.2s
# 233:	learn: 0.2299377	total: 3.72s	remaining: 12.2s
# 234:	learn: 0.2298708	total: 3.73s	remaining: 12.1s
# 235:	learn: 0.2297720	total: 3.74s	remaining: 12.1s
# 236:	learn: 0.2297054	total: 3.75s	remaining: 12.1s
# 237:	learn: 0.2295980	total: 3.77s	remaining: 12.1s
# 238:	learn: 0.2295331	total: 3.78s	remaining: 12s
# 239:	learn: 0.2294760	total: 3.79s	remaining: 12s
# 240:	learn: 0.2294132	total: 3.8s	remaining: 12s
# 241:	learn: 0.2293175	total: 3.81s	remaining: 11.9s
# 242:	learn: 0.2292521	total: 3.83s	remaining: 11.9s
# 243:	learn: 0.2291896	total: 3.84s	remaining: 11.9s
# 244:	learn: 0.2291266	total: 3.85s	remaining: 11.9s
# 245:	learn: 0.2290682	total: 3.86s	remaining: 11.8s
# 246:	learn: 0.2289896	total: 3.87s	remaining: 11.8s
# 247:	learn: 0.2289234	total: 3.89s	remaining: 11.8s
# 248:	learn: 0.2288298	total: 3.9s	remaining: 11.8s
# 249:	learn: 0.2287854	total: 3.91s	remaining: 11.7s
# 250:	learn: 0.2287033	total: 3.92s	remaining: 11.7s
# 251:	learn: 0.2286221	total: 3.94s	remaining: 11.7s
# 252:	learn: 0.2285511	total: 3.95s	remaining: 11.7s
# 253:	learn: 0.2284752	total: 3.96s	remaining: 11.6s
# 254:	learn: 0.2283874	total: 3.97s	remaining: 11.6s
# 255:	learn: 0.2283315	total: 3.99s	remaining: 11.6s
# 256:	learn: 0.2282394	total: 4s	remaining: 11.6s
# 257:	learn: 0.2281309	total: 4.01s	remaining: 11.5s
# 258:	learn: 0.2280484	total: 4.02s	remaining: 11.5s
# 259:	learn: 0.2279659	total: 4.03s	remaining: 11.5s
# 260:	learn: 0.2279196	total: 4.04s	remaining: 11.5s
# 261:	learn: 0.2278565	total: 4.06s	remaining: 11.4s
# 262:	learn: 0.2277891	total: 4.07s	remaining: 11.4s
# 263:	learn: 0.2277218	total: 4.09s	remaining: 11.4s
# 264:	learn: 0.2276570	total: 4.1s	remaining: 11.4s
# 265:	learn: 0.2275563	total: 4.11s	remaining: 11.3s
# 266:	learn: 0.2275095	total: 4.12s	remaining: 11.3s
# 267:	learn: 0.2274248	total: 4.14s	remaining: 11.3s
# 268:	learn: 0.2273405	total: 4.15s	remaining: 11.3s
# 269:	learn: 0.2272530	total: 4.16s	remaining: 11.3s
# 270:	learn: 0.2272025	total: 4.17s	remaining: 11.2s
# 271:	learn: 0.2271549	total: 4.18s	remaining: 11.2s
# 272:	learn: 0.2270965	total: 4.2s	remaining: 11.2s
# 273:	learn: 0.2270383	total: 4.21s	remaining: 11.1s
# 274:	learn: 0.2269423	total: 4.22s	remaining: 11.1s
# 275:	learn: 0.2268668	total: 4.23s	remaining: 11.1s
# 276:	learn: 0.2267779	total: 4.24s	remaining: 11.1s
# 277:	learn: 0.2267204	total: 4.25s	remaining: 11s
# 278:	learn: 0.2266438	total: 4.27s	remaining: 11s
# 279:	learn: 0.2265981	total: 4.28s	remaining: 11s
# 280:	learn: 0.2265183	total: 4.3s	remaining: 11s
# 281:	learn: 0.2264458	total: 4.31s	remaining: 11s
# 282:	learn: 0.2263711	total: 4.32s	remaining: 11s
# 283:	learn: 0.2262964	total: 4.33s	remaining: 10.9s
# 284:	learn: 0.2262136	total: 4.35s	remaining: 10.9s
# 285:	learn: 0.2261336	total: 4.36s	remaining: 10.9s
# 286:	learn: 0.2260492	total: 4.37s	remaining: 10.9s
# 287:	learn: 0.2259532	total: 4.38s	remaining: 10.8s
# 288:	learn: 0.2258896	total: 4.4s	remaining: 10.8s
# 289:	learn: 0.2258277	total: 4.41s	remaining: 10.8s
# 290:	learn: 0.2257787	total: 4.42s	remaining: 10.8s
# 291:	learn: 0.2257335	total: 4.43s	remaining: 10.8s
# 292:	learn: 0.2256379	total: 4.45s	remaining: 10.7s
# 293:	learn: 0.2255892	total: 4.46s	remaining: 10.7s
# 294:	learn: 0.2255250	total: 4.48s	remaining: 10.7s
# 295:	learn: 0.2254739	total: 4.5s	remaining: 10.7s
# 296:	learn: 0.2253969	total: 4.51s	remaining: 10.7s
# 297:	learn: 0.2252911	total: 4.52s	remaining: 10.7s
# 298:	learn: 0.2252146	total: 4.54s	remaining: 10.6s
# 299:	learn: 0.2251265	total: 4.55s	remaining: 10.6s
# 300:	learn: 0.2250597	total: 4.57s	remaining: 10.6s
# 301:	learn: 0.2250059	total: 4.58s	remaining: 10.6s
# 302:	learn: 0.2249198	total: 4.6s	remaining: 10.6s
# 303:	learn: 0.2248304	total: 4.62s	remaining: 10.6s
# 304:	learn: 0.2247901	total: 4.63s	remaining: 10.6s
# 305:	learn: 0.2247099	total: 4.65s	remaining: 10.5s
# 306:	learn: 0.2246719	total: 4.66s	remaining: 10.5s
# 307:	learn: 0.2246013	total: 4.69s	remaining: 10.5s
# 308:	learn: 0.2245356	total: 4.71s	remaining: 10.5s
# 309:	learn: 0.2244479	total: 4.72s	remaining: 10.5s
# 310:	learn: 0.2243644	total: 4.73s	remaining: 10.5s
# 311:	learn: 0.2243262	total: 4.74s	remaining: 10.5s
# 312:	learn: 0.2242201	total: 4.75s	remaining: 10.4s
# 313:	learn: 0.2241390	total: 4.76s	remaining: 10.4s
# 314:	learn: 0.2240769	total: 4.78s	remaining: 10.4s
# 315:	learn: 0.2240141	total: 4.79s	remaining: 10.4s
# 316:	learn: 0.2239636	total: 4.8s	remaining: 10.3s
# 317:	learn: 0.2238897	total: 4.81s	remaining: 10.3s
# 318:	learn: 0.2237930	total: 4.83s	remaining: 10.3s
# 319:	learn: 0.2237193	total: 4.84s	remaining: 10.3s
# 320:	learn: 0.2236366	total: 4.85s	remaining: 10.3s
# 321:	learn: 0.2235682	total: 4.86s	remaining: 10.2s
# 322:	learn: 0.2234955	total: 4.87s	remaining: 10.2s
# 323:	learn: 0.2234000	total: 4.89s	remaining: 10.2s
# 324:	learn: 0.2233609	total: 4.9s	remaining: 10.2s
# 325:	learn: 0.2232754	total: 4.92s	remaining: 10.2s
# 326:	learn: 0.2232189	total: 4.93s	remaining: 10.2s
# 327:	learn: 0.2231472	total: 4.95s	remaining: 10.1s
# 328:	learn: 0.2230892	total: 4.96s	remaining: 10.1s
# 329:	learn: 0.2230541	total: 4.97s	remaining: 10.1s
# 330:	learn: 0.2229839	total: 4.98s	remaining: 10.1s
# 331:	learn: 0.2229330	total: 5s	remaining: 10.1s
# 332:	learn: 0.2228766	total: 5.01s	remaining: 10s
# 333:	learn: 0.2227837	total: 5.02s	remaining: 10s
# 334:	learn: 0.2227387	total: 5.03s	remaining: 9.99s
# 335:	learn: 0.2226816	total: 5.04s	remaining: 9.97s
# 336:	learn: 0.2226287	total: 5.06s	remaining: 9.95s
# 337:	learn: 0.2225604	total: 5.07s	remaining: 9.93s
# 338:	learn: 0.2224962	total: 5.09s	remaining: 9.93s
# 339:	learn: 0.2224208	total: 5.1s	remaining: 9.9s
# 340:	learn: 0.2223530	total: 5.11s	remaining: 9.88s
# 341:	learn: 0.2222903	total: 5.13s	remaining: 9.86s
# 342:	learn: 0.2222421	total: 5.14s	remaining: 9.84s
# 343:	learn: 0.2221595	total: 5.15s	remaining: 9.82s
# 344:	learn: 0.2220864	total: 5.16s	remaining: 9.8s
# 345:	learn: 0.2220012	total: 5.17s	remaining: 9.78s
# 346:	learn: 0.2219502	total: 5.18s	remaining: 9.76s
# 347:	learn: 0.2218880	total: 5.2s	remaining: 9.74s
# 348:	learn: 0.2218309	total: 5.21s	remaining: 9.71s
# 349:	learn: 0.2217777	total: 5.22s	remaining: 9.69s
# 350:	learn: 0.2217051	total: 5.23s	remaining: 9.68s
# 351:	learn: 0.2216653	total: 5.24s	remaining: 9.65s
# 352:	learn: 0.2215949	total: 5.26s	remaining: 9.64s
# 353:	learn: 0.2215039	total: 5.27s	remaining: 9.63s
# 354:	learn: 0.2214541	total: 5.29s	remaining: 9.61s
# 355:	learn: 0.2214135	total: 5.3s	remaining: 9.6s
# 356:	learn: 0.2213594	total: 5.32s	remaining: 9.58s
# 357:	learn: 0.2212937	total: 5.34s	remaining: 9.57s
# 358:	learn: 0.2212370	total: 5.35s	remaining: 9.55s
# 359:	learn: 0.2211867	total: 5.37s	remaining: 9.54s
# 360:	learn: 0.2211273	total: 5.38s	remaining: 9.53s
# 361:	learn: 0.2210813	total: 5.4s	remaining: 9.52s
# 362:	learn: 0.2210171	total: 5.41s	remaining: 9.5s
# 363:	learn: 0.2209713	total: 5.43s	remaining: 9.48s
# 364:	learn: 0.2208979	total: 5.44s	remaining: 9.46s
# 365:	learn: 0.2208250	total: 5.45s	remaining: 9.45s
# 366:	learn: 0.2207546	total: 5.46s	remaining: 9.43s
# 367:	learn: 0.2206871	total: 5.48s	remaining: 9.4s
# 368:	learn: 0.2206279	total: 5.49s	remaining: 9.39s
# 369:	learn: 0.2205821	total: 5.51s	remaining: 9.38s
# 370:	learn: 0.2205159	total: 5.52s	remaining: 9.37s
# 371:	learn: 0.2204596	total: 5.54s	remaining: 9.36s
# 372:	learn: 0.2203893	total: 5.56s	remaining: 9.35s
# 373:	learn: 0.2203491	total: 5.57s	remaining: 9.33s
# 374:	learn: 0.2202761	total: 5.59s	remaining: 9.32s
# 375:	learn: 0.2202251	total: 5.61s	remaining: 9.3s
# 376:	learn: 0.2201708	total: 5.62s	remaining: 9.29s
# 377:	learn: 0.2201222	total: 5.63s	remaining: 9.27s
# 378:	learn: 0.2200721	total: 5.64s	remaining: 9.25s
# 379:	learn: 0.2200169	total: 5.66s	remaining: 9.23s
# 380:	learn: 0.2199287	total: 5.67s	remaining: 9.21s
# 381:	learn: 0.2198789	total: 5.69s	remaining: 9.2s
# 382:	learn: 0.2197904	total: 5.7s	remaining: 9.19s
# 383:	learn: 0.2197070	total: 5.72s	remaining: 9.17s
# 384:	learn: 0.2196396	total: 5.73s	remaining: 9.16s
# 385:	learn: 0.2195448	total: 5.75s	remaining: 9.14s
# 386:	learn: 0.2194435	total: 5.76s	remaining: 9.12s
# 387:	learn: 0.2193894	total: 5.77s	remaining: 9.11s
# 388:	learn: 0.2193556	total: 5.79s	remaining: 9.09s
# 389:	learn: 0.2192916	total: 5.8s	remaining: 9.07s
# 390:	learn: 0.2192190	total: 5.81s	remaining: 9.05s
# 391:	learn: 0.2191692	total: 5.83s	remaining: 9.04s
# 392:	learn: 0.2191127	total: 5.84s	remaining: 9.02s
# 393:	learn: 0.2190849	total: 5.85s	remaining: 9s
# 394:	learn: 0.2190427	total: 5.87s	remaining: 8.98s
# 395:	learn: 0.2189954	total: 5.88s	remaining: 8.97s
# 396:	learn: 0.2189301	total: 5.89s	remaining: 8.95s
# 397:	learn: 0.2188764	total: 5.91s	remaining: 8.94s
# 398:	learn: 0.2188151	total: 5.92s	remaining: 8.92s
# 399:	learn: 0.2187390	total: 5.93s	remaining: 8.9s
# 400:	learn: 0.2186980	total: 5.95s	remaining: 8.88s
# 401:	learn: 0.2186629	total: 5.96s	remaining: 8.87s
# 402:	learn: 0.2186107	total: 5.98s	remaining: 8.86s
# 403:	learn: 0.2185475	total: 5.99s	remaining: 8.84s
# 404:	learn: 0.2184925	total: 6s	remaining: 8.82s
# 405:	learn: 0.2184404	total: 6.02s	remaining: 8.8s
# 406:	learn: 0.2183829	total: 6.03s	remaining: 8.79s
# 407:	learn: 0.2183353	total: 6.04s	remaining: 8.77s
# 408:	learn: 0.2182994	total: 6.05s	remaining: 8.75s
# 409:	learn: 0.2182428	total: 6.07s	remaining: 8.73s
# 410:	learn: 0.2181671	total: 6.09s	remaining: 8.72s
# 411:	learn: 0.2181291	total: 6.1s	remaining: 8.71s
# 412:	learn: 0.2180712	total: 6.11s	remaining: 8.69s
# 413:	learn: 0.2180193	total: 6.13s	remaining: 8.67s
# 414:	learn: 0.2179513	total: 6.14s	remaining: 8.65s
# 415:	learn: 0.2179148	total: 6.15s	remaining: 8.63s
# 416:	learn: 0.2178245	total: 6.16s	remaining: 8.62s
# 417:	learn: 0.2177713	total: 6.18s	remaining: 8.6s
# 418:	learn: 0.2176866	total: 6.19s	remaining: 8.58s
# 419:	learn: 0.2176410	total: 6.2s	remaining: 8.57s
# 420:	learn: 0.2175419	total: 6.22s	remaining: 8.55s
# 421:	learn: 0.2175009	total: 6.23s	remaining: 8.53s
# 422:	learn: 0.2174255	total: 6.24s	remaining: 8.52s
# 423:	learn: 0.2173836	total: 6.26s	remaining: 8.5s
# 424:	learn: 0.2173404	total: 6.27s	remaining: 8.49s
# 425:	learn: 0.2172930	total: 6.29s	remaining: 8.48s
# 426:	learn: 0.2172431	total: 6.31s	remaining: 8.46s
# 427:	learn: 0.2171827	total: 6.32s	remaining: 8.44s
# 428:	learn: 0.2171121	total: 6.33s	remaining: 8.43s
# 429:	learn: 0.2170341	total: 6.35s	remaining: 8.41s
# 430:	learn: 0.2169917	total: 6.36s	remaining: 8.4s
# 431:	learn: 0.2169548	total: 6.38s	remaining: 8.38s
# 432:	learn: 0.2169108	total: 6.39s	remaining: 8.37s
# 433:	learn: 0.2168666	total: 6.4s	remaining: 8.35s
# 434:	learn: 0.2168087	total: 6.42s	remaining: 8.33s
# 435:	learn: 0.2167282	total: 6.43s	remaining: 8.31s
# 436:	learn: 0.2166611	total: 6.44s	remaining: 8.3s
# 437:	learn: 0.2165991	total: 6.45s	remaining: 8.28s
# 438:	learn: 0.2165352	total: 6.47s	remaining: 8.26s
# 439:	learn: 0.2165033	total: 6.48s	remaining: 8.24s
# 440:	learn: 0.2164613	total: 6.49s	remaining: 8.23s
# 441:	learn: 0.2163881	total: 6.51s	remaining: 8.21s
# 442:	learn: 0.2163332	total: 6.52s	remaining: 8.2s
# 443:	learn: 0.2162672	total: 6.53s	remaining: 8.18s
# 444:	learn: 0.2162359	total: 6.54s	remaining: 8.16s
# 445:	learn: 0.2161708	total: 6.56s	remaining: 8.14s
# 446:	learn: 0.2161173	total: 6.57s	remaining: 8.13s
# 447:	learn: 0.2160596	total: 6.58s	remaining: 8.11s
# 448:	learn: 0.2159965	total: 6.59s	remaining: 8.09s
# 449:	learn: 0.2159169	total: 6.61s	remaining: 8.08s
# 450:	learn: 0.2158470	total: 6.62s	remaining: 8.06s
# 451:	learn: 0.2157423	total: 6.63s	remaining: 8.04s
# 452:	learn: 0.2156976	total: 6.64s	remaining: 8.02s
# 453:	learn: 0.2156395	total: 6.66s	remaining: 8.01s
# 454:	learn: 0.2155999	total: 6.67s	remaining: 7.99s
# 455:	learn: 0.2155499	total: 6.69s	remaining: 7.98s
# 456:	learn: 0.2154475	total: 6.71s	remaining: 7.97s
# 457:	learn: 0.2153729	total: 6.72s	remaining: 7.95s
# 458:	learn: 0.2153188	total: 6.73s	remaining: 7.94s
# 459:	learn: 0.2152608	total: 6.75s	remaining: 7.92s
# 460:	learn: 0.2152057	total: 6.76s	remaining: 7.91s
# 461:	learn: 0.2151664	total: 6.79s	remaining: 7.9s
# 462:	learn: 0.2150900	total: 6.8s	remaining: 7.89s
# 463:	learn: 0.2150496	total: 6.81s	remaining: 7.87s
# 464:	learn: 0.2149828	total: 6.83s	remaining: 7.86s
# 465:	learn: 0.2149143	total: 6.84s	remaining: 7.84s
# 466:	learn: 0.2148775	total: 6.85s	remaining: 7.82s
# 467:	learn: 0.2148154	total: 6.87s	remaining: 7.8s
# 468:	learn: 0.2147693	total: 6.88s	remaining: 7.79s
# 469:	learn: 0.2147441	total: 6.89s	remaining: 7.77s
# 470:	learn: 0.2146707	total: 6.91s	remaining: 7.76s
# 471:	learn: 0.2145938	total: 6.92s	remaining: 7.74s
# 472:	learn: 0.2145454	total: 6.93s	remaining: 7.72s
# 473:	learn: 0.2145086	total: 6.95s	remaining: 7.71s
# 474:	learn: 0.2144544	total: 6.96s	remaining: 7.7s
# 475:	learn: 0.2143872	total: 6.97s	remaining: 7.68s
# 476:	learn: 0.2143163	total: 6.99s	remaining: 7.66s
# 477:	learn: 0.2142523	total: 7s	remaining: 7.65s
# 478:	learn: 0.2141898	total: 7.02s	remaining: 7.63s
# 479:	learn: 0.2141216	total: 7.03s	remaining: 7.62s
# 480:	learn: 0.2140526	total: 7.04s	remaining: 7.6s
# 481:	learn: 0.2139871	total: 7.05s	remaining: 7.58s
# 482:	learn: 0.2139409	total: 7.07s	remaining: 7.57s
# 483:	learn: 0.2138769	total: 7.09s	remaining: 7.56s
# 484:	learn: 0.2138127	total: 7.1s	remaining: 7.54s
# 485:	learn: 0.2137218	total: 7.12s	remaining: 7.53s
# 486:	learn: 0.2136841	total: 7.13s	remaining: 7.51s
# 487:	learn: 0.2136065	total: 7.15s	remaining: 7.5s
# 488:	learn: 0.2135636	total: 7.17s	remaining: 7.49s
# 489:	learn: 0.2134938	total: 7.18s	remaining: 7.47s
# 490:	learn: 0.2134689	total: 7.19s	remaining: 7.46s
# 491:	learn: 0.2134151	total: 7.2s	remaining: 7.44s
# 492:	learn: 0.2133604	total: 7.21s	remaining: 7.42s
# 493:	learn: 0.2133054	total: 7.23s	remaining: 7.4s
# 494:	learn: 0.2132300	total: 7.24s	remaining: 7.38s
# 495:	learn: 0.2131416	total: 7.25s	remaining: 7.37s
# 496:	learn: 0.2130840	total: 7.27s	remaining: 7.36s
# 497:	learn: 0.2130270	total: 7.28s	remaining: 7.34s
# 498:	learn: 0.2129543	total: 7.3s	remaining: 7.33s
# 499:	learn: 0.2129077	total: 7.31s	remaining: 7.31s
# 500:	learn: 0.2128526	total: 7.33s	remaining: 7.3s
# 501:	learn: 0.2127910	total: 7.34s	remaining: 7.28s
# 502:	learn: 0.2127219	total: 7.35s	remaining: 7.26s
# 503:	learn: 0.2126537	total: 7.36s	remaining: 7.25s
# 504:	learn: 0.2126277	total: 7.37s	remaining: 7.23s
# 505:	learn: 0.2125579	total: 7.39s	remaining: 7.21s
# 506:	learn: 0.2125232	total: 7.4s	remaining: 7.2s
# 507:	learn: 0.2124873	total: 7.42s	remaining: 7.18s
# 508:	learn: 0.2124342	total: 7.43s	remaining: 7.17s
# 509:	learn: 0.2123500	total: 7.44s	remaining: 7.15s
# 510:	learn: 0.2123150	total: 7.46s	remaining: 7.14s
# 511:	learn: 0.2122521	total: 7.47s	remaining: 7.12s
# 512:	learn: 0.2122062	total: 7.48s	remaining: 7.1s
# 513:	learn: 0.2121544	total: 7.5s	remaining: 7.09s
# 514:	learn: 0.2120862	total: 7.51s	remaining: 7.07s
# 515:	learn: 0.2120193	total: 7.53s	remaining: 7.06s
# 516:	learn: 0.2119960	total: 7.54s	remaining: 7.04s
# 517:	learn: 0.2119531	total: 7.57s	remaining: 7.04s
# 518:	learn: 0.2118754	total: 7.58s	remaining: 7.02s
# 519:	learn: 0.2118148	total: 7.59s	remaining: 7.01s
# 520:	learn: 0.2117755	total: 7.6s	remaining: 6.99s
# 521:	learn: 0.2116997	total: 7.61s	remaining: 6.97s
# 522:	learn: 0.2116268	total: 7.63s	remaining: 6.96s
# 523:	learn: 0.2115842	total: 7.64s	remaining: 6.94s
# 524:	learn: 0.2115504	total: 7.66s	remaining: 6.93s
# 525:	learn: 0.2114689	total: 7.67s	remaining: 6.91s
# 526:	learn: 0.2114304	total: 7.68s	remaining: 6.9s
# 527:	learn: 0.2113839	total: 7.7s	remaining: 6.88s
# 528:	learn: 0.2113195	total: 7.71s	remaining: 6.86s
# 529:	learn: 0.2112436	total: 7.72s	remaining: 6.85s
# 530:	learn: 0.2111930	total: 7.74s	remaining: 6.83s
# 531:	learn: 0.2111414	total: 7.75s	remaining: 6.82s
# 532:	learn: 0.2110964	total: 7.76s	remaining: 6.8s
# 533:	learn: 0.2110525	total: 7.77s	remaining: 6.78s
# 534:	learn: 0.2110072	total: 7.79s	remaining: 6.77s
# 535:	learn: 0.2109775	total: 7.8s	remaining: 6.75s
# 536:	learn: 0.2109295	total: 7.81s	remaining: 6.73s
# 537:	learn: 0.2108953	total: 7.82s	remaining: 6.71s
# 538:	learn: 0.2108499	total: 7.83s	remaining: 6.7s
# 539:	learn: 0.2107890	total: 7.84s	remaining: 6.68s
# 540:	learn: 0.2107178	total: 7.86s	remaining: 6.67s
# 541:	learn: 0.2106767	total: 7.87s	remaining: 6.65s
# 542:	learn: 0.2106424	total: 7.88s	remaining: 6.63s
# 543:	learn: 0.2105860	total: 7.9s	remaining: 6.62s
# 544:	learn: 0.2105363	total: 7.91s	remaining: 6.6s
# 545:	learn: 0.2104771	total: 7.92s	remaining: 6.59s
# 546:	learn: 0.2104078	total: 7.94s	remaining: 6.57s
# 547:	learn: 0.2103599	total: 7.95s	remaining: 6.56s
# 548:	learn: 0.2103208	total: 7.96s	remaining: 6.54s
# 549:	learn: 0.2102660	total: 7.97s	remaining: 6.52s
# 550:	learn: 0.2102210	total: 7.99s	remaining: 6.51s
# 551:	learn: 0.2101521	total: 8s	remaining: 6.49s
# 552:	learn: 0.2101078	total: 8.01s	remaining: 6.47s
# 553:	learn: 0.2100627	total: 8.02s	remaining: 6.46s
# 554:	learn: 0.2100015	total: 8.03s	remaining: 6.44s
# 555:	learn: 0.2099636	total: 8.04s	remaining: 6.42s
# 556:	learn: 0.2099009	total: 8.06s	remaining: 6.41s
# 557:	learn: 0.2098488	total: 8.07s	remaining: 6.39s
# 558:	learn: 0.2097908	total: 8.08s	remaining: 6.38s
# 559:	learn: 0.2097414	total: 8.09s	remaining: 6.36s
# 560:	learn: 0.2096993	total: 8.11s	remaining: 6.34s
# 561:	learn: 0.2096447	total: 8.12s	remaining: 6.33s
# 562:	learn: 0.2096054	total: 8.13s	remaining: 6.31s
# 563:	learn: 0.2095392	total: 8.14s	remaining: 6.29s
# 564:	learn: 0.2094775	total: 8.15s	remaining: 6.28s
# 565:	learn: 0.2094392	total: 8.16s	remaining: 6.26s
# 566:	learn: 0.2093976	total: 8.17s	remaining: 6.24s
# 567:	learn: 0.2093685	total: 8.19s	remaining: 6.22s
# 568:	learn: 0.2093138	total: 8.2s	remaining: 6.21s
# 569:	learn: 0.2092505	total: 8.21s	remaining: 6.19s
# 570:	learn: 0.2091814	total: 8.22s	remaining: 6.18s
# 571:	learn: 0.2091284	total: 8.23s	remaining: 6.16s
# 572:	learn: 0.2090919	total: 8.24s	remaining: 6.14s
# 573:	learn: 0.2090541	total: 8.26s	remaining: 6.13s
# 574:	learn: 0.2089960	total: 8.27s	remaining: 6.11s
# 575:	learn: 0.2089478	total: 8.28s	remaining: 6.1s
# 576:	learn: 0.2088883	total: 8.3s	remaining: 6.08s
# 577:	learn: 0.2088589	total: 8.31s	remaining: 6.07s
# 578:	learn: 0.2088096	total: 8.32s	remaining: 6.05s
# 579:	learn: 0.2087660	total: 8.33s	remaining: 6.03s
# 580:	learn: 0.2086898	total: 8.34s	remaining: 6.02s
# 581:	learn: 0.2086481	total: 8.36s	remaining: 6s
# 582:	learn: 0.2085761	total: 8.37s	remaining: 5.98s
# 583:	learn: 0.2085184	total: 8.38s	remaining: 5.97s
# 584:	learn: 0.2084457	total: 8.39s	remaining: 5.95s
# 585:	learn: 0.2083660	total: 8.4s	remaining: 5.93s
# 586:	learn: 0.2083186	total: 8.41s	remaining: 5.92s
# 587:	learn: 0.2082708	total: 8.42s	remaining: 5.9s
# 588:	learn: 0.2082150	total: 8.44s	remaining: 5.89s
# 589:	learn: 0.2081725	total: 8.45s	remaining: 5.87s
# 590:	learn: 0.2081030	total: 8.46s	remaining: 5.86s
# 591:	learn: 0.2080424	total: 8.48s	remaining: 5.84s
# 592:	learn: 0.2079674	total: 8.49s	remaining: 5.83s
# 593:	learn: 0.2079031	total: 8.5s	remaining: 5.81s
# 594:	learn: 0.2078421	total: 8.51s	remaining: 5.79s
# 595:	learn: 0.2078067	total: 8.52s	remaining: 5.78s
# 596:	learn: 0.2077785	total: 8.53s	remaining: 5.76s
# 597:	learn: 0.2077324	total: 8.54s	remaining: 5.74s
# 598:	learn: 0.2076960	total: 8.55s	remaining: 5.73s
# 599:	learn: 0.2076478	total: 8.57s	remaining: 5.71s
# 600:	learn: 0.2075984	total: 8.58s	remaining: 5.69s
# 601:	learn: 0.2075593	total: 8.59s	remaining: 5.68s
# 602:	learn: 0.2074951	total: 8.6s	remaining: 5.66s
# 603:	learn: 0.2074591	total: 8.61s	remaining: 5.65s
# 604:	learn: 0.2073952	total: 8.62s	remaining: 5.63s
# 605:	learn: 0.2073203	total: 8.63s	remaining: 5.61s
# 606:	learn: 0.2072908	total: 8.65s	remaining: 5.6s
# 607:	learn: 0.2072470	total: 8.66s	remaining: 5.59s
# 608:	learn: 0.2071914	total: 8.68s	remaining: 5.57s
# 609:	learn: 0.2071230	total: 8.69s	remaining: 5.55s
# 610:	learn: 0.2070787	total: 8.7s	remaining: 5.54s
# 611:	learn: 0.2070298	total: 8.71s	remaining: 5.52s
# 612:	learn: 0.2069677	total: 8.72s	remaining: 5.51s
# 613:	learn: 0.2069228	total: 8.73s	remaining: 5.49s
# 614:	learn: 0.2068742	total: 8.75s	remaining: 5.47s
# 615:	learn: 0.2068140	total: 8.76s	remaining: 5.46s
# 616:	learn: 0.2067617	total: 8.77s	remaining: 5.45s
# 617:	learn: 0.2066907	total: 8.78s	remaining: 5.43s
# 618:	learn: 0.2066526	total: 8.79s	remaining: 5.41s
# 619:	learn: 0.2066229	total: 8.81s	remaining: 5.4s
# 620:	learn: 0.2065724	total: 8.82s	remaining: 5.38s
# 621:	learn: 0.2065427	total: 8.83s	remaining: 5.37s
# 622:	learn: 0.2064876	total: 8.85s	remaining: 5.35s
# 623:	learn: 0.2064457	total: 8.86s	remaining: 5.34s
# 624:	learn: 0.2064175	total: 8.87s	remaining: 5.32s
# 625:	learn: 0.2063679	total: 8.88s	remaining: 5.31s
# 626:	learn: 0.2063189	total: 8.89s	remaining: 5.29s
# 627:	learn: 0.2062468	total: 8.91s	remaining: 5.28s
# 628:	learn: 0.2061810	total: 8.92s	remaining: 5.26s
# 629:	learn: 0.2061316	total: 8.93s	remaining: 5.24s
# 630:	learn: 0.2060698	total: 8.94s	remaining: 5.23s
# 631:	learn: 0.2060274	total: 8.95s	remaining: 5.21s
# 632:	learn: 0.2059659	total: 8.97s	remaining: 5.2s
# 633:	learn: 0.2059054	total: 8.98s	remaining: 5.18s
# 634:	learn: 0.2058636	total: 8.99s	remaining: 5.17s
# 635:	learn: 0.2057878	total: 9s	remaining: 5.15s
# 636:	learn: 0.2057370	total: 9.02s	remaining: 5.14s
# 637:	learn: 0.2056964	total: 9.03s	remaining: 5.12s
# 638:	learn: 0.2056459	total: 9.05s	remaining: 5.11s
# 639:	learn: 0.2056118	total: 9.07s	remaining: 5.1s
# 640:	learn: 0.2055744	total: 9.08s	remaining: 5.08s
# 641:	learn: 0.2055240	total: 9.09s	remaining: 5.07s
# 642:	learn: 0.2054777	total: 9.1s	remaining: 5.05s
# 643:	learn: 0.2054456	total: 9.11s	remaining: 5.04s
# 644:	learn: 0.2053789	total: 9.12s	remaining: 5.02s
# 645:	learn: 0.2053311	total: 9.13s	remaining: 5s
# 646:	learn: 0.2052802	total: 9.14s	remaining: 4.99s
# 647:	learn: 0.2052368	total: 9.16s	remaining: 4.97s
# 648:	learn: 0.2052029	total: 9.17s	remaining: 4.96s
# 649:	learn: 0.2051373	total: 9.18s	remaining: 4.94s
# 650:	learn: 0.2050873	total: 9.19s	remaining: 4.93s
# 651:	learn: 0.2049953	total: 9.2s	remaining: 4.91s
# 652:	learn: 0.2049533	total: 9.21s	remaining: 4.9s
# 653:	learn: 0.2049185	total: 9.22s	remaining: 4.88s
# 654:	learn: 0.2048850	total: 9.23s	remaining: 4.86s
# 655:	learn: 0.2048226	total: 9.25s	remaining: 4.85s
# 656:	learn: 0.2047829	total: 9.28s	remaining: 4.84s
# 657:	learn: 0.2047564	total: 9.29s	remaining: 4.83s
# 658:	learn: 0.2047082	total: 9.3s	remaining: 4.81s
# 659:	learn: 0.2046487	total: 9.31s	remaining: 4.8s
# 660:	learn: 0.2046222	total: 9.32s	remaining: 4.78s
# 661:	learn: 0.2045938	total: 9.33s	remaining: 4.76s
# 662:	learn: 0.2045383	total: 9.34s	remaining: 4.75s
# 663:	learn: 0.2045008	total: 9.36s	remaining: 4.73s
# 664:	learn: 0.2044500	total: 9.37s	remaining: 4.72s
# 665:	learn: 0.2044065	total: 9.38s	remaining: 4.7s
# 666:	learn: 0.2043514	total: 9.39s	remaining: 4.69s
# 667:	learn: 0.2043127	total: 9.4s	remaining: 4.67s
# 668:	learn: 0.2042610	total: 9.41s	remaining: 4.66s
# 669:	learn: 0.2042063	total: 9.42s	remaining: 4.64s
# 670:	learn: 0.2041418	total: 9.44s	remaining: 4.63s
# 671:	learn: 0.2041065	total: 9.45s	remaining: 4.61s
# 672:	learn: 0.2040752	total: 9.46s	remaining: 4.6s
# 673:	learn: 0.2040449	total: 9.48s	remaining: 4.58s
# 674:	learn: 0.2039755	total: 9.49s	remaining: 4.57s
# 675:	learn: 0.2039138	total: 9.5s	remaining: 4.55s
# 676:	learn: 0.2038333	total: 9.51s	remaining: 4.54s
# 677:	learn: 0.2037956	total: 9.52s	remaining: 4.52s
# 678:	learn: 0.2037541	total: 9.53s	remaining: 4.51s
# 679:	learn: 0.2036885	total: 9.54s	remaining: 4.49s
# 680:	learn: 0.2036372	total: 9.56s	remaining: 4.48s
# 681:	learn: 0.2035996	total: 9.57s	remaining: 4.46s
# 682:	learn: 0.2035535	total: 9.58s	remaining: 4.45s
# 683:	learn: 0.2035181	total: 9.59s	remaining: 4.43s
# 684:	learn: 0.2035034	total: 9.6s	remaining: 4.42s
# 685:	learn: 0.2034769	total: 9.61s	remaining: 4.4s
# 686:	learn: 0.2034300	total: 9.62s	remaining: 4.38s
# 687:	learn: 0.2034030	total: 9.64s	remaining: 4.37s
# 688:	learn: 0.2033430	total: 9.66s	remaining: 4.36s
# 689:	learn: 0.2032974	total: 9.67s	remaining: 4.34s
# 690:	learn: 0.2032303	total: 9.68s	remaining: 4.33s
# 691:	learn: 0.2031994	total: 9.69s	remaining: 4.32s
# 692:	learn: 0.2031438	total: 9.71s	remaining: 4.3s
# 693:	learn: 0.2031084	total: 9.72s	remaining: 4.28s
# 694:	learn: 0.2030639	total: 9.73s	remaining: 4.27s
# 695:	learn: 0.2030189	total: 9.74s	remaining: 4.25s
# 696:	learn: 0.2029513	total: 9.75s	remaining: 4.24s
# 697:	learn: 0.2029028	total: 9.76s	remaining: 4.22s
# 698:	learn: 0.2028527	total: 9.77s	remaining: 4.21s
# 699:	learn: 0.2028054	total: 9.79s	remaining: 4.19s
# 700:	learn: 0.2027655	total: 9.8s	remaining: 4.18s
# 701:	learn: 0.2027315	total: 9.81s	remaining: 4.16s
# 702:	learn: 0.2026720	total: 9.82s	remaining: 4.15s
# 703:	learn: 0.2026290	total: 9.83s	remaining: 4.13s
# 704:	learn: 0.2025680	total: 9.85s	remaining: 4.12s
# 705:	learn: 0.2025371	total: 9.86s	remaining: 4.11s
# 706:	learn: 0.2024776	total: 9.87s	remaining: 4.09s
# 707:	learn: 0.2024223	total: 9.88s	remaining: 4.08s
# 708:	learn: 0.2023499	total: 9.89s	remaining: 4.06s
# 709:	learn: 0.2023100	total: 9.91s	remaining: 4.05s
# 710:	learn: 0.2022508	total: 9.92s	remaining: 4.03s
# 711:	learn: 0.2021948	total: 9.93s	remaining: 4.02s
# 712:	learn: 0.2021590	total: 9.94s	remaining: 4s
# 713:	learn: 0.2021000	total: 9.95s	remaining: 3.99s
# 714:	learn: 0.2020594	total: 9.96s	remaining: 3.97s
# 715:	learn: 0.2020249	total: 9.98s	remaining: 3.96s
# 716:	learn: 0.2019691	total: 9.99s	remaining: 3.94s
# 717:	learn: 0.2019247	total: 10s	remaining: 3.93s
# 718:	learn: 0.2018838	total: 10s	remaining: 3.91s
# 719:	learn: 0.2018473	total: 10s	remaining: 3.9s
# 720:	learn: 0.2018268	total: 10s	remaining: 3.88s
# 721:	learn: 0.2017579	total: 10s	remaining: 3.87s
# 722:	learn: 0.2017288	total: 10.1s	remaining: 3.85s
# 723:	learn: 0.2017007	total: 10.1s	remaining: 3.84s
# 724:	learn: 0.2016489	total: 10.1s	remaining: 3.83s
# 725:	learn: 0.2016021	total: 10.1s	remaining: 3.81s
# 726:	learn: 0.2015502	total: 10.1s	remaining: 3.8s
# 727:	learn: 0.2015131	total: 10.1s	remaining: 3.78s
# 728:	learn: 0.2014715	total: 10.1s	remaining: 3.77s
# 729:	learn: 0.2014271	total: 10.1s	remaining: 3.75s
# 730:	learn: 0.2013489	total: 10.2s	remaining: 3.74s
# 731:	learn: 0.2013177	total: 10.2s	remaining: 3.72s
# 732:	learn: 0.2012868	total: 10.2s	remaining: 3.71s
# 733:	learn: 0.2012188	total: 10.2s	remaining: 3.69s
# 734:	learn: 0.2011779	total: 10.2s	remaining: 3.68s
# 735:	learn: 0.2011474	total: 10.2s	remaining: 3.67s
# 736:	learn: 0.2011135	total: 10.2s	remaining: 3.65s
# 737:	learn: 0.2010869	total: 10.2s	remaining: 3.64s
# 738:	learn: 0.2010485	total: 10.3s	remaining: 3.62s
# 739:	learn: 0.2010038	total: 10.3s	remaining: 3.61s
# 740:	learn: 0.2009573	total: 10.3s	remaining: 3.59s
# 741:	learn: 0.2008945	total: 10.3s	remaining: 3.58s
# 742:	learn: 0.2008278	total: 10.3s	remaining: 3.56s
# 743:	learn: 0.2007936	total: 10.3s	remaining: 3.55s
# 744:	learn: 0.2007520	total: 10.3s	remaining: 3.54s
# 745:	learn: 0.2007094	total: 10.3s	remaining: 3.52s
# 746:	learn: 0.2006663	total: 10.4s	remaining: 3.51s
# 747:	learn: 0.2006352	total: 10.4s	remaining: 3.49s
# 748:	learn: 0.2005943	total: 10.4s	remaining: 3.48s
# 749:	learn: 0.2005494	total: 10.4s	remaining: 3.46s
# 750:	learn: 0.2005033	total: 10.4s	remaining: 3.45s
# 751:	learn: 0.2004740	total: 10.4s	remaining: 3.43s
# 752:	learn: 0.2004264	total: 10.4s	remaining: 3.42s
# 753:	learn: 0.2004003	total: 10.4s	remaining: 3.41s
# 754:	learn: 0.2003713	total: 10.5s	remaining: 3.39s
# 755:	learn: 0.2003407	total: 10.5s	remaining: 3.38s
# 756:	learn: 0.2002897	total: 10.5s	remaining: 3.36s
# 757:	learn: 0.2002331	total: 10.5s	remaining: 3.35s
# 758:	learn: 0.2001686	total: 10.5s	remaining: 3.33s
# 759:	learn: 0.2001133	total: 10.5s	remaining: 3.32s
# 760:	learn: 0.2000535	total: 10.5s	remaining: 3.3s
# 761:	learn: 0.2000134	total: 10.5s	remaining: 3.29s
# 762:	learn: 0.1999611	total: 10.6s	remaining: 3.28s
# 763:	learn: 0.1999130	total: 10.6s	remaining: 3.26s
# 764:	learn: 0.1998730	total: 10.6s	remaining: 3.25s
# 765:	learn: 0.1998311	total: 10.6s	remaining: 3.23s
# 766:	learn: 0.1998077	total: 10.6s	remaining: 3.22s
# 767:	learn: 0.1997442	total: 10.6s	remaining: 3.21s
# 768:	learn: 0.1997010	total: 10.6s	remaining: 3.19s
# 769:	learn: 0.1996501	total: 10.6s	remaining: 3.18s
# 770:	learn: 0.1995896	total: 10.7s	remaining: 3.16s
# 771:	learn: 0.1995463	total: 10.7s	remaining: 3.15s
# 772:	learn: 0.1994968	total: 10.7s	remaining: 3.13s
# 773:	learn: 0.1994690	total: 10.7s	remaining: 3.12s
# 774:	learn: 0.1994144	total: 10.7s	remaining: 3.1s
# 775:	learn: 0.1993777	total: 10.7s	remaining: 3.09s
# 776:	learn: 0.1993084	total: 10.7s	remaining: 3.08s
# 777:	learn: 0.1992584	total: 10.7s	remaining: 3.06s
# 778:	learn: 0.1992379	total: 10.7s	remaining: 3.05s
# 779:	learn: 0.1992043	total: 10.8s	remaining: 3.03s
# 780:	learn: 0.1991651	total: 10.8s	remaining: 3.02s
# 781:	learn: 0.1990902	total: 10.8s	remaining: 3s
# 782:	learn: 0.1990409	total: 10.8s	remaining: 2.99s
# 783:	learn: 0.1990002	total: 10.8s	remaining: 2.98s
# 784:	learn: 0.1989388	total: 10.8s	remaining: 2.96s
# 785:	learn: 0.1989051	total: 10.8s	remaining: 2.95s
# 786:	learn: 0.1988503	total: 10.8s	remaining: 2.93s
# 787:	learn: 0.1987986	total: 10.9s	remaining: 2.92s
# 788:	learn: 0.1987330	total: 10.9s	remaining: 2.9s
# 789:	learn: 0.1987007	total: 10.9s	remaining: 2.89s
# 790:	learn: 0.1986649	total: 10.9s	remaining: 2.88s
# 791:	learn: 0.1986336	total: 10.9s	remaining: 2.86s
# 792:	learn: 0.1986078	total: 10.9s	remaining: 2.85s
# 793:	learn: 0.1985624	total: 10.9s	remaining: 2.83s
# 794:	learn: 0.1985267	total: 10.9s	remaining: 2.82s
# 795:	learn: 0.1984754	total: 10.9s	remaining: 2.8s
# 796:	learn: 0.1984261	total: 11s	remaining: 2.79s
# 797:	learn: 0.1983611	total: 11s	remaining: 2.77s
# 798:	learn: 0.1983112	total: 11s	remaining: 2.76s
# 799:	learn: 0.1982585	total: 11s	remaining: 2.75s
# 800:	learn: 0.1982396	total: 11s	remaining: 2.73s
# 801:	learn: 0.1981822	total: 11s	remaining: 2.72s
# 802:	learn: 0.1981487	total: 11s	remaining: 2.71s
# 803:	learn: 0.1980986	total: 11s	remaining: 2.69s
# 804:	learn: 0.1980439	total: 11.1s	remaining: 2.68s
# 805:	learn: 0.1980123	total: 11.1s	remaining: 2.66s
# 806:	learn: 0.1979721	total: 11.1s	remaining: 2.65s
# 807:	learn: 0.1979550	total: 11.1s	remaining: 2.63s
# 808:	learn: 0.1979312	total: 11.1s	remaining: 2.62s
# 809:	learn: 0.1978810	total: 11.1s	remaining: 2.6s
# 810:	learn: 0.1978206	total: 11.1s	remaining: 2.59s
# 811:	learn: 0.1977460	total: 11.1s	remaining: 2.58s
# 812:	learn: 0.1977043	total: 11.1s	remaining: 2.56s
# 813:	learn: 0.1976574	total: 11.2s	remaining: 2.55s
# 814:	learn: 0.1975969	total: 11.2s	remaining: 2.54s
# 815:	learn: 0.1975617	total: 11.2s	remaining: 2.52s
# 816:	learn: 0.1975222	total: 11.2s	remaining: 2.51s
# 817:	learn: 0.1974751	total: 11.2s	remaining: 2.49s
# 818:	learn: 0.1974323	total: 11.2s	remaining: 2.48s
# 819:	learn: 0.1973936	total: 11.2s	remaining: 2.47s
# 820:	learn: 0.1973471	total: 11.3s	remaining: 2.45s
# 821:	learn: 0.1973060	total: 11.3s	remaining: 2.44s
# 822:	learn: 0.1972628	total: 11.3s	remaining: 2.42s
# 823:	learn: 0.1972229	total: 11.3s	remaining: 2.41s
# 824:	learn: 0.1971829	total: 11.3s	remaining: 2.4s
# 825:	learn: 0.1971347	total: 11.3s	remaining: 2.38s
# 826:	learn: 0.1970747	total: 11.3s	remaining: 2.37s
# 827:	learn: 0.1970258	total: 11.3s	remaining: 2.35s
# 828:	learn: 0.1969730	total: 11.3s	remaining: 2.34s
# 829:	learn: 0.1969296	total: 11.4s	remaining: 2.33s
# 830:	learn: 0.1968801	total: 11.4s	remaining: 2.31s
# 831:	learn: 0.1968147	total: 11.4s	remaining: 2.3s
# 832:	learn: 0.1967870	total: 11.4s	remaining: 2.28s
# 833:	learn: 0.1967360	total: 11.4s	remaining: 2.27s
# 834:	learn: 0.1967111	total: 11.4s	remaining: 2.25s
# 835:	learn: 0.1966647	total: 11.4s	remaining: 2.24s
# 836:	learn: 0.1966300	total: 11.4s	remaining: 2.23s
# 837:	learn: 0.1966082	total: 11.5s	remaining: 2.21s
# 838:	learn: 0.1965822	total: 11.5s	remaining: 2.2s
# 839:	learn: 0.1965556	total: 11.5s	remaining: 2.19s
# 840:	learn: 0.1965165	total: 11.5s	remaining: 2.17s
# 841:	learn: 0.1964623	total: 11.5s	remaining: 2.16s
# 842:	learn: 0.1963986	total: 11.5s	remaining: 2.15s
# 843:	learn: 0.1963187	total: 11.5s	remaining: 2.13s
# 844:	learn: 0.1962740	total: 11.5s	remaining: 2.12s
# 845:	learn: 0.1962222	total: 11.6s	remaining: 2.1s
# 846:	learn: 0.1961742	total: 11.6s	remaining: 2.09s
# 847:	learn: 0.1961391	total: 11.6s	remaining: 2.07s
# 848:	learn: 0.1961020	total: 11.6s	remaining: 2.06s
# 849:	learn: 0.1960748	total: 11.6s	remaining: 2.05s
# 850:	learn: 0.1960338	total: 11.6s	remaining: 2.03s
# 851:	learn: 0.1959974	total: 11.6s	remaining: 2.02s
# 852:	learn: 0.1959778	total: 11.6s	remaining: 2s
# 853:	learn: 0.1959421	total: 11.6s	remaining: 1.99s
# 854:	learn: 0.1959214	total: 11.7s	remaining: 1.98s
# 855:	learn: 0.1958710	total: 11.7s	remaining: 1.96s
# 856:	learn: 0.1958363	total: 11.7s	remaining: 1.95s
# 857:	learn: 0.1957979	total: 11.7s	remaining: 1.94s
# 858:	learn: 0.1957476	total: 11.7s	remaining: 1.92s
# 859:	learn: 0.1957153	total: 11.7s	remaining: 1.91s
# 860:	learn: 0.1956780	total: 11.7s	remaining: 1.89s
# 861:	learn: 0.1956340	total: 11.7s	remaining: 1.88s
# 862:	learn: 0.1955829	total: 11.7s	remaining: 1.86s
# 863:	learn: 0.1955419	total: 11.8s	remaining: 1.85s
# 864:	learn: 0.1954945	total: 11.8s	remaining: 1.84s
# 865:	learn: 0.1954509	total: 11.8s	remaining: 1.82s
# 866:	learn: 0.1954170	total: 11.8s	remaining: 1.81s
# 867:	learn: 0.1953741	total: 11.8s	remaining: 1.79s
# 868:	learn: 0.1953134	total: 11.8s	remaining: 1.78s
# 869:	learn: 0.1952914	total: 11.8s	remaining: 1.77s
# 870:	learn: 0.1952664	total: 11.8s	remaining: 1.75s
# 871:	learn: 0.1952140	total: 11.9s	remaining: 1.74s
# 872:	learn: 0.1951466	total: 11.9s	remaining: 1.73s
# 873:	learn: 0.1950943	total: 11.9s	remaining: 1.71s
# 874:	learn: 0.1950290	total: 11.9s	remaining: 1.7s
# 875:	learn: 0.1949938	total: 11.9s	remaining: 1.69s
# 876:	learn: 0.1949410	total: 11.9s	remaining: 1.67s
# 877:	learn: 0.1949068	total: 11.9s	remaining: 1.66s
# 878:	learn: 0.1948547	total: 11.9s	remaining: 1.64s
# 879:	learn: 0.1948138	total: 12s	remaining: 1.63s
# 880:	learn: 0.1947600	total: 12s	remaining: 1.61s
# 881:	learn: 0.1947301	total: 12s	remaining: 1.6s
# 882:	learn: 0.1947009	total: 12s	remaining: 1.59s
# 883:	learn: 0.1946641	total: 12s	remaining: 1.57s
# 884:	learn: 0.1946404	total: 12s	remaining: 1.56s
# 885:	learn: 0.1946086	total: 12s	remaining: 1.55s
# 886:	learn: 0.1945389	total: 12s	remaining: 1.53s
# 887:	learn: 0.1944899	total: 12.1s	remaining: 1.52s
# 888:	learn: 0.1944530	total: 12.1s	remaining: 1.51s
# 889:	learn: 0.1944180	total: 12.1s	remaining: 1.49s
# 890:	learn: 0.1943554	total: 12.1s	remaining: 1.48s
# 891:	learn: 0.1943283	total: 12.1s	remaining: 1.47s
# 892:	learn: 0.1942988	total: 12.1s	remaining: 1.45s
# 893:	learn: 0.1942480	total: 12.1s	remaining: 1.44s
# 894:	learn: 0.1942252	total: 12.1s	remaining: 1.42s
# 895:	learn: 0.1941853	total: 12.1s	remaining: 1.41s
# 896:	learn: 0.1941610	total: 12.2s	remaining: 1.4s
# 897:	learn: 0.1941303	total: 12.2s	remaining: 1.38s
# 898:	learn: 0.1940866	total: 12.2s	remaining: 1.37s
# 899:	learn: 0.1940698	total: 12.2s	remaining: 1.35s
# 900:	learn: 0.1940324	total: 12.2s	remaining: 1.34s
# 901:	learn: 0.1939964	total: 12.2s	remaining: 1.33s
# 902:	learn: 0.1939505	total: 12.2s	remaining: 1.31s
# 903:	learn: 0.1939105	total: 12.2s	remaining: 1.3s
# 904:	learn: 0.1938743	total: 12.3s	remaining: 1.29s
# 905:	learn: 0.1938120	total: 12.3s	remaining: 1.27s
# 906:	learn: 0.1937605	total: 12.3s	remaining: 1.26s
# 907:	learn: 0.1937480	total: 12.3s	remaining: 1.25s
# 908:	learn: 0.1937057	total: 12.3s	remaining: 1.23s
# 909:	learn: 0.1936845	total: 12.3s	remaining: 1.22s
# 910:	learn: 0.1936449	total: 12.3s	remaining: 1.2s
# 911:	learn: 0.1936123	total: 12.3s	remaining: 1.19s
# 912:	learn: 0.1935913	total: 12.4s	remaining: 1.18s
# 913:	learn: 0.1935452	total: 12.4s	remaining: 1.16s
# 914:	learn: 0.1935035	total: 12.4s	remaining: 1.15s
# 915:	learn: 0.1934333	total: 12.4s	remaining: 1.14s
# 916:	learn: 0.1933764	total: 12.4s	remaining: 1.12s
# 917:	learn: 0.1933423	total: 12.4s	remaining: 1.11s
# 918:	learn: 0.1933061	total: 12.4s	remaining: 1.09s
# 919:	learn: 0.1932664	total: 12.4s	remaining: 1.08s
# 920:	learn: 0.1932351	total: 12.5s	remaining: 1.07s
# 921:	learn: 0.1931965	total: 12.5s	remaining: 1.05s
# 922:	learn: 0.1931653	total: 12.5s	remaining: 1.04s
# 923:	learn: 0.1931377	total: 12.5s	remaining: 1.03s
# 924:	learn: 0.1930982	total: 12.5s	remaining: 1.01s
# 925:	learn: 0.1930596	total: 12.5s	remaining: 1000ms
# 926:	learn: 0.1930347	total: 12.5s	remaining: 986ms
# 927:	learn: 0.1929876	total: 12.5s	remaining: 972ms
# 928:	learn: 0.1929462	total: 12.5s	remaining: 959ms
# 929:	learn: 0.1929235	total: 12.6s	remaining: 945ms
# 930:	learn: 0.1929064	total: 12.6s	remaining: 931ms
# 931:	learn: 0.1928630	total: 12.6s	remaining: 918ms
# 932:	learn: 0.1928032	total: 12.6s	remaining: 904ms
# 933:	learn: 0.1927571	total: 12.6s	remaining: 890ms
# 934:	learn: 0.1927319	total: 12.6s	remaining: 877ms
# 935:	learn: 0.1926831	total: 12.6s	remaining: 864ms
# 936:	learn: 0.1926247	total: 12.6s	remaining: 850ms
# 937:	learn: 0.1925540	total: 12.7s	remaining: 836ms
# 938:	learn: 0.1925318	total: 12.7s	remaining: 823ms
# 939:	learn: 0.1924957	total: 12.7s	remaining: 809ms
# 940:	learn: 0.1924667	total: 12.7s	remaining: 796ms
# 941:	learn: 0.1924202	total: 12.7s	remaining: 782ms
# 942:	learn: 0.1923770	total: 12.7s	remaining: 768ms
# 943:	learn: 0.1923335	total: 12.7s	remaining: 755ms
# 944:	learn: 0.1922862	total: 12.7s	remaining: 741ms
# 945:	learn: 0.1922556	total: 12.7s	remaining: 728ms
# 946:	learn: 0.1921995	total: 12.8s	remaining: 714ms
# 947:	learn: 0.1921737	total: 12.8s	remaining: 700ms
# 948:	learn: 0.1921318	total: 12.8s	remaining: 687ms
# 949:	learn: 0.1920876	total: 12.8s	remaining: 673ms
# 950:	learn: 0.1920458	total: 12.8s	remaining: 660ms
# 951:	learn: 0.1919915	total: 12.8s	remaining: 646ms
# 952:	learn: 0.1919578	total: 12.8s	remaining: 633ms
# 953:	learn: 0.1919413	total: 12.8s	remaining: 619ms
# 954:	learn: 0.1918932	total: 12.9s	remaining: 606ms
# 955:	learn: 0.1918502	total: 12.9s	remaining: 592ms
# 956:	learn: 0.1918135	total: 12.9s	remaining: 579ms
# 957:	learn: 0.1917517	total: 12.9s	remaining: 565ms
# 958:	learn: 0.1917165	total: 12.9s	remaining: 552ms
# 959:	learn: 0.1917011	total: 12.9s	remaining: 538ms
# 960:	learn: 0.1916860	total: 12.9s	remaining: 525ms
# 961:	learn: 0.1916441	total: 12.9s	remaining: 511ms
# 962:	learn: 0.1915783	total: 12.9s	remaining: 497ms
# 963:	learn: 0.1915378	total: 13s	remaining: 484ms
# 964:	learn: 0.1914940	total: 13s	remaining: 471ms
# 965:	learn: 0.1914459	total: 13s	remaining: 457ms
# 966:	learn: 0.1913994	total: 13s	remaining: 444ms
# 967:	learn: 0.1913540	total: 13s	remaining: 430ms
# 968:	learn: 0.1912923	total: 13s	remaining: 416ms
# 969:	learn: 0.1912159	total: 13s	remaining: 403ms
# 970:	learn: 0.1911707	total: 13s	remaining: 390ms
# 971:	learn: 0.1911186	total: 13.1s	remaining: 376ms
# 972:	learn: 0.1910725	total: 13.1s	remaining: 363ms
# 973:	learn: 0.1910327	total: 13.1s	remaining: 349ms
# 974:	learn: 0.1909913	total: 13.1s	remaining: 336ms
# 975:	learn: 0.1909480	total: 13.1s	remaining: 322ms
# 976:	learn: 0.1909111	total: 13.1s	remaining: 309ms
# 977:	learn: 0.1908746	total: 13.1s	remaining: 295ms
# 978:	learn: 0.1908309	total: 13.1s	remaining: 282ms
# 979:	learn: 0.1908006	total: 13.2s	remaining: 268ms
# 980:	learn: 0.1907829	total: 13.2s	remaining: 255ms
# 981:	learn: 0.1907602	total: 13.2s	remaining: 241ms
# 982:	learn: 0.1907313	total: 13.2s	remaining: 228ms
# 983:	learn: 0.1907157	total: 13.2s	remaining: 215ms
# 984:	learn: 0.1906868	total: 13.2s	remaining: 201ms
# 985:	learn: 0.1906762	total: 13.2s	remaining: 188ms
# 986:	learn: 0.1906523	total: 13.2s	remaining: 174ms
# 987:	learn: 0.1906013	total: 13.2s	remaining: 161ms
# 988:	learn: 0.1905674	total: 13.3s	remaining: 147ms
# 989:	learn: 0.1905028	total: 13.3s	remaining: 134ms
# 990:	learn: 0.1904609	total: 13.3s	remaining: 121ms
# 991:	learn: 0.1904300	total: 13.3s	remaining: 107ms
# 992:	learn: 0.1903588	total: 13.3s	remaining: 93.8ms
# 993:	learn: 0.1903158	total: 13.3s	remaining: 80.4ms
# 994:	learn: 0.1902843	total: 13.3s	remaining: 67ms
# 995:	learn: 0.1902497	total: 13.3s	remaining: 53.6ms
# 996:	learn: 0.1902076	total: 13.4s	remaining: 40.2ms
# 997:	learn: 0.1901750	total: 13.4s	remaining: 26.8ms
# 998:	learn: 0.1901279	total: 13.4s	remaining: 13.4ms
# 999:	learn: 0.1900855	total: 13.4s	remaining: 0us
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8517
#            1       0.51      0.14      0.22       912
#
#     accuracy                           0.90      9429
#    macro avg       0.71      0.56      0.58      9429
# weighted avg       0.88      0.90      0.88      9429
#
# Precision: 0.5100401606425703
# Accuracy: 0.903807402693817
# AUC: 0.8480085752128353

# %%
params_CatBoost= {
                  'depth': [3,5,10],
                  'learning_rate' : [0.01,0.1,1],
                  'iterations' : [5,10,50,100]
                 }

gs_cat_combined= GridSearchCV(estimator= cat_combined, param_grid= params_CatBoost, cv=5, scoring='precision', n_jobs=-1, verbose=2)
gs_cat_combined.fit(X_train_combined, y_train)

print("Best Parameters:", gs_cat_combined.best_params_)
print("Best Precision Score:", gs_cat_combined.best_score_)

tuned_cat_combined= gs_cat_combined.best_estimator_
y_pred_tuned_cat_combined= tuned_cat_combined.predict(X_test_combined)
y_pred_prob_tuned_cat_combined= tuned_cat_combined.predict_proba(X_test_combined)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_cat_combined, labels= tuned_cat_combined.classes_)
print(classification_report(y_test, y_pred_tuned_cat_combined, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_cat_combined, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_cat_combined))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_cat_combined))
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# 0:	learn: 0.5910857	total: 17.1ms	remaining: 154ms
# 1:	learn: 0.5141547	total: 32.8ms	remaining: 131ms
# 2:	learn: 0.4598812	total: 47.5ms	remaining: 111ms
# 3:	learn: 0.4155299	total: 59.3ms	remaining: 89ms
# 4:	learn: 0.3830648	total: 73.5ms	remaining: 73.5ms
# 5:	learn: 0.3568865	total: 88ms	remaining: 58.7ms
# 6:	learn: 0.3400753	total: 99.7ms	remaining: 42.7ms
# 7:	learn: 0.3224750	total: 112ms	remaining: 28ms
# 8:	learn: 0.3084385	total: 124ms	remaining: 13.8ms
# 9:	learn: 0.2997350	total: 137ms	remaining: 0us
# Best Parameters: {'depth': 5, 'iterations': 10, 'learning_rate': 0.1}
# Best Precision Score: 0.8683982683982684
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      8517
#            1       1.00      0.00      0.00       912
#
#     accuracy                           0.90      9429
#    macro avg       0.95      0.50      0.48      9429
# weighted avg       0.91      0.90      0.86      9429
#
# Precision: 1.0
# Accuracy: 0.9034892353377877
# AUC: 0.8282274460367192

# %% [markdown]
# --- Visualisation ---

# %%
precision_scores= {
                    'Logistic Regression Precision:': precision_score(y_test, y_pred_lr_combined, zero_division= 0),
                    'Decision Tree Precision:': precision_score(y_test, y_pred_dt_combined, zero_division= 0),
                    'Tuned Decision Tree Precision:': precision_score(y_test, y_pred_tuned_dt_combined, zero_division= 0),
                    'KNeighborsClassifier Precision:': precision_score(y_test, y_pred_knn_combined, zero_division= 0),
                    'Tuned KNeighborsClassifier Precision:': precision_score(y_test, y_pred_tuned_knn_combined, zero_division= 0),
                    'GaussianNB Precision:': precision_score(y_test, y_pred_nb_combined, zero_division= 0),
                    'SVM Precision:': precision_score(y_test, y_pred_svc_combined, zero_division= 0),
                    'Random Forest Precision:': precision_score(y_test, y_pred_rf_combined, zero_division= 0),
                    'Tuned Random Forest Precision:': precision_score(y_test, y_pred_tuned_rf_combined, zero_division= 0),
                    'AdaBoost Precision:': precision_score(y_test, y_pred_ada_combined, zero_division= 0),
                    'Tuned AdaBoost Precision:': precision_score(y_test, y_pred_tuned_ada_combined, zero_division= 0),
                    'GradientBoosting Precision:': precision_score(y_test, y_pred_grb_combined, zero_division= 0),
                    'Tuned GradientBoosting Precision:': precision_score(y_test, y_pred_tuned_grb_combined, zero_division= 0),
                    'XGB Precision:': precision_score(y_test, y_pred_xgb_combined, zero_division= 0),
                    'Tuned XGB Precision:': precision_score(y_test, y_pred_tuned_xgb_combined, zero_division= 0),
                    'LGBM Precision:': precision_score(y_test, y_pred_lgm_combined, zero_division= 0),
                    'Tuned LGBM Precision:': precision_score(y_test, y_pred_tuned_lgm_combined, zero_division= 0),
                    'CatBoost Precision:': precision_score(y_test, y_pred_cat_combined, zero_division= 0),
                    'Tuned CatBoost Precision:': precision_score(y_test, y_pred_tuned_cat_combined, zero_division= 0)
                  }

combined_precision= pd.DataFrame(list(precision_scores.items()), columns= ['Model', 'Precision Score'])
combined_precision= combined_precision.sort_values(by= 'Precision Score', ascending=False)
print(combined_precision)
# Out:
#                                     Model  Precision Score
# 18              Tuned CatBoost Precision:         1.000000
# 12      Tuned GradientBoosting Precision:         1.000000
# 8          Tuned Random Forest Precision:         0.578947
# 0          Logistic Regression Precision:         0.560185
# 4   Tuned KNeighborsClassifier Precision:         0.560000
# 9                     AdaBoost Precision:         0.534799
# 11            GradientBoosting Precision:         0.533654
# 16                  Tuned LGBM Precision:         0.526316
# 10              Tuned AdaBoost Precision:         0.521127
# 17                    CatBoost Precision:         0.510040
# 14                   Tuned XGB Precision:         0.500000
# 15                        LGBM Precision:         0.495192
# 13                         XGB Precision:         0.467085
# 2          Tuned Decision Tree Precision:         0.430556
# 7                Random Forest Precision:         0.426667
# 3         KNeighborsClassifier Precision:         0.364286
# 1                Decision Tree Precision:         0.239024
# 5                   GaussianNB Precision:         0.212112
# 6                          SVM Precision:         0.166667

# %%
accuracy_scores= {
                    'Logistic Regression Accuracy:': accuracy_score(y_test, y_pred_lr_combined),
                    'Decision Tree Accuracy:': accuracy_score(y_test, y_pred_dt_combined),
                    'Tuned Decision Tree Accuracy:': accuracy_score(y_test, y_pred_tuned_dt_combined),
                    'KNeighborsClassifier Accuracy:': accuracy_score(y_test, y_pred_knn_combined),
                    'Tuned KNeighborsClassifier Accuracy:': accuracy_score(y_test, y_pred_tuned_knn_combined),
                    'GaussianNB Accuracy:': accuracy_score(y_test, y_pred_nb_combined),
                    'SVM Accuracy:': accuracy_score(y_test, y_pred_svc_combined),
                    'Random Forest Accuracy:': accuracy_score(y_test, y_pred_rf_combined),
                    'Tuned Random Forest Accuracy:': accuracy_score(y_test, y_pred_tuned_rf_combined),
                    'AdaBoost Accuracy:': accuracy_score(y_test, y_pred_ada_combined),
                    'Tuned AdaBoost Accuracy:': accuracy_score(y_test, y_pred_tuned_ada_combined),
                    'GradientBoosting Accuracy:': accuracy_score(y_test, y_pred_grb_combined),
                    'Tuned GradientBoosting Accuracy:': accuracy_score(y_test, y_pred_tuned_grb_combined),
                    'XGB Accuracy:': accuracy_score(y_test, y_pred_xgb_combined),
                    'Tuned XGB Accuracy:': accuracy_score(y_test, y_pred_tuned_xgb_combined),
                    'LGBM Accuracy:': accuracy_score(y_test, y_pred_lgm_combined),
                    'Tuned LGBM Accuracy:': accuracy_score(y_test, y_pred_tuned_lgm_combined),
                    'CatBoost Accuracy:': accuracy_score(y_test, y_pred_cat_combined),
                    'Tuned CatBoost Accuracy:': accuracy_score(y_test, y_pred_tuned_cat_combined)
                  }

combined_accuracy= pd.DataFrame(list(accuracy_scores.items()), columns= ['Model', 'Accuracy Score'])
combined_accuracy= combined_accuracy.sort_values(by= 'Accuracy Score', ascending=False)
print(combined_accuracy)
# Out:
#                                    Model  Accuracy Score
# 0          Logistic Regression Accuracy:        0.906035
# 9                     AdaBoost Accuracy:        0.905292
# 11            GradientBoosting Accuracy:        0.904762
# 10              Tuned AdaBoost Accuracy:        0.904550
# 16                  Tuned LGBM Accuracy:        0.904550
# 8          Tuned Random Forest Accuracy:        0.904232
# 17                    CatBoost Accuracy:        0.903807
# 4   Tuned KNeighborsClassifier Accuracy:        0.903595
# 18              Tuned CatBoost Accuracy:        0.903489
# 12      Tuned GradientBoosting Accuracy:        0.903383
# 14                   Tuned XGB Accuracy:        0.903277
# 15                        LGBM Accuracy:        0.903065
# 6                          SVM Accuracy:        0.902004
# 2          Tuned Decision Tree Accuracy:        0.901156
# 13                         XGB Accuracy:        0.901050
# 7                Random Forest Accuracy:        0.900944
# 3         KNeighborsClassifier Accuracy:        0.895217
# 1                Decision Tree Accuracy:        0.846537
# 5                   GaussianNB Accuracy:        0.700605

# %%
auc_scores= {
                    'Logistic Regression AUC:': roc_auc_score(y_test, y_pred_prob_lr_combined),
                    'Decision Tree AUC:': roc_auc_score(y_test, y_pred_prob_dt_combined),
                    'Tuned Decision Tree AUC:': roc_auc_score(y_test, y_pred_prob_tuned_dt_combined),
                    'KNeighborsClassifier AUC:': roc_auc_score(y_test, y_pred_prob_knn_combined),
                    'Tuned KNeighborsClassifier AUC:': roc_auc_score(y_test, y_pred_prob_tuned_knn_combined),
                    'GaussianNB AUC:': roc_auc_score(y_test, y_pred_prob_nb_combined),
                    'SVM AUC:': roc_auc_score(y_test, y_pred_prob_svc_combined),
                    'Random Forest AUC:': roc_auc_score(y_test, y_pred_prob_rf_combined),
                    'Tuned Random Forest AUC:': roc_auc_score(y_test, y_pred_prob_tuned_rf_combined),
                    'AdaBoost AUC:': roc_auc_score(y_test, y_pred_prob_ada_combined),
                    'Tuned AdaBoost AUC:': roc_auc_score(y_test, y_pred_prob_tuned_ada_combined),
                    'GradientBoosting AUC:': roc_auc_score(y_test, y_pred_prob_grb_combined),
                    'Tuned GradientBoosting AUC:': roc_auc_score(y_test, y_pred_prob_tuned_grb_combined),
                    'XGB AUC:': roc_auc_score(y_test, y_pred_prob_xgb_combined),
                    'Tuned XGB AUC:': roc_auc_score(y_test, y_pred_prob_tuned_xgb_combined),
                    'LGBM AUC:': roc_auc_score(y_test, y_pred_prob_lgm_combined),
                    'Tuned LGBM AUC:': roc_auc_score(y_test, y_pred_prob_tuned_lgm_combined),
                    'CatBoost AUC:': roc_auc_score(y_test, y_pred_prob_cat_combined),
                    'Tuned CatBoost AUC:': roc_auc_score(y_test, y_pred_prob_tuned_cat_combined)
                  }

combined_auc= pd.DataFrame(list(auc_scores.items()), columns= ['Model', 'AUC Score'])
combined_auc= combined_auc.sort_values(by= 'AUC Score', ascending=False)
print(combined_auc)
# Out:
#                               Model  AUC Score
# 0          Logistic Regression AUC:   0.854134
# 9                     AdaBoost AUC:   0.853293
# 11            GradientBoosting AUC:   0.853279
# 10              Tuned AdaBoost AUC:   0.851915
# 15                        LGBM AUC:   0.849840
# 16                  Tuned LGBM AUC:   0.849110
# 8          Tuned Random Forest AUC:   0.848299
# 17                    CatBoost AUC:   0.848009
# 14                   Tuned XGB AUC:   0.839528
# 13                         XGB AUC:   0.838144
# 12      Tuned GradientBoosting AUC:   0.829749
# 18              Tuned CatBoost AUC:   0.828227
# 7                Random Forest AUC:   0.822360
# 4   Tuned KNeighborsClassifier AUC:   0.813718
# 5                   GaussianNB AUC:   0.805580
# 2          Tuned Decision Tree AUC:   0.802002
# 3         KNeighborsClassifier AUC:   0.702689
# 6                          SVM AUC:   0.696488
# 1                Decision Tree AUC:   0.588169
