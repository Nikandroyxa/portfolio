# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df= pd.read_csv('C://Users//User//Desktop//MSc Westminster//Dissertation//DataSets//Heart_Attack_Prediction.csv')

# %%
columns=df.columns

for column in columns:
    if df[column].dtype=="int32":
        df[column]=df[column].astype("int16")
    elif df[column].dtype=="float64":
        df[column]=df[column].astype("float16")
    elif df[column].dtype=="object":
        df[column]=df[column].astype("category")

# %%
df['Sex']= df['Sex'].map({'Female': 0, 'Male': 1})
df['Sex']= pd.to_numeric(df['Sex'])

df['Diet']= df['Diet'].map({'Healthy': 0, 'Average': 1, 'Unhealthy':2})
df['Diet']= pd.to_numeric(df['Diet'])

df[['HBP', 'LBP']]= df['Blood Pressure'].str.split('/', expand= True)
df['HBP']= pd.to_numeric(df['HBP'])
df['LBP']= pd.to_numeric(df['LBP'])

df['Diabetes'] = df['Diabetes'].map({0: 1, 1: 0})

df['Exercise Hours Per Week']= round(df['Exercise Hours Per Week'], 0)

df['Sedentary Hours Per Day']= round(df['Sedentary Hours Per Day'], 0)

df['Income']= round(df['Income'], 0)

df['BMI']= round(df['BMI'], 0)

df = df.drop(columns=['Patient ID', 'Blood Pressure', 'Country', 'Continent', 'Hemisphere'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Age                              8763 non-null   int64
#  1   Sex                              8763 non-null   int64
#  2   Cholesterol                      8763 non-null   int64
#  3   Heart Rate                       8763 non-null   int64
#  4   Diabetes                         8763 non-null   int64
#  5   Family History                   8763 non-null   int64
#  6   Smoking                          8763 non-null   int64
#  7   Obesity                          8763 non-null   int64
#  8   Alcohol Consumption              8763 non-null   int64
#  9   Exercise Hours Per Week          8763 non-null   float16
#  10  Diet                             8763 non-null   int64
#  11  Previous Heart Problems          8763 non-null   int64
#  12  Medication Use                   8763 non-null   int64
#  13  Stress Level                     8763 non-null   int64
#  14  Sedentary Hours Per Day          8763 non-null   float16
#  15  Income                           8763 non-null   int64
#  16  BMI                              8763 non-null   float16
#  17  Triglycerides                    8763 non-null   int64
#  18  Physical Activity Days Per Week  8763 non-null   int64
#  19  Sleep Hours Per Day              8763 non-null   int64
#  20  Heart Attack Risk                8763 non-null   int64
#  21  HBP                              8763 non-null   int64
#  22  LBP                              8763 non-null   int64
# dtypes: float16(3), int64(20)
# memory usage: 1.4 MB

# %%
df.describe().transpose()
# Out:
#                                   count          mean           std      min  \
# Age                              8763.0  5.370798e+01     21.249509     18.0
# Sex                              8763.0  6.973639e-01      0.459425      0.0
# Cholesterol                      8763.0  2.598772e+02     80.863276    120.0
# Heart Rate                       8763.0  7.502168e+01     20.550948     40.0
# Diabetes                         8763.0  3.477120e-01      0.476271      0.0
# Family History                   8763.0  4.929819e-01      0.499979      0.0
# Smoking                          8763.0  8.968390e-01      0.304186      0.0
# Obesity                          8763.0  5.014265e-01      0.500026      0.0
# Alcohol Consumption              8763.0  5.980828e-01      0.490313      0.0
# Exercise Hours Per Week          8763.0           inf      5.796875      0.0
# Diet                             8763.0  9.921260e-01      0.817134      0.0
# Previous Heart Problems          8763.0  4.958348e-01      0.500011      0.0
# Medication Use                   8763.0  4.983453e-01      0.500026      0.0
# Stress Level                     8763.0  5.469702e+00      2.859622      1.0
# Sedentary Hours Per Day          8763.0  5.992188e+00      3.490234      0.0
# Income                           8763.0  1.582632e+05  80575.190806  20062.0
# BMI                              8763.0           inf      6.328125     18.0
# Triglycerides                    8763.0  4.176771e+02    223.748137     30.0
# Physical Activity Days Per Week  8763.0  3.489672e+00      2.282687      0.0
# Sleep Hours Per Day              8763.0  7.023508e+00      1.988473      4.0
# Heart Attack Risk                8763.0  3.582107e-01      0.479502      0.0
# HBP                              8763.0  1.350757e+02     26.349976     90.0
# LBP                              8763.0  8.515611e+01     14.676565     60.0
#
#                                      25%       50%       75%       max
# Age                                 35.0      54.0      72.0      90.0
# Sex                                  0.0       1.0       1.0       1.0
# Cholesterol                        192.0     259.0     330.0     400.0
# Heart Rate                          57.0      75.0      93.0     110.0
# Diabetes                             0.0       0.0       1.0       1.0
# Family History                       0.0       0.0       1.0       1.0
# Smoking                              1.0       1.0       1.0       1.0
# Obesity                              0.0       1.0       1.0       1.0
# Alcohol Consumption                  0.0       1.0       1.0       1.0
# Exercise Hours Per Week              5.0      10.0      15.0      20.0
# Diet                                 0.0       1.0       2.0       2.0
# Previous Heart Problems              0.0       0.0       1.0       1.0
# Medication Use                       0.0       0.0       1.0       1.0
# Stress Level                         3.0       5.0       8.0      10.0
# Sedentary Hours Per Day              3.0       6.0       9.0      12.0
# Income                           88310.0  157866.0  227749.0  299954.0
# BMI                                 23.0      29.0      34.0      40.0
# Triglycerides                      225.5     417.0     612.0     800.0
# Physical Activity Days Per Week      2.0       3.0       5.0       7.0
# Sleep Hours Per Day                  5.0       7.0       9.0      10.0
# Heart Attack Risk                    0.0       0.0       1.0       1.0
# HBP                                112.0     135.0     158.0     180.0
# LBP                                 72.0      85.0      98.0     110.0

# %%
X= df.drop(['Heart Attack Risk'], axis= 1)
y= df['Heart Attack Risk']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size= 0.2, random_state= 15, stratify= y)

from sklearn.preprocessing import RobustScaler
scaler= RobustScaler()
scaler.fit(X_train)

X_train= scaler.transform(X_train)
X_test= scaler.transform(X_test)

# %%
from imblearn.under_sampling import ClusterCentroids
from imblearn.over_sampling import ADASYN
from sklearn.cluster import KMeans

cc= ClusterCentroids(random_state= 15, estimator= KMeans(n_init= 10))
ada= ADASYN(random_state= 15)

X_cc, y_cc= cc.fit_resample(X_train, y_train)
X_cc_ada, y_cc_ada= ada.fit_resample(X_cc, y_cc)

# %% [markdown]
# --- LogisticRegression ---

# %%
from sklearn.metrics import confusion_matrix, classification_report, precision_score, roc_auc_score, accuracy_score
from sklearn.linear_model import LogisticRegression
lr_cc_ada= LogisticRegression(random_state=15)
lr_cc_ada.fit(X_cc_ada, y_cc_ada)
y_pred_lr_cc_ada= lr_cc_ada.predict(X_test)
y_pred_prob_lr_cc_ada= lr_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_lr_cc_ada, labels= lr_cc_ada.classes_)
print(classification_report(y_test, y_pred_lr_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_lr_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_lr_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_lr_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.46      0.54      1125
#            1       0.35      0.53      0.43       628
#
#     accuracy                           0.49      1753
#    macro avg       0.50      0.50      0.48      1753
# weighted avg       0.54      0.49      0.50      1753
#
# Precision: 0.3546325878594249
# Accuracy: 0.4860239589275528
# AUC: 0.4957940552016985

# %% [markdown]
# --- DecisionTreeClassifier ---

# %%
from sklearn.tree import DecisionTreeClassifier
dt_cc_ada= DecisionTreeClassifier(random_state=15)
dt_cc_ada.fit(X_cc_ada, y_cc_ada)
y_pred_dt_cc_ada= dt_cc_ada.predict(X_test)
y_pred_prob_dt_cc_ada= dt_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_dt_cc_ada, labels= dt_cc_ada.classes_)
print(classification_report(y_test, y_pred_dt_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_dt_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_dt_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_dt_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.40      0.49      1125
#            1       0.35      0.59      0.44       628
#
#     accuracy                           0.47      1753
#    macro avg       0.50      0.50      0.47      1753
# weighted avg       0.54      0.47      0.47      1753
#
# Precision: 0.3547459252157239
# Accuracy: 0.46891043924700515
# AUC: 0.4954748761500354

# %% [markdown]
# --- Tuned - DecisionTreeClassifier ---

# %%
from sklearn.model_selection import GridSearchCV
param_grid= {
             'max_depth': [None, 10, 20, 30, 40, 50],
             'min_samples_split': [2, 10, 20],
             'min_samples_leaf': [1, 5, 10],
             'max_features': [None, 'sqrt', 'log2'],
             'criterion': ['gini', 'entropy']
            }

gs_dt_cc_ada= GridSearchCV(estimator= dt_cc_ada, param_grid= param_grid, cv= 5, scoring= 'precision')
gs_dt_cc_ada.fit(X_cc_ada, y_cc_ada)

print("Best Parameters:", gs_dt_cc_ada.best_params_)
print("Best Precision Score:", gs_dt_cc_ada.best_score_)
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Best Precision Score: 0.6093004135175338

# %%
tuned_dt_cc_ada= gs_dt_cc_ada.best_estimator_
y_pred_tuned_dt_cc_ada= tuned_dt_cc_ada.predict(X_test)
y_pred_prob_tuned_dt_cc_ada= tuned_dt_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_dt_cc_ada, labels= tuned_dt_cc_ada.classes_)
print(classification_report(y_test, y_pred_tuned_dt_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_dt_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_dt_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_dt_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.23      0.34      1125
#            1       0.35      0.75      0.48       628
#
#     accuracy                           0.42      1753
#    macro avg       0.49      0.49      0.41      1753
# weighted avg       0.53      0.42      0.39      1753
#
# Precision: 0.3530291697830965
# Accuracy: 0.41756988020536223
# AUC: 0.4936751592356688

# %% [markdown]
# --- KNeighborsClassifier ---

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_cc_ada= KNeighborsClassifier()
knn_cc_ada.fit(X_cc_ada, y_cc_ada)
y_pred_knn_cc_ada= knn_cc_ada.predict(X_test)
y_pred_prob_knn_cc_ada= knn_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_knn_cc_ada, labels= knn_cc_ada.classes_)
print(classification_report(y_test, y_pred_knn_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_knn_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_knn_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_knn_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.63      0.64      1125
#            1       0.38      0.41      0.39       628
#
#     accuracy                           0.55      1753
#    macro avg       0.52      0.52      0.52      1753
# weighted avg       0.56      0.55      0.55      1753
#
# Precision: 0.3789004457652303
# Accuracy: 0.5487735310895607
# AUC: 0.5051549893842887

# %% [markdown]
# --- Tuned - KNeighborsClassifier ---

# %%
param_grid= {
             'n_neighbors': np.arange(1,40),
             'weights': ['uniform', 'distance'],
             'metric': ['euclidean', 'manhattan', 'minkowski']
            }

gs_knn_cc_ada= GridSearchCV(estimator= knn_cc_ada, param_grid= param_grid, cv=5, scoring= 'precision')
gs_knn_cc_ada.fit(X_cc_ada, y_cc_ada)
print("Best Parameters:", gs_knn_cc_ada.best_params_)
print("Best Precision Score:", gs_knn_cc_ada.best_score_)
# Out:
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 38, 'weights': 'uniform'}
# Best Precision Score: 0.5354433781500635

# %%
tuned_knn_cc_ada= gs_knn_cc_ada.best_estimator_
y_pred_tuned_knn_cc_ada= tuned_knn_cc_ada.predict(X_test)
y_pred_prob_tuned_knn_cc_ada= tuned_knn_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_knn_cc_ada, labels= tuned_knn_cc_ada.classes_)
print(classification_report(y_test, y_pred_tuned_knn_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_knn_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_knn_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_knn_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.48      0.55      1125
#            1       0.36      0.53      0.43       628
#
#     accuracy                           0.50      1753
#    macro avg       0.50      0.50      0.49      1753
# weighted avg       0.54      0.50      0.51      1753
#
# Precision: 0.3616557734204793
# Accuracy: 0.4968625213918996
# AUC: 0.5007898089171975

# %% [markdown]
# --- GaussianNB ---

# %%
from sklearn.naive_bayes import GaussianNB
nb_cc_ada= GaussianNB()
nb_cc_ada.fit(X_cc_ada, y_cc_ada)
y_pred_nb_cc_ada= nb_cc_ada.predict(X_test)
y_pred_prob_nb_cc_ada= nb_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_nb_cc_ada, labels= nb_cc_ada.classes_)
print(classification_report(y_test, y_pred_nb_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_nb_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_nb_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_nb_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.34      0.45      1125
#            1       0.36      0.67      0.47       628
#
#     accuracy                           0.46      1753
#    macro avg       0.51      0.51      0.46      1753
# weighted avg       0.55      0.46      0.45      1753
#
# Precision: 0.36246786632390743
# Accuracy: 0.45864232743867656
# AUC: 0.5029285208775655

# %% [markdown]
# --- SVM ---

# %%
from sklearn.svm import SVC
svc_cc_ada= SVC(kernel= 'rbf',probability= True, gamma= 1, random_state=15)
svc_cc_ada.fit(X_cc_ada, y_cc_ada)
y_pred_svc_cc_ada= svc_cc_ada.predict(X_test)
y_pred_prob_svc_cc_ada= svc_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_svc_cc_ada, labels= svc_cc_ada.classes_)
print(classification_report(y_test, y_pred_svc_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_svc_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_svc_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_svc_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.39      0.49      1125
#            1       0.37      0.64      0.47       628
#
#     accuracy                           0.48      1753
#    macro avg       0.52      0.52      0.48      1753
# weighted avg       0.56      0.48      0.48      1753
#
# Precision: 0.3702677746999077
# Accuracy: 0.4814603536794067
# AUC: 0.514890304317056

# %% [markdown]
# --- Random Forest ---

# %%
from sklearn.ensemble import RandomForestClassifier
rf_cc_ada= RandomForestClassifier(random_state=15)
rf_cc_ada.fit(X_cc_ada, y_cc_ada)
y_pred_rf_cc_ada= rf_cc_ada.predict(X_test)
y_pred_prob_rf_cc_ada= rf_cc_ada.predict_proba(X_test)[:,1]

# %%
cm= confusion_matrix(y_test, y_pred_rf_cc_ada, labels= rf_cc_ada.classes_)
print(classification_report(y_test, y_pred_rf_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_rf_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_rf_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_rf_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.24      0.36      1125
#            1       0.37      0.79      0.50       628
#
#     accuracy                           0.44      1753
#    macro avg       0.52      0.52      0.43      1753
# weighted avg       0.57      0.44      0.41      1753
#
# Precision: 0.3688888888888889
# Accuracy: 0.43981745579007414
# AUC: 0.5315590941259731

# %%
param_grid= {
             'n_estimators': [100, 200, 300],
             'max_depth': [None, 10, 20, 30],
             'min_samples_split': [2, 5, 10],
             'min_samples_leaf': [1, 2, 4],
            }

gs_tuned_rf_cc_ada= GridSearchCV(estimator= rf_cc_ada, param_grid= param_grid, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_tuned_rf_cc_ada.fit(X_cc_ada, y_cc_ada)
print("Best Parameters:", gs_tuned_rf_cc_ada.best_params_)
print("Best Precision Score:", gs_tuned_rf_cc_ada.best_score_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Best Precision Score: 0.6516161672925838

# %%
tuned_rf_cc_ada= gs_tuned_rf_cc_ada.best_estimator_
y_pred_tuned_rf_cc_ada= tuned_rf_cc_ada.predict(X_test)
y_pred_prob_tuned_rf_cc_ada= tuned_rf_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_rf_cc_ada, labels= tuned_rf_cc_ada.classes_)
print(classification_report(y_test, y_pred_tuned_rf_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_rf_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_rf_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_rf_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.20      0.31      1125
#            1       0.37      0.83      0.51       628
#
#     accuracy                           0.43      1753
#    macro avg       0.53      0.52      0.41      1753
# weighted avg       0.57      0.43      0.38      1753
#
# Precision: 0.36779184247538677
# Accuracy: 0.4272675413576726
# AUC: 0.5307501769285209

# %% [markdown]
# --- AdaBoost ---

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_cc_ada= AdaBoostClassifier(random_state=15)
ada_cc_ada.fit(X_cc_ada, y_cc_ada)
y_pred_ada_cc_ada= ada_cc_ada.predict(X_test)
y_pred_prob_ada_cc_ada= ada_cc_ada.predict_proba(X_test)[:,1]

# %%
cm= confusion_matrix(y_test, y_pred_ada_cc_ada, labels= ada_cc_ada.classes_)
print(classification_report(y_test, y_pred_ada_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_ada_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_ada_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_ada_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.24      0.35      1125
#            1       0.36      0.77      0.49       628
#
#     accuracy                           0.43      1753
#    macro avg       0.51      0.51      0.42      1753
# weighted avg       0.55      0.43      0.40      1753
#
# Precision: 0.36227544910179643
# Accuracy: 0.4318311466058186
# AUC: 0.5004536447275301

# %%
param_grid= {'n_estimators': [50, 100, 200]}

gs_ada_cc_ada= GridSearchCV(estimator= ada_cc_ada, param_grid= param_grid, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_ada_cc_ada.fit(X_cc_ada, y_cc_ada)
print("Best Parameters:", gs_ada_cc_ada.best_params_)
print("Best Precision Score:", gs_ada_cc_ada.best_score_)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best Parameters: {'n_estimators': 200}
# Best Precision Score: 0.6590731799160817

# %%
tuned_ada_cc_ada= gs_ada_cc_ada.best_estimator_
y_pred_tuned_ada_cc_ada= tuned_ada_cc_ada.predict(X_test)
y_pred_prob_tuned_ada_cc_ada= tuned_ada_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_ada_cc_ada, labels= tuned_ada_cc_ada.classes_)
print(classification_report(y_test, y_pred_tuned_ada_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_ada_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_ada_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_ada_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.20      0.30      1125
#            1       0.36      0.80      0.49       628
#
#     accuracy                           0.41      1753
#    macro avg       0.50      0.50      0.40      1753
# weighted avg       0.54      0.41      0.37      1753
#
# Precision: 0.35658362989323844
# Accuracy: 0.41186537364517967
# AUC: 0.49108846426043884

# %% [markdown]
# --- GradientBoosting ---

# %%
from sklearn.ensemble import GradientBoostingClassifier
grb_cc_ada= GradientBoostingClassifier(random_state=15)
grb_cc_ada.fit(X_cc_ada, y_cc_ada)
y_pred_grb_cc_ada= grb_cc_ada.predict(X_test)
y_pred_prob_grb_cc_ada= grb_cc_ada.predict_proba(X_test)[:,1]


cm= confusion_matrix(y_test, y_pred_grb_cc_ada, labels= grb_cc_ada.classes_)
print(classification_report(y_test, y_pred_grb_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_grb_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_grb_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_grb_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.13      0.22      1125
#            1       0.36      0.88      0.51       628
#
#     accuracy                           0.40      1753
#    macro avg       0.51      0.51      0.37      1753
# weighted avg       0.55      0.40      0.32      1753
#
# Precision: 0.3612018288700196
# Accuracy: 0.3993154592127781
# AUC: 0.4964062278839349

# %%
param_grid= {'learning_rate': [0.01, 0.1, 0.2]}

gs_grb_cc_ada= GridSearchCV(estimator= grb_cc_ada, param_grid= param_grid, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_grb_cc_ada.fit(X_cc_ada, y_cc_ada)

print("Best Parameters:", gs_grb_cc_ada.best_params_)
print("Best Precision Score:", gs_grb_cc_ada.best_score_)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best Parameters: {'learning_rate': 0.2}
# Best Precision Score: 0.682375263210336

# %%
tuned_grb_cc_ada= gs_grb_cc_ada.best_estimator_
y_pred_tuned_grb_cc_ada= tuned_grb_cc_ada.predict(X_test)
y_pred_prob_tuned_grb_cc_ada= tuned_grb_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_grb_cc_ada, labels= tuned_grb_cc_ada.classes_)
print(classification_report(y_test, y_pred_tuned_grb_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_grb_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_grb_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_grb_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.16      0.26      1125
#            1       0.36      0.85      0.51       628
#
#     accuracy                           0.41      1753
#    macro avg       0.51      0.51      0.39      1753
# weighted avg       0.55      0.41      0.35      1753
#
# Precision: 0.36203389830508476
# Accuracy: 0.40958357102110665
# AUC: 0.49968860580325547

# %% [markdown]
# --- XGB ---

# %%
from xgboost import XGBClassifier
xgb_cc_ada= XGBClassifier(random_state=15)
xgb_cc_ada.fit(X_cc_ada, y_cc_ada)
y_pred_xgb_cc_ada= xgb_cc_ada.predict(X_test)
y_pred_prob_xgb_cc_ada= xgb_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_xgb_cc_ada, labels= xgb_cc_ada.classes_)
print(classification_report(y_test, y_pred_xgb_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_xgb_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_xgb_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_xgb_cc_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.25      0.36      1125
#            1       0.37      0.78      0.50       628
#
#     accuracy                           0.44      1753
#    macro avg       0.52      0.51      0.43      1753
# weighted avg       0.56      0.44      0.41      1753
#
# Precision: 0.36554307116104867
# Accuracy: 0.4369652025099829
# AUC: 0.5009624911535739

# %%
params_XGBoost= {'learning_rate': [0.01, 0.1, 1.0]}

gs_xgb_cc_ada= GridSearchCV(estimator= xgb_cc_ada, param_grid= params_XGBoost, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_xgb_cc_ada.fit(X_cc_ada, y_cc_ada)

print("Best Parameters:", gs_xgb_cc_ada.best_params_)
print("Best Precision Score:", gs_xgb_cc_ada.best_score_)

tuned_xgb_cc_ada= gs_xgb_cc_ada.best_estimator_
y_pred_tuned_xgb_cc_ada= tuned_xgb_cc_ada.predict(X_test)
y_pred_prob_tuned_xgb_cc_ada= tuned_xgb_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_xgb_cc_ada, labels= tuned_xgb_cc_ada.classes_)
print(classification_report(y_test, y_pred_tuned_xgb_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_xgb_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_xgb_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_xgb_cc_ada))
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best Parameters: {'learning_rate': 0.1}
# Best Precision Score: 0.6810592125162939
#               precision    recall  f1-score   support
#
#            0       0.69      0.18      0.29      1125
#            1       0.37      0.85      0.51       628
#
#     accuracy                           0.42      1753
#    macro avg       0.53      0.52      0.40      1753
# weighted avg       0.57      0.42      0.37      1753
#
# Precision: 0.3677685950413223
# Accuracy: 0.4227039361095265
# AUC: 0.5057756546355272

# %% [markdown]
# --- LGBM ---

# %%
from lightgbm import LGBMClassifier
lgm_cc_ada= LGBMClassifier(random_state=15)
lgm_cc_ada.fit(X_cc_ada, y_cc_ada)
y_pred_lgm_cc_ada= lgm_cc_ada.predict(X_test)
y_pred_prob_lgm_cc_ada= lgm_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_lgm_cc_ada, labels= lgm_cc_ada.classes_)
print(classification_report(y_test, y_pred_lgm_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_lgm_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_lgm_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_lgm_cc_ada))
# Out:
# [LightGBM] [Info] Number of positive: 2511, number of negative: 2511
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.035117 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2259
# [LightGBM] [Info] Number of data points in the train set: 5022, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
#               precision    recall  f1-score   support
#
#            0       0.64      0.19      0.29      1125
#            1       0.36      0.81      0.50       628
#
#     accuracy                           0.41      1753
#    macro avg       0.50      0.50      0.39      1753
# weighted avg       0.54      0.41      0.36      1753
#
# Precision: 0.3570422535211268
# Accuracy: 0.41015402167712495
# AUC: 0.4994196744515216

# %%
params_LGB= {'learning_rate': [0.001, 0.01, 0.1, 1.0],
             'num_leaves': [31, 127],
             'reg_alpha': [0.1, 0.5],
             'min_data_in_leaf': [30, 50, 100, 300, 400]}

gs_lgm_cc_ada= GridSearchCV(estimator= lgm_cc_ada, param_grid= params_LGB, cv=5, scoring='precision', n_jobs=-1, verbose=2)
gs_lgm_cc_ada.fit(X_cc_ada, y_cc_ada)

print("Best Parameters:", gs_lgm_cc_ada.best_params_)
print("Best Precision Score:", gs_lgm_cc_ada.best_score_)

tuned_lgm_cc_ada= gs_lgm_cc_ada.best_estimator_
y_pred_tuned_lgm_cc_ada= tuned_lgm_cc_ada.predict(X_test)
y_pred_prob_tuned_lgm_cc_ada= tuned_lgm_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_lgm_cc_ada, labels= tuned_lgm_cc_ada.classes_)
print(classification_report(y_test, y_pred_tuned_lgm_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_lgm_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_lgm_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_lgm_cc_ada))
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Info] Number of positive: 2511, number of negative: 2511
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.063766 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2259
# [LightGBM] [Info] Number of data points in the train set: 5022, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Best Parameters: {'learning_rate': 1.0, 'min_data_in_leaf': 400, 'num_leaves': 31, 'reg_alpha': 0.5}
# Best Precision Score: 0.6808078911098866
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=400
#               precision    recall  f1-score   support
#
#            0       0.63      0.30      0.40      1125
#            1       0.36      0.69      0.47       628
#
#     accuracy                           0.44      1753
#    macro avg       0.49      0.50      0.44      1753
# weighted avg       0.53      0.44      0.43      1753
#
# Precision: 0.3550488599348534
# Accuracy: 0.43867655447803766
# AUC: 0.5010743099787686

# %% [markdown]
# --- CatBoost ---

# %%
from catboost import CatBoostClassifier
cat_cc_ada= CatBoostClassifier(random_state=15)
cat_cc_ada.fit(X_cc_ada, y_cc_ada)
y_pred_cat_cc_ada= cat_cc_ada.predict(X_test)
y_pred_prob_cat_cc_ada= cat_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_cat_cc_ada, labels= cat_cc_ada.classes_)
print(classification_report(y_test, y_pred_cat_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_cat_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_cat_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_cat_cc_ada))
# Out:
# Learning rate set to 0.020521
# 0:	learn: 0.6875346	total: 154ms	remaining: 2m 34s
# 1:	learn: 0.6821820	total: 170ms	remaining: 1m 24s
# 2:	learn: 0.6780490	total: 186ms	remaining: 1m 1s
# 3:	learn: 0.6744670	total: 204ms	remaining: 50.8s
# 4:	learn: 0.6716766	total: 220ms	remaining: 43.9s
# 5:	learn: 0.6679932	total: 234ms	remaining: 38.8s
# 6:	learn: 0.6651857	total: 249ms	remaining: 35.3s
# 7:	learn: 0.6619761	total: 264ms	remaining: 32.7s
# 8:	learn: 0.6584363	total: 282ms	remaining: 31s
# 9:	learn: 0.6560422	total: 299ms	remaining: 29.6s
# 10:	learn: 0.6535808	total: 313ms	remaining: 28.1s
# 11:	learn: 0.6517033	total: 327ms	remaining: 26.9s
# 12:	learn: 0.6497055	total: 346ms	remaining: 26.3s
# 13:	learn: 0.6454030	total: 360ms	remaining: 25.3s
# 14:	learn: 0.6410719	total: 374ms	remaining: 24.6s
# 15:	learn: 0.6384602	total: 399ms	remaining: 24.6s
# 16:	learn: 0.6358159	total: 420ms	remaining: 24.3s
# 17:	learn: 0.6326414	total: 441ms	remaining: 24.1s
# 18:	learn: 0.6309296	total: 458ms	remaining: 23.7s
# 19:	learn: 0.6296053	total: 472ms	remaining: 23.1s
# 20:	learn: 0.6269074	total: 489ms	remaining: 22.8s
# 21:	learn: 0.6236885	total: 508ms	remaining: 22.6s
# 22:	learn: 0.6222992	total: 531ms	remaining: 22.5s
# 23:	learn: 0.6196374	total: 545ms	remaining: 22.1s
# 24:	learn: 0.6183198	total: 557ms	remaining: 21.7s
# 25:	learn: 0.6160490	total: 572ms	remaining: 21.4s
# 26:	learn: 0.6146152	total: 587ms	remaining: 21.1s
# 27:	learn: 0.6123086	total: 600ms	remaining: 20.8s
# 28:	learn: 0.6102872	total: 617ms	remaining: 20.7s
# 29:	learn: 0.6078786	total: 632ms	remaining: 20.4s
# 30:	learn: 0.6069299	total: 648ms	remaining: 20.3s
# 31:	learn: 0.6048642	total: 664ms	remaining: 20.1s
# 32:	learn: 0.6026636	total: 681ms	remaining: 19.9s
# 33:	learn: 0.6016272	total: 693ms	remaining: 19.7s
# 34:	learn: 0.6010985	total: 705ms	remaining: 19.4s
# 35:	learn: 0.5999272	total: 714ms	remaining: 19.1s
# 36:	learn: 0.5985026	total: 728ms	remaining: 18.9s
# 37:	learn: 0.5968305	total: 740ms	remaining: 18.7s
# 38:	learn: 0.5952884	total: 754ms	remaining: 18.6s
# 39:	learn: 0.5928489	total: 767ms	remaining: 18.4s
# 40:	learn: 0.5914164	total: 782ms	remaining: 18.3s
# 41:	learn: 0.5902140	total: 798ms	remaining: 18.2s
# 42:	learn: 0.5898085	total: 811ms	remaining: 18.1s
# 43:	learn: 0.5886958	total: 824ms	remaining: 17.9s
# 44:	learn: 0.5880031	total: 835ms	remaining: 17.7s
# 45:	learn: 0.5869941	total: 849ms	remaining: 17.6s
# 46:	learn: 0.5851131	total: 864ms	remaining: 17.5s
# 47:	learn: 0.5841371	total: 880ms	remaining: 17.5s
# 48:	learn: 0.5835047	total: 893ms	remaining: 17.3s
# 49:	learn: 0.5830980	total: 909ms	remaining: 17.3s
# 50:	learn: 0.5814371	total: 922ms	remaining: 17.2s
# 51:	learn: 0.5809101	total: 935ms	remaining: 17s
# 52:	learn: 0.5804175	total: 950ms	remaining: 17s
# 53:	learn: 0.5797705	total: 964ms	remaining: 16.9s
# 54:	learn: 0.5792379	total: 979ms	remaining: 16.8s
# 55:	learn: 0.5764316	total: 995ms	remaining: 16.8s
# 56:	learn: 0.5750198	total: 1.01s	remaining: 16.7s
# 57:	learn: 0.5744903	total: 1.03s	remaining: 16.7s
# 58:	learn: 0.5740417	total: 1.04s	remaining: 16.6s
# 59:	learn: 0.5728780	total: 1.05s	remaining: 16.5s
# 60:	learn: 0.5724484	total: 1.07s	remaining: 16.4s
# 61:	learn: 0.5720596	total: 1.08s	remaining: 16.4s
# 62:	learn: 0.5716984	total: 1.1s	remaining: 16.3s
# 63:	learn: 0.5712662	total: 1.11s	remaining: 16.3s
# 64:	learn: 0.5705680	total: 1.13s	remaining: 16.2s
# 65:	learn: 0.5698944	total: 1.14s	remaining: 16.2s
# 66:	learn: 0.5694699	total: 1.16s	remaining: 16.1s
# 67:	learn: 0.5686842	total: 1.17s	remaining: 16s
# 68:	learn: 0.5680759	total: 1.19s	remaining: 16s
# 69:	learn: 0.5676757	total: 1.2s	remaining: 15.9s
# 70:	learn: 0.5672393	total: 1.21s	remaining: 15.9s
# 71:	learn: 0.5664279	total: 1.23s	remaining: 15.8s
# 72:	learn: 0.5656694	total: 1.24s	remaining: 15.8s
# 73:	learn: 0.5635744	total: 1.26s	remaining: 15.8s
# 74:	learn: 0.5624365	total: 1.27s	remaining: 15.7s
# 75:	learn: 0.5620169	total: 1.29s	remaining: 15.6s
# 76:	learn: 0.5615544	total: 1.3s	remaining: 15.6s
# 77:	learn: 0.5606372	total: 1.31s	remaining: 15.5s
# 78:	learn: 0.5601553	total: 1.33s	remaining: 15.5s
# 79:	learn: 0.5598284	total: 1.34s	remaining: 15.4s
# 80:	learn: 0.5595127	total: 1.35s	remaining: 15.4s
# 81:	learn: 0.5583907	total: 1.37s	remaining: 15.3s
# 82:	learn: 0.5579554	total: 1.38s	remaining: 15.2s
# 83:	learn: 0.5576099	total: 1.39s	remaining: 15.2s
# 84:	learn: 0.5569568	total: 1.41s	remaining: 15.1s
# 85:	learn: 0.5567060	total: 1.42s	remaining: 15.1s
# 86:	learn: 0.5561125	total: 1.44s	remaining: 15.1s
# 87:	learn: 0.5554686	total: 1.45s	remaining: 15s
# 88:	learn: 0.5550948	total: 1.47s	remaining: 15s
# 89:	learn: 0.5543310	total: 1.48s	remaining: 15s
# 90:	learn: 0.5534979	total: 1.49s	remaining: 14.9s
# 91:	learn: 0.5530983	total: 1.51s	remaining: 14.9s
# 92:	learn: 0.5526979	total: 1.52s	remaining: 14.9s
# 93:	learn: 0.5521071	total: 1.54s	remaining: 14.8s
# 94:	learn: 0.5514560	total: 1.55s	remaining: 14.8s
# 95:	learn: 0.5510992	total: 1.57s	remaining: 14.8s
# 96:	learn: 0.5506364	total: 1.58s	remaining: 14.7s
# 97:	learn: 0.5497046	total: 1.6s	remaining: 14.7s
# 98:	learn: 0.5493366	total: 1.61s	remaining: 14.7s
# 99:	learn: 0.5489547	total: 1.62s	remaining: 14.6s
# 100:	learn: 0.5487153	total: 1.64s	remaining: 14.6s
# 101:	learn: 0.5483570	total: 1.65s	remaining: 14.5s
# 102:	learn: 0.5478948	total: 1.66s	remaining: 14.5s
# 103:	learn: 0.5475246	total: 1.68s	remaining: 14.5s
# 104:	learn: 0.5466010	total: 1.69s	remaining: 14.4s
# 105:	learn: 0.5459881	total: 1.71s	remaining: 14.4s
# 106:	learn: 0.5454831	total: 1.73s	remaining: 14.4s
# 107:	learn: 0.5447538	total: 1.74s	remaining: 14.4s
# 108:	learn: 0.5439813	total: 1.76s	remaining: 14.4s
# 109:	learn: 0.5435416	total: 1.77s	remaining: 14.3s
# 110:	learn: 0.5432759	total: 1.78s	remaining: 14.3s
# 111:	learn: 0.5428043	total: 1.8s	remaining: 14.3s
# 112:	learn: 0.5420590	total: 1.81s	remaining: 14.2s
# 113:	learn: 0.5413569	total: 1.83s	remaining: 14.2s
# 114:	learn: 0.5409427	total: 1.84s	remaining: 14.2s
# 115:	learn: 0.5402149	total: 1.86s	remaining: 14.2s
# 116:	learn: 0.5399415	total: 1.87s	remaining: 14.1s
# 117:	learn: 0.5396911	total: 1.88s	remaining: 14.1s
# 773:	learn: 0.3626309	total: 9.84s	remaining: 2.87s
# 774:	learn: 0.3622793	total: 9.85s	remaining: 2.86s
# 775:	learn: 0.3620309	total: 9.86s	remaining: 2.85s
# 776:	learn: 0.3618487	total: 9.87s	remaining: 2.83s
# 777:	learn: 0.3616584	total: 9.88s	remaining: 2.82s
# 778:	learn: 0.3614166	total: 9.89s	remaining: 2.8s
# 779:	learn: 0.3611571	total: 9.9s	remaining: 2.79s
# 780:	learn: 0.3609750	total: 9.91s	remaining: 2.78s
# 781:	learn: 0.3607716	total: 9.91s	remaining: 2.76s
# 782:	learn: 0.3605257	total: 9.92s	remaining: 2.75s
# 783:	learn: 0.3601708	total: 9.93s	remaining: 2.74s
# 784:	learn: 0.3599645	total: 9.94s	remaining: 2.72s
# 785:	learn: 0.3598260	total: 9.95s	remaining: 2.71s
# 786:	learn: 0.3595856	total: 9.96s	remaining: 2.7s
# 787:	learn: 0.3593719	total: 9.97s	remaining: 2.68s
# 788:	learn: 0.3591468	total: 9.98s	remaining: 2.67s
# 789:	learn: 0.3589769	total: 9.99s	remaining: 2.66s
# 790:	learn: 0.3588056	total: 10s	remaining: 2.64s
# 791:	learn: 0.3586282	total: 10s	remaining: 2.63s
# 792:	learn: 0.3584556	total: 10s	remaining: 2.62s
# 793:	learn: 0.3583015	total: 10s	remaining: 2.6s
# 794:	learn: 0.3581505	total: 10s	remaining: 2.59s
# 795:	learn: 0.3579907	total: 10.1s	remaining: 2.58s
# 796:	learn: 0.3578522	total: 10.1s	remaining: 2.56s
# 797:	learn: 0.3576068	total: 10.1s	remaining: 2.55s
# 798:	learn: 0.3574556	total: 10.1s	remaining: 2.54s
# 799:	learn: 0.3572281	total: 10.1s	remaining: 2.52s
# 800:	learn: 0.3570138	total: 10.1s	remaining: 2.51s
# 801:	learn: 0.3567997	total: 10.1s	remaining: 2.5s
# 802:	learn: 0.3566110	total: 10.1s	remaining: 2.49s
# 803:	learn: 0.3563864	total: 10.1s	remaining: 2.47s
# 804:	learn: 0.3562003	total: 10.2s	remaining: 2.46s
# 805:	learn: 0.3559796	total: 10.2s	remaining: 2.45s
# 806:	learn: 0.3557219	total: 10.2s	remaining: 2.43s
# 807:	learn: 0.3555682	total: 10.2s	remaining: 2.42s
# 808:	learn: 0.3554193	total: 10.2s	remaining: 2.41s
# 809:	learn: 0.3552175	total: 10.2s	remaining: 2.4s
# 810:	learn: 0.3549632	total: 10.2s	remaining: 2.38s
# 811:	learn: 0.3547130	total: 10.2s	remaining: 2.37s
# 812:	learn: 0.3544892	total: 10.2s	remaining: 2.36s
# 813:	learn: 0.3543087	total: 10.3s	remaining: 2.34s
# 814:	learn: 0.3540908	total: 10.3s	remaining: 2.33s
# 815:	learn: 0.3539591	total: 10.3s	remaining: 2.32s
# 816:	learn: 0.3537261	total: 10.3s	remaining: 2.3s
# 817:	learn: 0.3534959	total: 10.3s	remaining: 2.29s
# 818:	learn: 0.3533491	total: 10.3s	remaining: 2.28s
# 819:	learn: 0.3531381	total: 10.3s	remaining: 2.26s
# 820:	learn: 0.3529379	total: 10.3s	remaining: 2.25s
# 821:	learn: 0.3527470	total: 10.3s	remaining: 2.24s
# 822:	learn: 0.3525536	total: 10.3s	remaining: 2.22s
# 823:	learn: 0.3523627	total: 10.3s	remaining: 2.21s
# 824:	learn: 0.3520992	total: 10.4s	remaining: 2.2s
# 825:	learn: 0.3518525	total: 10.4s	remaining: 2.18s
# 826:	learn: 0.3516122	total: 10.4s	remaining: 2.17s
# 827:	learn: 0.3514038	total: 10.4s	remaining: 2.16s
# 828:	learn: 0.3512240	total: 10.4s	remaining: 2.14s
# 829:	learn: 0.3510289	total: 10.4s	remaining: 2.13s
# 830:	learn: 0.3508172	total: 10.4s	remaining: 2.12s
# 831:	learn: 0.3505932	total: 10.4s	remaining: 2.1s
# 832:	learn: 0.3504225	total: 10.4s	remaining: 2.09s
# 833:	learn: 0.3502404	total: 10.4s	remaining: 2.08s
# 834:	learn: 0.3500208	total: 10.5s	remaining: 2.06s
# 835:	learn: 0.3497706	total: 10.5s	remaining: 2.05s
# 836:	learn: 0.3495328	total: 10.5s	remaining: 2.04s
# 837:	learn: 0.3493143	total: 10.5s	remaining: 2.02s
# 838:	learn: 0.3491505	total: 10.5s	remaining: 2.01s
# 839:	learn: 0.3489542	total: 10.5s	remaining: 2s
# 840:	learn: 0.3487784	total: 10.5s	remaining: 1.99s
# 841:	learn: 0.3485801	total: 10.5s	remaining: 1.97s
# 842:	learn: 0.3483524	total: 10.5s	remaining: 1.96s
# 843:	learn: 0.3482254	total: 10.5s	remaining: 1.95s
# 844:	learn: 0.3480651	total: 10.5s	remaining: 1.93s
# 845:	learn: 0.3478611	total: 10.6s	remaining: 1.92s
# 846:	learn: 0.3476407	total: 10.6s	remaining: 1.91s
# 847:	learn: 0.3474613	total: 10.6s	remaining: 1.89s
# 848:	learn: 0.3472319	total: 10.6s	remaining: 1.88s
# 849:	learn: 0.3470045	total: 10.6s	remaining: 1.87s
# 850:	learn: 0.3468307	total: 10.6s	remaining: 1.85s
# 851:	learn: 0.3466555	total: 10.6s	remaining: 1.84s
# 852:	learn: 0.3465281	total: 10.6s	remaining: 1.83s
# 853:	learn: 0.3463607	total: 10.6s	remaining: 1.82s
# 854:	learn: 0.3461883	total: 10.6s	remaining: 1.8s
# 855:	learn: 0.3460236	total: 10.6s	remaining: 1.79s
# 856:	learn: 0.3458096	total: 10.7s	remaining: 1.78s
# 857:	learn: 0.3456877	total: 10.7s	remaining: 1.76s
# 858:	learn: 0.3455192	total: 10.7s	remaining: 1.75s
# 859:	learn: 0.3453001	total: 10.7s	remaining: 1.74s
# 860:	learn: 0.3451339	total: 10.7s	remaining: 1.73s
# 861:	learn: 0.3449601	total: 10.7s	remaining: 1.71s
# 862:	learn: 0.3447903	total: 10.7s	remaining: 1.7s
# 863:	learn: 0.3444539	total: 10.7s	remaining: 1.69s
# 864:	learn: 0.3442624	total: 10.7s	remaining: 1.68s
# 865:	learn: 0.3441546	total: 10.7s	remaining: 1.66s
# 866:	learn: 0.3439591	total: 10.8s	remaining: 1.65s
# 867:	learn: 0.3437894	total: 10.8s	remaining: 1.64s
# 868:	learn: 0.3435199	total: 10.8s	remaining: 1.62s
# 869:	learn: 0.3433256	total: 10.8s	remaining: 1.61s
# 870:	learn: 0.3431237	total: 10.8s	remaining: 1.6s
# 871:	learn: 0.3429495	total: 10.8s	remaining: 1.58s
# 872:	learn: 0.3427331	total: 10.8s	remaining: 1.57s
# 873:	learn: 0.3425253	total: 10.8s	remaining: 1.56s
# 874:	learn: 0.3423250	total: 10.8s	remaining: 1.55s
# 875:	learn: 0.3421308	total: 10.8s	remaining: 1.53s
# 876:	learn: 0.3419208	total: 10.8s	remaining: 1.52s
# 877:	learn: 0.3417382	total: 10.9s	remaining: 1.51s
# 878:	learn: 0.3415601	total: 10.9s	remaining: 1.5s
# 879:	learn: 0.3413361	total: 10.9s	remaining: 1.48s
# 880:	learn: 0.3410347	total: 10.9s	remaining: 1.47s
# 881:	learn: 0.3407943	total: 10.9s	remaining: 1.46s
# 882:	learn: 0.3406372	total: 10.9s	remaining: 1.44s
# 883:	learn: 0.3404760	total: 10.9s	remaining: 1.43s
# 884:	learn: 0.3402815	total: 10.9s	remaining: 1.42s
# 885:	learn: 0.3400753	total: 10.9s	remaining: 1.41s
# 886:	learn: 0.3399117	total: 10.9s	remaining: 1.39s
# 887:	learn: 0.3397338	total: 10.9s	remaining: 1.38s
# 888:	learn: 0.3395135	total: 11s	remaining: 1.37s
# 889:	learn: 0.3393601	total: 11s	remaining: 1.35s
# 890:	learn: 0.3392261	total: 11s	remaining: 1.34s
# 891:	learn: 0.3390418	total: 11s	remaining: 1.33s
# 892:	learn: 0.3388241	total: 11s	remaining: 1.32s
# 893:	learn: 0.3386075	total: 11s	remaining: 1.3s
# 894:	learn: 0.3384083	total: 11s	remaining: 1.29s
# 895:	learn: 0.3382172	total: 11s	remaining: 1.28s
# 896:	learn: 0.3380568	total: 11s	remaining: 1.27s
# 897:	learn: 0.3378707	total: 11s	remaining: 1.25s
# 898:	learn: 0.3377327	total: 11s	remaining: 1.24s
# 899:	learn: 0.3375198	total: 11.1s	remaining: 1.23s
# 900:	learn: 0.3373394	total: 11.1s	remaining: 1.22s
# 901:	learn: 0.3371680	total: 11.1s	remaining: 1.2s
# 902:	learn: 0.3370014	total: 11.1s	remaining: 1.19s
# 903:	learn: 0.3368543	total: 11.1s	remaining: 1.18s
# 904:	learn: 0.3366069	total: 11.1s	remaining: 1.17s
# 905:	learn: 0.3364744	total: 11.1s	remaining: 1.15s
# 906:	learn: 0.3362706	total: 11.1s	remaining: 1.14s
# 907:	learn: 0.3361193	total: 11.1s	remaining: 1.13s
# 908:	learn: 0.3359128	total: 11.1s	remaining: 1.11s
# 909:	learn: 0.3356645	total: 11.2s	remaining: 1.1s
# 910:	learn: 0.3354613	total: 11.2s	remaining: 1.09s
# 911:	learn: 0.3353228	total: 11.2s	remaining: 1.08s
# 912:	learn: 0.3351521	total: 11.2s	remaining: 1.06s
# 913:	learn: 0.3349624	total: 11.2s	remaining: 1.05s
# 962:	learn: 0.3258361	total: 11.9s	remaining: 456ms
# 963:	learn: 0.3257010	total: 11.9s	remaining: 444ms
# 964:	learn: 0.3254951	total: 11.9s	remaining: 432ms
# 965:	learn: 0.3252880	total: 11.9s	remaining: 420ms
# 966:	learn: 0.3251688	total: 11.9s	remaining: 407ms
# 967:	learn: 0.3250201	total: 12s	remaining: 395ms
# 968:	learn: 0.3248566	total: 12s	remaining: 383ms
# 969:	learn: 0.3247489	total: 12s	remaining: 371ms
# 970:	learn: 0.3245964	total: 12s	remaining: 359ms
# 971:	learn: 0.3244386	total: 12s	remaining: 346ms
# 972:	learn: 0.3242923	total: 12s	remaining: 334ms
# 973:	learn: 0.3239699	total: 12.1s	remaining: 322ms
# 974:	learn: 0.3237368	total: 12.1s	remaining: 309ms
# 975:	learn: 0.3235409	total: 12.1s	remaining: 297ms
# 976:	learn: 0.3233743	total: 12.1s	remaining: 285ms
# 977:	learn: 0.3231885	total: 12.1s	remaining: 273ms
# 978:	learn: 0.3229982	total: 12.1s	remaining: 260ms
# 979:	learn: 0.3228427	total: 12.2s	remaining: 248ms
# 980:	learn: 0.3226577	total: 12.2s	remaining: 236ms
# 981:	learn: 0.3225220	total: 12.2s	remaining: 223ms
# 982:	learn: 0.3223519	total: 12.2s	remaining: 211ms
# 983:	learn: 0.3221596	total: 12.2s	remaining: 199ms
# 984:	learn: 0.3220284	total: 12.2s	remaining: 186ms
# 985:	learn: 0.3217415	total: 12.2s	remaining: 174ms
# 986:	learn: 0.3216098	total: 12.3s	remaining: 162ms
# 987:	learn: 0.3213672	total: 12.3s	remaining: 149ms
# 988:	learn: 0.3211813	total: 12.3s	remaining: 137ms
# 989:	learn: 0.3210053	total: 12.3s	remaining: 124ms
# 990:	learn: 0.3208782	total: 12.3s	remaining: 112ms
# 991:	learn: 0.3206801	total: 12.3s	remaining: 99.5ms
# 992:	learn: 0.3205096	total: 12.4s	remaining: 87.1ms
# 993:	learn: 0.3203151	total: 12.4s	remaining: 74.6ms
# 994:	learn: 0.3201775	total: 12.4s	remaining: 62.2ms
# 995:	learn: 0.3200193	total: 12.4s	remaining: 49.8ms
# 996:	learn: 0.3198078	total: 12.4s	remaining: 37.3ms
# 997:	learn: 0.3196601	total: 12.4s	remaining: 24.9ms
# 998:	learn: 0.3195550	total: 12.4s	remaining: 12.4ms
# 999:	learn: 0.3193310	total: 12.4s	remaining: 0us
#               precision    recall  f1-score   support
#
#            0       0.64      0.15      0.24      1125
#            1       0.36      0.85      0.50       628
#
#     accuracy                           0.40      1753
#    macro avg       0.50      0.50      0.37      1753
# weighted avg       0.54      0.40      0.33      1753
#
# Precision: 0.35719063545150503
# Accuracy: 0.3981745579007416
# AUC: 0.5020297239915075

# %%
params_CatBoost= {
                  'depth': [3,5,10],
                  'learning_rate' : [0.01,0.1,1],
                  'iterations' : [5,10,50,100]
                 }

gs_cat_cc_ada= GridSearchCV(estimator= cat_cc_ada, param_grid= params_CatBoost, cv=5, scoring='precision', n_jobs=-1, verbose=2)
gs_cat_cc_ada.fit(X_cc_ada, y_cc_ada)

print("Best Parameters:", gs_cat_cc_ada.best_params_)
print("Best Precision Score:", gs_cat_cc_ada.best_score_)

tuned_cat_cc_ada= gs_cat_cc_ada.best_estimator_
y_pred_tuned_cat_cc_ada= tuned_cat_cc_ada.predict(X_test)
y_pred_prob_tuned_cat_cc_ada= tuned_cat_cc_ada.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_cat_cc_ada, labels= tuned_cat_cc_ada.classes_)
print(classification_report(y_test, y_pred_tuned_cat_cc_ada, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_cat_cc_ada, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_cat_cc_ada))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_cat_cc_ada))
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# 0:	learn: 0.6420712	total: 5.07ms	remaining: 502ms
# 1:	learn: 0.6057058	total: 10.3ms	remaining: 505ms
# 2:	learn: 0.5947583	total: 14.8ms	remaining: 480ms
# 3:	learn: 0.5619598	total: 21ms	remaining: 505ms
# 4:	learn: 0.5570645	total: 26ms	remaining: 494ms
# 5:	learn: 0.5459694	total: 29.8ms	remaining: 467ms
# 6:	learn: 0.5427322	total: 34.7ms	remaining: 461ms
# 7:	learn: 0.5394417	total: 39.2ms	remaining: 450ms
# 8:	learn: 0.5376021	total: 44.3ms	remaining: 448ms
# 9:	learn: 0.5342235	total: 49.1ms	remaining: 442ms
# 10:	learn: 0.5311242	total: 52.8ms	remaining: 427ms
# 11:	learn: 0.5276281	total: 59.2ms	remaining: 434ms
# 12:	learn: 0.5252162	total: 63.2ms	remaining: 423ms
# 13:	learn: 0.5186864	total: 67.5ms	remaining: 415ms
# 14:	learn: 0.5159267	total: 73.2ms	remaining: 415ms
# 15:	learn: 0.5138667	total: 78.3ms	remaining: 411ms
# 16:	learn: 0.5050812	total: 83ms	remaining: 405ms
# 17:	learn: 0.5030745	total: 88.6ms	remaining: 403ms
# 18:	learn: 0.5004487	total: 94.2ms	remaining: 402ms
# 19:	learn: 0.4967515	total: 98.9ms	remaining: 396ms
# 20:	learn: 0.4942725	total: 104ms	remaining: 390ms
# 21:	learn: 0.4921627	total: 109ms	remaining: 386ms
# 22:	learn: 0.4855535	total: 114ms	remaining: 382ms
# 23:	learn: 0.4829731	total: 120ms	remaining: 379ms
# 24:	learn: 0.4806302	total: 124ms	remaining: 373ms
# 25:	learn: 0.4788027	total: 130ms	remaining: 369ms
# 26:	learn: 0.4744247	total: 135ms	remaining: 365ms
# 27:	learn: 0.4731591	total: 139ms	remaining: 359ms
# 28:	learn: 0.4715265	total: 144ms	remaining: 352ms
# 29:	learn: 0.4695050	total: 152ms	remaining: 354ms
# 30:	learn: 0.4678204	total: 156ms	remaining: 348ms
# 31:	learn: 0.4642471	total: 161ms	remaining: 342ms
# 32:	learn: 0.4622056	total: 169ms	remaining: 343ms
# 33:	learn: 0.4578000	total: 174ms	remaining: 337ms
# 34:	learn: 0.4554010	total: 179ms	remaining: 333ms
# 35:	learn: 0.4532590	total: 185ms	remaining: 329ms
# 86:	learn: 0.3534526	total: 437ms	remaining: 65.2ms
# 87:	learn: 0.3521835	total: 442ms	remaining: 60.3ms
# 88:	learn: 0.3504132	total: 447ms	remaining: 55.3ms
# 89:	learn: 0.3490469	total: 451ms	remaining: 50.1ms
# 90:	learn: 0.3471247	total: 456ms	remaining: 45.1ms
# 91:	learn: 0.3458036	total: 461ms	remaining: 40.1ms
# 92:	learn: 0.3442535	total: 465ms	remaining: 35ms
# 93:	learn: 0.3426541	total: 469ms	remaining: 30ms
# 94:	learn: 0.3410839	total: 476ms	remaining: 25ms
# 95:	learn: 0.3392090	total: 482ms	remaining: 20.1ms
# 96:	learn: 0.3376264	total: 489ms	remaining: 15.1ms
# 97:	learn: 0.3366872	total: 494ms	remaining: 10.1ms
# 98:	learn: 0.3355351	total: 500ms	remaining: 5.05ms
# 99:	learn: 0.3339567	total: 506ms	remaining: 0us
# Best Parameters: {'depth': 3, 'iterations': 100, 'learning_rate': 1}
# Best Precision Score: 0.6748096569469108
#               precision    recall  f1-score   support
#
#            0       0.64      0.26      0.37      1125
#            1       0.36      0.74      0.48       628
#
#     accuracy                           0.43      1753
#    macro avg       0.50      0.50      0.43      1753
# weighted avg       0.54      0.43      0.41      1753
#
# Precision: 0.35895465026902384
# Accuracy: 0.43240159726183686
# AUC: 0.4929384288747346

# %% [markdown]
# --- Visualisation ---

# %%
print('Logistic Regression Precision:', precision_score(y_test, y_pred_lr_cc_ada, zero_division= 0))
print('Decision Tree Precision:', precision_score(y_test, y_pred_dt_cc_ada, zero_division= 0))
print('Tuned Decision Tree Precision:', precision_score(y_test, y_pred_tuned_dt_cc_ada, zero_division= 0))
print('KNeighborsClassifier Precision:', precision_score(y_test, y_pred_knn_cc_ada, zero_division= 0))
print('Tuned KNeighborsClassifier Precision:', precision_score(y_test, y_pred_tuned_knn_cc_ada, zero_division= 0))
print('GaussianNB Precision:', precision_score(y_test, y_pred_nb_cc_ada, zero_division= 0))
print('SVM Precision:', precision_score(y_test, y_pred_svc_cc_ada, zero_division= 0))
print('Random Forest Precision:', precision_score(y_test, y_pred_rf_cc_ada, zero_division= 0))
print('Tuned Random Forest Precision:', precision_score(y_test, y_pred_tuned_rf_cc_ada, zero_division= 0))
print('AdaBoost Precision:', precision_score(y_test, y_pred_ada_cc_ada, zero_division= 0))
print('Tuned AdaBoost Precision:', precision_score(y_test, y_pred_tuned_ada_cc_ada, zero_division= 0))
print('GradientBoosting Precision:', precision_score(y_test, y_pred_grb_cc_ada, zero_division= 0))
print('Tuned GradientBoosting Precision:', precision_score(y_test, y_pred_tuned_grb_cc_ada, zero_division= 0))
print('XGB Precision:', precision_score(y_test, y_pred_xgb_cc_ada, zero_division= 0))
print('Tuned XGB Precision:', precision_score(y_test, y_pred_tuned_xgb_cc_ada, zero_division= 0))
print('LGBM Precision:', precision_score(y_test, y_pred_lgm_cc_ada, zero_division= 0))
print('Tuned LGBM Precision:', precision_score(y_test, y_pred_tuned_lgm_cc_ada, zero_division= 0))
print('CatBoost Precision:', precision_score(y_test, y_pred_cat_cc_ada, zero_division= 0))
print('Tuned CatBoost Precision:', precision_score(y_test, y_pred_tuned_cat_cc_ada, zero_division= 0))
# Out:
# Logistic Regression Precision: 0.3546325878594249
# Decision Tree Precision: 0.3547459252157239
# Tuned Decision Tree Precision: 0.3530291697830965
# KNeighborsClassifier Precision: 0.3789004457652303
# Tuned KNeighborsClassifier Precision: 0.3616557734204793
# GaussianNB Precision: 0.36246786632390743
# SVM Precision: 0.3702677746999077
# Random Forest Precision: 0.3688888888888889
# Tuned Random Forest Precision: 0.36779184247538677
# AdaBoost Precision: 0.36227544910179643
# Tuned AdaBoost Precision: 0.35658362989323844
# GradientBoosting Precision: 0.3612018288700196
# Tuned GradientBoosting Precision: 0.36203389830508476
# XGB Precision: 0.36554307116104867
# Tuned XGB Precision: 0.3677685950413223
# LGBM Precision: 0.3570422535211268
# Tuned LGBM Precision: 0.3550488599348534
# CatBoost Precision: 0.35719063545150503
# Tuned CatBoost Precision: 0.35895465026902384

# %%
precision_scores= {
                    'Logistic Regression Precision:': precision_score(y_test, y_pred_lr_cc_ada, zero_division= 0),
                    'Decision Tree Precision:': precision_score(y_test, y_pred_dt_cc_ada, zero_division= 0),
                    'Tuned Decision Tree Precision:': precision_score(y_test, y_pred_tuned_dt_cc_ada, zero_division= 0),
                    'KNeighborsClassifier Precision:': precision_score(y_test, y_pred_knn_cc_ada, zero_division= 0),
                    'Tuned KNeighborsClassifier Precision:': precision_score(y_test, y_pred_tuned_knn_cc_ada, zero_division= 0),
                    'GaussianNB Precision:': precision_score(y_test, y_pred_nb_cc_ada, zero_division= 0),
                    'SVM Precision:': precision_score(y_test, y_pred_svc_cc_ada, zero_division= 0),
                    'Random Forest Precision:': precision_score(y_test, y_pred_rf_cc_ada, zero_division= 0),
                    'Tuned Random Forest Precision:': precision_score(y_test, y_pred_tuned_rf_cc_ada, zero_division= 0),
                    'AdaBoost Precision:': precision_score(y_test, y_pred_ada_cc_ada, zero_division= 0),
                    'Tuned AdaBoost Precision:': precision_score(y_test, y_pred_tuned_ada_cc_ada, zero_division= 0),
                    'GradientBoosting Precision:': precision_score(y_test, y_pred_grb_cc_ada, zero_division= 0),
                    'Tuned GradientBoosting Precision:': precision_score(y_test, y_pred_tuned_grb_cc_ada, zero_division= 0),
                    'XGB Precision:': precision_score(y_test, y_pred_xgb_cc_ada, zero_division= 0),
                    'Tuned XGB Precision:': precision_score(y_test, y_pred_tuned_xgb_cc_ada, zero_division= 0),
                    'LGBM Precision:': precision_score(y_test, y_pred_lgm_cc_ada, zero_division= 0),
                    'Tuned LGBM Precision:': precision_score(y_test, y_pred_tuned_lgm_cc_ada, zero_division= 0),
                    'CatBoost Precision:': precision_score(y_test, y_pred_cat_cc_ada, zero_division= 0),
                    'Tuned CatBoost Precision:': precision_score(y_test, y_pred_tuned_cat_cc_ada, zero_division= 0)
                  }

cc_ada_precision= pd.DataFrame(list(precision_scores.items()), columns= ['Model', 'Precision Score'])
cc_ada_precision= cc_ada_precision.sort_values(by= 'Precision Score', ascending=False)
print(cc_ada_precision)
# Out:
#                                     Model  Precision Score
# 3         KNeighborsClassifier Precision:         0.378900
# 6                          SVM Precision:         0.370268
# 7                Random Forest Precision:         0.368889
# 8          Tuned Random Forest Precision:         0.367792
# 14                   Tuned XGB Precision:         0.367769
# 13                         XGB Precision:         0.365543
# 5                   GaussianNB Precision:         0.362468
# 9                     AdaBoost Precision:         0.362275
# 12      Tuned GradientBoosting Precision:         0.362034
# 4   Tuned KNeighborsClassifier Precision:         0.361656
# 11            GradientBoosting Precision:         0.361202
# 18              Tuned CatBoost Precision:         0.358955
# 17                    CatBoost Precision:         0.357191
# 15                        LGBM Precision:         0.357042
# 10              Tuned AdaBoost Precision:         0.356584
# 16                  Tuned LGBM Precision:         0.355049
# 1                Decision Tree Precision:         0.354746
# 0          Logistic Regression Precision:         0.354633
# 2          Tuned Decision Tree Precision:         0.353029

# %%
accuracy_scores= {
                    'Logistic Regression Accuracy:': accuracy_score(y_test, y_pred_lr_cc_ada),
                    'Decision Tree Accuracy:': accuracy_score(y_test, y_pred_dt_cc_ada),
                    'Tuned Decision Tree Accuracy:': accuracy_score(y_test, y_pred_tuned_dt_cc_ada),
                    'KNeighborsClassifier Accuracy:': accuracy_score(y_test, y_pred_knn_cc_ada),
                    'Tuned KNeighborsClassifier Accuracy:': accuracy_score(y_test, y_pred_tuned_knn_cc_ada),
                    'GaussianNB Accuracy:': accuracy_score(y_test, y_pred_nb_cc_ada),
                    'SVM Accuracy:': accuracy_score(y_test, y_pred_svc_cc_ada),
                    'Random Forest Accuracy:': accuracy_score(y_test, y_pred_rf_cc_ada),
                    'Tuned Random Forest Accuracy:': accuracy_score(y_test, y_pred_tuned_rf_cc_ada),
                    'AdaBoost Accuracy:': accuracy_score(y_test, y_pred_ada_cc_ada),
                    'Tuned AdaBoost Accuracy:': accuracy_score(y_test, y_pred_tuned_ada_cc_ada),
                    'GradientBoosting Accuracy:': accuracy_score(y_test, y_pred_grb_cc_ada),
                    'Tuned GradientBoosting Accuracy:': accuracy_score(y_test, y_pred_tuned_grb_cc_ada),
                    'XGB Accuracy:': accuracy_score(y_test, y_pred_xgb_cc_ada),
                    'Tuned XGB Accuracy:': accuracy_score(y_test, y_pred_tuned_xgb_cc_ada),
                    'LGBM Accuracy:': accuracy_score(y_test, y_pred_lgm_cc_ada),
                    'Tuned LGBM Accuracy:': accuracy_score(y_test, y_pred_tuned_lgm_cc_ada),
                    'CatBoost Accuracy:': accuracy_score(y_test, y_pred_cat_cc_ada),
                    'Tuned CatBoost Accuracy:': accuracy_score(y_test, y_pred_tuned_cat_cc_ada)
                  }

cc_ada_accuracy= pd.DataFrame(list(accuracy_scores.items()), columns= ['Model', 'Accuracy Score'])
cc_ada_accuracy= cc_ada_accuracy.sort_values(by= 'Accuracy Score', ascending=False)
print(cc_ada_accuracy)
# Out:
#                                    Model  Accuracy Score
# 3         KNeighborsClassifier Accuracy:        0.548774
# 4   Tuned KNeighborsClassifier Accuracy:        0.496863
# 0          Logistic Regression Accuracy:        0.486024
# 6                          SVM Accuracy:        0.481460
# 1                Decision Tree Accuracy:        0.468910
# 5                   GaussianNB Accuracy:        0.458642
# 7                Random Forest Accuracy:        0.439817
# 16                  Tuned LGBM Accuracy:        0.438677
# 13                         XGB Accuracy:        0.436965
# 18              Tuned CatBoost Accuracy:        0.432402
# 9                     AdaBoost Accuracy:        0.431831
# 8          Tuned Random Forest Accuracy:        0.427268
# 14                   Tuned XGB Accuracy:        0.422704
# 2          Tuned Decision Tree Accuracy:        0.417570
# 10              Tuned AdaBoost Accuracy:        0.411865
# 15                        LGBM Accuracy:        0.410154
# 12      Tuned GradientBoosting Accuracy:        0.409584
# 11            GradientBoosting Accuracy:        0.399315
# 17                    CatBoost Accuracy:        0.398175

# %%
auc_scores= {
                    'Logistic Regression AUC:': roc_auc_score(y_test, y_pred_prob_lr_cc_ada),
                    'Decision Tree AUC:': roc_auc_score(y_test, y_pred_prob_dt_cc_ada),
                    'Tuned Decision Tree AUC:': roc_auc_score(y_test, y_pred_prob_tuned_dt_cc_ada),
                    'KNeighborsClassifier AUC:': roc_auc_score(y_test, y_pred_prob_knn_cc_ada),
                    'Tuned KNeighborsClassifier AUC:': roc_auc_score(y_test, y_pred_prob_tuned_knn_cc_ada),
                    'GaussianNB AUC:': roc_auc_score(y_test, y_pred_prob_nb_cc_ada),
                    'SVM AUC:': roc_auc_score(y_test, y_pred_prob_svc_cc_ada),
                    'Random Forest AUC:': roc_auc_score(y_test, y_pred_prob_rf_cc_ada),
                    'Tuned Random Forest AUC:': roc_auc_score(y_test, y_pred_prob_tuned_rf_cc_ada),
                    'AdaBoost AUC:': roc_auc_score(y_test, y_pred_prob_ada_cc_ada),
                    'Tuned AdaBoost AUC:': roc_auc_score(y_test, y_pred_prob_tuned_ada_cc_ada),
                    'GradientBoosting AUC:': roc_auc_score(y_test, y_pred_prob_grb_cc_ada),
                    'Tuned GradientBoosting AUC:': roc_auc_score(y_test, y_pred_prob_tuned_grb_cc_ada),
                    'XGB AUC:': roc_auc_score(y_test, y_pred_prob_xgb_cc_ada),
                    'Tuned XGB AUC:': roc_auc_score(y_test, y_pred_prob_tuned_xgb_cc_ada),
                    'LGBM AUC:': roc_auc_score(y_test, y_pred_prob_lgm_cc_ada),
                    'Tuned LGBM AUC:': roc_auc_score(y_test, y_pred_prob_tuned_lgm_cc_ada),
                    'CatBoost AUC:': roc_auc_score(y_test, y_pred_prob_cat_cc_ada),
                    'Tuned CatBoost AUC:': roc_auc_score(y_test, y_pred_prob_tuned_cat_cc_ada)
                  }

cc_ada_auc= pd.DataFrame(list(auc_scores.items()), columns= ['Model', 'AUC Score'])
cc_ada_auc= cc_ada_auc.sort_values(by= 'AUC Score', ascending=False)
print(cc_ada_auc)
# Out:
#                               Model  AUC Score
# 7                Random Forest AUC:   0.531559
# 8          Tuned Random Forest AUC:   0.530750
# 6                          SVM AUC:   0.514890
# 14                   Tuned XGB AUC:   0.505776
# 3         KNeighborsClassifier AUC:   0.505155
# 5                   GaussianNB AUC:   0.502929
# 17                    CatBoost AUC:   0.502030
# 16                  Tuned LGBM AUC:   0.501074
# 13                         XGB AUC:   0.500962
# 4   Tuned KNeighborsClassifier AUC:   0.500790
# 9                     AdaBoost AUC:   0.500454
# 12      Tuned GradientBoosting AUC:   0.499689
# 15                        LGBM AUC:   0.499420
# 0          Logistic Regression AUC:   0.498474
# 11            GradientBoosting AUC:   0.496406
# 1                Decision Tree AUC:   0.495475
# 2          Tuned Decision Tree AUC:   0.493675
# 18              Tuned CatBoost AUC:   0.492938
# 10              Tuned AdaBoost AUC:   0.491088
