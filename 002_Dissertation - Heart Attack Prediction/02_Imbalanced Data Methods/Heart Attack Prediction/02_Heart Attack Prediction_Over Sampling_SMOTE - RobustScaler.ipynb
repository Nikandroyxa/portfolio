# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df= pd.read_csv('C://Users//User//Desktop//MSc Westminster//Dissertation//DataSets//Heart_Attack_Prediction.csv')

# %%
columns=df.columns

for column in columns:
    if df[column].dtype=="int32":
        df[column]=df[column].astype("int16")
    elif df[column].dtype=="float64":
        df[column]=df[column].astype("float16")
    elif df[column].dtype=="object":
        df[column]=df[column].astype("category")

# %%
df['Sex']= df['Sex'].map({'Female': 0, 'Male': 1})
df['Sex']= pd.to_numeric(df['Sex'])

df['Diet']= df['Diet'].map({'Healthy': 0, 'Average': 1, 'Unhealthy':2})
df['Diet']= pd.to_numeric(df['Diet'])

df[['HBP', 'LBP']]= df['Blood Pressure'].str.split('/', expand= True)
df['HBP']= pd.to_numeric(df['HBP'])
df['LBP']= pd.to_numeric(df['LBP'])

df['Diabetes'] = df['Diabetes'].map({0: 1, 1: 0})

df['Exercise Hours Per Week']= round(df['Exercise Hours Per Week'], 0)

df['Sedentary Hours Per Day']= round(df['Sedentary Hours Per Day'], 0)

df['Income']= round(df['Income'], 0)

df['BMI']= round(df['BMI'], 0)

df = df.drop(columns=['Patient ID', 'Blood Pressure', 'Country', 'Continent', 'Hemisphere'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Age                              8763 non-null   int64
#  1   Sex                              8763 non-null   int64
#  2   Cholesterol                      8763 non-null   int64
#  3   Heart Rate                       8763 non-null   int64
#  4   Diabetes                         8763 non-null   int64
#  5   Family History                   8763 non-null   int64
#  6   Smoking                          8763 non-null   int64
#  7   Obesity                          8763 non-null   int64
#  8   Alcohol Consumption              8763 non-null   int64
#  9   Exercise Hours Per Week          8763 non-null   float16
#  10  Diet                             8763 non-null   int64
#  11  Previous Heart Problems          8763 non-null   int64
#  12  Medication Use                   8763 non-null   int64
#  13  Stress Level                     8763 non-null   int64
#  14  Sedentary Hours Per Day          8763 non-null   float16
#  15  Income                           8763 non-null   int64
#  16  BMI                              8763 non-null   float16
#  17  Triglycerides                    8763 non-null   int64
#  18  Physical Activity Days Per Week  8763 non-null   int64
#  19  Sleep Hours Per Day              8763 non-null   int64
#  20  Heart Attack Risk                8763 non-null   int64
#  21  HBP                              8763 non-null   int64
#  22  LBP                              8763 non-null   int64
# dtypes: float16(3), int64(20)
# memory usage: 1.4 MB

# %%
df.describe().transpose()
# Out:
#                                   count          mean           std      min  \
# Age                              8763.0  5.370798e+01     21.249509     18.0
# Sex                              8763.0  6.973639e-01      0.459425      0.0
# Cholesterol                      8763.0  2.598772e+02     80.863276    120.0
# Heart Rate                       8763.0  7.502168e+01     20.550948     40.0
# Diabetes                         8763.0  3.477120e-01      0.476271      0.0
# Family History                   8763.0  4.929819e-01      0.499979      0.0
# Smoking                          8763.0  8.968390e-01      0.304186      0.0
# Obesity                          8763.0  5.014265e-01      0.500026      0.0
# Alcohol Consumption              8763.0  5.980828e-01      0.490313      0.0
# Exercise Hours Per Week          8763.0           inf      5.796875      0.0
# Diet                             8763.0  9.921260e-01      0.817134      0.0
# Previous Heart Problems          8763.0  4.958348e-01      0.500011      0.0
# Medication Use                   8763.0  4.983453e-01      0.500026      0.0
# Stress Level                     8763.0  5.469702e+00      2.859622      1.0
# Sedentary Hours Per Day          8763.0  5.992188e+00      3.490234      0.0
# Income                           8763.0  1.582632e+05  80575.190806  20062.0
# BMI                              8763.0           inf      6.328125     18.0
# Triglycerides                    8763.0  4.176771e+02    223.748137     30.0
# Physical Activity Days Per Week  8763.0  3.489672e+00      2.282687      0.0
# Sleep Hours Per Day              8763.0  7.023508e+00      1.988473      4.0
# Heart Attack Risk                8763.0  3.582107e-01      0.479502      0.0
# HBP                              8763.0  1.350757e+02     26.349976     90.0
# LBP                              8763.0  8.515611e+01     14.676565     60.0
#
#                                      25%       50%       75%       max
# Age                                 35.0      54.0      72.0      90.0
# Sex                                  0.0       1.0       1.0       1.0
# Cholesterol                        192.0     259.0     330.0     400.0
# Heart Rate                          57.0      75.0      93.0     110.0
# Diabetes                             0.0       0.0       1.0       1.0
# Family History                       0.0       0.0       1.0       1.0
# Smoking                              1.0       1.0       1.0       1.0
# Obesity                              0.0       1.0       1.0       1.0
# Alcohol Consumption                  0.0       1.0       1.0       1.0
# Exercise Hours Per Week              5.0      10.0      15.0      20.0
# Diet                                 0.0       1.0       2.0       2.0
# Previous Heart Problems              0.0       0.0       1.0       1.0
# Medication Use                       0.0       0.0       1.0       1.0
# Stress Level                         3.0       5.0       8.0      10.0
# Sedentary Hours Per Day              3.0       6.0       9.0      12.0
# Income                           88310.0  157866.0  227749.0  299954.0
# BMI                                 23.0      29.0      34.0      40.0
# Triglycerides                      225.5     417.0     612.0     800.0
# Physical Activity Days Per Week      2.0       3.0       5.0       7.0
# Sleep Hours Per Day                  5.0       7.0       9.0      10.0
# Heart Attack Risk                    0.0       0.0       1.0       1.0
# HBP                                112.0     135.0     158.0     180.0
# LBP                                 72.0      85.0      98.0     110.0

# %%
X= df.drop(['Heart Attack Risk'], axis= 1)
y= df['Heart Attack Risk']

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE
sm= SMOTE(random_state= 15)

X_sm, y_sm= sm.fit_resample(X, y)
print(f'SMOTE: {Counter(y_sm)}')
# Out:
# SMOTE: Counter({0: 5624, 1: 5624})

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

from sklearn.preprocessing import RobustScaler
scaler= RobustScaler()
scaler.fit(X_train)

X_train= scaler.transform(X_train)
X_test= scaler.transform(X_test)

X_sm_train, y_sm_train= sm.fit_resample(X_train, y_train)

# %% [markdown]
# --- LogisticRegression ---

# %%
from sklearn.metrics import confusion_matrix, classification_report, precision_score, accuracy_score, roc_auc_score
from sklearn.linear_model import LogisticRegression
lr_sm= LogisticRegression(random_state=15)
lr_sm.fit(X_sm_train, y_sm_train)
y_pred_lr_sm= lr_sm.predict(X_test)
y_pred_prob_lr_sm= lr_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_lr_sm, labels= lr_sm.classes_)
print(classification_report(y_test, y_pred_lr_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_lr_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_lr_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_lr_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.49      0.55      1125
#            1       0.34      0.48      0.40       628
#
#     accuracy                           0.48      1753
#    macro avg       0.48      0.48      0.47      1753
# weighted avg       0.52      0.48      0.49      1753
#
# Precision: 0.3409350057012543
# Accuracy: 0.48260125499144324
# AUC: 0.4833460721868365

# %% [markdown]
# --- DecisionTreeClassifier ---

# %%
from sklearn.tree import DecisionTreeClassifier
dt_sm= DecisionTreeClassifier(random_state=15)
dt_sm.fit(X_sm_train, y_sm_train)
y_pred_dt_sm= dt_sm.predict(X_test)
y_pred_prob_dt_sm= dt_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_dt_sm, labels= dt_sm.classes_)
print(classification_report(y_test, y_pred_dt_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_dt_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_dt_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_dt_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.63      0.63      1125
#            1       0.35      0.36      0.36       628
#
#     accuracy                           0.53      1753
#    macro avg       0.50      0.49      0.49      1753
# weighted avg       0.54      0.53      0.53      1753
#
# Precision: 0.351937984496124
# Accuracy: 0.5328009127210497
# AUC: 0.4949547062986553

# %% [markdown]
# --- Tuned - DecisionTreeClassifier ---

# %%
from sklearn.model_selection import GridSearchCV
param_grid= {
             'max_depth': [None, 10, 20, 30, 40, 50],
             'min_samples_split': [2, 10, 20],
             'min_samples_leaf': [1, 5, 10],
             'max_features': [None, 'sqrt', 'log2'],
             'criterion': ['gini', 'entropy']
            }

gs_dt_sm= GridSearchCV(estimator= dt_sm, param_grid= param_grid, cv= 5, scoring= 'precision')
gs_dt_sm.fit(X_sm_train, y_sm_train)

print("Best Parameters:", gs_dt_sm.best_params_)
print("Best Precision Score:", gs_dt_sm.best_score_)
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# Best Precision Score: 0.6057394503615686

# %%
tuned_dt_sm= gs_dt_sm.best_estimator_
y_pred_tuned_dt_sm= tuned_dt_sm.predict(X_test)
y_pred_prob_tuned_dt_sm= tuned_dt_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_dt_sm, labels= tuned_dt_sm.classes_)
print(classification_report(y_test, y_pred_tuned_dt_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_dt_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_dt_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_dt_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.64      0.64      1125
#            1       0.34      0.33      0.34       628
#
#     accuracy                           0.53      1753
#    macro avg       0.49      0.49      0.49      1753
# weighted avg       0.53      0.53      0.53      1753
#
# Precision: 0.34146341463414637
# Accuracy: 0.5305191100969766
# AUC: 0.49344727530077853

# %% [markdown]
# --- KNeighborsClassifier ---

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_sm= KNeighborsClassifier()
knn_sm.fit(X_sm_train, y_sm_train)
y_pred_knn_sm= knn_sm.predict(X_test)
y_pred_prob_knn_sm= knn_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_knn_sm, labels= knn_sm.classes_)
print(classification_report(y_test, y_pred_knn_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_knn_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_knn_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_knn_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.44      0.52      1125
#            1       0.35      0.55      0.43       628
#
#     accuracy                           0.48      1753
#    macro avg       0.49      0.49      0.47      1753
# weighted avg       0.53      0.48      0.49      1753
#
# Precision: 0.3531827515400411
# Accuracy: 0.47860810039931545
# AUC: 0.49442745930644016

# %% [markdown]
# --- Tuned - KNeighborsClassifier ---

# %%
param_grid= {
             'n_neighbors': np.arange(1,40),
             'weights': ['uniform', 'distance'],
             'metric': ['euclidean', 'manhattan', 'minkowski']
            }

gs_knn_sm= GridSearchCV(estimator= knn_sm, param_grid= param_grid, cv=5, scoring= 'precision')
gs_knn_sm.fit(X_sm_train, y_sm_train)
print("Best Parameters:", gs_knn_sm.best_params_)
print("Best Precision Score:", gs_knn_sm.best_score_)
# Out:
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 2, 'weights': 'uniform'}
# Best Precision Score: 0.7317628346408013

# %%
tuned_knn_sm= gs_knn_sm.best_estimator_
y_pred_tuned_knn_sm= tuned_knn_sm.predict(X_test)
y_pred_prob_tuned_knn_sm= tuned_knn_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_knn_sm, labels= tuned_knn_sm.classes_)
print(classification_report(y_test, y_pred_tuned_knn_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_knn_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_knn_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_knn_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.76      0.70      1125
#            1       0.35      0.22      0.27       628
#
#     accuracy                           0.57      1753
#    macro avg       0.49      0.49      0.48      1753
# weighted avg       0.53      0.57      0.54      1753
#
# Precision: 0.3472906403940887
# Accuracy: 0.5710211066742726
# AUC: 0.5012257607926398

# %% [markdown]
# --- GaussianNB ---

# %%
from sklearn.naive_bayes import GaussianNB
nb_sm= GaussianNB()
nb_sm.fit(X_sm_train, y_sm_train)
y_pred_nb_sm= nb_sm.predict(X_test)
y_pred_prob_nb_sm= nb_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_nb_sm, labels= nb_sm.classes_)
print(classification_report(y_test, y_pred_nb_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_nb_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_nb_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_nb_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.55      0.59      1125
#            1       0.36      0.46      0.41       628
#
#     accuracy                           0.52      1753
#    macro avg       0.50      0.50      0.50      1753
# weighted avg       0.54      0.52      0.53      1753
#
# Precision: 0.3628428927680798
# Accuracy: 0.5162578436965203
# AUC: 0.4983057324840764

# %% [markdown]
# --- SVM ---

# %%
from sklearn.svm import SVC
svc_sm= SVC(kernel= 'rbf', gamma= 1, probability= True, random_state=15)
svc_sm.fit(X_sm_train, y_sm_train)
y_pred_svc_sm= svc_sm.predict(X_test)
y_pred_prob_svc_sm= svc_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_svc_sm, labels= svc_sm.classes_)
print(classification_report(y_test, y_pred_svc_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_svc_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_svc_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_svc_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.98      0.78      1125
#            1       0.37      0.02      0.03       628
#
#     accuracy                           0.64      1753
#    macro avg       0.51      0.50      0.40      1753
# weighted avg       0.54      0.64      0.51      1753
#
# Precision: 0.37037037037037035
# Accuracy: 0.6377638334284085
# AUC: 0.5061380042462845

# %% [markdown]
# --- Random Forest ---

# %%
from sklearn.ensemble import RandomForestClassifier
rf_sm= RandomForestClassifier(random_state=15)
rf_sm.fit(X_sm_train, y_sm_train)
y_pred_rf_sm= rf_sm.predict(X_test)
y_pred_prob_rf_sm= rf_sm.predict_proba(X_test)[:,1]

# %%
cm= confusion_matrix(y_test, y_pred_rf_sm, labels= rf_sm.classes_)
print(classification_report(y_test, y_pred_rf_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_rf_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_rf_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_rf_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.89      0.74      1125
#            1       0.32      0.09      0.15       628
#
#     accuracy                           0.60      1753
#    macro avg       0.48      0.49      0.44      1753
# weighted avg       0.52      0.60      0.53      1753
#
# Precision: 0.3224043715846995
# Accuracy: 0.6046776953793497
# AUC: 0.4964479830148619

# %%
param_grid= {
             'n_estimators': [100, 200, 300],
             'max_depth': [None, 10, 20, 30],
             'min_samples_split': [2, 5, 10],
             'min_samples_leaf': [1, 2, 4],
            }

gs_tuned_rf_sm= GridSearchCV(estimator= rf_sm, param_grid= param_grid, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_tuned_rf_sm.fit(X_sm_train, y_sm_train)
print("Best Parameters:", gs_tuned_rf_sm.best_params_)
print("Best Precision Score:", gs_tuned_rf_sm.best_score_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Best Precision Score: 0.8470306425011855

# %%
tuned_rf_sm= gs_tuned_rf_sm.best_estimator_
y_pred_tuned_rf_sm= tuned_rf_sm.predict(X_test)
y_pred_prob_tuned_rf_sm= tuned_rf_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_rf_sm, labels= tuned_rf_sm.classes_)
print(classification_report(y_test, y_pred_tuned_rf_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_rf_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_rf_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_rf_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.91      0.75      1125
#            1       0.33      0.08      0.13       628
#
#     accuracy                           0.61      1753
#    macro avg       0.49      0.50      0.44      1753
# weighted avg       0.53      0.61      0.53      1753
#
# Precision: 0.3333333333333333
# Accuracy: 0.6138049058756417
# AUC: 0.5068570417551309

# %% [markdown]
# --- AdaBoost ---

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_sm= AdaBoostClassifier(random_state=15)
ada_sm.fit(X_sm_train, y_sm_train)
y_pred_ada_sm= ada_sm.predict(X_test)
y_pred_prob_ada_sm= ada_sm.predict_proba(X_test)[:,1]

# %%
cm= confusion_matrix(y_test, y_pred_ada_sm, labels= ada_sm.classes_)
print(classification_report(y_test, y_pred_ada_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_ada_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_ada_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_ada_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.76      0.70      1125
#            1       0.37      0.25      0.30       628
#
#     accuracy                           0.58      1753
#    macro avg       0.51      0.50      0.50      1753
# weighted avg       0.55      0.58      0.55      1753
#
# Precision: 0.36682242990654207
# Accuracy: 0.5767256132344553
# AUC: 0.506932059447983

# %%
param_grid= {'n_estimators': [50, 100, 200]}

gs_ada_sm= GridSearchCV(estimator= ada_sm, param_grid= param_grid, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_ada_sm.fit(X_sm_train, y_sm_train)
print("Best Parameters:", gs_ada_sm.best_params_)
print("Best Precision Score:", gs_ada_sm.best_score_)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best Parameters: {'n_estimators': 200}
# Best Precision Score: 0.6713648797226366

# %%
tuned_ada_sm= gs_ada_sm.best_estimator_
y_pred_tuned_ada_sm= tuned_ada_sm.predict(X_test)
y_pred_prob_tuned_ada_sm= tuned_ada_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_ada_sm, labels= tuned_ada_sm.classes_)
print(classification_report(y_test, y_pred_tuned_ada_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_ada_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_ada_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_ada_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.86      0.74      1125
#            1       0.36      0.14      0.20       628
#
#     accuracy                           0.60      1753
#    macro avg       0.50      0.50      0.47      1753
# weighted avg       0.54      0.60      0.54      1753
#
# Precision: 0.35802469135802467
# Accuracy: 0.6023958927552767
# AUC: 0.5033234253361643

# %% [markdown]
# --- GradientBoosting ---

# %%
from sklearn.ensemble import GradientBoostingClassifier
grb_sm= GradientBoostingClassifier(random_state=15)
grb_sm.fit(X_sm_train, y_sm_train)
y_pred_grb_sm= grb_sm.predict(X_test)
y_pred_prob_grb_sm= grb_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_grb_sm, labels= grb_sm.classes_)
print(classification_report(y_test, y_pred_grb_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_grb_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_grb_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_grb_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.95      0.77      1125
#            1       0.41      0.06      0.11       628
#
#     accuracy                           0.63      1753
#    macro avg       0.53      0.51      0.44      1753
# weighted avg       0.56      0.63      0.53      1753
#
# Precision: 0.41237113402061853
# Accuracy: 0.6320593268682259
# AUC: 0.5017154989384289

# %%
param_grid= {'learning_rate': [0.01, 0.1, 0.2]}

gs_grb_sm= GridSearchCV(estimator= grb_sm, param_grid= param_grid, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_grb_sm.fit(X_sm_train, y_sm_train)

print("Best Parameters:", gs_grb_sm.best_params_)
print("Best Precision Score:", gs_grb_sm.best_score_)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best Parameters: {'learning_rate': 0.1}
# Best Precision Score: 0.740911275265736

# %%
tuned_grb_sm= gs_grb_sm.best_estimator_
y_pred_tuned_grb_sm= tuned_grb_sm.predict(X_test)
y_pred_prob_tuned_grb_sm= tuned_grb_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_grb_sm, labels= tuned_grb_sm.classes_)
print(classification_report(y_test, y_pred_tuned_grb_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_grb_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_grb_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_grb_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.95      0.77      1125
#            1       0.41      0.06      0.11       628
#
#     accuracy                           0.63      1753
#    macro avg       0.53      0.51      0.44      1753
# weighted avg       0.56      0.63      0.53      1753
#
# Precision: 0.41237113402061853
# Accuracy: 0.6320593268682259
# AUC: 0.5017154989384289

# %% [markdown]
# --- XGB ---

# %%
from xgboost import XGBClassifier
xgb_sm= XGBClassifier(random_state=15)
xgb_sm.fit(X_sm_train, y_sm_train)
y_pred_xgb_sm= xgb_sm.predict(X_test)
y_pred_prob_xgb_sm= xgb_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_xgb_sm, labels= xgb_sm.classes_)
print(classification_report(y_test, y_pred_xgb_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_xgb_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_xgb_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_xgb_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.76      0.69      1125
#            1       0.35      0.24      0.28       628
#
#     accuracy                           0.57      1753
#    macro avg       0.50      0.50      0.49      1753
# weighted avg       0.54      0.57      0.55      1753
#
# Precision: 0.3547619047619048
# Accuracy: 0.5721620079863092
# AUC: 0.49179476291578206

# %%
params_XGBoost= {'learning_rate': [0.01, 0.1, 1.0]}

gs_xgb_sm= GridSearchCV(estimator= xgb_sm, param_grid= params_XGBoost, cv= 5, scoring= 'precision', n_jobs= -1, verbose= 2)
gs_xgb_sm.fit(X_sm_train, y_sm_train)

print("Best Parameters:", gs_xgb_sm.best_params_)
print("Best Precision Score:", gs_xgb_sm.best_score_)

tuned_xgb_sm= gs_xgb_sm.best_estimator_
y_pred_tuned_xgb_sm= tuned_xgb_sm.predict(X_test)
y_pred_prob_tuned_xgb_sm= tuned_xgb_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_xgb_sm, labels= tuned_xgb_sm.classes_)
print(classification_report(y_test, y_pred_tuned_xgb_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_xgb_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_xgb_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_xgb_sm))
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best Parameters: {'learning_rate': 0.01}
# Best Precision Score: 0.7260289772745361
#               precision    recall  f1-score   support
#
#            0       0.64      0.91      0.75      1125
#            1       0.36      0.09      0.14       628
#
#     accuracy                           0.62      1753
#    macro avg       0.50      0.50      0.45      1753
# weighted avg       0.54      0.62      0.53      1753
#
# Precision: 0.35947712418300654
# Accuracy: 0.6172276098117513
# AUC: 0.5004968152866243

# %% [markdown]
# --- LGBM ---

# %%
from lightgbm import LGBMClassifier
lgm_sm= LGBMClassifier(random_state=15)
lgm_sm.fit(X_sm_train, y_sm_train)
y_pred_lgm_sm= lgm_sm.predict(X_test)
y_pred_prob_lgm_sm= lgm_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_lgm_sm, labels= lgm_sm.classes_)
print(classification_report(y_test, y_pred_lgm_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_lgm_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_lgm_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_lgm_sm))
# Out:
# [LightGBM] [Info] Number of positive: 4499, number of negative: 4499
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005556 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5210
# [LightGBM] [Info] Number of data points in the train set: 8998, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
#               precision    recall  f1-score   support
#
#            0       0.64      0.89      0.74      1125
#            1       0.36      0.11      0.17       628
#
#     accuracy                           0.61      1753
#    macro avg       0.50      0.50      0.46      1753
# weighted avg       0.54      0.61      0.54      1753
#
# Precision: 0.3582089552238806
# Accuracy: 0.6092413006274957
# AUC: 0.5124685067232838

# %%
params_LGB= {'learning_rate': [0.001, 0.01, 0.1, 1.0],
             'num_leaves': [31, 127],
             'reg_alpha': [0.1, 0.5],
             'min_data_in_leaf': [30, 50, 100, 300, 400]}

gs_lgm_sm= GridSearchCV(estimator= lgm_sm, param_grid= params_LGB, cv=5, scoring='precision', n_jobs=-1, verbose=2)
gs_lgm_sm.fit(X_sm_train, y_sm_train)

print("Best Parameters:", gs_lgm_sm.best_params_)
print("Best Precision Score:", gs_lgm_sm.best_score_)

tuned_lgm_sm= gs_lgm_sm.best_estimator_
y_pred_tuned_lgm_sm= tuned_lgm_sm.predict(X_test)
y_pred_prob_tuned_lgm_sm= tuned_lgm_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_lgm_sm, labels= tuned_lgm_sm.classes_)
print(classification_report(y_test, y_pred_tuned_lgm_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_lgm_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_lgm_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_lgm_sm))
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 4499, number of negative: 4499
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.017976 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5210
# [LightGBM] [Info] Number of data points in the train set: 8998, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Best Parameters: {'learning_rate': 0.01, 'min_data_in_leaf': 50, 'num_leaves': 31, 'reg_alpha': 0.5}
# Best Precision Score: 0.7765370587940112
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
#               precision    recall  f1-score   support
#
#            0       0.64      0.97      0.77      1125
#            1       0.25      0.02      0.03       628
#
#     accuracy                           0.63      1753
#    macro avg       0.44      0.49      0.40      1753
# weighted avg       0.50      0.63      0.51      1753
#
# Precision: 0.25
# Accuracy: 0.6303479749001711
# AUC: 0.49403821656050956

# %% [markdown]
# --- CatBoost ---

# %%
from catboost import CatBoostClassifier
cat_sm= CatBoostClassifier(random_state=15)
cat_sm.fit(X_sm_train, y_sm_train)
y_pred_cat_sm= cat_sm.predict(X_test)
y_pred_prob_cat_sm= cat_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_cat_sm, labels= cat_sm.classes_)
print(classification_report(y_test, y_pred_cat_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_cat_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_cat_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_cat_sm))
# Out:
# Learning rate set to 0.026324
# 0:	learn: 0.6907329	total: 150ms	remaining: 2m 30s
# 1:	learn: 0.6850326	total: 165ms	remaining: 1m 22s
# 2:	learn: 0.6816974	total: 179ms	remaining: 59.4s
# 3:	learn: 0.6733581	total: 189ms	remaining: 47.1s
# 4:	learn: 0.6691780	total: 203ms	remaining: 40.5s
# 5:	learn: 0.6676729	total: 215ms	remaining: 35.6s
# 6:	learn: 0.6647432	total: 227ms	remaining: 32.2s
# 7:	learn: 0.6614870	total: 238ms	remaining: 29.5s
# 8:	learn: 0.6575607	total: 250ms	remaining: 27.5s
# 9:	learn: 0.6558292	total: 259ms	remaining: 25.7s
# 10:	learn: 0.6539755	total: 270ms	remaining: 24.3s
# 11:	learn: 0.6512837	total: 285ms	remaining: 23.5s
# 12:	learn: 0.6495404	total: 298ms	remaining: 22.6s
# 13:	learn: 0.6455938	total: 316ms	remaining: 22.3s
# 14:	learn: 0.6430033	total: 329ms	remaining: 21.6s
# 15:	learn: 0.6408475	total: 345ms	remaining: 21.2s
# 16:	learn: 0.6391764	total: 355ms	remaining: 20.5s
# 17:	learn: 0.6350393	total: 369ms	remaining: 20.1s
# 18:	learn: 0.6343359	total: 384ms	remaining: 19.8s
# 19:	learn: 0.6331521	total: 401ms	remaining: 19.6s
# 20:	learn: 0.6310668	total: 414ms	remaining: 19.3s
# 21:	learn: 0.6265013	total: 428ms	remaining: 19s
# 22:	learn: 0.6246351	total: 444ms	remaining: 18.8s
# 23:	learn: 0.6234879	total: 459ms	remaining: 18.7s
# 24:	learn: 0.6210910	total: 472ms	remaining: 18.4s
# 25:	learn: 0.6191657	total: 482ms	remaining: 18.1s
# 26:	learn: 0.6182270	total: 494ms	remaining: 17.8s
# 27:	learn: 0.6168396	total: 505ms	remaining: 17.5s
# 28:	learn: 0.6148008	total: 516ms	remaining: 17.3s
# 29:	learn: 0.6144654	total: 532ms	remaining: 17.2s
# 30:	learn: 0.6131126	total: 543ms	remaining: 17s
# 31:	learn: 0.6100773	total: 556ms	remaining: 16.8s
# 32:	learn: 0.6064424	total: 569ms	remaining: 16.7s
# 33:	learn: 0.6044282	total: 585ms	remaining: 16.6s
# 34:	learn: 0.6037270	total: 597ms	remaining: 16.5s
# 35:	learn: 0.6022210	total: 610ms	remaining: 16.3s
# 36:	learn: 0.6006596	total: 628ms	remaining: 16.3s
# 37:	learn: 0.5998767	total: 639ms	remaining: 16.2s
# 38:	learn: 0.5987018	total: 650ms	remaining: 16s
# 39:	learn: 0.5974894	total: 661ms	remaining: 15.9s
# 40:	learn: 0.5956151	total: 680ms	remaining: 15.9s
# 41:	learn: 0.5946941	total: 691ms	remaining: 15.8s
# 42:	learn: 0.5942819	total: 706ms	remaining: 15.7s
# 43:	learn: 0.5938611	total: 720ms	remaining: 15.6s
# 44:	learn: 0.5928067	total: 733ms	remaining: 15.6s
# 45:	learn: 0.5916228	total: 748ms	remaining: 15.5s
# 46:	learn: 0.5898008	total: 760ms	remaining: 15.4s
# 47:	learn: 0.5887357	total: 773ms	remaining: 15.3s
# 48:	learn: 0.5874075	total: 788ms	remaining: 15.3s
# 49:	learn: 0.5862138	total: 802ms	remaining: 15.2s
# 50:	learn: 0.5853983	total: 814ms	remaining: 15.2s
# 51:	learn: 0.5847162	total: 826ms	remaining: 15.1s
# 52:	learn: 0.5842146	total: 837ms	remaining: 14.9s
# 53:	learn: 0.5833563	total: 847ms	remaining: 14.8s
# 54:	learn: 0.5829919	total: 860ms	remaining: 14.8s
# 55:	learn: 0.5827003	total: 873ms	remaining: 14.7s
# 56:	learn: 0.5823697	total: 889ms	remaining: 14.7s
# 57:	learn: 0.5814861	total: 906ms	remaining: 14.7s
# 58:	learn: 0.5809007	total: 920ms	remaining: 14.7s
# 59:	learn: 0.5796361	total: 930ms	remaining: 14.6s
# 60:	learn: 0.5792288	total: 942ms	remaining: 14.5s
# 61:	learn: 0.5781613	total: 953ms	remaining: 14.4s
# 62:	learn: 0.5775142	total: 964ms	remaining: 14.3s
# 63:	learn: 0.5765470	total: 983ms	remaining: 14.4s
# 64:	learn: 0.5759288	total: 1s	remaining: 14.4s
# 65:	learn: 0.5747924	total: 1.01s	remaining: 14.3s
# 66:	learn: 0.5744542	total: 1.02s	remaining: 14.3s
# 67:	learn: 0.5738212	total: 1.04s	remaining: 14.2s
# 68:	learn: 0.5734839	total: 1.05s	remaining: 14.1s
# 69:	learn: 0.5722417	total: 1.06s	remaining: 14.1s
# 70:	learn: 0.5720064	total: 1.07s	remaining: 14s
# 71:	learn: 0.5711596	total: 1.08s	remaining: 14s
# 72:	learn: 0.5708490	total: 1.1s	remaining: 13.9s
# 73:	learn: 0.5698918	total: 1.11s	remaining: 13.9s
# 74:	learn: 0.5691278	total: 1.13s	remaining: 13.9s
# 75:	learn: 0.5688388	total: 1.14s	remaining: 13.9s
# 76:	learn: 0.5684919	total: 1.16s	remaining: 13.9s
# 77:	learn: 0.5676859	total: 1.17s	remaining: 13.8s
# 78:	learn: 0.5665320	total: 1.18s	remaining: 13.7s
# 79:	learn: 0.5658149	total: 1.19s	remaining: 13.7s
# 80:	learn: 0.5651439	total: 1.2s	remaining: 13.7s
# 81:	learn: 0.5644183	total: 1.22s	remaining: 13.6s
# 82:	learn: 0.5640925	total: 1.23s	remaining: 13.6s
# 83:	learn: 0.5638713	total: 1.24s	remaining: 13.5s
# 84:	learn: 0.5633210	total: 1.25s	remaining: 13.5s
# 85:	learn: 0.5631327	total: 1.27s	remaining: 13.5s
# 86:	learn: 0.5621839	total: 1.28s	remaining: 13.4s
# 87:	learn: 0.5616634	total: 1.29s	remaining: 13.4s
# 88:	learn: 0.5613329	total: 1.3s	remaining: 13.3s
# 89:	learn: 0.5609874	total: 1.31s	remaining: 13.3s
# 90:	learn: 0.5604222	total: 1.33s	remaining: 13.3s
# 91:	learn: 0.5601109	total: 1.34s	remaining: 13.3s
# 92:	learn: 0.5598062	total: 1.36s	remaining: 13.2s
# 93:	learn: 0.5593962	total: 1.37s	remaining: 13.2s
# 94:	learn: 0.5591194	total: 1.39s	remaining: 13.2s
# 95:	learn: 0.5589195	total: 1.4s	remaining: 13.2s
# 96:	learn: 0.5585827	total: 1.41s	remaining: 13.1s
# 97:	learn: 0.5583089	total: 1.42s	remaining: 13.1s
# 98:	learn: 0.5579665	total: 1.44s	remaining: 13.1s
# 99:	learn: 0.5574254	total: 1.45s	remaining: 13s
# 100:	learn: 0.5571392	total: 1.46s	remaining: 13s
# 101:	learn: 0.5567985	total: 1.48s	remaining: 13s
# 102:	learn: 0.5564500	total: 1.49s	remaining: 13s
# 103:	learn: 0.5562031	total: 1.5s	remaining: 13s
# 104:	learn: 0.5556450	total: 1.52s	remaining: 12.9s
# 105:	learn: 0.5550037	total: 1.53s	remaining: 12.9s
# 106:	learn: 0.5546272	total: 1.54s	remaining: 12.8s
# 107:	learn: 0.5543118	total: 1.55s	remaining: 12.8s
# 108:	learn: 0.5537669	total: 1.56s	remaining: 12.8s
# 109:	learn: 0.5534437	total: 1.58s	remaining: 12.8s
# 110:	learn: 0.5532045	total: 1.59s	remaining: 12.7s
# 111:	learn: 0.5529354	total: 1.6s	remaining: 12.7s
# 112:	learn: 0.5522231	total: 1.62s	remaining: 12.7s
# 113:	learn: 0.5520247	total: 1.63s	remaining: 12.7s
# 114:	learn: 0.5514183	total: 1.64s	remaining: 12.6s
# 115:	learn: 0.5511579	total: 1.65s	remaining: 12.6s
# 116:	learn: 0.5510367	total: 1.67s	remaining: 12.6s
# 117:	learn: 0.5505738	total: 1.68s	remaining: 12.5s
# 118:	learn: 0.5500764	total: 1.69s	remaining: 12.5s
# 119:	learn: 0.5492627	total: 1.7s	remaining: 12.5s
# 120:	learn: 0.5487676	total: 1.71s	remaining: 12.5s
# 121:	learn: 0.5485445	total: 1.73s	remaining: 12.4s
# 122:	learn: 0.5482575	total: 1.74s	remaining: 12.4s
# 123:	learn: 0.5478669	total: 1.75s	remaining: 12.4s
# 124:	learn: 0.5476053	total: 1.77s	remaining: 12.4s
# 125:	learn: 0.5471159	total: 1.78s	remaining: 12.3s
# 126:	learn: 0.5467646	total: 1.79s	remaining: 12.3s
# 127:	learn: 0.5464300	total: 1.8s	remaining: 12.3s
# 128:	learn: 0.5457191	total: 1.81s	remaining: 12.3s
# 129:	learn: 0.5454638	total: 1.83s	remaining: 12.2s
# 130:	learn: 0.5452006	total: 1.84s	remaining: 12.2s
# 131:	learn: 0.5449394	total: 1.85s	remaining: 12.2s
# 132:	learn: 0.5444871	total: 1.87s	remaining: 12.2s
# 133:	learn: 0.5441765	total: 1.88s	remaining: 12.2s
# 134:	learn: 0.5439492	total: 1.9s	remaining: 12.2s
# 135:	learn: 0.5437937	total: 1.91s	remaining: 12.1s
# 136:	learn: 0.5435001	total: 1.92s	remaining: 12.1s
# 137:	learn: 0.5432136	total: 1.94s	remaining: 12.1s
# 138:	learn: 0.5427067	total: 1.95s	remaining: 12.1s
# 139:	learn: 0.5423334	total: 1.96s	remaining: 12.1s
# 140:	learn: 0.5421365	total: 1.97s	remaining: 12s
# 141:	learn: 0.5418268	total: 1.99s	remaining: 12s
# 142:	learn: 0.5414997	total: 2s	remaining: 12s
# 143:	learn: 0.5412207	total: 2.01s	remaining: 12s
# 144:	learn: 0.5410869	total: 2.02s	remaining: 11.9s
# 145:	learn: 0.5408704	total: 2.03s	remaining: 11.9s
# 146:	learn: 0.5405479	total: 2.05s	remaining: 11.9s
# 147:	learn: 0.5403679	total: 2.06s	remaining: 11.9s
# 148:	learn: 0.5399948	total: 2.07s	remaining: 11.8s
# 149:	learn: 0.5392057	total: 2.08s	remaining: 11.8s
# 150:	learn: 0.5389479	total: 2.1s	remaining: 11.8s
# 151:	learn: 0.5386283	total: 2.11s	remaining: 11.8s
# 152:	learn: 0.5384278	total: 2.13s	remaining: 11.8s
# 153:	learn: 0.5381414	total: 2.14s	remaining: 11.8s
# 154:	learn: 0.5378407	total: 2.15s	remaining: 11.7s
# 155:	learn: 0.5374114	total: 2.16s	remaining: 11.7s
# 156:	learn: 0.5368981	total: 2.17s	remaining: 11.7s
# 157:	learn: 0.5366493	total: 2.19s	remaining: 11.7s
# 158:	learn: 0.5363963	total: 2.2s	remaining: 11.6s
# 159:	learn: 0.5361384	total: 2.21s	remaining: 11.6s
# 160:	learn: 0.5358642	total: 2.23s	remaining: 11.6s
# 161:	learn: 0.5356385	total: 2.24s	remaining: 11.6s
# 162:	learn: 0.5354227	total: 2.25s	remaining: 11.6s
# 163:	learn: 0.5351830	total: 2.26s	remaining: 11.5s
# 164:	learn: 0.5350250	total: 2.28s	remaining: 11.5s
# 165:	learn: 0.5348371	total: 2.29s	remaining: 11.5s
# 166:	learn: 0.5346212	total: 2.3s	remaining: 11.5s
# 167:	learn: 0.5343269	total: 2.32s	remaining: 11.5s
# 168:	learn: 0.5340510	total: 2.33s	remaining: 11.5s
# 169:	learn: 0.5336223	total: 2.34s	remaining: 11.4s
# 170:	learn: 0.5333225	total: 2.36s	remaining: 11.4s
# 171:	learn: 0.5330119	total: 2.37s	remaining: 11.4s
# 172:	learn: 0.5328449	total: 2.38s	remaining: 11.4s
# 173:	learn: 0.5326907	total: 2.39s	remaining: 11.4s
# 174:	learn: 0.5324890	total: 2.41s	remaining: 11.3s
# 175:	learn: 0.5322672	total: 2.42s	remaining: 11.3s
# 176:	learn: 0.5320375	total: 2.43s	remaining: 11.3s
# 177:	learn: 0.5315815	total: 2.44s	remaining: 11.3s
# 178:	learn: 0.5313565	total: 2.45s	remaining: 11.3s
# 179:	learn: 0.5311681	total: 2.48s	remaining: 11.3s
# 180:	learn: 0.5309764	total: 2.49s	remaining: 11.3s
# 181:	learn: 0.5307276	total: 2.5s	remaining: 11.3s
# 182:	learn: 0.5303051	total: 2.52s	remaining: 11.2s
# 183:	learn: 0.5300210	total: 2.53s	remaining: 11.2s
# 184:	learn: 0.5298559	total: 2.54s	remaining: 11.2s
# 185:	learn: 0.5296332	total: 2.56s	remaining: 11.2s
# 186:	learn: 0.5292310	total: 2.57s	remaining: 11.2s
# 187:	learn: 0.5289657	total: 2.58s	remaining: 11.1s
# 188:	learn: 0.5287521	total: 2.6s	remaining: 11.1s
# 189:	learn: 0.5285451	total: 2.61s	remaining: 11.1s
# 190:	learn: 0.5281922	total: 2.62s	remaining: 11.1s
# 191:	learn: 0.5279786	total: 2.63s	remaining: 11.1s
# 192:	learn: 0.5277292	total: 2.65s	remaining: 11.1s
# 193:	learn: 0.5271155	total: 2.66s	remaining: 11.1s
# 194:	learn: 0.5269315	total: 2.68s	remaining: 11.1s
# 195:	learn: 0.5266644	total: 2.69s	remaining: 11s
# 196:	learn: 0.5264860	total: 2.71s	remaining: 11s
# 197:	learn: 0.5262508	total: 2.72s	remaining: 11s
# 198:	learn: 0.5261240	total: 2.73s	remaining: 11s
# 199:	learn: 0.5259385	total: 2.74s	remaining: 11s
# 200:	learn: 0.5257065	total: 2.76s	remaining: 11s
# 201:	learn: 0.5253479	total: 2.77s	remaining: 10.9s
# 202:	learn: 0.5250725	total: 2.78s	remaining: 10.9s
# 203:	learn: 0.5248711	total: 2.79s	remaining: 10.9s
# 204:	learn: 0.5246310	total: 2.81s	remaining: 10.9s
# 205:	learn: 0.5243891	total: 2.82s	remaining: 10.9s
# 206:	learn: 0.5242020	total: 2.83s	remaining: 10.9s
# 207:	learn: 0.5237528	total: 2.85s	remaining: 10.9s
# 208:	learn: 0.5235693	total: 2.87s	remaining: 10.8s
# 209:	learn: 0.5232588	total: 2.88s	remaining: 10.8s
# 210:	learn: 0.5230784	total: 2.89s	remaining: 10.8s
# 211:	learn: 0.5226922	total: 2.9s	remaining: 10.8s
# 212:	learn: 0.5224351	total: 2.92s	remaining: 10.8s
# 213:	learn: 0.5222831	total: 2.93s	remaining: 10.8s
# 214:	learn: 0.5219744	total: 2.95s	remaining: 10.8s
# 215:	learn: 0.5218187	total: 2.96s	remaining: 10.8s
# 216:	learn: 0.5216301	total: 2.98s	remaining: 10.7s
# 217:	learn: 0.5212543	total: 2.99s	remaining: 10.7s
# 218:	learn: 0.5210619	total: 3s	remaining: 10.7s
# 219:	learn: 0.5208835	total: 3.02s	remaining: 10.7s
# 220:	learn: 0.5207014	total: 3.03s	remaining: 10.7s
# 221:	learn: 0.5204255	total: 3.04s	remaining: 10.7s
# 222:	learn: 0.5201570	total: 3.05s	remaining: 10.6s
# 223:	learn: 0.5198900	total: 3.06s	remaining: 10.6s
# 224:	learn: 0.5197010	total: 3.08s	remaining: 10.6s
# 225:	learn: 0.5195034	total: 3.09s	remaining: 10.6s
# 226:	learn: 0.5192371	total: 3.1s	remaining: 10.6s
# 227:	learn: 0.5190073	total: 3.11s	remaining: 10.5s
# 228:	learn: 0.5187325	total: 3.13s	remaining: 10.5s
# 229:	learn: 0.5184546	total: 3.14s	remaining: 10.5s
# 230:	learn: 0.5181786	total: 3.15s	remaining: 10.5s
# 231:	learn: 0.5179925	total: 3.16s	remaining: 10.5s
# 232:	learn: 0.5176312	total: 3.18s	remaining: 10.5s
# 233:	learn: 0.5173767	total: 3.19s	remaining: 10.4s
# 234:	learn: 0.5171163	total: 3.2s	remaining: 10.4s
# 235:	learn: 0.5169198	total: 3.21s	remaining: 10.4s
# 236:	learn: 0.5165657	total: 3.23s	remaining: 10.4s
# 237:	learn: 0.5163726	total: 3.25s	remaining: 10.4s
# 238:	learn: 0.5162464	total: 3.26s	remaining: 10.4s
# 239:	learn: 0.5159701	total: 3.27s	remaining: 10.4s
# 240:	learn: 0.5158731	total: 3.28s	remaining: 10.3s
# 241:	learn: 0.5156577	total: 3.29s	remaining: 10.3s
# 242:	learn: 0.5154476	total: 3.31s	remaining: 10.3s
# 243:	learn: 0.5152749	total: 3.32s	remaining: 10.3s
# 244:	learn: 0.5150820	total: 3.34s	remaining: 10.3s
# 245:	learn: 0.5149373	total: 3.35s	remaining: 10.3s
# 246:	learn: 0.5147689	total: 3.37s	remaining: 10.3s
# 247:	learn: 0.5145036	total: 3.38s	remaining: 10.2s
# 248:	learn: 0.5139625	total: 3.4s	remaining: 10.3s
# 249:	learn: 0.5137524	total: 3.41s	remaining: 10.2s
# 250:	learn: 0.5135536	total: 3.42s	remaining: 10.2s
# 251:	learn: 0.5133311	total: 3.44s	remaining: 10.2s
# 252:	learn: 0.5131607	total: 3.45s	remaining: 10.2s
# 345:	learn: 0.4914615	total: 4.73s	remaining: 8.95s
# 346:	learn: 0.4912791	total: 4.74s	remaining: 8.93s
# 347:	learn: 0.4911158	total: 4.76s	remaining: 8.91s
# 348:	learn: 0.4909441	total: 4.77s	remaining: 8.9s
# 349:	learn: 0.4907123	total: 4.79s	remaining: 8.89s
# 350:	learn: 0.4903515	total: 4.8s	remaining: 8.87s
# 351:	learn: 0.4900219	total: 4.81s	remaining: 8.86s
# 352:	learn: 0.4897363	total: 4.82s	remaining: 8.84s
# 353:	learn: 0.4895352	total: 4.84s	remaining: 8.82s
# 354:	learn: 0.4892842	total: 4.85s	remaining: 8.81s
# 355:	learn: 0.4890681	total: 4.87s	remaining: 8.8s
# 356:	learn: 0.4888579	total: 4.88s	remaining: 8.79s
# 357:	learn: 0.4886525	total: 4.89s	remaining: 8.77s
# 358:	learn: 0.4883982	total: 4.91s	remaining: 8.76s
# 359:	learn: 0.4880360	total: 4.92s	remaining: 8.75s
# 360:	learn: 0.4877491	total: 4.93s	remaining: 8.74s
# 361:	learn: 0.4875751	total: 4.95s	remaining: 8.72s
# 362:	learn: 0.4873279	total: 4.97s	remaining: 8.72s
# 363:	learn: 0.4871121	total: 4.98s	remaining: 8.7s
# 364:	learn: 0.4868824	total: 5s	remaining: 8.69s
# 365:	learn: 0.4866795	total: 5.01s	remaining: 8.67s
# 366:	learn: 0.4865205	total: 5.02s	remaining: 8.66s
# 367:	learn: 0.4863285	total: 5.03s	remaining: 8.64s
# 368:	learn: 0.4860445	total: 5.05s	remaining: 8.63s
# 369:	learn: 0.4858772	total: 5.06s	remaining: 8.62s
# 370:	learn: 0.4856631	total: 5.07s	remaining: 8.6s
# 371:	learn: 0.4853132	total: 5.09s	remaining: 8.59s
# 372:	learn: 0.4851095	total: 5.1s	remaining: 8.57s
# 373:	learn: 0.4848841	total: 5.11s	remaining: 8.56s
# 374:	learn: 0.4846624	total: 5.13s	remaining: 8.54s
# 375:	learn: 0.4844528	total: 5.14s	remaining: 8.54s
# 376:	learn: 0.4842720	total: 5.16s	remaining: 8.53s
# 377:	learn: 0.4841258	total: 5.17s	remaining: 8.52s
# 378:	learn: 0.4839444	total: 5.19s	remaining: 8.5s
# 379:	learn: 0.4836899	total: 5.2s	remaining: 8.48s
# 380:	learn: 0.4835145	total: 5.21s	remaining: 8.47s
# 381:	learn: 0.4833163	total: 5.22s	remaining: 8.45s
# 382:	learn: 0.4830537	total: 5.24s	remaining: 8.43s
# 383:	learn: 0.4828713	total: 5.25s	remaining: 8.42s
# 384:	learn: 0.4825546	total: 5.26s	remaining: 8.4s
# 385:	learn: 0.4822984	total: 5.27s	remaining: 8.39s
# 386:	learn: 0.4820314	total: 5.29s	remaining: 8.37s
# 387:	learn: 0.4818337	total: 5.3s	remaining: 8.36s
# 388:	learn: 0.4817024	total: 5.31s	remaining: 8.34s
# 389:	learn: 0.4815068	total: 5.32s	remaining: 8.32s
# 390:	learn: 0.4812687	total: 5.33s	remaining: 8.31s
# 391:	learn: 0.4809932	total: 5.34s	remaining: 8.29s
# 392:	learn: 0.4805228	total: 5.36s	remaining: 8.28s
# 393:	learn: 0.4802656	total: 5.38s	remaining: 8.27s
# 394:	learn: 0.4800522	total: 5.39s	remaining: 8.26s
# 395:	learn: 0.4795283	total: 5.4s	remaining: 8.24s
# 396:	learn: 0.4792795	total: 5.42s	remaining: 8.22s
# 397:	learn: 0.4790757	total: 5.42s	remaining: 8.21s
# 398:	learn: 0.4789203	total: 5.44s	remaining: 8.2s
# 399:	learn: 0.4787993	total: 5.46s	remaining: 8.19s
# 400:	learn: 0.4786033	total: 5.47s	remaining: 8.17s
# 401:	learn: 0.4781157	total: 5.48s	remaining: 8.16s
# 402:	learn: 0.4778589	total: 5.5s	remaining: 8.14s
# 403:	learn: 0.4775722	total: 5.51s	remaining: 8.12s
# 404:	learn: 0.4773138	total: 5.52s	remaining: 8.11s
# 405:	learn: 0.4771472	total: 5.54s	remaining: 8.1s
# 406:	learn: 0.4768611	total: 5.55s	remaining: 8.09s
# 407:	learn: 0.4767008	total: 5.56s	remaining: 8.07s
# 408:	learn: 0.4764159	total: 5.58s	remaining: 8.06s
# 409:	learn: 0.4761118	total: 5.59s	remaining: 8.04s
# 410:	learn: 0.4757563	total: 5.6s	remaining: 8.02s
# 411:	learn: 0.4755012	total: 5.61s	remaining: 8.01s
# 412:	learn: 0.4753414	total: 5.63s	remaining: 8s
# 413:	learn: 0.4750998	total: 5.64s	remaining: 7.98s
# 414:	learn: 0.4748403	total: 5.65s	remaining: 7.96s
# 415:	learn: 0.4746076	total: 5.66s	remaining: 7.95s
# 416:	learn: 0.4743785	total: 5.67s	remaining: 7.93s
# 417:	learn: 0.4741821	total: 5.68s	remaining: 7.92s
# 418:	learn: 0.4739631	total: 5.7s	remaining: 7.9s
# 419:	learn: 0.4735725	total: 5.71s	remaining: 7.89s
# 420:	learn: 0.4733219	total: 5.73s	remaining: 7.88s
# 421:	learn: 0.4730753	total: 5.75s	remaining: 7.87s
# 422:	learn: 0.4728514	total: 5.76s	remaining: 7.86s
# 423:	learn: 0.4726727	total: 5.77s	remaining: 7.84s
# 424:	learn: 0.4724071	total: 5.79s	remaining: 7.83s
# 425:	learn: 0.4722466	total: 5.8s	remaining: 7.82s
# 426:	learn: 0.4720246	total: 5.81s	remaining: 7.8s
# 427:	learn: 0.4718600	total: 5.83s	remaining: 7.79s
# 428:	learn: 0.4716721	total: 5.84s	remaining: 7.77s
# 429:	learn: 0.4715158	total: 5.85s	remaining: 7.76s
# 430:	learn: 0.4710098	total: 5.87s	remaining: 7.75s
# 431:	learn: 0.4707496	total: 5.88s	remaining: 7.73s
# 432:	learn: 0.4704713	total: 5.89s	remaining: 7.72s
# 433:	learn: 0.4702138	total: 5.91s	remaining: 7.7s
# 434:	learn: 0.4699605	total: 5.92s	remaining: 7.69s
# 435:	learn: 0.4696590	total: 5.93s	remaining: 7.68s
# 436:	learn: 0.4694975	total: 5.95s	remaining: 7.66s
# 576:	learn: 0.4392417	total: 7.84s	remaining: 5.75s
# 577:	learn: 0.4390684	total: 7.86s	remaining: 5.73s
# 578:	learn: 0.4389076	total: 7.87s	remaining: 5.72s
# 579:	learn: 0.4387234	total: 7.9s	remaining: 5.72s
# 580:	learn: 0.4385269	total: 7.91s	remaining: 5.71s
# 581:	learn: 0.4383158	total: 7.93s	remaining: 5.69s
# 582:	learn: 0.4380741	total: 7.94s	remaining: 5.68s
# 583:	learn: 0.4378533	total: 7.96s	remaining: 5.67s
# 584:	learn: 0.4375875	total: 7.97s	remaining: 5.65s
# 585:	learn: 0.4374089	total: 7.99s	remaining: 5.64s
# 586:	learn: 0.4372450	total: 8s	remaining: 5.63s
# 587:	learn: 0.4370771	total: 8.01s	remaining: 5.61s
# 588:	learn: 0.4368302	total: 8.03s	remaining: 5.6s
# 589:	learn: 0.4366741	total: 8.04s	remaining: 5.59s
# 590:	learn: 0.4364765	total: 8.06s	remaining: 5.58s
# 591:	learn: 0.4362801	total: 8.08s	remaining: 5.57s
# 592:	learn: 0.4361489	total: 8.09s	remaining: 5.55s
# 593:	learn: 0.4359756	total: 8.1s	remaining: 5.54s
# 594:	learn: 0.4357742	total: 8.11s	remaining: 5.52s
# 595:	learn: 0.4355844	total: 8.13s	remaining: 5.51s
# 596:	learn: 0.4354208	total: 8.15s	remaining: 5.5s
# 597:	learn: 0.4351391	total: 8.16s	remaining: 5.49s
# 598:	learn: 0.4349456	total: 8.19s	remaining: 5.48s
# 599:	learn: 0.4347245	total: 8.21s	remaining: 5.47s
# 600:	learn: 0.4345656	total: 8.22s	remaining: 5.46s
# 601:	learn: 0.4343659	total: 8.23s	remaining: 5.44s
# 602:	learn: 0.4341755	total: 8.25s	remaining: 5.43s
# 603:	learn: 0.4339935	total: 8.26s	remaining: 5.41s
# 604:	learn: 0.4337965	total: 8.27s	remaining: 5.4s
# 605:	learn: 0.4336153	total: 8.29s	remaining: 5.39s
# 606:	learn: 0.4334896	total: 8.31s	remaining: 5.38s
# 607:	learn: 0.4332083	total: 8.32s	remaining: 5.36s
# 608:	learn: 0.4329847	total: 8.33s	remaining: 5.35s
# 609:	learn: 0.4328579	total: 8.35s	remaining: 5.34s
# 610:	learn: 0.4326861	total: 8.36s	remaining: 5.32s
# 611:	learn: 0.4324169	total: 8.39s	remaining: 5.32s
# 612:	learn: 0.4321938	total: 8.41s	remaining: 5.31s
# 613:	learn: 0.4319186	total: 8.44s	remaining: 5.3s
# 614:	learn: 0.4317733	total: 8.45s	remaining: 5.29s
# 615:	learn: 0.4315701	total: 8.46s	remaining: 5.28s
# 616:	learn: 0.4313968	total: 8.49s	remaining: 5.27s
# 617:	learn: 0.4312064	total: 8.51s	remaining: 5.26s
# 618:	learn: 0.4310410	total: 8.52s	remaining: 5.25s
# 619:	learn: 0.4308415	total: 8.54s	remaining: 5.23s
# 620:	learn: 0.4305516	total: 8.56s	remaining: 5.22s
# 621:	learn: 0.4303924	total: 8.57s	remaining: 5.21s
# 714:	learn: 0.4133676	total: 9.92s	remaining: 3.96s
# 715:	learn: 0.4131529	total: 9.94s	remaining: 3.94s
# 716:	learn: 0.4130436	total: 9.95s	remaining: 3.93s
# 717:	learn: 0.4128458	total: 9.97s	remaining: 3.92s
# 718:	learn: 0.4127267	total: 9.99s	remaining: 3.9s
# 719:	learn: 0.4124894	total: 10s	remaining: 3.89s
# 720:	learn: 0.4123212	total: 10s	remaining: 3.88s
# 721:	learn: 0.4121708	total: 10s	remaining: 3.86s
# 722:	learn: 0.4119549	total: 10s	remaining: 3.85s
# 723:	learn: 0.4117553	total: 10.1s	remaining: 3.83s
# 724:	learn: 0.4115659	total: 10.1s	remaining: 3.82s
# 725:	learn: 0.4113220	total: 10.1s	remaining: 3.8s
# 726:	learn: 0.4111572	total: 10.1s	remaining: 3.79s
# 727:	learn: 0.4109117	total: 10.1s	remaining: 3.78s
# 728:	learn: 0.4107831	total: 10.1s	remaining: 3.76s
# 729:	learn: 0.4106556	total: 10.1s	remaining: 3.75s
# 730:	learn: 0.4104499	total: 10.2s	remaining: 3.74s
# 731:	learn: 0.4102169	total: 10.2s	remaining: 3.72s
# 732:	learn: 0.4101077	total: 10.2s	remaining: 3.71s
# 733:	learn: 0.4099398	total: 10.2s	remaining: 3.69s
# 734:	learn: 0.4097411	total: 10.2s	remaining: 3.68s
# 735:	learn: 0.4095592	total: 10.2s	remaining: 3.67s
# 736:	learn: 0.4093769	total: 10.2s	remaining: 3.65s
# 737:	learn: 0.4091626	total: 10.2s	remaining: 3.64s
# 738:	learn: 0.4089478	total: 10.3s	remaining: 3.63s
# 739:	learn: 0.4087359	total: 10.3s	remaining: 3.61s
# 740:	learn: 0.4084891	total: 10.3s	remaining: 3.6s
# 741:	learn: 0.4083598	total: 10.3s	remaining: 3.59s
# 742:	learn: 0.4081840	total: 10.3s	remaining: 3.57s
# 743:	learn: 0.4080416	total: 10.3s	remaining: 3.56s
# 744:	learn: 0.4078675	total: 10.4s	remaining: 3.54s
# 745:	learn: 0.4076361	total: 10.4s	remaining: 3.53s
# 746:	learn: 0.4074295	total: 10.4s	remaining: 3.52s
# 747:	learn: 0.4072848	total: 10.4s	remaining: 3.5s
# 748:	learn: 0.4070946	total: 10.4s	remaining: 3.49s
# 749:	learn: 0.4069126	total: 10.4s	remaining: 3.47s
# 750:	learn: 0.4066824	total: 10.4s	remaining: 3.46s
# 751:	learn: 0.4064533	total: 10.4s	remaining: 3.44s
# 752:	learn: 0.4063006	total: 10.5s	remaining: 3.43s
# 753:	learn: 0.4061758	total: 10.5s	remaining: 3.42s
# 754:	learn: 0.4060294	total: 10.5s	remaining: 3.4s
# 755:	learn: 0.4058428	total: 10.5s	remaining: 3.39s
# 756:	learn: 0.4056339	total: 10.5s	remaining: 3.38s
# 757:	learn: 0.4054370	total: 10.5s	remaining: 3.36s
# 758:	learn: 0.4053019	total: 10.5s	remaining: 3.35s
# 759:	learn: 0.4051086	total: 10.6s	remaining: 3.33s
# 760:	learn: 0.4048759	total: 10.6s	remaining: 3.32s
# 761:	learn: 0.4046892	total: 10.6s	remaining: 3.31s
# 762:	learn: 0.4045282	total: 10.6s	remaining: 3.29s
# 763:	learn: 0.4043996	total: 10.6s	remaining: 3.28s
# 764:	learn: 0.4041902	total: 10.6s	remaining: 3.26s
# 765:	learn: 0.4040427	total: 10.6s	remaining: 3.25s
# 766:	learn: 0.4038693	total: 10.7s	remaining: 3.23s
# 767:	learn: 0.4036907	total: 10.7s	remaining: 3.22s
# 768:	learn: 0.4035851	total: 10.7s	remaining: 3.21s
# 769:	learn: 0.4033249	total: 10.7s	remaining: 3.19s
# 770:	learn: 0.4031884	total: 10.7s	remaining: 3.18s
# 771:	learn: 0.4030535	total: 10.7s	remaining: 3.17s
# 772:	learn: 0.4028925	total: 10.7s	remaining: 3.15s
# 773:	learn: 0.4027651	total: 10.8s	remaining: 3.14s
# 774:	learn: 0.4025755	total: 10.8s	remaining: 3.13s
# 775:	learn: 0.4024308	total: 10.8s	remaining: 3.11s
# 776:	learn: 0.4022299	total: 10.8s	remaining: 3.1s
# 777:	learn: 0.4020646	total: 10.8s	remaining: 3.08s
# 778:	learn: 0.4018954	total: 10.8s	remaining: 3.07s
# 779:	learn: 0.4017618	total: 10.8s	remaining: 3.06s
# 780:	learn: 0.4016644	total: 10.9s	remaining: 3.04s
# 781:	learn: 0.4014656	total: 10.9s	remaining: 3.03s
# 782:	learn: 0.4013247	total: 10.9s	remaining: 3.02s
# 783:	learn: 0.4011795	total: 10.9s	remaining: 3s
# 784:	learn: 0.4010022	total: 10.9s	remaining: 2.99s
# 785:	learn: 0.4008381	total: 10.9s	remaining: 2.98s
# 786:	learn: 0.4006921	total: 10.9s	remaining: 2.96s
# 787:	learn: 0.4004776	total: 11s	remaining: 2.95s
# 788:	learn: 0.4003362	total: 11s	remaining: 2.94s
# 789:	learn: 0.4002110	total: 11s	remaining: 2.92s
# 790:	learn: 0.4000135	total: 11s	remaining: 2.91s
# 791:	learn: 0.3998419	total: 11s	remaining: 2.9s
# 792:	learn: 0.3996675	total: 11s	remaining: 2.88s
# 793:	learn: 0.3995054	total: 11.1s	remaining: 2.87s
# 794:	learn: 0.3993431	total: 11.1s	remaining: 2.85s
# 795:	learn: 0.3992136	total: 11.1s	remaining: 2.84s
# 796:	learn: 0.3990588	total: 11.1s	remaining: 2.83s
# 797:	learn: 0.3988319	total: 11.1s	remaining: 2.81s
# 798:	learn: 0.3986756	total: 11.1s	remaining: 2.8s
# 799:	learn: 0.3984943	total: 11.1s	remaining: 2.79s
# 800:	learn: 0.3983728	total: 11.2s	remaining: 2.77s
# 801:	learn: 0.3982241	total: 11.2s	remaining: 2.76s
# 802:	learn: 0.3980314	total: 11.2s	remaining: 2.74s
# 803:	learn: 0.3978302	total: 11.2s	remaining: 2.73s
# 804:	learn: 0.3976372	total: 11.2s	remaining: 2.72s
# 805:	learn: 0.3974943	total: 11.2s	remaining: 2.7s
# 806:	learn: 0.3973180	total: 11.2s	remaining: 2.69s
# 807:	learn: 0.3971516	total: 11.3s	remaining: 2.67s
# 808:	learn: 0.3969941	total: 11.3s	remaining: 2.66s
# 809:	learn: 0.3968083	total: 11.3s	remaining: 2.65s
# 810:	learn: 0.3965987	total: 11.3s	remaining: 2.63s
# 811:	learn: 0.3964271	total: 11.3s	remaining: 2.62s
# 812:	learn: 0.3962611	total: 11.3s	remaining: 2.61s
# 813:	learn: 0.3961185	total: 11.3s	remaining: 2.59s
# 814:	learn: 0.3960167	total: 11.4s	remaining: 2.58s
# 815:	learn: 0.3958517	total: 11.4s	remaining: 2.56s
# 816:	learn: 0.3957388	total: 11.4s	remaining: 2.55s
# 817:	learn: 0.3955385	total: 11.4s	remaining: 2.54s
# 818:	learn: 0.3953539	total: 11.4s	remaining: 2.52s
# 819:	learn: 0.3951922	total: 11.4s	remaining: 2.51s
# 820:	learn: 0.3950440	total: 11.5s	remaining: 2.5s
# 821:	learn: 0.3949120	total: 11.5s	remaining: 2.48s
# 822:	learn: 0.3947666	total: 11.5s	remaining: 2.47s
# 823:	learn: 0.3946449	total: 11.5s	remaining: 2.46s
# 824:	learn: 0.3944893	total: 11.5s	remaining: 2.44s
# 825:	learn: 0.3943088	total: 11.5s	remaining: 2.43s
# 826:	learn: 0.3941938	total: 11.5s	remaining: 2.41s
# 827:	learn: 0.3940341	total: 11.6s	remaining: 2.4s
# 828:	learn: 0.3938771	total: 11.6s	remaining: 2.38s
# 829:	learn: 0.3937306	total: 11.6s	remaining: 2.37s
# 830:	learn: 0.3935858	total: 11.6s	remaining: 2.36s
# 831:	learn: 0.3934533	total: 11.6s	remaining: 2.34s
# 832:	learn: 0.3932747	total: 11.6s	remaining: 2.33s
# 833:	learn: 0.3931911	total: 11.6s	remaining: 2.32s
# 834:	learn: 0.3930736	total: 11.7s	remaining: 2.3s
# 835:	learn: 0.3929166	total: 11.7s	remaining: 2.29s
# 836:	learn: 0.3927523	total: 11.7s	remaining: 2.27s
# 837:	learn: 0.3926133	total: 11.7s	remaining: 2.26s
# 838:	learn: 0.3925243	total: 11.7s	remaining: 2.25s
# 839:	learn: 0.3923531	total: 11.7s	remaining: 2.23s
# 840:	learn: 0.3922095	total: 11.7s	remaining: 2.22s
# 841:	learn: 0.3920460	total: 11.7s	remaining: 2.2s
# 842:	learn: 0.3919270	total: 11.8s	remaining: 2.19s
# 843:	learn: 0.3917953	total: 11.8s	remaining: 2.18s
# 844:	learn: 0.3916022	total: 11.8s	remaining: 2.16s
# 845:	learn: 0.3914974	total: 11.8s	remaining: 2.15s
# 846:	learn: 0.3912986	total: 11.8s	remaining: 2.13s
# 847:	learn: 0.3911671	total: 11.8s	remaining: 2.12s
# 848:	learn: 0.3909722	total: 11.8s	remaining: 2.11s
# 849:	learn: 0.3908318	total: 11.9s	remaining: 2.09s
# 850:	learn: 0.3907033	total: 11.9s	remaining: 2.08s
# 851:	learn: 0.3905094	total: 11.9s	remaining: 2.06s
# 852:	learn: 0.3903575	total: 11.9s	remaining: 2.05s
# 853:	learn: 0.3901918	total: 11.9s	remaining: 2.04s
# 854:	learn: 0.3900367	total: 11.9s	remaining: 2.02s
# 855:	learn: 0.3899142	total: 11.9s	remaining: 2.01s
# 856:	learn: 0.3897713	total: 12s	remaining: 1.99s
# 857:	learn: 0.3896450	total: 12s	remaining: 1.98s
# 858:	learn: 0.3894881	total: 12s	remaining: 1.97s
# 859:	learn: 0.3893028	total: 12s	remaining: 1.95s
# 860:	learn: 0.3890882	total: 12s	remaining: 1.94s
# 861:	learn: 0.3888989	total: 12s	remaining: 1.92s
# 862:	learn: 0.3887932	total: 12s	remaining: 1.91s
# 863:	learn: 0.3886433	total: 12s	remaining: 1.9s
# 864:	learn: 0.3885568	total: 12.1s	remaining: 1.88s
# 865:	learn: 0.3884490	total: 12.1s	remaining: 1.87s
# 866:	learn: 0.3882449	total: 12.1s	remaining: 1.85s
# 867:	learn: 0.3881339	total: 12.1s	remaining: 1.84s
# 868:	learn: 0.3880185	total: 12.1s	remaining: 1.83s
# 869:	learn: 0.3879269	total: 12.1s	remaining: 1.81s
# 870:	learn: 0.3876797	total: 12.2s	remaining: 1.8s
# 871:	learn: 0.3875122	total: 12.2s	remaining: 1.79s
# 872:	learn: 0.3873387	total: 12.2s	remaining: 1.77s
# 873:	learn: 0.3871596	total: 12.2s	remaining: 1.76s
# 874:	learn: 0.3870019	total: 12.2s	remaining: 1.74s
# 875:	learn: 0.3868547	total: 12.2s	remaining: 1.73s
# 876:	learn: 0.3867131	total: 12.2s	remaining: 1.72s
# 877:	learn: 0.3865679	total: 12.3s	remaining: 1.7s
# 878:	learn: 0.3864687	total: 12.3s	remaining: 1.69s
# 879:	learn: 0.3864028	total: 12.3s	remaining: 1.67s
# 880:	learn: 0.3862495	total: 12.3s	remaining: 1.66s
# 881:	learn: 0.3860776	total: 12.3s	remaining: 1.65s
# 882:	learn: 0.3859188	total: 12.3s	remaining: 1.63s
# 883:	learn: 0.3857746	total: 12.3s	remaining: 1.62s
# 884:	learn: 0.3856009	total: 12.4s	remaining: 1.6s
# 885:	learn: 0.3853905	total: 12.4s	remaining: 1.59s
# 886:	learn: 0.3851938	total: 12.4s	remaining: 1.58s
# 887:	learn: 0.3850106	total: 12.4s	remaining: 1.56s
# 888:	learn: 0.3848413	total: 12.4s	remaining: 1.55s
# 889:	learn: 0.3846673	total: 12.4s	remaining: 1.54s
# 890:	learn: 0.3844270	total: 12.4s	remaining: 1.52s
# 891:	learn: 0.3842431	total: 12.5s	remaining: 1.51s
# 892:	learn: 0.3841485	total: 12.5s	remaining: 1.49s
# 893:	learn: 0.3839975	total: 12.5s	remaining: 1.48s
# 894:	learn: 0.3838351	total: 12.5s	remaining: 1.47s
# 895:	learn: 0.3836797	total: 12.5s	remaining: 1.45s
# 896:	learn: 0.3835558	total: 12.5s	remaining: 1.44s
# 897:	learn: 0.3834148	total: 12.6s	remaining: 1.43s
# 898:	learn: 0.3832500	total: 12.6s	remaining: 1.41s
# 899:	learn: 0.3830938	total: 12.6s	remaining: 1.4s
# 900:	learn: 0.3829015	total: 12.6s	remaining: 1.39s
# 901:	learn: 0.3827563	total: 12.6s	remaining: 1.37s
# 902:	learn: 0.3825534	total: 12.6s	remaining: 1.36s
# 903:	learn: 0.3823539	total: 12.6s	remaining: 1.34s
# 904:	learn: 0.3822411	total: 12.7s	remaining: 1.33s
# 905:	learn: 0.3821073	total: 12.7s	remaining: 1.31s
# 906:	learn: 0.3820176	total: 12.7s	remaining: 1.3s
# 907:	learn: 0.3818630	total: 12.7s	remaining: 1.29s
# 908:	learn: 0.3817354	total: 12.7s	remaining: 1.27s
# 909:	learn: 0.3815469	total: 12.7s	remaining: 1.26s
# 910:	learn: 0.3814412	total: 12.8s	remaining: 1.25s
# 911:	learn: 0.3812451	total: 12.8s	remaining: 1.23s
# 912:	learn: 0.3810477	total: 12.8s	remaining: 1.22s
# 913:	learn: 0.3809218	total: 12.8s	remaining: 1.2s
# 914:	learn: 0.3807709	total: 12.8s	remaining: 1.19s
# 915:	learn: 0.3805874	total: 12.8s	remaining: 1.18s
# 916:	learn: 0.3804540	total: 12.8s	remaining: 1.16s
# 917:	learn: 0.3802848	total: 12.9s	remaining: 1.15s
# 918:	learn: 0.3801697	total: 12.9s	remaining: 1.13s
# 919:	learn: 0.3800370	total: 12.9s	remaining: 1.12s
# 920:	learn: 0.3799166	total: 12.9s	remaining: 1.11s
# 921:	learn: 0.3797348	total: 12.9s	remaining: 1.09s
# 922:	learn: 0.3796346	total: 12.9s	remaining: 1.08s
# 923:	learn: 0.3794619	total: 12.9s	remaining: 1.06s
# 924:	learn: 0.3793369	total: 13s	remaining: 1.05s
# 925:	learn: 0.3791755	total: 13s	remaining: 1.04s
# 926:	learn: 0.3789769	total: 13s	remaining: 1.02s
# 927:	learn: 0.3787241	total: 13s	remaining: 1.01s
# 928:	learn: 0.3785145	total: 13s	remaining: 995ms
# 929:	learn: 0.3782496	total: 13s	remaining: 980ms
# 930:	learn: 0.3780874	total: 13s	remaining: 967ms
# 931:	learn: 0.3778822	total: 13.1s	remaining: 953ms
# 932:	learn: 0.3777363	total: 13.1s	remaining: 938ms
# 933:	learn: 0.3775267	total: 13.1s	remaining: 924ms
# 934:	learn: 0.3773649	total: 13.1s	remaining: 910ms
# 935:	learn: 0.3772438	total: 13.1s	remaining: 896ms
# 936:	learn: 0.3770722	total: 13.1s	remaining: 882ms
# 937:	learn: 0.3768462	total: 13.1s	remaining: 868ms
# 938:	learn: 0.3767339	total: 13.1s	remaining: 854ms
# 939:	learn: 0.3765591	total: 13.2s	remaining: 840ms
# 940:	learn: 0.3763583	total: 13.2s	remaining: 826ms
# 941:	learn: 0.3762280	total: 13.2s	remaining: 812ms
# 942:	learn: 0.3760517	total: 13.2s	remaining: 798ms
# 943:	learn: 0.3759349	total: 13.2s	remaining: 784ms
# 944:	learn: 0.3757997	total: 13.2s	remaining: 770ms
# 945:	learn: 0.3756066	total: 13.2s	remaining: 756ms
# 946:	learn: 0.3754448	total: 13.3s	remaining: 742ms
	remaining: 0us
#               precision    recall  f1-score   support
#
#            0       0.64      0.90      0.75      1125
#            1       0.36      0.10      0.16       628
#
#     accuracy                           0.61      1753
#    macro avg       0.50      0.50      0.45      1753
# weighted avg       0.54      0.61      0.54      1753
#
# Precision: 0.36046511627906974
# Accuracy: 0.61437535653166
# AUC: 0.5173913658881812

# %%
params_CatBoost= {
                  'depth': [3,5,10],
                  'learning_rate' : [0.01,0.1,1],
                  'iterations' : [5,10,50,100]
                 }

gs_cat_sm= GridSearchCV(estimator= cat_sm, param_grid= params_CatBoost, cv=5, scoring='precision', n_jobs=-1, verbose=2)
gs_cat_sm.fit(X_sm_train, y_sm_train)

print("Best Parameters:", gs_cat_sm.best_params_)
print("Best Precision Score:", gs_cat_sm.best_score_)

tuned_cat_sm= gs_cat_sm.best_estimator_
y_pred_tuned_cat_sm= tuned_cat_sm.predict(X_test)
y_pred_prob_tuned_cat_sm= tuned_cat_sm.predict_proba(X_test)[:,1]

cm= confusion_matrix(y_test, y_pred_tuned_cat_sm, labels= tuned_cat_sm.classes_)
print(classification_report(y_test, y_pred_tuned_cat_sm, zero_division=0))
print('Precision:', precision_score(y_test, y_pred_tuned_cat_sm, zero_division=0))
print('Accuracy:', accuracy_score(y_test, y_pred_tuned_cat_sm))
print('AUC:', roc_auc_score(y_test, y_pred_prob_tuned_cat_sm))
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# 0:	learn: 0.6918666	total: 61.9ms	remaining: 3.03s
# 1:	learn: 0.6903282	total: 125ms	remaining: 2.99s
# 2:	learn: 0.6882915	total: 198ms	remaining: 3.11s
# 3:	learn: 0.6857054	total: 265ms	remaining: 3.05s
# 4:	learn: 0.6837698	total: 342ms	remaining: 3.07s
# 5:	learn: 0.6814174	total: 410ms	remaining: 3s
# 6:	learn: 0.6795870	total: 484ms	remaining: 2.98s
# 7:	learn: 0.6779700	total: 549ms	remaining: 2.88s
# 8:	learn: 0.6756482	total: 616ms	remaining: 2.81s
# 9:	learn: 0.6732791	total: 683ms	remaining: 2.73s
# 10:	learn: 0.6711756	total: 754ms	remaining: 2.67s
# 11:	learn: 0.6696921	total: 827ms	remaining: 2.62s
# 12:	learn: 0.6684135	total: 893ms	remaining: 2.54s
# 13:	learn: 0.6671910	total: 961ms	remaining: 2.47s
# 14:	learn: 0.6661969	total: 1.03s	remaining: 2.41s
# 15:	learn: 0.6647681	total: 1.11s	remaining: 2.35s
# 16:	learn: 0.6636202	total: 1.18s	remaining: 2.29s
# 17:	learn: 0.6624200	total: 1.25s	remaining: 2.23s
# 18:	learn: 0.6615761	total: 1.32s	remaining: 2.16s
# 19:	learn: 0.6601583	total: 1.4s	remaining: 2.1s
# 20:	learn: 0.6591195	total: 1.47s	remaining: 2.03s
# 21:	learn: 0.6578278	total: 1.54s	remaining: 1.96s
# 22:	learn: 0.6563940	total: 1.6s	remaining: 1.88s
# 23:	learn: 0.6552587	total: 1.67s	remaining: 1.81s
# 24:	learn: 0.6538947	total: 1.74s	remaining: 1.74s
# 25:	learn: 0.6529415	total: 1.81s	remaining: 1.67s
# 26:	learn: 0.6520408	total: 1.88s	remaining: 1.6s
# 27:	learn: 0.6507740	total: 1.96s	remaining: 1.54s
# 28:	learn: 0.6492822	total: 2.03s	remaining: 1.47s
# 29:	learn: 0.6478955	total: 2.1s	remaining: 1.4s
# 30:	learn: 0.6471287	total: 2.17s	remaining: 1.33s
# 31:	learn: 0.6464166	total: 2.24s	remaining: 1.26s
# 32:	learn: 0.6454358	total: 2.31s	remaining: 1.19s
# 33:	learn: 0.6447558	total: 2.37s	remaining: 1.12s
# 34:	learn: 0.6439148	total: 2.44s	remaining: 1.04s
# 35:	learn: 0.6428596	total: 2.51s	remaining: 976ms
# 36:	learn: 0.6421387	total: 2.58s	remaining: 906ms
# 37:	learn: 0.6411333	total: 2.64s	remaining: 835ms
# 38:	learn: 0.6398354	total: 2.71s	remaining: 765ms
# 39:	learn: 0.6387745	total: 2.78s	remaining: 695ms
# 40:	learn: 0.6369418	total: 2.85s	remaining: 626ms
# 41:	learn: 0.6364393	total: 2.92s	remaining: 555ms
# 42:	learn: 0.6355176	total: 2.99s	remaining: 487ms
# 43:	learn: 0.6345472	total: 3.06s	remaining: 418ms
# 44:	learn: 0.6332577	total: 3.13s	remaining: 348ms
# 45:	learn: 0.6325357	total: 3.2s	remaining: 278ms
# 46:	learn: 0.6316182	total: 3.26s	remaining: 208ms
# 47:	learn: 0.6303022	total: 3.32s	remaining: 138ms
# 48:	learn: 0.6292546	total: 3.39s	remaining: 69.1ms
# 49:	learn: 0.6275395	total: 3.48s	remaining: 0us
# Best Parameters: {'depth': 10, 'iterations': 50, 'learning_rate': 0.01}
# Best Precision Score: 0.9341333613946473
#               precision    recall  f1-score   support
#
#            0       0.64      0.98      0.78      1125
#            1       0.39      0.02      0.04       628
#
#     accuracy                           0.64      1753
#    macro avg       0.52      0.50      0.41      1753
# weighted avg       0.55      0.64      0.51      1753
#
# Precision: 0.3888888888888889
# Accuracy: 0.6371933827723902
# AUC: 0.48701486199575367

# %% [markdown]
# --- Visualisation ---

# %%
print('Logistic Regression Precision:', precision_score(y_test, y_pred_lr_sm, zero_division= 0))
print('Decision Tree Precision:', precision_score(y_test, y_pred_dt_sm, zero_division= 0))
print('Tuned Decision Tree Precision:', precision_score(y_test, y_pred_tuned_dt_sm, zero_division= 0))
print('KNeighborsClassifier Precision:', precision_score(y_test, y_pred_knn_sm, zero_division= 0))
print('Tuned KNeighborsClassifier Precision:', precision_score(y_test, y_pred_tuned_knn_sm, zero_division= 0))
print('GaussianNB Precision:', precision_score(y_test, y_pred_nb_sm, zero_division= 0))
print('SVM Precision:', precision_score(y_test, y_pred_svc_sm, zero_division= 0))
print('Random Forest Precision:', precision_score(y_test, y_pred_rf_sm, zero_division= 0))
print('Tuned Random Forest Precision:', precision_score(y_test, y_pred_tuned_rf_sm, zero_division= 0))
print('AdaBoost Precision:', precision_score(y_test, y_pred_ada_sm, zero_division= 0))
print('Tuned AdaBoost Precision:', precision_score(y_test, y_pred_tuned_ada_sm, zero_division= 0))
print('GradientBoosting Precision:', precision_score(y_test, y_pred_grb_sm, zero_division= 0))
print('Tuned GradientBoosting Precision:', precision_score(y_test, y_pred_tuned_grb_sm, zero_division= 0))
print('XGB Precision:', precision_score(y_test, y_pred_xgb_sm, zero_division= 0))
print('Tuned XGB Precision:', precision_score(y_test, y_pred_tuned_xgb_sm, zero_division= 0))
print('LGBM Precision:', precision_score(y_test, y_pred_lgm_sm, zero_division= 0))
print('Tuned LGBM Precision:', precision_score(y_test, y_pred_tuned_lgm_sm, zero_division= 0))
print('CatBoost Precision:', precision_score(y_test, y_pred_cat_sm, zero_division= 0))
print('Tuned CatBoost Precision:', precision_score(y_test, y_pred_tuned_cat_sm, zero_division= 0))
# Out:
# Logistic Regression Precision: 0.3409350057012543
# Decision Tree Precision: 0.351937984496124
# Tuned Decision Tree Precision: 0.34146341463414637
# KNeighborsClassifier Precision: 0.3531827515400411
# Tuned KNeighborsClassifier Precision: 0.3472906403940887
# GaussianNB Precision: 0.3628428927680798
# SVM Precision: 0.37037037037037035
# Random Forest Precision: 0.3224043715846995
# Tuned Random Forest Precision: 0.3333333333333333
# AdaBoost Precision: 0.36682242990654207
# Tuned AdaBoost Precision: 0.35802469135802467
# GradientBoosting Precision: 0.41237113402061853
# Tuned GradientBoosting Precision: 0.41237113402061853
# XGB Precision: 0.3547619047619048
# Tuned XGB Precision: 0.35947712418300654
# LGBM Precision: 0.3582089552238806
# Tuned LGBM Precision: 0.25
# CatBoost Precision: 0.36046511627906974
# Tuned CatBoost Precision: 0.3888888888888889

# %%
precision_scores= {
                    'Logistic Regression Precision:': precision_score(y_test, y_pred_lr_sm, zero_division= 0),
                    'Decision Tree Precision:': precision_score(y_test, y_pred_dt_sm, zero_division= 0),
                    'Tuned Decision Tree Precision:': precision_score(y_test, y_pred_tuned_dt_sm, zero_division= 0),
                    'KNeighborsClassifier Precision:': precision_score(y_test, y_pred_knn_sm, zero_division= 0),
                    'Tuned KNeighborsClassifier Precision:': precision_score(y_test, y_pred_tuned_knn_sm, zero_division= 0),
                    'GaussianNB Precision:': precision_score(y_test, y_pred_nb_sm, zero_division= 0),
                    'SVM Precision:': precision_score(y_test, y_pred_svc_sm, zero_division= 0),
                    'Random Forest Precision:': precision_score(y_test, y_pred_rf_sm, zero_division= 0),
                    'Tuned Random Forest Precision:': precision_score(y_test, y_pred_tuned_rf_sm, zero_division= 0),
                    'AdaBoost Precision:': precision_score(y_test, y_pred_ada_sm, zero_division= 0),
                    'Tuned AdaBoost Precision:': precision_score(y_test, y_pred_tuned_ada_sm, zero_division= 0),
                    'GradientBoosting Precision:': precision_score(y_test, y_pred_grb_sm, zero_division= 0),
                    'Tuned GradientBoosting Precision:': precision_score(y_test, y_pred_tuned_grb_sm, zero_division= 0),
                    'XGB Precision:': precision_score(y_test, y_pred_xgb_sm, zero_division= 0),
                    'Tuned XGB Precision:': precision_score(y_test, y_pred_tuned_xgb_sm, zero_division= 0),
                    'LGBM Precision:': precision_score(y_test, y_pred_lgm_sm, zero_division= 0),
                    'Tuned LGBM Precision:': precision_score(y_test, y_pred_tuned_lgm_sm, zero_division= 0),
                    'CatBoost Precision:': precision_score(y_test, y_pred_cat_sm, zero_division= 0),
                    'Tuned CatBoost Precision:': precision_score(y_test, y_pred_tuned_cat_sm, zero_division= 0)
                  }

smote_precision= pd.DataFrame(list(precision_scores.items()), columns= ['Model', 'Precision Score'])
smote_precision= smote_precision.sort_values(by= 'Precision Score', ascending=False)
print(smote_precision)
# Out:
#                                     Model  Precision Score
# 12      Tuned GradientBoosting Precision:         0.412371
# 11            GradientBoosting Precision:         0.412371
# 18              Tuned CatBoost Precision:         0.388889
# 6                          SVM Precision:         0.370370
# 9                     AdaBoost Precision:         0.366822
# 5                   GaussianNB Precision:         0.362843
# 17                    CatBoost Precision:         0.360465
# 14                   Tuned XGB Precision:         0.359477
# 15                        LGBM Precision:         0.358209
# 10              Tuned AdaBoost Precision:         0.358025
# 13                         XGB Precision:         0.354762
# 3         KNeighborsClassifier Precision:         0.353183
# 1                Decision Tree Precision:         0.351938
# 4   Tuned KNeighborsClassifier Precision:         0.347291
# 2          Tuned Decision Tree Precision:         0.341463
# 0          Logistic Regression Precision:         0.340935
# 8          Tuned Random Forest Precision:         0.333333
# 7                Random Forest Precision:         0.322404
# 16                  Tuned LGBM Precision:         0.250000

# %%
accuracy_scores= {
                    'Logistic Regression Accuracy:': accuracy_score(y_test, y_pred_lr_sm),
                    'Decision Tree Accuracy:': accuracy_score(y_test, y_pred_dt_sm),
                    'Tuned Decision Tree Accuracy:': accuracy_score(y_test, y_pred_tuned_dt_sm),
                    'KNeighborsClassifier Accuracy:': accuracy_score(y_test, y_pred_knn_sm),
                    'Tuned KNeighborsClassifier Accuracy:': accuracy_score(y_test, y_pred_tuned_knn_sm),
                    'GaussianNB Accuracy:': accuracy_score(y_test, y_pred_nb_sm),
                    'SVM Accuracy:': accuracy_score(y_test, y_pred_svc_sm),
                    'Random Forest Accuracy:': accuracy_score(y_test, y_pred_rf_sm),
                    'Tuned Random Forest Accuracy:': accuracy_score(y_test, y_pred_tuned_rf_sm),
                    'AdaBoost Accuracy:': accuracy_score(y_test, y_pred_ada_sm),
                    'Tuned AdaBoost Accuracy:': accuracy_score(y_test, y_pred_tuned_ada_sm),
                    'GradientBoosting Accuracy:': accuracy_score(y_test, y_pred_grb_sm),
                    'Tuned GradientBoosting Accuracy:': accuracy_score(y_test, y_pred_tuned_grb_sm),
                    'XGB Accuracy:': accuracy_score(y_test, y_pred_xgb_sm),
                    'Tuned XGB Accuracy:': accuracy_score(y_test, y_pred_tuned_xgb_sm),
                    'LGBM Accuracy:': accuracy_score(y_test, y_pred_lgm_sm),
                    'Tuned LGBM Accuracy:': accuracy_score(y_test, y_pred_tuned_lgm_sm),
                    'CatBoost Accuracy:': accuracy_score(y_test, y_pred_cat_sm),
                    'Tuned CatBoost Accuracy:': accuracy_score(y_test, y_pred_tuned_cat_sm)
                  }

smote_accuracy= pd.DataFrame(list(accuracy_scores.items()), columns= ['Model', 'Accuracy Score'])
smote_accuracy= smote_accuracy.sort_values(by= 'Accuracy Score', ascending=False)
print(smote_accuracy)
# Out:
#                                    Model  Accuracy Score
# 6                          SVM Accuracy:        0.637764
# 18              Tuned CatBoost Accuracy:        0.637193
# 11            GradientBoosting Accuracy:        0.632059
# 12      Tuned GradientBoosting Accuracy:        0.632059
# 16                  Tuned LGBM Accuracy:        0.630348
# 14                   Tuned XGB Accuracy:        0.617228
# 17                    CatBoost Accuracy:        0.614375
# 8          Tuned Random Forest Accuracy:        0.613805
# 15                        LGBM Accuracy:        0.609241
# 7                Random Forest Accuracy:        0.604678
# 10              Tuned AdaBoost Accuracy:        0.602396
# 9                     AdaBoost Accuracy:        0.576726
# 13                         XGB Accuracy:        0.572162
# 4   Tuned KNeighborsClassifier Accuracy:        0.571021
# 1                Decision Tree Accuracy:        0.532801
# 2          Tuned Decision Tree Accuracy:        0.530519
# 5                   GaussianNB Accuracy:        0.516258
# 0          Logistic Regression Accuracy:        0.482601
# 3         KNeighborsClassifier Accuracy:        0.478608

# %%
auc_scores= {
                    'Logistic Regression AUC:': roc_auc_score(y_test, y_pred_prob_lr_sm),
                    'Decision Tree AUC:': roc_auc_score(y_test, y_pred_prob_dt_sm),
                    'Tuned Decision Tree AUC:': roc_auc_score(y_test, y_pred_prob_tuned_dt_sm),
                    'KNeighborsClassifier AUC:': roc_auc_score(y_test, y_pred_prob_knn_sm),
                    'Tuned KNeighborsClassifier AUC:': roc_auc_score(y_test, y_pred_prob_tuned_knn_sm),
                    'GaussianNB AUC:': roc_auc_score(y_test, y_pred_prob_nb_sm),
                    'SVM AUC:': roc_auc_score(y_test, y_pred_prob_svc_sm),
                    'Random Forest AUC:': roc_auc_score(y_test, y_pred_prob_rf_sm),
                    'Tuned Random Forest AUC:': roc_auc_score(y_test, y_pred_prob_tuned_rf_sm),
                    'AdaBoost AUC:': roc_auc_score(y_test, y_pred_prob_ada_sm),
                    'Tuned AdaBoost AUC:': roc_auc_score(y_test, y_pred_prob_tuned_ada_sm),
                    'GradientBoosting AUC:': roc_auc_score(y_test, y_pred_prob_grb_sm),
                    'Tuned GradientBoosting AUC:': roc_auc_score(y_test, y_pred_prob_tuned_grb_sm),
                    'XGB AUC:': roc_auc_score(y_test, y_pred_prob_xgb_sm),
                    'Tuned XGB AUC:': roc_auc_score(y_test, y_pred_prob_tuned_xgb_sm),
                    'LGBM AUC:': roc_auc_score(y_test, y_pred_prob_lgm_sm),
                    'Tuned LGBM AUC:': roc_auc_score(y_test, y_pred_prob_tuned_lgm_sm),
                    'CatBoost AUC:': roc_auc_score(y_test, y_pred_prob_cat_sm),
                    'Tuned CatBoost AUC:': roc_auc_score(y_test, y_pred_prob_tuned_cat_sm)
                  }

smote_auc= pd.DataFrame(list(auc_scores.items()), columns= ['Model', 'AUC Score'])
smote_auc= smote_auc.sort_values(by= 'AUC Score', ascending=False)
print(smote_auc)
# Out:
#                               Model  AUC Score
# 17                    CatBoost AUC:   0.517391
# 15                        LGBM AUC:   0.512469
# 9                     AdaBoost AUC:   0.506932
# 8          Tuned Random Forest AUC:   0.506857
# 6                          SVM AUC:   0.506138
# 10              Tuned AdaBoost AUC:   0.503323
# 11            GradientBoosting AUC:   0.501715
# 12      Tuned GradientBoosting AUC:   0.501715
# 4   Tuned KNeighborsClassifier AUC:   0.501226
# 14                   Tuned XGB AUC:   0.500497
# 5                   GaussianNB AUC:   0.498306
# 7                Random Forest AUC:   0.496448
# 1                Decision Tree AUC:   0.494955
# 3         KNeighborsClassifier AUC:   0.494427
# 16                  Tuned LGBM AUC:   0.494038
# 2          Tuned Decision Tree AUC:   0.493447
# 13                         XGB AUC:   0.491795
# 18              Tuned CatBoost AUC:   0.487015
# 0          Logistic Regression AUC:   0.483346
