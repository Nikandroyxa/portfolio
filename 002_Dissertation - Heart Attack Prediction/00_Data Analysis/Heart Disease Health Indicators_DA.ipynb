# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df= pd.read_csv('C://Users//User//Desktop//MSc Westminster//Dissertation//DataSets//Heart_Disease_Indicators.csv')
df.head(5)
# Out:
#    HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0                     0       1         1          1   40       1       0
# 1                     0       0         0          0   25       1       0
# 2                     0       1         1          1   28       0       0
# 3                     0       1         0          1   27       0       0
# 4                     0       1         1          1   24       0       0
#
#    Diabetes  PhysActivity  Fruits  ...  AnyHealthcare  NoDocbcCost  GenHlth  \
# 0         0             0       0  ...              1            0        5
# 1         0             1       0  ...              0            1        3
# 2         0             0       1  ...              1            1        5
# 3         0             1       1  ...              1            0        2
# 4         0             1       1  ...              1            0        2
#
#    MentHlth  PhysHlth  DiffWalk  Sex  Age  Education  Income
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253661 entries, 0 to 253660
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   HeartDiseaseorAttack  253661 non-null  int64
#  1   HighBP                253661 non-null  int64
#  2   HighChol              253661 non-null  int64
#  3   CholCheck             253661 non-null  int64
#  4   BMI                   253661 non-null  int64
#  5   Smoker                253661 non-null  int64
#  6   Stroke                253661 non-null  int64
#  7   Diabetes              253661 non-null  int64
#  8   PhysActivity          253661 non-null  int64
#  9   Fruits                253661 non-null  int64
#  10  Veggies               253661 non-null  int64
#  11  HvyAlcoholConsump     253661 non-null  int64
#  12  AnyHealthcare         253661 non-null  int64
#  13  NoDocbcCost           253661 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# HeartDiseaseorAttack    0
# HighBP                  0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# Stroke                  0
# Diabetes                0
# PhysActivity            0
# Fruits                  0
# Veggies                 0
# HvyAlcoholConsump       0
# AnyHealthcare           0
# NoDocbcCost             0
# GenHlth                 0
# MentHlth                0
# PhysHlth                0
# DiffWalk                0
# Sex                     0
# Age                     0
# Education               0
# Income                  0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                          count       mean       std   min   25%   50%   75%  \
# HeartDiseaseorAttack  253661.0   0.094173  0.292070   0.0   0.0   0.0   0.0
# HighBP                253661.0   0.428990  0.494933   0.0   0.0   0.0   1.0
# HighChol              253661.0   0.424113  0.494209   0.0   0.0   0.0   1.0
# CholCheck             253661.0   0.962667  0.189578   0.0   1.0   1.0   1.0
# BMI                   253661.0  28.382475  6.608638  12.0  24.0  27.0  31.0
# Smoker                253661.0   0.443186  0.496763   0.0   0.0   0.0   1.0
# Stroke                253661.0   0.040570  0.197292   0.0   0.0   0.0   0.0
# Diabetes              253661.0   0.296904  0.698147   0.0   0.0   0.0   0.0
# PhysActivity          253661.0   0.756577  0.429149   0.0   1.0   1.0   1.0
# Fruits                253661.0   0.634264  0.481637   0.0   0.0   1.0   1.0
# Veggies               253661.0   0.811437  0.391162   0.0   1.0   1.0   1.0
# ...

# %%
from sklearn.model_selection import train_test_split

target_size = 50000

num_class_0 = int(target_size * df['HeartDiseaseorAttack'].value_counts(normalize=True)[0])
num_class_1 = target_size - num_class_0

df_class_0 = df[df['HeartDiseaseorAttack'] == 0]
df_class_1 = df[df['HeartDiseaseorAttack'] == 1]

df_class_0_sampled = df_class_0.sample(n=num_class_0, random_state=15)
df_class_1_sampled = df_class_1.sample(n=num_class_1, random_state=15)

df_sampled = pd.concat([df_class_0_sampled, df_class_1_sampled])

df_sampled = df_sampled.sample(frac=1, random_state=15).reset_index(drop=True)
print(df_sampled['HeartDiseaseorAttack'].value_counts(normalize=True))
# Out:
# 0    0.90582
# 1    0.09418
# Name: HeartDiseaseorAttack, dtype: float64

# %%
df_sampled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   HeartDiseaseorAttack  50000 non-null  int64
#  1   HighBP                50000 non-null  int64
#  2   HighChol              50000 non-null  int64
#  3   CholCheck             50000 non-null  int64
#  4   BMI                   50000 non-null  int64
#  5   Smoker                50000 non-null  int64
#  6   Stroke                50000 non-null  int64
#  7   Diabetes              50000 non-null  int64
#  8   PhysActivity          50000 non-null  int64
#  9   Fruits                50000 non-null  int64
#  10  Veggies               50000 non-null  int64
#  11  HvyAlcoholConsump     50000 non-null  int64
#  12  AnyHealthcare         50000 non-null  int64
#  13  NoDocbcCost           50000 non-null  int64
#  14  GenHlth               50000 non-null  int64
# ...

# %%
df_sampled.isnull().sum()
# Out:
# HeartDiseaseorAttack    0
# HighBP                  0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# Stroke                  0
# Diabetes                0
# PhysActivity            0
# Fruits                  0
# Veggies                 0
# HvyAlcoholConsump       0
# AnyHealthcare           0
# NoDocbcCost             0
# GenHlth                 0
# MentHlth                0
# PhysHlth                0
# DiffWalk                0
# Sex                     0
# Age                     0
# Education               0
# Income                  0
# dtype: int64

# %%
df_sampled.describe().transpose()
# Out:
#                         count      mean       std   min   25%   50%   75%  \
# HeartDiseaseorAttack  50000.0   0.09418  0.292082   0.0   0.0   0.0   0.0
# HighBP                50000.0   0.42536  0.494402   0.0   0.0   0.0   1.0
# HighChol              50000.0   0.42344  0.494109   0.0   0.0   0.0   1.0
# CholCheck             50000.0   0.96208  0.191005   0.0   1.0   1.0   1.0
# BMI                   50000.0  28.37510  6.555238  12.0  24.0  27.0  31.0
# Smoker                50000.0   0.43992  0.496382   0.0   0.0   0.0   1.0
# Stroke                50000.0   0.03984  0.195585   0.0   0.0   0.0   0.0
# Diabetes              50000.0   0.29746  0.698790   0.0   0.0   0.0   0.0
# PhysActivity          50000.0   0.75996  0.427112   0.0   1.0   1.0   1.0
# Fruits                50000.0   0.63636  0.481052   0.0   0.0   1.0   1.0
# Veggies               50000.0   0.81066  0.391782   0.0   1.0   1.0   1.0
# HvyAlcoholConsump     50000.0   0.05604  0.230001   0.0   0.0   0.0   0.0
# ...

# %% [markdown]
# --- HeartDiseaseorAttack ---

# %%
df_sampled['HeartDiseaseorAttack'].value_counts()
# Out:
# 0    45291
# 1     4709
# Name: HeartDiseaseorAttack, dtype: int64

# %%
sns.countplot(data= df_sampled, x= 'HeartDiseaseorAttack')
plt.title('Heart Disease')
plt.show()

# %% [markdown]
# --- HighBP ---

# %%
df_sampled['HighBP'].value_counts()
# Out:
# 0    28732
# 1    21268
# Name: HighBP, dtype: int64

# %%
sns.countplot(data= df_sampled, x= 'HighBP')
plt.title('High Blood Ppressure')
plt.show()

# %%
labels= ['No', 'Yes']

sns.countplot(data= df_sampled, x= 'HighBP', hue= 'HeartDiseaseorAttack')
plt.xticks(ticks=[0,1], labels= labels)
plt.title('Heart Disease or Attack Counts by HighBP')
plt.xlabel('High Blood Ppressure')
plt.show()

# %% [markdown]
# --- HighChol ---

# %%
df_sampled['HighChol'].value_counts()
# Out:
# 0    28828
# 1    21172
# Name: HighChol, dtype: int64

# %%
sns.countplot(data= df_sampled, x= 'HighChol')
plt.title('High Cholesterol')
plt.show()

# %%
labels= ['No', 'Yes']

sns.countplot(data= df_sampled, x= 'HighChol', hue= 'HeartDiseaseorAttack')
plt.xticks(ticks=[0,1], labels= labels)
plt.title('Heart Disease or Attack Counts by HighChol')
plt.xlabel('High Cholesterol')
plt.show()

# %% [markdown]
# --- BMI ---

# %%
df_sampled['BMI'].describe()
# Out:
# count    50000.000000
# mean        28.375100
# std          6.555238
# min         12.000000
# 25%         24.000000
# 50%         27.000000
# 75%         31.000000
# max         98.000000
# Name: BMI, dtype: float64

# %%
plt.figure(figsize= (15, 5))
plt.hist(df_sampled['BMI'], bins= 200)
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.title('BMI Distribution')
plt.show()

# %%
plt.figure(figsize= (10, 5))
sns.boxplot(x= 'HeartDiseaseorAttack', y= 'BMI', data= df_sampled)
plt.title('Boxplot of BMI by Heart Disease or Attack')
plt.xlabel('Heart Disease or Attack')
plt.ylabel('BMI')
plt.show()

# %% [markdown]
# --- Smoker ---

# %%
df_sampled['Smoker'].value_counts()
# Out:
# 0    28004
# 1    21996
# Name: Smoker, dtype: int64

# %%
sns.countplot(data= df_sampled, x= 'Smoker')
plt.title('Smoker')
plt.show()

# %%
labels= ['No', 'Yes']

sns.countplot(data= df_sampled, x= 'Smoker', hue= 'HeartDiseaseorAttack')
plt.xticks(ticks=[0,1], labels= labels)
plt.title('Heart Disease or Attack Counts by Smoker')
plt.xlabel('Smoker')
plt.show()

# %% [markdown]
# --- Stroke ---

# %%
df_sampled['Stroke'].value_counts()
# Out:
# 0    48008
# 1     1992
# Name: Stroke, dtype: int64

# %%
sns.countplot(data= df_sampled, x= 'Stroke')
plt.title('Stroke')
plt.show()

# %%
labels= ['No', 'Yes']

sns.countplot(data= df_sampled, x= 'Stroke', hue= 'HeartDiseaseorAttack')
plt.xticks(ticks= [0, 1], labels= labels)
plt.title('Heart Disease or Attack Counts by Stroke')
plt.show()

# %%
stroke_no_heart_disease = df_sampled[(df_sampled['Stroke'] == 1) & (df_sampled['HeartDiseaseorAttack'] == 0)]
stroke_and_heart_disease = df_sampled[(df_sampled['Stroke'] == 1) & (df_sampled['HeartDiseaseorAttack'] == 1)]

count_stroke_no_heart_disease = stroke_no_heart_disease.shape[0]
count_stroke_and_heart_disease = stroke_and_heart_disease.shape[0]

print(f"Stroke without heart disease or attack: {count_stroke_no_heart_disease}")
print(f"Stroke with heart disease or attack: {count_stroke_and_heart_disease}")
# Out:
# Stroke without heart disease or attack: 1214
# Stroke with heart disease or attack: 778

# %% [markdown]
# --- Diabetes ---

# %%
df_sampled['Diabetes'].value_counts()
# Out:
# 0    42110
# 2     6983
# 1      907
# Name: Diabetes, dtype: int64

# %%
sns.countplot(data= df_sampled, x= 'Diabetes')
plt.title('Diabetes')
# Out:
# Text(0.5, 1.0, 'Diabetes')

# %%
labels= ['No', '1', 'Yes']

sns.countplot(data= df_sampled, x= 'Diabetes', hue= 'HeartDiseaseorAttack')
plt.xticks(ticks= [0, 1, 2], labels= labels)
plt.title('Heart Disease or Attack Counts by Diabetes')
plt.show()

# %% [markdown]
# --- PhysActivity ---

# %%
df['PhysActivity'].value_counts()
# Out:
# 1    191914
# 0     61747
# Name: PhysActivity, dtype: int64

# %%
sns.countplot(data= df_sampled, x= 'PhysActivity')
plt.title('PhysActivity')
plt.show()

# %%
sns.countplot(data= df_sampled, x= 'PhysActivity', hue= 'HeartDiseaseorAttack')
plt.xlabel('PhysActivity')
plt.title('Heart Disease or Attack Counts by Diabetes')
plt.show()

# %% [markdown]
# --- Fruits ---

# %%
df['Fruits'].value_counts()
# Out:
# 1    160888
# 0     92773
# Name: Fruits, dtype: int64

# %%
sns.countplot(data= df_sampled, x= 'Fruits')
plt.title('Fruits')
# Out:
# Text(0.5, 1.0, 'Fruits')

# %%
sns.countplot(data= df_sampled, x= 'Fruits', hue= 'HeartDiseaseorAttack')
plt.xlabel('Fruits')
plt.title('Heart Disease or Attack Counts by Fruits')
plt.show()

# %% [markdown]
# --- Veggies ---

# %%
df_sampled['Veggies'].value_counts()
# Out:
# 1    40533
# 0     9467
# Name: Veggies, dtype: int64

# %%
sns.countplot(data= df_sampled, x= 'Veggies', hue= 'HeartDiseaseorAttack')
plt.xlabel('Veggies')
plt.title('Heart Disease or Attack Counts by Veggies')
plt.show()

# %% [markdown]
# --- HvyAlcoholConsump ---

# %%
df_sampled['HvyAlcoholConsump'].value_counts()
# Out:
# 0    47198
# 1     2802
# Name: HvyAlcoholConsump, dtype: int64

# %%
sns.countplot(data= df_sampled, x= 'HvyAlcoholConsump', hue= 'HeartDiseaseorAttack')
plt.xlabel('HvyAlcoholConsump')
plt.title('Heart Disease or Attack Counts by HvyAlcoholConsump')
plt.show()

# %% [markdown]
# --- GenHlth ---

# %%
df_sampled['GenHlth'].value_counts()
# Out:
# 2    17511
# 3    14963
# 1     8932
# 4     6234
# 5     2360
# Name: GenHlth, dtype: int64

# %%
sns.countplot(data= df_sampled, x= 'GenHlth')
plt.title('GenHlth')
plt.show()

# %%
sns.countplot(data= df_sampled, x= 'GenHlth', hue= 'HeartDiseaseorAttack')
plt.xlabel('GenHlth')
plt.title('Heart Disease or Attack Counts by GenHlth')
plt.show()

# %% [markdown]
# --- MentHlth ---

# %%
df_sampled['MentHlth'].value_counts()
# Out:
# 0     34598
# 2      2533
# 30     2385
# 5      1783
# 1      1680
# 3      1495
# 10     1302
# 15     1036
# 4       751
# 20      641
# 7       630
# 14      268
# 25      215
# 6       179
# 8       115
# 12       86
# 28       81
# 21       39
# 29       33
# 16       23
# 27       22
# 18       22
# 9        17
# 13       12
# 22       11
# 26       10
# 17        9
# 23        7
# 11        7
# 24        6
# 19        4
# Name: MentHlth, dtype: int64

# %%
sns.countplot(data= df_sampled, x= 'MentHlth')
# Out:
# <AxesSubplot:xlabel='MentHlth', ylabel='count'>

# %%
sns.countplot(data= df_sampled, x= 'MentHlth', hue= 'HeartDiseaseorAttack')
plt.xlabel('MentHlth')
plt.title('Heart Disease or Attack Counts by MentHlth')
plt.show()

# %% [markdown]
# --- DiffWalk ---

# %%
df_sampled['DiffWalk'].value_counts()
# Out:
# 0    41501
# 1     8499
# Name: DiffWalk, dtype: int64

# %%
sns.countplot(data= df_sampled, x= 'DiffWalk')
plt.title('DiffWalk')
plt.show()

# %%
labels= ['No', 'Yes']
sns.countplot(data= df_sampled, x= 'DiffWalk',  hue= 'HeartDiseaseorAttack')
plt.xticks(ticks= [0,1], labels= labels)
plt.title('Heart Disease or Attack Counts by DiffWalk')
plt.show()

# %% [markdown]
# --- Sex ---

# %%
df_sampled['Sex'].value_counts()
# Out:
# 0    28124
# 1    21876
# Name: Sex, dtype: int64

# %%
plt.figure(figsize= (10, 5))
sns.countplot(x= 'Sex', data= df_sampled)
plt.title('Distribution of Sex')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %%
labels= ['Female', 'Male']

sns.countplot(data= df_sampled, x= 'Sex', hue= 'HeartDiseaseorAttack')
plt.xticks(ticks=[0,1], labels= labels)
plt.title('Heart Disease or Attack Counts by Sex')
plt.xlabel('Sex')
plt.show()

# %% [markdown]
# --- Age ---

# %%
df_sampled['Age'].describe()
# Out:
# count    50000.00000
# mean         8.01922
# std          3.06941
# min          1.00000
# 25%          6.00000
# 50%          8.00000
# 75%         10.00000
# max         13.00000
# Name: Age, dtype: float64

# %%
plt.figure(figsize= (15, 5))
plt.hist(df_sampled['Age'], bins= 25)
plt.title('Age Distribution')
plt.ylabel('Frequency')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.figure(figsize= (10, 5))
sns.boxplot(x= 'HeartDiseaseorAttack', y= 'Age', data= df_sampled)
plt.title('Boxplot of Age by Heart Disease or Attack')
plt.xlabel('Heart Disease or Attack')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize= (10, 5))
sns.violinplot(x= 'HeartDiseaseorAttack', y= 'Age', data= df_sampled)
plt.title('Age Distribution by HeartDiseaseorAttack')
plt.xlabel('Heart Disease or Attack')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# --- Correlation Matrix ---

# %%
    cor_matr= df_sampled.corr()

    plt.figure(figsize= (20, 12))
    sns.heatmap(cor_matr, annot= True, cmap= 'coolwarm')
    plt.title('Correlation Matrix')
    plt.show()

# %%
cor_matr
# Out:
#                       HeartDiseaseorAttack    HighBP  HighChol  CholCheck  \
# HeartDiseaseorAttack              1.000000  0.209549  0.178637   0.046808
# HighBP                            0.209549  1.000000  0.301230   0.099010
# HighChol                          0.178637  0.301230  1.000000   0.081132
# CholCheck                         0.046808  0.099010  0.081132   1.000000
# BMI                               0.047557  0.208157  0.108470   0.031855
# Smoker                            0.117728  0.103891  0.086113  -0.011584
# Stroke                            0.206700  0.131895  0.093029   0.021702
# Diabetes                          0.178076  0.268708  0.214972   0.067429
# PhysActivity                     -0.092450 -0.139688 -0.087367   0.002668
# Fruits                           -0.020301 -0.043654 -0.036267   0.020796
# Veggies                          -0.038171 -0.057422 -0.038568   0.004279
# HvyAlcoholConsump                -0.027358 -0.007186 -0.017859  -0.027201
# ...

# %% [markdown]
# --- Visualization ---

# %%
fig, ax= plt.subplots(1, 3, figsize=(15, 4))

sns.countplot(data= df_sampled, x= 'HeartDiseaseorAttack', ax= ax[0])
ax[0].set_title('Heart Disease')

sns.countplot(data= df_sampled, x= 'Sex', hue= 'HeartDiseaseorAttack', ax= ax[1])
ax[1].set_title('Heart Disease or Attack Counts by Sex')
ax[1].set_xlabel('Sex')
ax[1].set_xticks(ticks=[0,1])
ax[1].set_xticklabels(['Female', 'Male'])

sns.countplot(data= df_sampled, x= 'GenHlth', hue= 'HeartDiseaseorAttack', ax= ax[2])
ax[2].set_xlabel('GenHlth')
ax[2].set_title('Heart Disease or Attack Counts by GenHlth')

plt.tight_layout()
plt.show()

# %%
fig, ax= plt.subplots(1, 2, figsize=(15, 4))

sns.violinplot(x= 'HeartDiseaseorAttack', y= 'Age', data= df_sampled, ax= ax[0])
ax[0].set_title('Age Distribution by HeartDiseaseorAttack')
ax[0].set_xlabel('Heart Disease or Attack')
ax[0].set_ylabel('Age')

sns.countplot(data= df_sampled, x= 'Fruits', hue= 'HeartDiseaseorAttack', ax= ax[1])
ax[1].set_xlabel('Fruits')
ax[1].set_title('Heart Disease or Attack Counts by Fruits')

plt.tight_layout()
plt.show()

# %%
fig, ax= plt.subplots(1, 2, figsize=(15, 4))

sns.countplot(data= df_sampled, x= 'HighBP', hue= 'HeartDiseaseorAttack', ax= ax[0])
ax[0].set_xticks(ticks=[0,1])
ax[0].set_xticklabels(['No', 'Yes'])
ax[0].set_title('Heart Disease or Attack Counts by HighBP')
ax[0].set_xlabel('High Blood Ppressure')

sns.countplot(data= df_sampled, x= 'HighChol', hue= 'HeartDiseaseorAttack', ax= ax[1])
ax[1].set_xticks(ticks=[0,1])
ax[1].set_xticklabels(['No', 'Yes'])
ax[1].set_title('Heart Disease or Attack Counts by HighChol')
ax[1].set_xlabel('High Cholesterol')

plt.tight_layout()
plt.show()

# %%
fig, ax= plt.subplots(1, 3, figsize=(15, 4))

sns.countplot(data= df_sampled, x= 'Smoker', hue= 'HeartDiseaseorAttack', ax= ax[0])
ax[0].set_xticks(ticks=[0,1])
ax[0].set_xticklabels(['No', 'Yes'])
ax[0].set_title('Heart Disease or Attack Counts by Smoker')
ax[0].set_xlabel('Smoker')

sns.countplot(data= df_sampled, x= 'Stroke', hue= 'HeartDiseaseorAttack', ax= ax[1])
ax[1].set_xticks(ticks= [0, 1], labels= labels)
ax[1].set_xticklabels(['No', 'Yes'])
ax[1].set_title('Heart Disease or Attack Counts by Stroke')
ax[1].set_xlabel('Stroke')

sns.countplot(data= df_sampled, x= 'Diabetes', hue= 'HeartDiseaseorAttack', ax= ax[2])
ax[2].set_xticks(ticks= [0, 1, 2])
ax[2].set_xticklabels(['No', '0', 'Yes'])
ax[2].set_title('Heart Disease or Attack Counts by Diabetes')
ax[2].set_xlabel('Diabetes')

plt.tight_layout()
plt.show()
